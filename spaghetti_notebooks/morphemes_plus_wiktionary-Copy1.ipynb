# %%
import pandas as pd
import pickle

morphemes = pd.read_pickle("morphemes_protoslavic.pkl")

# %%
morphemes.to_pickle("morphemes_protoslavic_v2.pkl")

# %%
import re

# %%
def set_base_verb(g, base_verb):
    morphemes.loc[
        g.index,
        "base_verb"
    ] = base_verb

# %%
AO = 'ꜵ'
YI = "⒥"
NASAL = "⒩"
BACKTICK = "’"

# %%
def split_carefully(x, true_stem):
    if " " in x:
        x = x.split(" ")[0]
    if any(weird in true_stem for weird in "[]()?"):
        splitted = re.split(true_stem, x)
        found_stem = x[len(splitted[0]): -len(splitted[1])]
        assert len(splitted) == 2
        return splitted[0], found_stem, splitted[1]
    x = x.replace('å', 'a')
    true_stem = true_stem.replace('å', 'a')

    if AO in true_stem:
        if true_stem.replace(AO, "a") in x:
            return list(x.partition(true_stem.replace(AO, "a")))
    return x.partition(true_stem.replace(AO, "o"))

def insert_YI(word, signature):

    if " " in word:
        word = word.split(" ")[0]

    if word[-3:] == "ęti":
        word = word[:-3] + "in" + NASAL + "ti"
    if "trim" not in word and "klimat" not in word:
        word = word.replace("idti", "jdti").replace("imati", "jmati")
    if signature == {'s', 't'}:
        if word[-3:] == "sti":
            # rasti -> rastti
            word = word[:-3] + "stti"
        
    base, end = word[:-5], word[-5:]
    
    # jehati
    if signature == {'đ', 'h'}:
        end = end.replace("žđati", "h" + YI + "ati")
    
    if signature == {'ć', 's'}:
        end = end.replace("šćati", "st" + YI + "ati")
    if signature == {'ć', 't'}:
        end = end.replace("šćati", "st" + YI + "ati")
        end = end.replace("ćati", "t" + YI + "ati")
    if signature == {'ć', 'č'}:
        end = end.replace("čiti", "ćiti")
        end = end.replace("čati", "ćati")

    if signature == {'đ', 'd'}:
        end = end.replace("žđati", "zd" + YI + "ati")
        end = end.replace("đati", "d" + YI + "ati")

    # puskati?
    if signature == {'ć', 'k'}:
        end = end.replace("šćati", "sk" + YI + "ati")
    if signature == {"c", "č"}:
        end = end.replace("čati", "c" + YI + "ati")
        end = end.replace("čiti", "c" + YI + "iti")

    if signature == {'k', 'č'}:
        base, end = word[:-6], word[-6:]
        end = end.replace("ščiti", "sk" + YI + "iti")
        end = end.replace("čiti", "k" + YI + "iti").replace("čivati", "k" + YI + "ivati")


    # pisati
    if signature == {'š', 's'}:  
        end = end.replace("šati", "s" + YI + "ati")
        end = end.replace("šiti", "s" + YI + "iti")
        
    if signature == {'š', 'h'}:
        end = end.replace("šiti", "h" + YI + "iti")
        end = end.replace("šati", "h" + YI + "ati")
    if signature == {'š'}:
        base, end = word[:-6], word[-6:]
        end = end.replace("šiti", "h" + YI + "iti")
        end = end.replace("šati", "h" + YI + "ati")
        end = end.replace("šivati", "h" + YI + "ivati")
        

    if signature == {'č', 'k'}:
        end = end.replace("čati", "k" + YI + "ati")
        
    if signature == {'ž', 'z'}:
        end = end.replace("žati", "z" + YI + "ati")
    if signature == {'ž', 'g'}:
        base, end = word[:-6], word[-6:]

        end = end.replace("žati", "g" + YI + "ati")
        end = end.replace("žiti", "g" + YI + "iti")
        end = end.replace("živati", "g" + YI + "ivati")

    return base + end

def manual_insert(base_verb, true_stem, last_cons=set(), dry_run=True, from_base_verb=True):
    if from_base_verb:
        g = morphemes.query("base_verb == @base_verb")
    else:
        g = morphemes.query("isv == @base_verb")
    manual_insert_g(g, true_stem, last_cons, dry_run)

def manual_insert_g(g, true_stem, last_cons=set(), dry_run=True):

    for i, row in g.isv.apply(lambda x: split_carefully(insert_YI(x, last_cons), true_stem)).items():
        if any(weird in true_stem for weird in "[]()?"):
            found_stem = row[1]
        else: 
            found_stem = true_stem

        if not dry_run:
            morphemes.loc[i, ['_prefix', '_stem', '_suffix']] = row[0], found_stem, row[2]
        raw_isv = g.loc[i, 'isv']
        #if also_insert_noun:
        #    morphemes.loc[[i], 'base_noun'] = true_stem
        #    print(raw_isv, " <- ", true_stem)

        print(raw_isv, "=", row[0], found_stem, row[2])

# %%
A = 65535 * (1-0.99)
trunc_B = 65535 
B = 76035

B/(A+B) - trunc_B/(A+trunc_B)
# Out:
# 0.00135558640741118

# %%
import json

with open("wiktionary_extended_new.json", "r", encoding="utf8") as f:
    words_data = json.load(f)

# %%
morphemes.prefix.unique()
# Out:
# array(['?', '’', 'de’', 'dez’', 'na’', 'obez’', 'råz’', 'sȯ’', 'vȯ’',
#        'vȯz’', 'v’', 'vy’', 'za’'], dtype=object)

# %%
possible_prefixes = {
    "ne", "bez", "naj",
    "do", "iz", "na", "nad", "ne", "o", "ob", "obez", "od", "po", "pod", 
    "prě", "prěd", "pri", "pro", 
    "råz",
    "de", 
    "s", "sȯ",
    "sų", "u", "v", 
    "vȯz", "vȯ",
    "vy", "za"
}

# %%
¬ne¬prě√měn^n|y

# %%
svc = morphemes._suffix.value_counts()
pvc = morphemes._prefix.value_counts()


sWTF = svc[svc < 6].index
pWTF = pvc[pvc < 6].index


morphemes.query("_prefix in @pWTF or _suffix in @sWTF or _suffix == ''")
# Out:
#             id             isv addition    partOfSpeech  \
# 130    24156.0  aklimatizovati      NaN    v.intr. ipf.
# 144    24165.0    akompanovati      NaN      v.tr. ipf.
# 338       37.0       anulovati      NaN  v.tr. ipf./pf.
# 417     6246.0     asimilovati      NaN      v.tr. ipf.
# 784    36698.0     bezpokojiti      NaN    v.refl. ipf.
# ...        ...             ...      ...             ...
# 17352   5474.0    zapakovyvati      NaN      v.tr. ipf.
# 17397  21659.0       zapoznati      NaN       v.tr. pf.
# 17407  21238.0    zapropastiti      NaN     v.refl. pf.
# 17539  23977.0       zauvažati      NaN      v.tr. ipf.
# 17540  23978.0       zauvažiti      NaN       v.tr. pf.
#
#                                    en genesis   pos prefix verb_stem  \
# 130                       acclimatize       I  verb      ?         ?
# 144                         accompany       I  verb      ?         ?
# 338                   cancel, nullify       I  verb      ?         ?
# 417                        assimilate       I  verb      ?         ?
# 784    worry, be anxious, feel uneasy     NaN  verb      ?         ?
# ...                               ...     ...   ...    ...       ...
# 17352                            pack       I  verb      ?         ?
# 17397                        acquaint     NaN  verb      ?         ?
# 17407            disappear completely     NaN  verb      ?         ?
# 17539                          notice     NaN  verb      ?         ?
# 17540                          notice     NaN  verb      ?         ?
#
#             base_verb         isv_orig left_stem_cand right_stem_cand  \
# 130    aklimatizovati   aklimatizovati      aklimatiz  aklimatizovati
# 144      akompanovati     akompanovati        akompan    akompanovati
# 338         anulovati        anulovati           anul       anulovati
# 417       asimilovati      asimilovati         asimil     asimilovati
# 784         †pokojiti   bezpokojiti sę        bezpoko        ?kojiti?
# ...               ...              ...            ...             ...
# 17352        pakovati     zapakovyvati          zapak    ?pakovyvati?
# 17397           znati        zapoznati         zapozn           znati
# 17407           pasti  zapropastiti sę      zapropast       ?pastiti?
# 17539          važiti        zauvažati         zauvaž         uvažati
# 17540          važiti        zauvažiti         zauvaž          važiti
#
#          derived_nouns base_noun  _prefix   _stem  _suffix  _is_irregular  \
# 130    |aklimatizacija    klimat        a  klimat  izovati              0
# 144                                     a  kompan    ovati              0
# 338         |anulacija                  a     nul    ovati              0
# 417       |asimilacija                  a   simil    ovati              0
# 784                        pokoj     ¬bez   pokoj      iti              0
# ...                ...       ...      ...     ...      ...            ...
# 17352                                 ¬za     pak  ovyvati              0
# 17397                              ¬za¬po      zn      ati              0
# 17407                             ¬za¬pro     pas     titi              0
# 17539                               ¬za¬u     vag     ⒥ati              0
# 17540                               ¬za¬u     vag     ⒥iti              0
#
#       reconstructed
# 130             NaN
# 144             NaN
# 338             NaN
# 417             NaN
# 784             NaN
# ...             ...
# 17352           NaN
# 17397  (zapo)+znati
# 17407        ?pasti
# 17539           NaN
# 17540           NaN
#
# [219 rows x 20 columns]

# %%
PREV = set(ORPHANS) or set(morphemes.base_verb.unique())
PREV = PREV & set(morphemes.base_verb.unique())

ORPHANS = set()

for base in PREV:
    if check_if_orphan(base):
        print(base, check_if_orphan(base))
        ORPHANS |= {base}
# Out:
# råzmetati True
# naklåti True

# %%
ORPHANS -= {'†ložiti', '†niziti', '†pokojiti', '†vysiti',
 '†gynųti',
 '†jati',
 '†kladati',
 '†lagati',
 '†městiti',
 '†nažiti',
 '†niknųti',
 '†pitati',
 '†plåšiti',
 '†spěti',
 '†strěti',
 '†trčati',
 '†vihnųti',
  'končati', 'jęti', 'slåditi', 'věděti', 'poriti', 'siliti', 'sȯmknųti', 'skråtiti', 'vladati', 'imati',
           "aklimatizovati", 'belěti', 'mråzosušati', 'bočiti', 'programovati', 'projektovati', 
            'obuzdati', 'opravdati', 'odšlupati', "ogråditi", "råzgråditi", "podobniti", 'prisposobiti',
            'dokonati', 'drěmnųti', 'nagråditi', 'zamknųti', 'utočniti', 'trojiti', 'niti', 'sȯvětovati', 'kati', 'obuti', 'odčajati',
            #?
            'vŕnųti', 'mrěti', 'sųsrědotočati', 'sȯniti', 'sloviti', 'občiti', 'pok' + YI + 'iti', #''
           }

morphemes.query("base_verb in @ORPHANS").shape, len(ORPHANS)
# # nakalati
# Out:
# ((3, 19), 2)

# %% [markdown]
# ## ANOMALY 1: missing prefixes

# %%
morphemes.query("_prefix == '' and prefix not in ['?', @BACKTICK]")#._prefix.value_counts()
# Out:
#             id      isv addition  partOfSpeech  \
# 14076  34119.0  sȯhnųti      NaN  v.intr. ipf.
# 14077  34121.0  sȯhnųti      NaN  v.intr. ipf.
# 14119   4150.0   sȯsati      NaN    v.tr. ipf.
#
#                                     en genesis   pos prefix verb_stem  \
# 14076  dry (intr.), become dry, wither     NaN  verb    sȯ’     hnųti
# 14077                        pine away     NaN  verb    sȯ’     hnųti
# 14119                             suck     NaN  verb    sȯ’      sati
#
#       base_verb  ... left_stem_cand right_stem_cand derived_nouns base_noun  \
# 14076   sȯhnųti  ...            sȯh         ?hnųti?
# 14077   sȯhnųti  ...            sȯh         ?hnųti?
# 14119    sȯsati  ...            sȯs           ?ati?        |sȯska
#
#       _prefix _stem _suffix _is_irregular  reconstructed aspect
# 14076           sȯh    nųti             0            NaN    ipf
# 14077           sȯh    nųti             0            NaN    ipf
# 14119           sȯs     ati             0            NaN    ipf
#
# [3 rows x 21 columns]

# %%
morphemes.query("isv.str.contains('stv')")#._prefix.value_counts()
# Out:
#             id                 isv addition  partOfSpeech  \
# 1568   24981.0            črstvěti      NaN  v.intr. ipf.
# 4592   14605.0          jestvovati      NaN  v.intr. ipf.
# 9061   36666.0       odsųtstvovati      NaN  v.intr. ipf.
# 11859  23860.0  prisųtstvovati pri     (+6)  v.intr. ipf.
# 14056  34940.0       sȯčuvstvovati      NaN  v.intr. ipf.
# 14589   6306.0           stvarjati      NaN    v.tr. ipf.
# 14593   6307.0            stvoriti      NaN     v.tr. pf.
# 14595  18738.0            stvŕditi      NaN     v.tr. pf.
# 14707  36821.0         sųtstvovati      NaN  v.intr. ipf.
# 15578   2948.0         učęstvovati      NaN  v.intr. ipf.
# 17048   9090.0  vzajemodějstvovati      NaN  v.intr. ipf.
#
#                                                       en genesis   pos prefix  \
# 1568                                        become stale     NaN  verb      ?
# 4592                                               exist     NaN  verb      ?
# 9061                                  be absent, be away     NaN  verb      ?
# 11859                              attend, be present at     NaN  verb      ?
# 14056           sympathize, commiserate, feel compassion     NaN  verb    sȯ’
# 14589                                 create, make, form     NaN  verb      ?
# 14593                                 create, make, form     NaN  verb      ?
# 14595  state, claim, assert, allege, affirm, contend,...     NaN  verb      ?
# 14707                                              exist     NaN  verb      ?
# 15578                                        participate     NaN  verb      ?
# 17048                                           interact     NaN  verb      ?
#
#          verb_stem base_verb  ...      left_stem_cand    right_stem_cand  \
# 1568             ?  črstvěti  ...               črstv           črstvěti
# 4592             ?      byti  ...               jestv         jestvovati
# 9061             ?      byti  ...            odsųtstv        sųtstvovati
# 11859            ?      byti  ...  prisųtstvovati pri    ?tstvovati pri?
# 14056  čuvstvovati    čuvati  ...            sȯčuvstv      ?čuvstvovati?
# 14589            ?   tvoriti  ...               stvar         ?tvarjati?
# 14593            ?   tvoriti  ...               stvor            tvoriti
# 14595            ?   tvŕditi  ...               stvŕd            tvŕditi
# 14707            ?      byti  ...              sųtstv        ?tstvovati?
# 15578            ?            ...              učęstv       ?čęstvovati?
# 17048            ?    dějati  ...       vzajemodějstv  ?jemodějstvovati?
#
#       derived_nouns base_noun _prefix  _stem _suffix _is_irregular  \
# 1568                                   črstv     ěti             0
# 4592                                                             1
# 9061                                                             1
# 11859                                                            1
# 14056                                                            1
# 14589                              ¬s   tvꜵr    jati             0
# 14593                              ¬s   tvꜵr     iti             0
# 14595                              ¬s   tvŕd     iti             0
# 14707                                                            1
# 15578                    čęsť      ¬u  čęstv   ovati             0
# 17048                                                            1
#
#        reconstructed aspect
# 1568             NaN    ipf
# 4592           ?byti    ipf
# 9061           ?byti    ipf
# 11859          ?byti    ipf
# 14056          ?čuti    ipf
# 14589       ?tvoriti    ipf
# 14593      sъtvoriti     pf
# 14595            NaN     pf
# 14707          ?byti    ipf
# 15578         ?uměti    ipf
# 17048        ?dějati    ipf
#
# [11 rows x 21 columns]

# %%
g = morphemes.query("isv == 'sȯvětovati'")
manual_insert_g(g, "vět", dry_run=0)
set_base_verb(g, 'sȯvětovati')

g = morphemes.query("isv == 'sȯčuvstvovati'")
manual_insert_g(g, "čuvstv", dry_run=0)

g = morphemes.query("isv == 'vȯzpitati'")
manual_insert_g(g, "pit", dry_run=0)

g = morphemes.query("base_verb == 'sȯzdati'")
manual_insert_g(g, "zd", dry_run=0)
set_base_verb(g, 'zdati')
# Out:
# sȯvětovati = sȯ vět ovati
# sȯčuvstvovati = sȯ čuvstv ovati
# vȯzpitati = vȯz pit ati

# %%
#morphemes.query("base_verb == 'sil'")
g = morphemes.query("base_verb.str.contains('sȯs')")
g
# Out:
#             id       isv addition partOfSpeech        en genesis   pos prefix  \
# 4274    4151.0  izsȯsati      NaN    v.tr. pf.  suck out     NaN  verb      ?
# 4297    5567.0  izsysati      NaN  #v.tr. ipf.  suck out     NaN  None      ?
# 14119   4150.0    sȯsati      NaN   v.tr. ipf.      suck     NaN  verb    sȯ’
# 16929  20273.0   vsosati      NaN    v.tr. pf.   suck in     NaN  verb      ?
#
#       verb_stem base_verb  ... left_stem_cand right_stem_cand derived_nouns  \
# 4274          ?    sȯsati  ...          izsȯs          sȯsati
# 4297          ?    sȯsati  ...          izsys         ?ysati?
# 14119      sati    sȯsati  ...            sȯs           ?ati?        |sȯska
# 16929         ?    sȯsati  ...           vsos          sosati
#
#       base_noun _prefix _stem _suffix _is_irregular  reconstructed aspect
# 4274                ¬iz   sȯs     ati             0            NaN     pf
# 4297                ¬iz   sys     ati             0            NaN    ipf
# 14119                     sȯs     ati             0            NaN    ipf
# 16929                ¬v   sos     ati             0            NaN     pf
#
# [4 rows x 21 columns]

# %%
morphemes.query("en.str.contains('suck')")
# Out:
#             id       isv addition partOfSpeech        en genesis   pos prefix  \
# 4274    4151.0  izsȯsati      NaN    v.tr. pf.  suck out     NaN  verb      ?
# 4297    5567.0  izsysati      NaN  #v.tr. ipf.  suck out     NaN  None      ?
# 14119   4150.0    sȯsati      NaN   v.tr. ipf.      suck     NaN  verb    sȯ’
# 16929  20273.0   vsosati      NaN    v.tr. pf.   suck in     NaN  verb      ?
#
#       verb_stem base_verb  ... left_stem_cand right_stem_cand derived_nouns  \
# 4274          ?    sȯsati  ...          izsȯs          sȯsati
# 4297          ?    sȯsati  ...          izsys         ?ysati?
# 14119      sati    sȯsati  ...            sȯs           ?ati?        |sȯska
# 16929         ?    sȯsati  ...           vsos          sosati
#
#       base_noun _prefix _stem _suffix _is_irregular  reconstructed aspect
# 4274                ¬iz   sȯs     ati             0            NaN     pf
# 4297                ¬iz   sys     ati             0            NaN    ipf
# 14119                     sȯs     ati             0            NaN    ipf
# 16929                ¬v   sos     ati             0            NaN     pf
#
# [4 rows x 21 columns]

# %%
g = morphemes.query("base_verb == 'deportovati'")
manual_insert_g(g, "port", dry_run=0)

g = morphemes.query("base_verb == 'dezinfikovati'")
manual_insert_g(g, "infik", dry_run=0)
set_base_verb(g, 'infikovati')

g = morphemes.query("base_verb == 'obezglåviti'")
manual_insert_g(g, "glåv", dry_run=0)
# Out:
# deportovati = de port ovati
# dezinfikovati = dez infik ovati
# obezglåviti = obez glåv iti
# obezglåvjati = obez glåv jati

# %%
g = morphemes.query("base_verb == 'vȯznikati'")
manual_insert_g(g, "nik", dry_run=0)

g = morphemes.query("isv.str.contains('veli')")
manual_insert_g(g, "velik", dry_run=0, last_cons={"č", 'k'})
set_base_verb(g, 'veličati')

g = morphemes.query("base_verb.str.contains('bogatiti')")
manual_insert_g(g, "bogat", dry_run=0, last_cons={'t', 'ć'})
set_base_verb(g, 'bogatiti')
# Out:
# vȯznikati = vȯz nik ati
# vȯznikati = vȯz nik ati
# vȯzniknųti = vȯz nik nųti
# vȯzniknųti = vȯz nik nųti
# prěuveličati = prěu velik ⒥ati
# prěuveličiti = prěu velik ⒥iti
# uveličati = u velik ⒥ati
# uveličiti = u velik ⒥iti
# vȯzveličati = vȯz velik ⒥ati
# vȯzveličivati = vȯz velik ⒥ivati
# obogaćati = o bogat ⒥ati
# obogatiti = o bogat iti
# vȯzbogaćati = vȯz bogat ⒥ati
# vȯzbogatiti = vȯz bogat iti

# %%
g = morphemes.query("base_verb.str.contains('plȯt')")
manual_insert_g(g, "plȯt", dry_run=0, last_cons={'t', 'ć'})

g = morphemes.query("base_verb.str.contains('vŕš[ia]ti')")
manual_insert_g(g, "vŕš", dry_run=0, last_cons={'t', 'ć'})
set_base_verb(g, 'vŕšiti')

g = morphemes.query("base_verb.str.contains('staviti')")
manual_insert_g(g, "stav", dry_run=0)#last_cons={'t', 'ć'})
set_base_verb(g, 'staviti')

g = morphemes.query("base_verb.str.contains('kres[ai]')")
manual_insert_g(g, "kres", dry_run=0, last_cons={'s', 'š'})
set_base_verb(g, 'kresati')
# Out:
# vȯplȯćati = vȯ plȯt ⒥ati
# vȯplȯtiti = vȯ plȯt iti
# dovŕšati = do vŕš ati
# dovŕšiti = do vŕš iti
# sȯvŕšati = sȯ vŕš ati
# sȯvŕšati = sȯ vŕš ati
# sȯvŕšiti = sȯ vŕš iti
# sȯvŕšiti = sȯ vŕš iti
# vȯzvŕšati = vȯz vŕš ati
# vȯzvŕšiti = vȯz vŕš iti
# zavŕšati = za vŕš ati
# zavŕšiti = za vŕš iti
# dostaviti = do stav iti
# dostaviti = do stav iti
# izstaviti = iz stav iti
# izstavjati = iz stav jati
# nastaviti = na stav iti
# nastaviti = na stav iti
# nastaviti = na stav iti
# nastaviti = na stav iti
# odstaviti = od stav iti
# ostaviti = o stav iti
# ostaviti = o stav iti
# postaviti pytańje = po stav iti
# postaviti = po stav iti
# postaviti = po stav iti
# postavjati = po stav jati
# postavjati = po stav jati
# pozastaviti = poza stav iti
# prědstaviti = prěd stav iti
# prědstaviti = prěd stav iti
# prěstaviti = prě stav iti
# prěstaviti = prě stav iti
# råzstaviti = raz stav iti
# råzstaviti = raz stav iti
# sȯstaviti = sȯ stav iti
# sȯstavjati = sȯ stav jati
# staviti na něčto =  stav iti
# staviti pytańje =  stav iti
# staviti =  stav iti
# sųpostaviti = sųpo stav iti
# sųpostavjati = sųpo stav jati
# ustaviti = u stav iti
# vstaviti = v stav iti
# zastaviti = za stav iti
# zastaviti = za stav iti
# zaustaviti = zau stav iti
# zaustaviti = zau stav iti
# zaustavjati = zau stav jati
# zaustavjati = zau stav jati
# kresati =  kres ati
# vȯzkresati = vȯz kres ati
# vȯzkresiti = vȯz kres iti
# vȯzkresnųti = vȯz kres nųti
# vȯzkrešati = vȯz kres ⒥ati

# %%
g = morphemes.query("isv.str.contains('sil')")
manual_insert_g(g, "sil", dry_run=0)
set_base_verb(g, 'siliti')
# Out:
# obezsiliti = obez sil iti
# obezsiljati = obez sil jati
# osiliti = o sil iti
# osiljati = o sil jati
# siliti =  sil iti
# usiliti = u sil iti
# usiljati = u sil jati
# usilovati = u sil ovati
# vȯzsiliti = vȯz sil iti
# vȯzsilovati = vȯz sil ovati

# %%
g = morphemes[morphemes.base_verb.str.contains("viniti")]
manual_insert_g(g, "vin", dry_run=0)
set_base_verb(g, 'viniti')

g = morphemes[morphemes.base_verb.str.contains("věda")]
manual_insert_g(g, "věd", dry_run=0)
set_base_verb(g, 'věděti')
# Out:
# izviniti = iz vin iti
# izviniti = iz vin iti
# izvinjati = iz vin jati
# izvinjati = iz vin jati
# obviniti za = ob vin iti
# obvinjati za = ob vin jati
# uneviniti = une vin iti
# unevinjati = une vin jati
# viniti za =  vin iti
# dovědati = do věd ati
# dověděti = do věd ěti
# izpovědati = izpo věd ati
# izpověděti = izpo věd ěti
# povědati = po věd ati
# pověděti = po věd ěti
# prědpovědati = prědpo věd ati
# prědpověděti = prědpo věd ěti

# %%
vc = morphemes.query("_prefix == ''").isv.apply(lambda x: bite_all_prefixes_off(x, '')).value_counts()
vc[vc > 10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[186], line 1
# ----> 1 vc = morphemes.query("_prefix == ''").isv.apply(lambda x: bite_all_prefixes_off(x, '')).value_counts()
#       2 vc[vc > 10]
#
# File ~\anaconda3\envs\isvbase\lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\anaconda3\envs\isvbase\lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# File ~\anaconda3\envs\isvbase\lib\site-packages\pandas\core\apply.py:1174, in SeriesApply.apply_standard(self)
#    1172     else:
#    1173         values = obj.astype(object)._values
# -> 1174         mapped = lib.map_infer(
#    1175             values,
#    1176             f,
#    1177             convert=self.convert_dtype,
#    1178         )
#    1180 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1181     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1182     #  See also GH#25959 regarding EA support
#    1183     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\anaconda3\envs\isvbase\lib\site-packages\pandas\_libs\lib.pyx:2924, in pandas._libs.lib.map_infer()
#
# Cell In[186], line 1, in <lambda>(x)
# ----> 1 vc = morphemes.query("_prefix == ''").isv.apply(lambda x: bite_all_prefixes_off(x, '')).value_counts()
#       2 vc[vc > 10]
#
# NameError: name 'bite_all_prefixes_off' is not defined

# %%
vc = morphemes.query("_prefix == ''").isv.str[:3].value_counts()
vc.head(22)
# Out:
# obr    22
# str    18
# pro    17
# sta    15
# pod    12
# ima    11
# zas    10
# kon    10
# vla     9
# pos     9
# obn     8
# odo     8
# prě     8
# tra     8
# byt     8
# upo     8
# kri     7
# par     7
# dos     7
# vit     7
# pra     7
# kom     7
# Name: isv, dtype: int64

# %%
def move_prefix(g, prefix):
    assert all(g._stem.str.startswith(prefix))
    assert all(g._prefix == '')
    morphemes.loc[g.index, '_stem'] = g._stem.str[len(prefix):]
    morphemes.loc[g.index, '_prefix'] = prefix


g = morphemes.query("isv.str.contains('^iz') and not base_verb.str.contains('^iz') and _prefix == ''")

move_prefix(g, 'iz')

morphemes.loc[g.index]
# Out:
# Empty DataFrame
# Columns: [id, isv, addition, partOfSpeech, en, genesis, pos, prefix, verb_stem, base_verb, isv_orig, left_stem_cand, right_stem_cand, derived_nouns, base_noun, _prefix, _stem, _suffix, _is_irregular, reconstructed, aspect]
# Index: []
#
# [0 rows x 21 columns]

# %%
g = morphemes.query("isv.str.contains('^iz') and base_verb.str.contains('^iz') and _prefix == ''")
g.base_verb.unique()
# Out:
# array(['izčezati', 'izčrkati', 'izjasniti', 'izključati', 'izkusiti',
#        'iznuriti', 'izobličati', 'izolovati', 'izopačati', 'izpråzdniti',
#        'iztěkati', 'izučati', 'izvěstiti'], dtype=object)

# %%
g1 = morphemes.query("base_verb.str.contains('věst') and not base_verb.str.contains('cv')")
g1 #šć
# Out:
#            id        isv addition partOfSpeech              en genesis   pos  \
# 4341   3688.0  izvěstiti      NaN    v.tr. pf.  inform, report     NaN  verb
# 4348   3692.0  izvěšćati      NaN   v.tr. ipf.  inform, report     NaN  verb
# 8633  22225.0  obvěstiti      NaN    v.tr. pf.        announce     NaN  verb
# 8634  22224.0  obvěšćati      NaN   v.tr. ipf.        announce     NaN  verb
#
#      prefix verb_stem  base_verb  ... left_stem_cand right_stem_cand  \
# 4341      ?         ?  izvěstiti  ...         izvěst        ?ěstiti?
# 4348      ?         ?  izvěstiti  ...         izvěšć        ?ěšćati?
# 8633      ?         ?  obvěstiti  ...         obvěst        ?ěstiti?
# 8634      ?         ?  obvěstiti  ...         obvěšć        ?ěšćati?
#
#             derived_nouns base_noun _prefix   _stem _suffix _is_irregular  \
# 4341  |izvěsťje|izvěstnik                    izvěst     iti             0
# 4348                                         izvěst    ⒥ati             0
# 8633                                         obvěst     iti             0
# 8634                                         obvěst    ⒥ati             0
#
#       reconstructed aspect
# 4341            NaN     pf
# 4348            NaN    ipf
# 8633            NaN     pf
# 8634            NaN    ipf
#
# [4 rows x 21 columns]

# %%
g1 = morphemes.query("isv.str.contains('črk')")
manual_insert_g(g1, "črk", dry_run=0)
set_base_verb(g1, 'črkati')

g1 = morphemes.query("isv.str.contains('jasn')")
manual_insert_g(g1, "jasn", dry_run=0)
set_base_verb(g1, 'jasněti')

g1 = morphemes.query("isv.str.contains('ključ')")
manual_insert_g(g1, "ključ", dry_run=0)
set_base_verb(g1, 'ključiti')

g1 = morphemes.query("base_verb.str.contains('nuri')")
manual_insert_g(g1, "nur", dry_run=0)
set_base_verb(g1, 'nuriti')

g1 = morphemes.query("base_verb.str.contains('kus[ia]')")
manual_insert_g(g1, "kus", dry_run=0, last_cons={"s", "š"})
set_base_verb(g1, 'kusati')

g1 = morphemes.query("base_verb.str.contains('izobličati')")
manual_insert_g(g1, "oblik", last_cons={'k', 'č'}, dry_run=0)
set_base_verb(g1, 'obličati')

g1 = morphemes.query("base_verb.str.contains('opač')")
manual_insert_g(g1, "opak", last_cons={'k', 'č'}, dry_run=0)
set_base_verb(g1, 'opačiti')

g1 = morphemes.query("base_verb.str.contains('pråzd')") #izpråzdniti
manual_insert_g(g1, "pråzd", dry_run=0)
set_base_verb(g1, 'pråzdniti')

g1 = morphemes.query("base_verb.str.contains('těk')")  # tekti
manual_insert_g(g1, "těk", dry_run=0)
set_base_verb(g1, 'tekti')

g1 = morphemes.query("base_verb.str.contains('uč[ai]ti') and not base_verb.str.contains('lj?u')").query("isv not in ['bučati', 'čučati', 'mučati']")
manual_insert_g(g1, "uk", dry_run=0, last_cons={'k', 'č'})
set_base_verb(g1, 'učiti')

g1 = morphemes.query("base_verb.str.contains('věst') and not base_verb.str.contains('cv')")
manual_insert_g(g1, "věst", dry_run=0, last_cons={"ć", 't'})
set_base_verb(g1, 'izvěstiti')
# Out:
# izčrkati = iz črk ati
# izčrknųti = iz črk nųti
# očrkati = o črk ati
# očrknųti = o črk nųti
# podčrkati = pod črk ati
# podčrknųti = pod črk nųti
# izjasniti = iz jasn iti
# izjasnjati = iz jasn jati
# jasněti =  jasn ěti
# objasniti = ob jasn iti
# objasnjati = ob jasn jati
# råzjasniti = raz jasn iti
# råzjasnjati = raz jasn jati
# izključati = iz ključ ati
# izključati = iz ključ ati
# izključiti = iz ključ iti
# izključiti = iz ključ iti
# odključati = od ključ ati
# odključati = od ključ ati
# odključiti = od ključ iti
# odključiti = od ključ iti
# podključati = pod ključ ati
# podključati = pod ključ ati
# podključiti = pod ključ iti
# podključiti = pod ključ iti
# prěključati = prě ključ ati
# prěključiti = prě ključ iti
# vključati = v ključ ati
# vključati = v ključ ati
# vključiti = v ključ iti
# vključiti = v ključ iti
# zaključati = za ključ ati
# zaključati = za ključ ati
# zaključati = za ključ ati
# zaključiti = za ključ iti
# zaključiti = za ključ iti
# zaključiti = za ključ iti
# iznuriti = iz nur iti
# iznurjati = iz nur jati
# zanuriti = za nur iti
# zanurjati = za nur jati
# izkusiti = iz kus iti
# izkušati = iz kus ⒥ati
# pokusiti = po kus iti
# pokusiti = po kus iti
# pokušati = po kus ⒥ati
# pokušati = po kus ⒥ati
# izobličati = iz oblik ⒥ati
# izobličiti = iz oblik ⒥iti
# izopačati = iz opak ⒥ati
# izopačiti = iz opak ⒥iti
# izpråzdniti = iz pråzd niti
# izpråzdnjati = iz pråzd njati
# opråzdniti = o pråzd niti
# opråzdnjati = o pråzd njati
# pråzdnovati =  pråzd novati
# iztěkati = iz těk ati
# iztěkati = iz těk ati
# proiztěkati = proiz těk ati
# izučati = iz uk ⒥ati
# izučiti = iz uk ⒥iti
# naučiti = na uk ⒥iti
# naučiti = na uk ⒥iti
# obučati = ob uk ⒥ati
# obučiti = ob uk ⒥iti
# odučati = od uk ⒥ati
# odučiti = od uk ⒥iti
# poučati = po uk ⒥ati
# poučiti = po uk ⒥iti
# priučati = pri uk ⒥ati
# priučati = pri uk ⒥ati
# priučiti = pri uk ⒥iti
# priučiti = pri uk ⒥iti
# učiti =  uk ⒥iti
# učiti =  uk ⒥iti
# izvěstiti = iz věst iti
# izvěšćati = iz věst ⒥ati
# obvěstiti = ob věst iti
# obvěšćati = ob věst ⒥ati

# %%
set_base_verb(morphemes.query("isv == 'tknųti'"), 'tykati')

# %%
morphemes.query("_stem == 'tk'")
# Out:
#             id        isv addition partOfSpeech                      en  \
# 2253   22119.0   dotknųti      NaN  v.refl. pf.                   touch
# 2254     481.0   dotknųti      NaN    v.tr. pf.                   touch
# 4309   26247.0    iztkati      NaN    v.tr. pf.                   weave
# 14133  34857.0    sȯtkati      NaN    v.tr. pf.                   weave
# 14248  22123.0  spotknųti      NaN  v.refl. pf.                 stumble
# 15231  34856.0      tkati      NaN   v.tr. ipf.                   weave
# 15232  22108.0     tknųti      NaN  v.refl. pf.      relate to, concern
# 15233  22099.0     tknųti      NaN    v.tr. pf.                   touch
# 15234  22101.0     tknųti      NaN    v.tr. pf.  stick, jab, poke, prod
# 17505  33093.0   zatknųti      NaN  v.refl. pf.                be stuck
# 17506  31567.0   zatknųti      NaN    v.tr. pf.           plug, stop up
#
#       genesis   pos prefix verb_stem base_verb  ... left_stem_cand  \
# 2253      NaN  verb      ?         ?    tykati  ...           dotk
# 2254      NaN  verb      ?         ?    tykati  ...           dotk
# 4309      NaN  verb      ?         ?     tkati  ...           iztk
# 14133     NaN  verb    sȯ’     tkati     tkati  ...           sȯtk
# 14248     NaN  verb      ?         ?    tykati  ...          spotk
# 15231     NaN  verb      ?         ?     tkati  ...             tk
# 15232     NaN  verb      ?         ?    tykati  ...             tk
# 15233     NaN  verb      ?         ?    tykati  ...             tk
# 15234     NaN  verb      ?         ?    tykati  ...             tk
# 17505     NaN  verb      ?         ?    tykati  ...           zatk
# 17506     NaN  verb      ?         ?    tykati  ...           zatk
#
#       right_stem_cand derived_nouns base_noun _prefix _stem _suffix  \
# 2253           tknųti                             ¬do    tk    nųti
# 2254           tknųti                             ¬do    tk    nųti
# 4309            tkati                             ¬iz    tk     ati
# 14133           tkati                             ¬sȯ    tk     ati
# 14248          tknųti                           ¬s¬po    tk    nųti
# 15231           tkati                                    tk     ati
# 15232          tknųti                                    tk    nųti
# 15233          tknųti                                    tk    nųti
# 15234          tknųti                                    tk    nųti
# 17505          tknųti                             ¬za    tk    nųti
# 17506          tknųti                             ¬za    tk    nųti
#
#       _is_irregular  reconstructed aspect
# 2253              0        ?tykati     pf
# 2254              0        ?tykati     pf
# 4309              0    (iz)+tъkati     pf
# 14133             0    (sȯ)+tъkati     pf
# 14248             0        ?tykati     pf
# 15231             0         tъkati    ipf
# 15232             0        tъknǫti     pf
# 15233             0        tъknǫti     pf
# 15234             0        tъknǫti     pf
# 17505             0        ?tykati     pf
# 17506             0        ?tykati     pf
#
# [11 rows x 21 columns]

# %%
g
# Out:
#            id           isv addition  partOfSpeech  \
# 3944   3550.0      izčezati      NaN  v.intr. ipf.
# 3946   3557.0     izčeznųti      NaN   v.intr. pf.
# 3952   3253.0      izčrkati      NaN    v.tr. ipf.
# 3953   3271.0     izčrknųti      NaN     v.tr. pf.
# 4016   4145.0     izjasniti      NaN     v.tr. pf.
# 4017   4144.0    izjasnjati      NaN    v.tr. ipf.
# 4032   2504.0    izključati      NaN    v.tr. ipf.
# 4033   3918.0    izključati      NaN    v.tr. ipf.
# 4038    482.0    izključiti      NaN     v.tr. pf.
# 4039   3920.0    izključiti      NaN     v.tr. pf.
# 4061   3603.0      izkusiti      NaN     v.tr. pf.
# 4063   4781.0      izkušati      NaN    v.tr. ipf.
# 4139  16391.0      iznuriti      NaN   v.intr. pf.
# 4140   8082.0     iznurjati      NaN  v.intr. ipf.
# 4142  20395.0    izobličati      NaN    v.tr. ipf.
# 4143  20396.0    izobličiti      NaN     v.tr. pf.
# 4152   2015.0     izolovati      NaN    v.tr. ipf.
# 4153  31929.0     izopačati      NaN    v.tr. ipf.
# 4154  26216.0     izopačiti      NaN     v.tr. pf.
# 4194  26231.0   izpråzdniti      NaN     v.tr. pf.
# 4195  31723.0  izpråzdnjati      NaN    v.tr. ipf.
# 4304   6070.0      iztěkati      NaN  v.intr. ipf.
# 4305  22066.0      iztěkati      NaN  v.intr. ipf.
# 4329  31724.0       izučati      NaN    v.tr. ipf.
# 4330  26256.0       izučiti      NaN     v.tr. pf.
# 4341   3688.0     izvěstiti      NaN     v.tr. pf.
# 4348   3692.0     izvěšćati      NaN    v.tr. ipf.
#
#                               en genesis   pos prefix verb_stem    base_verb  \
# 3944           disappear, vanish     NaN  verb      ?         ?     izčezati
# 3946           disappear, vanish     NaN  verb      ?         ?     izčezati
# 3952           delete, cross out     NaN  verb      ?         ?     izčrkati
# 3953           delete, cross out     NaN  verb      ?         ?     izčrkati
# 4016                     clarify     NaN  verb      ?         ?    izjasniti
# 4017                     clarify     NaN  verb      ?         ?    izjasniti
# 4032             exclude, except     NaN  verb      ?         ?   izključati
# 4033        turn off, switch off     NaN  verb      ?         ?   izključati
# 4038             exclude, except     NaN  verb      ?         ?   izključati
# 4039        turn off, switch off     NaN  verb      ?         ?   izključati
# 4061         experience, undergo     NaN  verb      ?         ?     izkusiti
# 4063         experience, undergo     NaN  verb      ?         ?     izkusiti
# 4139                      emerge     NaN  verb      ?         ?     iznuriti
# 4140                      emerge     NaN  verb      ?         ?     iznuriti
# 4142                      unmask     NaN  verb      ?         ?   izobličati
# 4143                      unmask     NaN  verb      ?         ?   izobličati
# 4152                     isolate       I  verb      ?         ?    izolovati
# 4153  disfigure, distort, deform     NaN  verb      ?         ?    izopačati
# 4154  disfigure, distort, deform     NaN  verb      ?         ?    izopačati
# 4194    empty, clear out, vacate     NaN  verb      ?         ?  izpråzdniti
# 4195    empty, clear out, vacate     NaN  verb      ?         ?  izpråzdniti
# 4304          flow out, leak out     NaN  verb      ?         ?     iztěkati
# 4305              elapse, expire     NaN  verb      ?         ?     iztěkati
# 4329                      #train     NaN  verb      ?         ?      izučati
# 4330                       train     NaN  verb      ?         ?      izučati
# 4341              inform, report     NaN  verb      ?         ?    izvěstiti
# 4348              inform, report     NaN  verb      ?         ?    izvěstiti
#
#       ... left_stem_cand right_stem_cand        derived_nouns base_noun  \
# 3944  ...          izčez        ?čezati?
# 3946  ...          izčez       ?čeznųti?
# 3952  ...          izčrk        ?črkati?
# 3953  ...          izčrk       ?črknųti?
# 4016  ...         izjasn       ?jasniti?
# 4017  ...         izjasn      ?jasnjati?
# 4032  ...        izključ      ?ključati?
# 4033  ...        izključ      ?ključati?
# 4038  ...        izključ      ?ključiti?
# 4039  ...        izključ      ?ključiti?
# 4061  ...          izkus        ?kusiti?                          izkus
# 4063  ...          izkuš        ?kušati?
# 4139  ...          iznur        ?nuriti?
# 4140  ...          iznur       ?nurjati?
# 4142  ...        izoblič        ?ličati?
# 4143  ...        izoblič        ?ličiti?
# 4152  ...           izol        ?lovati?           |izolacija
# 4153  ...         izopač        ?pačati?
# 4154  ...         izopač        ?pačiti?
# 4194  ...       izpråzdn     ?pråzdniti?
# 4195  ...       izpråzdn    ?pråzdnjati?
# 4304  ...          iztěk        ?těkati?
# 4305  ...          iztěk        ?těkati?
# 4329  ...           izuč          ?čati?
# 4330  ...           izuč           učiti
# 4341  ...         izvěst        ?ěstiti?  |izvěsťje|izvěstnik
# 4348  ...         izvěšć        ?ěšćati?
#
#      _prefix     _stem _suffix _is_irregular  reconstructed aspect
# 3944             izčez     ati             0            NaN    ipf
# 3946             izčez    nųti             0            NaN     pf
# 3952             izčrk     ati             0            NaN    ipf
# 3953             izčrk    nųti             0            NaN     pf
# 4016            izjasn     iti             0            NaN     pf
# 4017            izjasn    jati             0            NaN    ipf
# 4032           izključ     ati             0            NaN    ipf
# 4033           izključ     ati             0            NaN    ipf
# 4038           izključ     iti             0            NaN     pf
# 4039           izključ     iti             0            NaN     pf
# 4061             izkus     iti             0      jьzkusiti     pf
# 4063             izkus    ⒥ati             0     ?jьzkusiti    ipf
# 4139             iznur     iti             0            NaN     pf
# 4140             iznur    jati             0            NaN    ipf
# 4142           izoblič     ati             0            NaN    ipf
# 4143           izoblič     iti             0            NaN     pf
# 4152              izol   ovati             0            NaN    ipf
# 4153            izopač     ati             0            NaN    ipf
# 4154            izopač     iti             0            NaN     pf
# 4194          izpråzdn     iti             0            NaN     pf
# 4195          izpråzdn    jati             0            NaN    ipf
# 4304             iztěk     ati             0            NaN    ipf
# 4305             iztěk     ati             0            NaN    ipf
# 4329              izuč     ati             0      ?jьzučiti    ipf
# 4330              izuč     iti             0       jьzučiti     pf
# 4341            izvěst     iti             0            NaN     pf
# 4348            izvěst    ⒥ati             0            NaN    ipf
#
# [27 rows x 21 columns]

# %%
for v in g.base_verb.str[2:].unique():
    if any(morphemes.isv == v) or any(morphemes.base_verb == v):
        print(v)
        print(morphemes[morphemes.isv == v].base_verb)
        stem = morphemes[morphemes.isv == v]._stem.values[0]
        print(stem)
        print(morphemes[morphemes.base_verb == v].shape)
        
        g1 = morphemes[morphemes.base_verb == "iz" + v]
        manual_insert_g(g1, stem, dry_run=0, last_cons={"h", "š"})
        set_base_verb(g1, v)
# Out:
# probovati
# 11961    probovati
# Name: base_verb, dtype: object
# probo
# (3, 21)
# izprobovati = iz probo vati
# izprobovyvati = iz probo vyvati
# seliti
# 13526    seliti
# Name: base_verb, dtype: object
# sel
# (2, 21)
# izseliti = iz sel iti
# izseliti = iz sel iti
# izseljati = iz sel jati
# izseljati = iz sel jati
# slušati
# 13925    slušati
# Name: base_verb, dtype: object
# sluh
# (5, 21)
# izslušati = izslušati sluh
# izslušivati = izslušivati sluh

# %%
#        g1 = morphemes[morphemes.base_verb == "iz" + v]
manual_insert_g(g1, stem, dry_run=0, last_cons={"š"})
# Out:
# izslušati = iz sluh ⒥ati
# izslušivati = iz sluh ⒥ivati

# %%
morphemes.loc[g1.index]
# Out:
#            id          isv addition partOfSpeech                   en genesis  \
# 4265  36533.0    izslušati      NaN    v.tr. pf.  hear out, listen to     NaN
# 4266  36532.0  izslušivati      NaN   v.tr. ipf.  hear out, listen to     NaN
#
#        pos prefix verb_stem base_verb  ... left_stem_cand right_stem_cand  \
# 4265  verb      ?         ?   slušati  ...         izsluš         slušati
# 4266  verb      ?         ?   slušati  ...         izsluš      ?lušivati?
#
#      derived_nouns base_noun      _prefix _stem _suffix _is_irregular  \
# 4265                            izslušati  sluh                     0
# 4266                          izslušivati  sluh                     0
#
#       reconstructed aspect
# 4265            NaN     pf
# 4266            NaN    ipf
#
# [2 rows x 21 columns]

# %%
morphemes.query("isv.str.contains('prěd')")
# Out:
#             id             isv             addition  partOfSpeech  \
# 3638   13823.0      idti vprěd          #(ide; šel)        v.ipf.
# 9428   29544.0      oprěděliti                  NaN     v.tr. pf.
# 9429   32606.0     oprěděljati                  NaN    v.tr. ipf.
# 11252   1189.0         prědati              (prěda)     v.tr. pf.
# 11253   3247.0         prědati              (prěda)     v.tr. pf.
# 11254  35613.0         prědati              (prěda)     v.tr. pf.
# 11256   1825.0       prědavati                  NaN    v.tr. ipf.
# 11257   3246.0       prědavati                  NaN    v.tr. ipf.
# 11258  35612.0       prědavati                  NaN    v.tr. ipf.
# 11266  23904.0      prědčuvati                  NaN    v.tr. ipf.
# 11271    501.0      prědhoditi                  NaN    v.tr. ipf.
# 11280  11220.0     prědkladati                  NaN    v.tr. ipf.
# 11281    602.0      prědlagati                  NaN    v.tr. ipf.
# 11286   1687.0      prědložiti                  NaN     v.tr. pf.
# 11300   1578.0       prědȯjdti  (prědȯjde; prědšel)     v.tr. pf.
# 11304  35310.0      prědpisati           (prědpiše)     v.tr. pf.
# 11305  35309.0    prědpisyvati                  NaN    v.tr. ipf.
# 11306   5407.0     prědplaćati                  NaN  v.intr. ipf.
# 11307   5408.0     prědplatiti                  NaN   v.intr. pf.
# 11309   3787.0    prědpočitati                  NaN    v.tr. ipf.
# 11311   3130.0   prědpokladati                  NaN    v.tr. ipf.
# 11312  20062.0    prědpolagati                  NaN    v.tr. ipf.
# 11315  18400.0    prědpoložiti                  NaN     v.tr. pf.
# 11317  16759.0  prědpostavjati                  NaN    v.tr. ipf.
# 11320  11250.0    prědpovědati                  NaN    v.tr. ipf.
# 11321  14927.0    prědpověděti           (prědpově)     v.tr. pf.
# 11323  35201.0     prědprijęti         (prědprijme)     v.tr. pf.
# 11324  35200.0    prědprijmati                  NaN    v.tr. ipf.
# 11329  11254.0      prědsědati                  NaN  v.intr. ipf.
# 11332   2897.0     prědskazati          (prědskaže)     v.tr. pf.
# 11333   3127.0   prědskazyvati                  NaN    v.tr. ipf.
# 11335  21762.0       prědstati                  NaN   v.intr. pf.
# 11337  21761.0     prědstavati                  NaN  v.intr. ipf.
# 11340   5406.0     prědstaviti                  NaN   v.refl. pf.
# 11341   2422.0     prědstaviti                  NaN     v.tr. pf.
# 11342   5405.0    prědstavjati                  NaN  v.refl. ipf.
# 11343   1524.0    prědstavjati                  NaN    v.tr. ipf.
# 11344  21766.0    prědstavjati                  NaN    v.tr. ipf.
# 11353   3128.0    prěduprěditi                  NaN     v.tr. pf.
# 11354  21047.0    prěduprěditi                  NaN     v.tr. pf.
# 11355  21048.0    prěduprěditi                  NaN     v.tr. pf.
# 11356   1884.0    prěduprěđati                  NaN    v.tr. ipf.
# 11357  21045.0    prěduprěđati                  NaN    v.tr. ipf.
# 11358  21046.0    prěduprěđati                  NaN    v.tr. ipf.
# 11366   5403.0      prědviděti           (prědvidi)     v.tr. pf.
# 11369   5404.0    prědvidyvati                  NaN    v.tr. ipf.
# 11371  23357.0      prědvyšati                  NaN    v.tr. ipf.
#
#                                                en genesis   pos prefix  \
# 3638                                      advance     NaN  verb      ?
# 9428                   define, determine, specify     NaN  verb      ?
# 9429                   define, determine, specify     NaN  verb      ?
# 11252                  hand over, deliver, convey     NaN  verb      ?
# 11253                                   broadcast     NaN  verb      ?
# 11254                                      betray     NaN  verb      ?
# 11256                  hand over, deliver, convey     NaN  verb      ?
# 11257                                   broadcast     NaN  verb      ?
# 11258                                      betray     NaN  verb      ?
# 11266         have a premonition, have an inkling     NaN  verb      ?
# 11271                                     precede     NaN  verb      ?
# 11280                     propose, offer, suggest     NaN  verb      ?
# 11281                     propose, offer, suggest     NaN  verb      ?
# 11286                     propose, offer, suggest     NaN  verb      ?
# 11300                                     precede     NaN  verb      ?
# 11304                                   prescribe     NaN  verb      ?
# 11305                                   prescribe     NaN  verb      ?
# 11306                              pay in advance     NaN  verb      ?
# 11307                              pay in advance     NaN  verb      ?
# 11309                                      prefer     NaN  verb      ?
# 11311  assume, suppose, presume, take for granted     NaN  verb      ?
# 11312  assume, suppose, presume, take for granted     NaN  verb      ?
# 11315  assume, suppose, presume, take for granted     NaN  verb      ?
# 11317                                      prefer     NaN  verb      ?
# 11320                           forecast, predict     NaN  verb      ?
# 11321                           forecast, predict     NaN  verb      ?
# 11323                                   undertake     NaN  verb      ?
# 11324                                   undertake     NaN  verb      ?
# 11329                                     preside     NaN  verb      ?
# 11332                           forecast, predict     NaN  verb      ?
# 11333                           forecast, predict     NaN  verb      ?
# 11335                     appear (before a court)     NaN  verb      ?
# 11337                     appear (before a court)     NaN  verb      ?
# 11340                           imagine, envision     NaN  verb      ?
# 11341                          present, introduce     NaN  verb      ?
# 11342                           imagine, envision     NaN  verb      ?
# 11343               present, introduce, represent     NaN  verb      ?
# 11344                                  constitute     NaN  verb      ?
# 11353                     warn, caution, admonish     NaN  verb      ?
# 11354                           notify in advance     NaN  verb      ?
# 11355                                     prevent     NaN  verb      ?
# 11356                     warn, caution, admonish     NaN  verb      ?
# 11357                           notify in advance     NaN  verb      ?
# 11358                                     prevent     NaN  verb      ?
# 11366                predict, foresee, anticipate     NaN  verb      ?
# 11369                predict, foresee, anticipate     NaN  verb      ?
# 11371                         prefer, like better     NaN  verb      ?
#
#       verb_stem     base_verb  ... left_stem_cand right_stem_cand  \
# 3638          ?          idti  ...     idti vprěd    ?idti vprěd?
# 9428          ?    oprěděliti  ...        oprěděl          děliti
# 9429          ?    oprěděliti  ...        oprěděl        ?ěljati?
# 11252         ?          dati  ...           prěd            dati
# 11253         ?          dati  ...           prěd            dati
# 11254         ?          dati  ...           prěd            dati
# 11256         ?        davati  ...         prědav          davati
# 11257         ?        davati  ...         prědav          davati
# 11258         ?        davati  ...         prědav          davati
# 11266         ?        čuvati  ...        prědčuv          čuvati
# 11271         ?        hoditi  ...        prědhod          hoditi
# 11280         ?        klasti  ...       prědklad       ?kladati?
# 11281         ?       †lagati  ...        prědlag        ?lagati?
# 11286         ?       †ložiti  ...        prědlož        ?ložiti?
# 11300         ?          idti  ...      prědȯjdti         ?ȯjdti?
# 11304         ?        pisati  ...        prědpis          pisati
# 11305         ?        pisati  ...        prědpis      ?pisyvati?
# 11306         ?       platiti  ...       prědplać       ?plaćati?
# 11307         ?       platiti  ...       prědplat         platiti
# 11309         ?        čitati  ...      prědpočit          čitati
# 11311         ?        klasti  ...     prědpoklad       pokladati
# 11312         ?       †lagati  ...      prědpolag        ?lagati?
# 11315         ?      položiti  ...      prědpolož        položiti
# 11317         ?      stavjati  ...     prědpostav        stavjati
# 11320         ?        věděti  ...      prědpověd        povědati
# 11321         ?        věděti  ...      prědpověd          věděti
# 11323         ?          jęti  ...    prědprijęti            jęti
# 11324         ?         imati  ...      prědprijm        prijmati
# 11329         ?        sědati  ...        prědsěd          sědati
# 11332         ?        kazati  ...       prědskaz          kazati
# 11333         ?        kazati  ...       prědskaz      ?kazyvati?
# 11335         ?         stati  ...         prědst            tati
# 11337         ?       stavati  ...       prědstav         stavati
# 11340         ?       staviti  ...       prědstav         staviti
# 11341         ?       staviti  ...       prědstav         staviti
# 11342         ?      stavjati  ...       prědstav        stavjati
# 11343         ?      stavjati  ...       prědstav        stavjati
# 11344         ?      stavjati  ...       prědstav        stavjati
# 11353         ?  prěduprěditi  ...      prěduprěd           ?iti?
# 11354         ?  prěduprěditi  ...      prěduprěd           ?iti?
# 11355         ?  prěduprěditi  ...      prěduprěd           ?iti?
# 11356         ?  prěduprěditi  ...      prěduprěđ          ?đati?
# 11357         ?  prěduprěditi  ...      prěduprěđ          ?đati?
# 11358         ?  prěduprěditi  ...      prěduprěđ          ?đati?
# 11366         ?        viděti  ...        prědvid          viděti
# 11369         ?        viděti  ...        prědvid       ?idyvati?
# 11371         ?       †vysiti  ...        prědvyš          ?šati?
#
#                           derived_nouns   base_noun    _prefix      _stem  \
# 3638                                                                   jd
# 9428                                                              oprěděl
# 9429                                                              oprěděl
# 11252                                                     ¬prě         da
# 11253                                                     ¬prě         da
# 11254                                                     ¬prě         da
# 11256  |prědavnik|prědavnica|prědavstvo                   ¬prě        dav
# 11257  |prědavnik|prědavnica|prědavstvo                   ¬prě        dav
# 11258  |prědavnik|prědavnica|prědavstvo                   ¬prě        dav
# 11266                                                    ¬prěd         ču
# 11271                       |prědhodnik                  ¬prěd        hꜵd
# 11280                                                     prěd       klad
# 11281                                                    ¬prěd        lag
# 11286                       |prědložnik                  ¬prěd        lož
# 11300                                                  ¬prěd¬ȯ         jd
# 11304                                                    ¬prěd        pis
# 11305                                                    ¬prěd       pisy
# 11306                                                    ¬prěd       plat
# 11307                                                    ¬prěd       plat
# 11309                                                 ¬prěd¬po        čit
# 11311                                                   prědpo       klad
# 11312                                                 ¬prěd¬po        lag
# 11315                                                    ¬prěd      polož
# 11317                                                 ¬prěd¬po         st
# 11320                                    !prědpověď     prědpo        věd
# 11321                                                   prědpo        věd
# 11323                                                ¬prěd¬pri        jin
# 11324                                                ¬prěd¬pri         jm
# 11329                       |prědsědnik                  ¬prěd        sěd
# 11332                                                  ¬prěd¬s        kaz
# 11333                                                  ¬prěd¬s       kazy
# 11335                                                    ¬prěd         st
# 11337                                                    ¬prěd         st
# 11340                                                     prěd       stav
# 11341                                                     prěd       stav
# 11342                                                    ¬prěd         st
# 11343                                                    ¬prěd         st
# 11344                                                    ¬prěd         st
# 11353                                                           prěduprěd
# 11354                                                           prěduprěd
# 11355                                                           prěduprěd
# 11356                                                           prěduprěd
# 11357                                                           prěduprěd
# 11358                                                           prěduprěd
# 11366                                                    ¬prěd        vid
# 11369                                                    ¬prěd        vid
# 11371                                                    ¬prěd        vys
#
#       _suffix _is_irregular    reconstructed aspect
# 3638       ti             0              NaN    ipf
# 9428      iti             0              NaN     pf
# 9429     jati             0              NaN    ipf
# 11252      ti             0          perdati     pf
# 11253      ti             0          perdati     pf
# 11254      ti             0          perdati     pf
# 11256     ati            -1     (prě)+davati    ipf
# 11257     ati            -1     (prě)+davati    ipf
# 11258     ati            -1     (prě)+davati    ipf
# 11266    vati             0            ?čuti    ipf
# 11271     iti             0    (prěd)+xoditi    ipf
# 11280     ati             0   (prěd)+kladati    ipf
# 11281     ati             0              NaN    ipf
# 11286     iti             0    (prěd)+ložiti     pf
# 11300      ti             0              NaN     pf
# 11304     ati             0    (prěd)+pisati     pf
# 11305    vati             0          ?pisati    ipf
# 11306    ⒥ati             0         ?platiti    ipf
# 11307     iti             0   (prěd)+platiti     pf
# 11309     ati             0  (prědpo)+čitati    ipf
# 11311     ati             0              NaN    ipf
# 11312     ati             0              NaN    ipf
# 11315     iti             0  (prěd)+položiti     pf
# 11317  avjati             0              NaN    ipf
# 11320     ati             0              NaN    ipf
# 11321     ěti             0              NaN     pf
# 11323     ⒩ti             0    (prědpri)+ęti     pf
# 11324     ati             0          ?jьmati    ipf
# 11329     ati             0              NaN    ipf
# 11332     ati             0   (prěds)+kazati     pf
# 11333    vati             0          ?kazati    ipf
# 11335     ati             0     (prěd)+stati     pf
# 11337   avati             0   (prěd)+stavati    ipf
# 11340     iti             0   (prěd)+staviti     pf
# 11341     iti             0   (prěd)+staviti     pf
# 11342  avjati             0              NaN    ipf
# 11343  avjati             0              NaN    ipf
# 11344  avjati             0              NaN    ipf
# 11353     iti             0              NaN     pf
# 11354     iti             0              NaN     pf
# 11355     iti             0              NaN     pf
# 11356    ⒥ati             0              NaN    ipf
# 11357    ⒥ati             0              NaN    ipf
# 11358    ⒥ati             0              NaN    ipf
# 11366     ěti             0      ?nenaviděti     pf
# 11369   yvati             0      ?nenaviděti    ipf
# 11371    ⒥ati             0          ?vysiti    ipf
#
# [47 rows x 21 columns]

# %%
morphemes.query("isv.str.contains('uprě')")
# Out:
#             id           isv addition partOfSpeech                       en  \
# 11353   3128.0  prěduprěditi      NaN    v.tr. pf.  warn, caution, admonish
# 11354  21047.0  prěduprěditi      NaN    v.tr. pf.        notify in advance
# 11355  21048.0  prěduprěditi      NaN    v.tr. pf.                  prevent
# 11356   1884.0  prěduprěđati      NaN   v.tr. ipf.  warn, caution, admonish
# 11357  21045.0  prěduprěđati      NaN   v.tr. ipf.        notify in advance
# 11358  21046.0  prěduprěđati      NaN   v.tr. ipf.                  prevent
#
#       genesis   pos prefix verb_stem     base_verb  ... left_stem_cand  \
# 11353     NaN  verb      ?         ?  prěduprěditi  ...      prěduprěd
# 11354     NaN  verb      ?         ?  prěduprěditi  ...      prěduprěd
# 11355     NaN  verb      ?         ?  prěduprěditi  ...      prěduprěd
# 11356     NaN  verb      ?         ?  prěduprěditi  ...      prěduprěđ
# 11357     NaN  verb      ?         ?  prěduprěditi  ...      prěduprěđ
# 11358     NaN  verb      ?         ?  prěduprěditi  ...      prěduprěđ
#
#       right_stem_cand derived_nouns base_noun _prefix      _stem _suffix  \
# 11353           ?iti?                                  prěduprěd     iti
# 11354           ?iti?                                  prěduprěd     iti
# 11355           ?iti?                                  prěduprěd     iti
# 11356          ?đati?                                  prěduprěd    ⒥ati
# 11357          ?đati?                                  prěduprěd    ⒥ati
# 11358          ?đati?                                  prěduprěd    ⒥ati
#
#       _is_irregular  reconstructed aspect
# 11353             0            NaN     pf
# 11354             0            NaN     pf
# 11355             0            NaN     pf
# 11356             0            NaN    ipf
# 11357             0            NaN    ipf
# 11358             0            NaN    ipf
#
# [6 rows x 21 columns]

# %%
morphemes.query("isv.str.contains('^pr[ěoi]') and not base_verb.str.contains('^pr[ěoi]') and _prefix == ''")
# Out:
#             id                 isv addition    partOfSpeech  \
# 11405  35802.0          prěkladati      NaN      v.tr. ipf.
# 11577  21053.0               prěti    (pre)          v.ipf.
# 11706   5563.0             prijati      NaN      v.tr. ipf.
# 11707   5564.0             prijati      NaN      v.tr. ipf.
# 11734  20079.0          prikladati      NaN      v.tr. ipf.
# 11859  23860.0  prisųtstvovati pri     (+6)    v.intr. ipf.
# 11999  35326.0  profesionalizovati      NaN  v.tr. ipf./pf.
# 12017  11564.0        programovati      NaN      v.tr. ipf.
# 12053   4361.0        projektovati      NaN      v.tr. ipf.
# 12189   5479.0        protivdějati      NaN    v.intr. ipf.
#
#                                      en genesis   pos prefix verb_stem  \
# 11405                         translate     NaN  verb      ?         ?
# 11577                       push, press     NaN  verb      ?         ?
# 11706               please, be pleasant     NaN  verb      ?         ?
# 11707  favour, favor, be beneficial for     NaN  verb      ?         ?
# 11734      attach, append, apply, affix     NaN  verb      ?         ?
# 11859             attend, be present at     NaN  verb      ?         ?
# 11999  professionalise, professionalize       I  verb      ?         ?
# 12017                           program       I  verb      ?         ?
# 12053                            design       I  verb      ?         ?
# 12189                        counteract     NaN  verb      ?         ?
#
#       base_verb  ...      left_stem_cand    right_stem_cand  \
# 11405            ...             prěklad          ?kladati?
# 11577    poriti  ...                  pr                 ti
# 11706     †jati  ...                 pri             ?jati?
# 11707     †jati  ...                 pri             ?jati?
# 11734            ...             priklad          ?kladati?
# 11859      byti  ...  prisųtstvovati pri    ?tstvovati pri?
# 11999            ...       profesionaliz  ?fesionalizovati?
# 12017            ...             program        ?gramovati?
# 12053            ...             projekt        ?jektovati?
# 12189    dějati  ...            protivdě        ?tivdějati?
#
#              derived_nouns    base_noun _prefix        _stem  _suffix  \
# 11405                           prěklad              prěklad      ati
# 11577                                                     pr      ěti
# 11706                                                  prija       ti
# 11707                                                  prija       ti
# 11734                           priklad              priklad      ati
# 11859
# 11999  |profesionalizacija  profesional          profesional  izovati
# 12017                          programa              program    ovati
# 12053                           projekt              projekt    ovati
# 12189
#
#       _is_irregular  reconstructed  aspect
# 11405             0     perkladati     ipf
# 11577             0        ?poriti     ipf
# 11706             0        prijati     ipf
# 11707             0        prijati     ipf
# 11734             0     prikladati     ipf
# 11859             1          ?byti     ipf
# 11999             0         ?uměti  ipf/pf
# 12017             0         ?uměti     ipf
# 12053             0         ?uměti     ipf
# 12189             1        ?dějati     ipf
#
# [10 rows x 21 columns]

# %%
g = morphemes.query("isv.str.contains('^pr[ěoi]') and _prefix == ''")
g
# Out:
#             id                 isv addition    partOfSpeech  \
# 11240  20619.0             prěčiti      NaN      v.tr. ipf.
# 11353   3128.0        prěduprěditi      NaN       v.tr. pf.
# 11354  21047.0        prěduprěditi      NaN       v.tr. pf.
# 11355  21048.0        prěduprěditi      NaN       v.tr. pf.
# 11356   1884.0        prěduprěđati      NaN      v.tr. ipf.
# 11357  21045.0        prěduprěđati      NaN      v.tr. ipf.
# 11358  21046.0        prěduprěđati      NaN      v.tr. ipf.
# 11577  21053.0               prěti    (pre)          v.ipf.
# 11698  11436.0         prijateliti      NaN    v.refl. ipf.
# 11706   5563.0             prijati      NaN      v.tr. ipf.
# 11707   5564.0             prijati      NaN      v.tr. ipf.
# 11859  23860.0  prisųtstvovati pri     (+6)    v.intr. ipf.
# 11960  11542.0     probovati snova      NaN      v.tr. ipf.
# 11961    238.0           probovati      NaN      v.tr. ipf.
# 11990   3078.0         produkovati      NaN      v.tr. ipf.
# 11995  20091.0         profanovati      NaN      v.tr. ipf.
# 11999  35326.0  profesionalizovati      NaN  v.tr. ipf./pf.
# 12017  11564.0        programovati      NaN      v.tr. ipf.
# 12053   4361.0        projektovati      NaN      v.tr. ipf.
# 12092   5330.0         propagovati      NaN      v.tr. ipf.
# 12102   4081.0         proponovati      NaN      v.tr. ipf.
# 12119   1853.0             prositi      NaN      v.tr. ipf.
# 12137  21100.0            prostiti      NaN     v.refl. pf.
# 12138  21099.0            prostiti      NaN       v.tr. pf.
# 12162  36523.0            prošćati      NaN    v.refl. ipf.
# 12163    547.0            prošćati      NaN      v.tr. ipf.
# 12189   5479.0        protivdějati      NaN    v.intr. ipf.
# 12191   2331.0           protiviti     (+3)    v.refl. ipf.
# 12233   4978.0         provokovati      NaN      v.tr. ipf.
#
#                                                 en genesis   pos prefix  \
# 11240                     contradict, deny, negate     NaN  verb      ?
# 11353                      warn, caution, admonish     NaN  verb      ?
# 11354                            notify in advance     NaN  verb      ?
# 11355                                      prevent     NaN  verb      ?
# 11356                      warn, caution, admonish     NaN  verb      ?
# 11357                            notify in advance     NaN  verb      ?
# 11358                                      prevent     NaN  verb      ?
# 11577                                  push, press     NaN  verb      ?
# 11698                                 make friends     NaN  verb      ?
# 11706                          please, be pleasant     NaN  verb      ?
# 11707             favour, favor, be beneficial for     NaN  verb      ?
# 11859                        attend, be present at     NaN  verb      ?
# 11960                                        retry     NaN  verb      ?
# 11961                          try, attempt, taste     NaN  verb      ?
# 11990                                      produce       I  verb      ?
# 11995                                      profane       I  verb      ?
# 11999             professionalise, professionalize       I  verb      ?
# 12017                                      program       I  verb      ?
# 12053                                       design       I  verb      ?
# 12092                          propagate, advocate       I  verb      ?
# 12102                                      propose       I  verb      ?
# 12119                            ask, require, beg     NaN  verb      ?
# 12137  say goodbye, bid farewell, take one’s leave     NaN  verb      ?
# 12138                                      forgive     NaN  verb      ?
# 12162  say goodbye, bid farewell, take one’s leave     NaN  verb      ?
# 12163                                      forgive     NaN  verb      ?
# 12189                                   counteract     NaN  verb      ?
# 12191                                       oppose     NaN  verb      ?
# 12233                                      provoke       I  verb      ?
#
#       verb_stem     base_verb  ...      left_stem_cand    right_stem_cand  \
# 11240         ?       prěčiti  ...                prěč             ?čiti?
# 11353         ?  prěduprěditi  ...           prěduprěd              ?iti?
# 11354         ?  prěduprěditi  ...           prěduprěd              ?iti?
# 11355         ?  prěduprěditi  ...           prěduprěd              ?iti?
# 11356         ?  prěduprěditi  ...           prěduprěđ             ?đati?
# 11357         ?  prěduprěditi  ...           prěduprěđ             ?đati?
# 11358         ?  prěduprěditi  ...           prěduprěđ             ?đati?
# 11577         ?        poriti  ...                  pr                 ti
# 11698         ?   prijateliti  ...            prijatel         ?jateliti?
# 11706         ?         †jati  ...                 pri             ?jati?
# 11707         ?         †jati  ...                 pri             ?jati?
# 11859         ?          byti  ...  prisųtstvovati pri    ?tstvovati pri?
# 11960         ?     probovati  ...     probovati snova     ?bovati snova?
# 11961         ?     probovati  ...                prob           ?bovati?
# 11990         ?   produkovati  ...              produk         ?dukovati?
# 11995         ?   profanovati  ...              profan         ?fanovati?
# 11999         ?                ...       profesionaliz  ?fesionalizovati?
# 12017         ?                ...             program        ?gramovati?
# 12053         ?  projektovati  ...             projekt        ?jektovati?
# 12092         ?   propagovati  ...              propag         ?pagovati?
# 12102         ?   proponovati  ...              propon           ?novati?
# 12119         ?       prositi  ...                pros              ?iti?
# 12137         ?      prostiti  ...               prost             ?titi?
# 12138         ?      prostiti  ...               prost             ?titi?
# 12162         ?      prostiti  ...               prošć            ?šćati?
# 12163         ?      prostiti  ...               prošć            ?šćati?
# 12189         ?        dějati  ...            protivdě        ?tivdějati?
# 12191         ?     protiviti  ...              protiv           ?tiviti?
# 12233         ?   provokovati  ...              provok             kovati
#
#              derived_nouns    base_noun _prefix        _stem  _suffix  \
# 11240             |prěčnik                              prěč      iti
# 11353                                              prěduprěd      iti
# 11354                                              prěduprěd      iti
# 11355                                              prěduprěd      iti
# 11356                                              prěduprěd     ⒥ati
# 11357                                              prěduprěd     ⒥ati
# 11358                                              prěduprěd     ⒥ati
# 11577                                                     pr      ěti
# 11698                                               prijatel      iti
# 11706                                                  prija       ti
# 11707                                                  prija       ti
# 11859
# 11960                                                  probo     vati
# 11961                             proba                probo     vati
# 11990          |produkcija                            produk    ovati
# 11995         |profanacija                            profan    ovati
# 11999  |profesionalizacija  profesional          profesional  izovati
# 12017                          programa              program    ovati
# 12053                           projekt              projekt    ovati
# 12092          |propaganda                            propag    ovati
# 12102                                                 propon    ovati
# 12119                                                   prꜵs      iti
# 12137            |prostosť                             prost      iti
# 12138            |prostosť                             prost      iti
# 12162                                                  prost     ⒥ati
# 12163                                                  prost     ⒥ati
# 12189
# 12191           |protivnik                            protiv      iti
# 12233         |provokacija                            provok    ovati
#
#       _is_irregular  reconstructed  aspect
# 11240             0        perčiti     ipf
# 11353             0            NaN      pf
# 11354             0            NaN      pf
# 11355             0            NaN      pf
# 11356             0            NaN     ipf
# 11357             0            NaN     ipf
# 11358             0            NaN     ipf
# 11577             0        ?poriti     ipf
# 11698             0            NaN     ipf
# 11706             0        prijati     ipf
# 11707             0        prijati     ipf
# 11859             1          ?byti     ipf
# 11960             0            NaN     ipf
# 11961             0            NaN     ipf
# 11990             0            NaN     ipf
# 11995             0            NaN     ipf
# 11999             0         ?uměti  ipf/pf
# 12017             0         ?uměti     ipf
# 12053             0         ?uměti     ipf
# 12092             0            NaN     ipf
# 12102             0            NaN     ipf
# 12119             0        prositi     ipf
# 12137             0       prostiti      pf
# 12138             0       prostiti      pf
# 12162             0      ?prostiti     ipf
# 12163             0      ?prostiti     ipf
# 12189             1        ?dějati     ipf
# 12191             0            NaN     ipf
# 12233             0            NaN     ipf
#
# [29 rows x 21 columns]

# %%
vc = g.base_verb.value_counts()
vc[vc > 1]
# Out:
# prěduprěditi    6
# prostiti        4
#                 2
# †jati           2
# probovati       2
# Name: base_verb, dtype: int64

# %%
g1 = morphemes.query("base_verb.str.contains('prašć')")
manual_insert_g(g1, "prast", last_cons={'ć', 't'}, dry_run=0)
set_base_verb(g1, 'prostiti')
# Out:
# oprašćati = o prast ⒥ati
# prašćati =  prast ⒥ati
# prašćati =  prast ⒥ati

# %%
g1 = morphemes.query("base_verb.str.contains('vŕ[tć]')")
manual_insert_g(g1, "vŕt", last_cons={'ć', 't'}, dry_run=0)
set_base_verb(g1, 'vŕtěti')

#morphemes.loc[g1.index, 'base_noun'] = 'inako'

#'vŕtěti'
g1 = morphemes.query("isv.str.contains('zemj')")
morphemes.loc[
    g1.index,
    'base_noun'
] = 'zemja'
manual_insert_g(g1, "zemj", dry_run=0)
set_base_verb(g1, '†zemjiti')


morphemes.loc[
    morphemes.query("isv == 'travmatizovati'").index,
    'base_noun'
] = 'travma'

g1 = morphemes.query("isv.str.contains('nik') and isv != 'komunikovati'")
manual_insert_g(g1, "nik", dry_run=0)
set_base_verb(g1, '†niknųti')

g1 = morphemes.query("isv.str.contains('hytr')")
manual_insert_g(g1, "hytr", dry_run=0)
set_base_verb(g1, '†hytriti')

g1 = morphemes.query("isv.str.contains('trav') and isv != 'travmatizovati'")
manual_insert_g(g1, "trav", dry_run=0)
set_base_verb(g1, '†traviti')
# Out:
# provŕćati = pro vŕt ⒥ati
# provŕtiti = pro vŕt iti
# vŕtěti =  vŕt ěti
# vŕtěti =  vŕt ěti
# vŕtěti =  vŕt ěti
# zavŕtěti = za vŕt ěti
# prizemjati = pri zemj ati
# prizemjiti = pri zemj iti
# izniknųti = iz nik nųti
# pronikati = pro nik ati
# proniknųti = pro nik nųti
# vnikati = v nik ati
# vniknųti = v nik nųti
# vȯznikati = vȯz nik ati
# vȯznikati = vȯz nik ati
# vȯzniknųti = vȯz nik nųti
# vȯzniknųti = vȯz nik nųti
# prěhytriti = prě hytr iti
# prěhytrjati = prě hytr jati
# otraviti = o trav iti
# otravjati = o trav jati
# prětraviti = prě trav iti
# prětravjati = prě trav jati

# %%
# morphemes.query("isv.str.contains('vyk(a|nų)ti') and not isv == 'vykati' ")
# Out:
#             id           isv addition  partOfSpeech                  en  \
# 4131   26209.0     izniknųti      NaN   v.intr. pf.   disappear, vanish
# 5168    1277.0  komunikovati      NaN  v.intr. ipf.         communicate
# 12085   4454.0     pronikati      NaN  v.intr. ipf.  pervade, penetrate
# 12087   4455.0    proniknųti      NaN   v.intr. pf.  pervade, penetrate
# 16542  20795.0       vnikati      NaN  v.intr. ipf.       arise, emerge
# 16543  20798.0      vniknųti      NaN   v.intr. pf.       arise, emerge
# 16732  15156.0     vȯznikati      NaN  v.intr. ipf.           originate
# 16733  20801.0     vȯznikati      NaN  v.intr. ipf.       arise, emerge
# 16735  20803.0    vȯzniknųti      NaN   v.intr. pf.               arise
# 16736  20804.0    vȯzniknųti      NaN   v.intr. pf.              emerge
#
#       genesis   pos prefix verb_stem     base_verb  ... left_stem_cand  \
# 4131      NaN  verb      ?         ?      †niknųti  ...          iznik
# 5168        I  verb      ?         ?  komunikovati  ...        komunik
# 12085     NaN  verb      ?         ?     pronikati  ...         pronik
# 12087     NaN  verb      ?         ?     pronikati  ...         pronik
# 16542     NaN  verb      ?         ?       vnikati  ...           vnik
# 16543     NaN  verb      ?         ?       vnikati  ...           vnik
# 16732     NaN  verb   vȯz’    nikati     vȯznikati  ...         vȯznik
# 16733     NaN  verb   vȯz’    nikati     vȯznikati  ...         vȯznik
# 16735     NaN  verb   vȯz’   niknųti     vȯznikati  ...         vȯznik
# 16736     NaN  verb   vȯz’   niknųti     vȯznikati  ...         vȯznik
#
#       right_stem_cand  derived_nouns base_noun _prefix    _stem _suffix  \
# 4131        ?niknųti?                               iz      nik    nųti
# 5168     komunikovati  |komunikacija                    komunik   ovati
# 12085        ?nikati?                                    pronik     ati
# 12087       ?niknųti?                                    pronik    nųti
# 16542        ?nikati?                                      vnik     ati
# 16543       ?niknųti?                                      vnik    nųti
# 16732        ?nikati?                              vȯz      nik     ati
# 16733        ?nikati?                              vȯz      nik     ati
# 16735       ?niknųti?                              vȯz      nik    nųti
# 16736       ?niknųti?                              vȯz      nik    nųti
#
#       _is_irregular  reconstructed aspect
# 4131              0       ?niknǫti     pf
# 5168              0            NaN    ipf
# 12085             0            NaN    ipf
# 12087             0            NaN     pf
# 16542             0            NaN    ipf
# 16543             0            NaN     pf
# 16732             0            NaN    ipf
# 16733             0            NaN    ipf
# 16735             0            NaN     pf
# 16736             0            NaN     pf
#
# [10 rows x 21 columns]

# %%
g1 = morphemes.query("base_verb.str.contains('mě[tć]iti')")
move_prefix(g1, 'pri')
morphemes.loc[g1.index, 'reconstructed'] = "(" + morphemes.loc[g1.index, '_prefix'] + ")+" + 'mětiti'
# Out:
# C:\Users\79165\AppData\Local\Temp\ipykernel_25148\3700476200.py:4: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   morphemes.loc[g.index, '_stem'] = g._stem.str[len(prefix):]
# C:\Users\79165\AppData\Local\Temp\ipykernel_25148\2999832909.py:3: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   morphemes.loc[g1.index, 'reconstructed'] = "(" + morphemes.loc[g1.index, '_prefix'] + ")+" + 'mětiti'

# %%
g1 = morphemes.query("isv.str.contains('inač')")

manual_insert_g(g1, "inak", last_cons={'č', 'k'}, dry_run=0)
set_base_verb(g1, '†inačiti')
morphemes.loc[g1.index, 'base_noun'] = 'inako'
morphemes.loc[g1.index]
# Out:
# prěinačati = prě inak ⒥ati
# prěinačiti = prě inak ⒥iti
#             id         isv addition partOfSpeech     en genesis   pos prefix  \
# 11395  18420.0  prěinačati      NaN   v.tr. ipf.  alter     NaN  verb      ?
# 11398  18423.0  prěinačiti      NaN    v.tr. pf.  alter     NaN  verb      ?
#
#       verb_stem base_verb  ... left_stem_cand right_stem_cand derived_nouns  \
# 11395         ?  †inačiti  ...        prěinač       ?inačati?
# 11398         ?  †inačiti  ...        prěinač       ?inačiti?
#
#       base_noun _prefix _stem _suffix _is_irregular  reconstructed aspect
# 11395     inako     prě  inak    ⒥ati             0            NaN    ipf
# 11398     inako     prě  inak    ⒥iti             0            NaN     pf
#
# [2 rows x 21 columns]

# %%
for v1 in vc[vc > 1].index:
    v = v1[3:]
    if v == '': continue
    if any(morphemes.isv == v) or any(morphemes.base_verb == v):
        print(v, v1)
        stem_ = None
        for g_cand in [morphemes[morphemes.isv == v], morphemes[morphemes.base_verb == v]]:
            if len(g_cand):
                stem_ = g_cand._stem.unique()
                if len(stem_) == 1:
                    stem = stem_[0]
                # print(g_cand)
        
        g1 = morphemes[morphemes.base_verb == v1]
        manual_insert_g(g1, stem, dry_run=0, last_cons={"š"})
        set_base_verb(g1, v)
# Out:
# větriti provětriti
# provětriti = pro větr iti
# provětrjati = pro větr jati
# vabiti privabiti
# privabiti = pri vab iti
# privabjati = pri vab jati
# sęgati prisęgati
# prisęgati = pri sęg ati
# prisęgnųti = pri sęg nųti
# vŕgati provŕgati
# provŕgati = pro vŕg ati
# provŕgnųti = pro vŕg nųti
# stigati prěstigati
# prěstigati = prě stig ati
# prěstignųti = prě stig nųti
# slušati prěslušati
# prěslušati = prě sluh ⒥ati
# prěslušivati = prě sluh ⒥ivati
# variti prěvariti
# prěvariti = prě var iti
# prěvarjati = prě var jati

# %%
g1 = morphemes.query("base_verb.str.contains('brěgti')")
manual_insert_g(g1, "brěg", dry_run=0)
set_base_verb(g1, 'brěgti')
morphemes.loc[g1.index, 'reconstructed'] = "(" + morphemes.loc[g1.index, '_prefix'] + ")+" + 'berťi'
# Out:
# prěnebrěgati = prěne brěg ati
# prěnebrěgti = prěne brěg ti
# C:\Users\79165\AppData\Local\Temp\ipykernel_25148\3521196858.py:4: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   morphemes.loc[g1.index, 'reconstructed'] = "(" + morphemes.loc[g1.index, '_prefix'] + ")+" + 'berťi'

# %%
BV = ['prisjediniti', 'prostiti', 'privykati', 'prěseliti', 'prilųčati']
morphemes.query("base_verb in @BV").sort_values(by='base_verb')
# Out:
#             id            isv addition  partOfSpeech  \
# 11747  36903.0      prilųčati      NaN  v.refl. ipf.
# 11748  36897.0      prilųčati      NaN    v.tr. ipf.
# 11749  36900.0      prilųčiti      NaN   v.refl. pf.
# 11750  36894.0      prilųčiti      NaN     v.tr. pf.
# 11822  36896.0   prisjediniti      NaN     v.tr. pf.
# 11821  36902.0   prisjediniti      NaN   v.refl. pf.
# 11823  36905.0  prisjedinjati      NaN  v.refl. ipf.
# 11824  36899.0  prisjedinjati      NaN    v.tr. ipf.
# 11929    351.0     privyknųti      NaN     v.tr. pf.
# 11928  11520.0     privyknųti      NaN   v.refl. pf.
# 11925   1268.0      privykati      NaN    v.tr. ipf.
# 11924  11519.0      privykati      NaN  v.refl. ipf.
# 12138  21099.0       prostiti      NaN     v.tr. pf.
# 12137  21100.0       prostiti      NaN   v.refl. pf.
# 9437    2132.0      oprostiti      NaN     v.tr. pf.
# 12162  36523.0       prošćati      NaN  v.refl. ipf.
# 12163    547.0       prošćati      NaN    v.tr. ipf.
# 11520  11353.0     prěseljati      NaN    v.tr. ipf.
# 11519  32968.0     prěseljati      NaN  v.refl. ipf.
# 11518  11352.0      prěseliti      NaN     v.tr. pf.
# 11517  32969.0      prěseliti      NaN   v.refl. pf.
#
#                                                 en genesis   pos prefix  \
# 11747                                join, connect     NaN  verb      ?
# 11748                              connect, attach     NaN  verb      ?
# 11749                                join, connect     NaN  verb      ?
# 11750                              connect, attach     NaN  verb      ?
# 11822                              connect, attach     NaN  verb      ?
# 11821                                join, connect     NaN  verb      ?
# 11823                                join, connect     NaN  verb      ?
# 11824                              connect, attach     NaN  verb      ?
# 11929                              accustom, inure     NaN  verb      ?
# 11928                                get used (to)     NaN  verb      ?
# 11925                              accustom, inure     NaN  verb      ?
# 11924                                get used (to)     NaN  verb      ?
# 12138                                      forgive     NaN  verb      ?
# 12137  say goodbye, bid farewell, take one’s leave     NaN  verb      ?
# 9437                                      simplify     NaN  verb      ?
# 12162  say goodbye, bid farewell, take one’s leave     NaN  verb      ?
# 12163                                      forgive     NaN  verb      ?
# 11520                                      migrate     NaN  verb      ?
# 11519                      move (change residence)     NaN  verb      ?
# 11518                                      migrate     NaN  verb      ?
# 11517                      move (change residence)     NaN  verb      ?
#
#       verb_stem     base_verb  ... left_stem_cand right_stem_cand  \
# 11747         ?     prilųčati  ...         prilųč        ?lųčati?
# 11748         ?     prilųčati  ...         prilųč        ?lųčati?
# 11749         ?     prilųčati  ...         prilųč        ?lųčiti?
# 11750         ?     prilųčati  ...         prilųč        ?lųčiti?
# 11822         ?  prisjediniti  ...      prisjedin       sjediniti
# 11821         ?  prisjediniti  ...      prisjedin       sjediniti
# 11823         ?  prisjediniti  ...      prisjedin      sjedinjati
# 11824         ?  prisjediniti  ...      prisjedin      sjedinjati
# 11929         ?     privykati  ...         privyk         ?knųti?
# 11928         ?     privykati  ...         privyk         ?knųti?
# 11925         ?     privykati  ...         privyk            kati
# 11924         ?     privykati  ...         privyk            kati
# 12138         ?      prostiti  ...          prost          ?titi?
# 12137         ?      prostiti  ...          prost          ?titi?
# 9437          ?      prostiti  ...         oprost        prostiti
# 12162         ?      prostiti  ...          prošć         ?šćati?
# 12163         ?      prostiti  ...          prošć         ?šćati?
# 11520         ?     prěseliti  ...         prěsel        ?eljati?
# 11519         ?     prěseliti  ...         prěsel        ?eljati?
# 11518         ?     prěseliti  ...         prěsel          seliti
# 11517         ?     prěseliti  ...         prěsel          seliti
#
#       derived_nouns base_noun _prefix      _stem _suffix _is_irregular  \
# 11747                                     prilųč     ati             0
# 11748                                     prilųč     ati             0
# 11749                                     prilųč     iti             0
# 11750                                     prilųč     iti             0
# 11822                                  prisjedin     iti             0
# 11821                                  prisjedin     iti             0
# 11823                                  prisjedin    jati             0
# 11824                                  prisjedin    jati             0
# 11929                                     privyk    nųti             0
# 11928                                     privyk    nųti             0
# 11925                                     privyk     ati             0
# 11924                                     privyk     ati             0
# 12138     |prostosť                        prost     iti             0
# 12137     |prostosť                        prost     iti             0
# 9437                               ¬o      prost     iti             0
# 12162                                      prost    ⒥ati             0
# 12163                                      prost    ⒥ati             0
# 11520                                     prěsel    jati             0
# 11519                                     prěsel    jati             0
# 11518                                     prěsel     iti             0
# 11517                                     prěsel     iti             0
#
#        reconstructed aspect
# 11747            NaN    ipf
# 11748            NaN    ipf
# 11749            NaN     pf
# 11750            NaN     pf
# 11822            NaN     pf
# 11821            NaN     pf
# 11823            NaN    ipf
# 11824            NaN    ipf
# 11929     privyknǫti     pf
# 11928     privyknǫti     pf
# 11925    ?privyknǫti    ipf
# 11924    ?privyknǫti    ipf
# 12138       prostiti     pf
# 12137       prostiti     pf
# 9437    (o)+prostiti     pf
# 12162      ?prostiti    ipf
# 12163      ?prostiti    ipf
# 11520            NaN    ipf
# 11519            NaN    ipf
# 11518            NaN     pf
# 11517            NaN     pf
#
# [21 rows x 21 columns]

# %%
g1 = morphemes.query("isv.str.contains('klast') and not isv.str.contains(' ')")
g1
# Out:
#          id     isv addition partOfSpeech        en genesis   pos prefix  \
# 4925  901.0  klasti  (klade)   v.tr. ipf.  put, lay     NaN  verb      ?
#
#      verb_stem base_verb  ... left_stem_cand right_stem_cand derived_nouns  \
# 4925         ?    klasti  ...         klasti          klasti
#
#      base_noun _prefix _stem _suffix _is_irregular  reconstructed aspect
# 4925                    klas      ti             0         klasti    ipf
#
# [1 rows x 21 columns]

# %%
g1 = morphemes.query("base_verb.str.contains('lųč[ai]ti')").sort_values(by='base_verb')
manual_insert_g(g1, "lųč", dry_run=0)
set_base_verb(g1, 'lųčiti')
morphemes.loc[g1.index, 'reconstructed'] = "(" + morphemes.loc[g1.index, '_prefix'] + ")+" + 'lǫčiti'
# Out:
# prilųčati = pri lųč ati
# prilųčati = pri lųč ati
# prilųčiti = pri lųč iti
# prilųčiti = pri lųč iti
# råzlųčati = raz lųč ati
# råzlųčiti = raz lųč iti
# slųčati = s lųč ati
# slųčiti = s lųč iti
# C:\Users\79165\AppData\Local\Temp\ipykernel_25148\1664909749.py:4: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   morphemes.loc[g1.index, 'reconstructed'] = "(" + g1._prefix + ")+" + 'lǫčiti'

# %%
morphemes.loc[g1.index]
# Out:
#             id        isv addition  partOfSpeech                     en  \
# 11747  36903.0  prilųčati      NaN  v.refl. ipf.          join, connect
# 11748  36897.0  prilųčati      NaN    v.tr. ipf.        connect, attach
# 11749  36900.0  prilųčiti      NaN   v.refl. pf.          join, connect
# 11750  36894.0  prilųčiti      NaN     v.tr. pf.        connect, attach
# 12676  20108.0  råzlųčati      NaN    v.tr. ipf.               separate
# 12678  20109.0  råzlųčiti      NaN     v.tr. pf.               separate
# 13916  20162.0    slųčati      NaN    v.tr. ipf.  join, combine, couple
# 13918  20166.0    slųčiti      NaN     v.tr. pf.  join, combine, couple
#
#       genesis   pos prefix verb_stem base_verb  ... left_stem_cand  \
# 11747     NaN  verb      ?         ?    lųčiti  ...         prilųč
# 11748     NaN  verb      ?         ?    lųčiti  ...         prilųč
# 11749     NaN  verb      ?         ?    lųčiti  ...         prilųč
# 11750     NaN  verb      ?         ?    lųčiti  ...         prilųč
# 12676     NaN  verb   råz’    lųčati    lųčiti  ...         råzlųč
# 12678     NaN  verb   råz’    lųčiti    lųčiti  ...         råzlųč
# 13916     NaN  verb      ?         ?    lųčiti  ...           slųč
# 13918     NaN  verb      ?         ?    lųčiti  ...           slųč
#
#       right_stem_cand derived_nouns base_noun _prefix _stem _suffix  \
# 11747        ?lųčati?                             pri   lųč     ati
# 11748        ?lųčati?                             pri   lųč     ati
# 11749        ?lųčiti?                             pri   lųč     iti
# 11750        ?lųčiti?                             pri   lųč     iti
# 12676        ?lųčati?    |råzlųčnik               raz   lųč     ati
# 12678        ?lųčiti?    |råzlųčnik               raz   lųč     iti
# 13916        ?lųčati?                               s   lųč     ati
# 13918        ?lųčiti?                               s   lųč     iti
#
#       _is_irregular  reconstructed aspect
# 11747             0   (pri)+lǫčiti    ipf
# 11748             0   (pri)+lǫčiti    ipf
# 11749             0   (pri)+lǫčiti     pf
# 11750             0   (pri)+lǫčiti     pf
# 12676             0   (raz)+lǫčiti    ipf
# 12678             0   (raz)+lǫčiti     pf
# 13916             0     (s)+lǫčiti    ipf
# 13918             0     (s)+lǫčiti     pf
#
# [8 rows x 21 columns]

# %%
g1 = morphemes.query("isv.str.contains('vyk(a|nų)ti') and not isv == 'vykati' ")
manual_insert_g(g1, "vyk", dry_run=0)
set_base_verb(g1, 'vyknųti')

g1 = morphemes.query("isv.str.contains('jedin')")
manual_insert_g(g1, "jedin", dry_run=0)
set_base_verb(g1, 'jediniti')

g1 = morphemes.query("isv.str.contains('sel') and not isv.str.contains('vesel')")
manual_insert_g(g1, "sel", dry_run=0)
set_base_verb(g1, 'seliti')

g1 = morphemes.query("isv.str.contains('klad') and not isv.str.contains(' ')")
manual_insert_g(g1, "klad", dry_run=0)
set_base_verb(g1, 'klasti')

set_base_verb(
    morphemes.query("isv.str.contains('projekt') "), 
    'projektovati'
)

set_base_verb(
    morphemes.query("isv.str.contains('sel') and isv.str.contains('vesel')"),
    'veseliti'
)
# Out:
# odvykati = od vyk ati
# odvykati = od vyk ati
# odvyknųti = od vyk nųti
# odvyknųti = od vyk nųti
# privykati = pri vyk ati
# privykati = pri vyk ati
# privyknųti = pri vyk nųti
# privyknųti = pri vyk nųti
# objediniti = ob jedin iti
# objedinjati = ob jedin jati
# prisjediniti = pris jedin iti
# prisjediniti = pris jedin iti
# prisjedinjati = pris jedin jati
# prisjedinjati = pris jedin jati
# råzjediniti = raz jedin iti
# råzjedinjati = raz jedin jati
# sjediniti = s jedin iti
# sjediniti = s jedin iti
# sjediniti = s jedin iti
# sjedinjati = s jedin jati
# sjedinjati = s jedin jati
# sjedinjati = s jedin jati
# ujediniti = u jedin iti
# ujedinjati = u jedin jati
# izseliti = iz sel iti
# izseliti = iz sel iti
# izseljati = iz sel jati
# izseljati = iz sel jati
# naseliti = na sel iti
# naseljati = na sel jati
# oseliti = o sel iti
# prěseliti = prě sel iti
# prěseliti = prě sel iti
# prěseljati = prě sel jati
# prěseljati = prě sel jati
# seliti =  sel iti
# dokladati = do klad ati
# izkladati = iz klad ati
# nakladati = na klad ati
# nakladati = na klad ati
# odkladati = od klad ati
# odkladati = od klad ati
# podkladati = pod klad ati
# pokladati = po klad ati
# prědkladati = prěd klad ati
# prědpokladati = prědpo klad ati
# prěkladati = prě klad ati
# prikladati = pri klad ati
# råzkladati = raz klad ati
# råzkladati = raz klad ati
# skladati = s klad ati
# skladati = s klad ati
# skladati = s klad ati
# skladovati = s klad ovati
# vkladati = v klad ati
# zakladati = za klad ati
# zakladati = za klad ati
# C:\Users\79165\AppData\Local\Temp\ipykernel_25148\2467056144.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   g1 = morphemes.query("isv.str.contains('vyk(a|nų)ti') and not isv == 'vykati' ")

# %%
morphemes.query("isv.str.contains('sel') and isv.str.contains('vesel')")
# Out:
#             id           isv addition  partOfSpeech                en genesis  \
# 11030  11074.0    poveseliti      NaN   v.refl. pf.   enjoy, have fun     NaN
# 12982  30580.0   råzveseliti      NaN     v.tr. pf.   amuse, cheer up     NaN
# 12983  30581.0  råzveseljati      NaN    v.tr. ipf.   amuse, cheer up     NaN
# 16294   3583.0      veseliti      NaN  v.refl. ipf.  #enjoy, have fun     NaN
# 16295  13581.0      veseliti      NaN    v.tr. ipf.         #liven up     NaN
#
#         pos prefix  verb_stem    base_verb  ... left_stem_cand  \
# 11030  verb      ?          ?     veseliti  ...        povesel
# 12982  verb   råz’   veseliti  råzveseliti  ...       råzvesel
# 12983  verb   råz’  veseljati  råzveseliti  ...       råzvesel
# 16294  verb      ?          ?     veseliti  ...          vesel
# 16295  verb      ?          ?     veseliti  ...          vesel
#
#       right_stem_cand      derived_nouns base_noun _prefix  _stem _suffix  \
# 11030        veseliti                                  ¬po  vesel     iti
# 12982        veseliti                                 ¬råz  vesel     iti
# 12983      ?eseljati?                                 ¬råz  vesel    jati
# 16294       ?eseliti?  |veseľje|veselosť                    vesel     iti
# 16295       ?eseliti?  |veseľje|veselosť                    vesel     iti
#
#       _is_irregular  reconstructed aspect
# 11030             0            NaN     pf
# 12982             0            NaN     pf
# 12983             0            NaN    ipf
# 16294             0            NaN    ipf
# 16295             0            NaN    ipf
#
# [5 rows x 21 columns]

# %%
#BV = morphemes.query("isv.str.contains('kla(d|st|d)')").base_verb.unique()

#morphemes.query("base_verb in @BV and base_verb != ''")

morphemes.query("isv.str.contains('projekt') ")
# Out:
#             id             isv addition partOfSpeech      en genesis   pos  \
# 12053   4361.0    projektovati      NaN   v.tr. ipf.  design       I  verb
# 17406  20833.0  zaprojektovati      NaN    v.tr. pf.  design       I  verb
#
#       prefix verb_stem     base_verb  ... left_stem_cand right_stem_cand  \
# 12053      ?         ?                ...        projekt     ?jektovati?
# 17406      ?         ?  projektovati  ...      zaprojekt    projektovati
#
#       derived_nouns base_noun _prefix    _stem _suffix _is_irregular  \
# 12053                 projekt          projekt   ovati             0
# 17406                             ¬za  projekt   ovati             0
#
#        reconstructed aspect
# 12053         ?uměti    ipf
# 17406            NaN     pf
#
# [2 rows x 21 columns]

# %%
g[g.base_verb == '']
# Out:
#             id                 isv addition    partOfSpeech  \
# 11405  35802.0          prěkladati      NaN      v.tr. ipf.
# 11734  20079.0          prikladati      NaN      v.tr. ipf.
# 11999  35326.0  profesionalizovati      NaN  v.tr. ipf./pf.
# 12017  11564.0        programovati      NaN      v.tr. ipf.
# 12053   4361.0        projektovati      NaN      v.tr. ipf.
#
#                                      en genesis   pos prefix verb_stem  \
# 11405                         translate     NaN  verb      ?         ?
# 11734      attach, append, apply, affix     NaN  verb      ?         ?
# 11999  professionalise, professionalize       I  verb      ?         ?
# 12017                           program       I  verb      ?         ?
# 12053                            design       I  verb      ?         ?
#
#       base_verb  ... left_stem_cand    right_stem_cand        derived_nouns  \
# 11405            ...        prěklad          ?kladati?
# 11734            ...        priklad          ?kladati?
# 11999            ...  profesionaliz  ?fesionalizovati?  |profesionalizacija
# 12017            ...        program        ?gramovati?
# 12053            ...        projekt        ?jektovati?
#
#          base_noun _prefix        _stem  _suffix _is_irregular  reconstructed  \
# 11405      prěklad              prěklad      ati             0     perkladati
# 11734      priklad              priklad      ati             0     prikladati
# 11999  profesional          profesional  izovati             0         ?uměti
# 12017     programa              program    ovati             0         ?uměti
# 12053      projekt              projekt    ovati             0         ?uměti
#
#        aspect
# 11405     ipf
# 11734     ipf
# 11999  ipf/pf
# 12017     ipf
# 12053     ipf
#
# [5 rows x 21 columns]

# %%
for v1 in g.base_verb.unique():
    v = v1[3:]
    if any(morphemes.isv == v) or any(morphemes.base_verb == v):
        print(v, v1)
        print(morphemes[morphemes.isv == v].base_verb)
        #stem = morphemes[morphemes.isv == v]._stem.values[0]
        #print(stem)
        print(morphemes[morphemes.base_verb == v].shape)
        
        #g1 = morphemes[morphemes.base_verb == "iz" + v]
        #manual_insert_g(g1, stem, dry_run=0, last_cons={"h", "š"})
        #set_base_verb(g1, v)
# Out:
#
# Series([], Name: base_verb, dtype: object)
# (123, 21)
# seliti prěseliti
# 13526    seliti
# Name: base_verb, dtype: object
# (6, 21)
# slušati prěslušati
# 13925    slušati
# Name: base_verb, dtype: object
# (7, 21)
# stigati prěstigati
# 14443    stigati
# 14444    stigati
# Name: base_verb, dtype: object
# (4, 21)
# variti prěvariti
# 16110    vrěti
# Name: base_verb, dtype: object
# (0, 21)
# sęgati prisęgati
# 13481    sęgati
# Name: base_verb, dtype: object
# (2, 21)
# sjediniti prisjediniti
# 13679    sjediniti
# 13680    sjediniti
# 13681    sjediniti
# Name: base_verb, dtype: object
# (6, 21)
# vabiti privabiti
# 16060    vabiti
# Name: base_verb, dtype: object
# (2, 21)
# vykati privykati
# 17010    kati
# Name: base_verb, dtype: object
# (0, 21)
# větriti provětriti
# 16326
# Name: base_verb, dtype: object
# (0, 21)
# vŕgati provŕgati
# 16855    vŕgati
# Name: base_verb, dtype: object
# (2, 21)

# %%
morphemes.query("_prefix == '' and isv.str.contains('^(ob|pod|za|od|u|do)')").sort_values(by='base_verb')
# Out:
# C:\Users\79165\AppData\Local\Temp\ipykernel_25148\2888902305.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   morphemes.query("_prefix == '' and isv.str.contains('^(ob|pod|za|od|u|do)')").sort_values(by='base_verb')
#             id         isv addition    partOfSpeech  \
# 17544  31583.0    zavěćati      NaN  v.tr. ipf./pf.
# 8415    5740.0    obmanųti      NaN       v.tr. pf.
# 8419   18014.0  obmanyvati      NaN      v.tr. ipf.
# 8510   22681.0    obråtiti     (+3)     v.refl. pf.
# 8511   22675.0    obråtiti      NaN     v.refl. pf.
# ...        ...         ...      ...             ...
# 17110  14041.0    začinati      NaN      v.tr. ipf.
# 8443   28845.0    obnažiti      NaN     v.refl. pf.
# 8444    5320.0    obnažiti      NaN       v.tr. pf.
# 8441    5321.0    obnažati      NaN    v.refl. ipf.
# 8442   33746.0    obnažati      NaN      v.tr. ipf.
#
#                                           en genesis   pos prefix verb_stem  \
# 17544                bequeath, leave by will     NaN  verb      ?         ?
# 8415   con, cheat, delude, deceive, hoodwink     NaN  verb      ?         ?
# 8419                                    fool     NaN  verb      ?         ?
# 8510                      address, appeal to     NaN  verb      ?         ?
# 8511               turn (intr.), turn around     NaN  verb      ?         ?
# ...                                      ...     ...   ...    ...       ...
# 17110       begin (tr.), start (tr.), embark     NaN  verb      ?         ?
# 8443                                   strip     NaN  verb      ?         ?
# 8444                          denude, expose     NaN  verb      ?         ?
# 8441                                   strip     NaN  verb      ?         ?
# 8442                          denude, expose     NaN  verb      ?         ?
#
#       base_verb  ... left_stem_cand right_stem_cand derived_nouns base_noun  \
# 17544            ...          zavěć         ?ěćati?                   zavět
# 8415             ...           obma        ?manųti?                   obman
# 8419             ...          obman      ?manyvati?     |obmannik     obman
# 8510             ...          obråt        ?råtiti?                   obråt
# 8511             ...          obråt        ?råtiti?                   obråt
# ...         ...  ...            ...             ...           ...       ...
# 17110  začinati  ...          začin        ?činati?
# 8443    †nažiti  ...          obnaž            žiti
# 8444    †nažiti  ...          obnaž            žiti
# 8441    †nažiti  ...          obnaž          ?žati?
# 8442    †nažiti  ...          obnaž          ?žati?
#
#       _prefix  _stem _suffix _is_irregular  reconstructed  aspect
# 17544          zavět    ⒥ati             0         ?uměti  ipf/pf
# 8415           obman     ųti             0         ?uměti      pf
# 8419           obman   yvati             0         ?uměti     ipf
# 8510           obråt     iti             0    ob(v)ortiti      pf
# 8511           obråt     iti             0    ob(v)ortiti      pf
# ...       ...    ...     ...           ...            ...     ...
# 17110          začin     ati             0        ?začęti     ipf
# 8443           obnaž     iti             0            NaN      pf
# 8444           obnaž     iti             0            NaN      pf
# 8441           obnaž     ati             0            NaN     ipf
# 8442           obnaž     ati             0            NaN     ipf
#
# [130 rows x 21 columns]

# %%
#začinati

# %%
morphemes.query("_prefix == '' and isv.str.contains('^(pod|do)')").sort_values(by='base_verb')
# Out:
# C:\Users\79165\AppData\Local\Temp\ipykernel_25148\2912944281.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   morphemes.query("_prefix == '' and isv.str.contains('^(pod|do)')").sort_values(by='base_verb')
#             id            isv     addition    partOfSpeech  \
# 2085   35297.0  dokumentovati          NaN  v.tr. ipf./pf.
# 1988   25273.0        dobrěti          NaN    v.intr. ipf.
# 2062    1181.0         dojiti          NaN      v.tr. ipf.
# 2187    7215.0   doråzuměvati          NaN    v.refl. ipf.
# 2207    4208.0    doskonaliti          NaN      v.tr. ipf.
# 10421  18268.0       podobati          NaN    v.refl. ipf.
# 10473   5612.0    podstrěkati  (podstrěče)      v.tr. ipf.
# 10474   4494.0   podstrěknųti          NaN      v.tr. ipf.
#
#                                             en genesis   pos prefix verb_stem  \
# 2085                                  document       I  verb      ?         ?
# 1988                               become good     NaN  verb      ?         ?
# 2062                                      milk     NaN  verb      ?         ?
# 2187                               communicate     NaN  verb      ?         ?
# 2207                                   perfect     NaN  verb      ?         ?
# 10421                      please, be liked by     NaN  verb      ?         ?
# 10473  incite, instigate, abet, stir up, rouse     NaN  verb      ?         ?
# 10474  incite, instigate, abet, stir up, rouse     NaN  verb      ?         ?
#
#           base_verb  ... left_stem_cand right_stem_cand   derived_nouns  \
# 2085                 ...       dokument   ?kumentovati?  |dokumentacija
# 1988        dobrěti  ...           dobr         ?brěti?        |dobrosť
# 2062         dojiti  ...             do          ?jiti?
# 2187   doråzuměvati  ...      doråzuměv        ?měvati?
# 2207    doskonaliti  ...       doskonal      ?konaliti?    |doskonalosť
# 10421      podobati  ...          podob           ?ati?
# 10473   podstrěkati  ...       podstrěk       ?trěkati?
# 10474   podstrěkati  ...       podstrěk      ?trěknųti?
#
#       base_noun _prefix     _stem _suffix _is_irregular  reconstructed  aspect
# 2085   dokument          dokument   ovati             0         ?uměti  ipf/pf
# 1988      dobry              dobr     ěti             0         ?uměti     ipf
# 2062                           do    jiti             0         dojiti     ipf
# 2187                      doråzum   ěvati             0            NaN     ipf
# 2207                     doskonal     iti             0            NaN     ipf
# 10421    podoba             podob     ati             0            NaN     ipf
# 10473                    podstrěk     ati             0            NaN     ipf
# 10474                    podstrěk    nųti             0            NaN     ipf
#
# [8 rows x 21 columns]

# %%
g
# Out:
#             id           isv     addition  partOfSpeech  \
# 10421  18268.0      podobati          NaN  v.refl. ipf.
# 10454  22358.0     podręditi          NaN     v.tr. pf.
# 10456  22359.0     podręđati          NaN    v.tr. ipf.
# 10463  10769.0    podslušati          NaN     v.tr. pf.
# 10466  22778.0  podslušivati          NaN    v.tr. ipf.
# 10467   5389.0    podsměhati          NaN  v.refl. ipf.
# 10468   5390.0   podsměhnųti          NaN   v.refl. pf.
# 10473   5612.0   podstrěkati  (podstrěče)    v.tr. ipf.
# 10474   4494.0  podstrěknųti          NaN    v.tr. ipf.
# 10505  22584.0     podvŕgati          NaN    v.tr. ipf.
# 10506  22585.0    podvŕgnųti          NaN     v.tr. pf.
# 10444  10758.0     podporiti          NaN     v.tr. pf.
#
#                                             en genesis   pos prefix verb_stem  \
# 10421                      please, be liked by     NaN  verb      ?         ?
# 10454                              subordinate     NaN  verb      ?         ?
# 10456                              subordinate     NaN  verb      ?         ?
# 10463                       eavesdrop, wiretap     NaN  verb      ?         ?
# 10466                       eavesdrop, wiretap     NaN  verb      ?         ?
# 10467                                     jeer     NaN  verb      ?         ?
# 10468                                     jeer     NaN  verb      ?         ?
# 10473  incite, instigate, abet, stir up, rouse     NaN  verb      ?         ?
# 10474  incite, instigate, abet, stir up, rouse     NaN  verb      ?         ?
# 10505                    expose to, subject to     NaN  verb      ?         ?
# 10506                    expose to, subject to     NaN  verb      ?         ?
# 10444                   support, back, back up     NaN  verb      ?         ?
#
#          base_verb  ... left_stem_cand right_stem_cand        derived_nouns  \
# 10421     podobati  ...          podob           ?ati?
# 10454    podręditi  ...         podręd        ?ręditi?
# 10456    podręditi  ...         podręđ        ?ręđati?
# 10463   podslušati  ...        podsluš         slušati
# 10466   podslušati  ...        podsluš      ?lušivati?
# 10467   podsměhati  ...        podsměh        ?měhati?
# 10468   podsměhati  ...        podsměh       ?měhnųti?
# 10473  podstrěkati  ...       podstrěk       ?trěkati?
# 10474  podstrěkati  ...       podstrěk      ?trěknųti?
# 10505    podvŕgati  ...         podvŕg          vŕgati
# 10506    podvŕgati  ...         podvŕg         vŕgnųti
# 10444       poriti  ...         podpor            riti  |podporka|podpornik
#
#       base_noun _prefix     _stem _suffix _is_irregular  reconstructed aspect
# 10421    podoba             podob     ati             0            NaN    ipf
# 10454                      podręd     iti             0     podъręditi     pf
# 10456                      podręd    ⒥ati             0    ?podъręditi    ipf
# 10463                     podsluš     ati             0            NaN     pf
# 10466                     podsluš   ivati             0            NaN    ipf
# 10467                     podsměh     ati             0            NaN    ipf
# 10468                     podsměh    nųti             0            NaN     pf
# 10473                    podstrěk     ati             0            NaN    ipf
# 10474                    podstrěk    nųti             0            NaN    ipf
# 10505                      podvŕg     ati             0            NaN    ipf
# 10506                      podvŕg    nųti             0            NaN     pf
# 10444                      podpor     iti             0        ?poriti     pf
#
# [12 rows x 21 columns]

# %%
move_prefix(morphemes.query("_stem == 'podpor'"), "pod")
# Out:
# C:\Users\79165\AppData\Local\Temp\ipykernel_25148\3700476200.py:4: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   morphemes.loc[g.index, '_stem'] = g._stem.str[len(prefix):]

# %%
CORRECT_VERBS = [
    'organizovati', 'okupovati', 'optimizovati', 'orientovati', 'uzurpovati',
    'uměti', 'ohati', 'učiti', 'užasati', 'ostriti', 'orųdovati', 'orųžiti', 'osnovati', 'oriti'
]

# %%
g = morphemes.query(
    "_prefix == '' and isv.str.contains('^(u|o)') and not isv.str.contains('^(ob|od)')"
).query(
    "(base_verb not in @CORRECT_VERBS and isv not in @CORRECT_VERBS)"
).sort_values(by='en')

g
# Out:
# C:\Users\79165\AppData\Local\Temp\ipykernel_25148\2100257503.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   g = morphemes.query(
#            id                  isv addition partOfSpeech            en  \
# 9155  29304.0  ogluhnųti, oglušeti      NaN  v.intr. pf.   become deaf
# 9507  33797.0                oriti      NaN   v.tr. ipf.     drag down
# 9479  22890.0                orati    (oŕe)       v.ipf.  plough, plow
#
#      genesis   pos prefix verb_stem base_verb  ...       left_stem_cand  \
# 9155     NaN  verb      ?         ?            ...  ogluhnųti, oglušeti
# 9507     NaN  verb      ?         ?     oriti  ...                   or
# 9479     NaN  verb      ?         ?     orati  ...                   or
#
#            right_stem_cand derived_nouns base_noun _prefix _stem _suffix  \
# 9155  ?gluhnųti, oglušeti?
# 9507                  riti         |orač                      or     iti
# 9479                ?rati?         |orač                      or     ati
#
#      _is_irregular  reconstructed aspect
# 9155             0         ?uměti     pf
# 9507             0          oriti    ipf
# 9479             0          orati    ipf
#
# [3 rows x 21 columns]

# %%
g.base_verb.unique()
# Out:
# array(['ovplyvniti', '', 'podobniti', 'ozdobiti', 'oprěděliti', 'oriti',
#        'opravniti', 'upokarnjati', 'uspravědliviti', 'orati'],
#       dtype=object)

# %%
morphemes.query('base_verb == "upokarnjati"')
# upokorniti
# koriti

# spravědliv
# Out:
#            id          isv addition partOfSpeech      en genesis   pos prefix  \
# 15790  5897.0  upokarnjati      NaN   v.tr. ipf.  humble     NaN  verb      ?
# 15791  5896.0   upokorniti      NaN    v.tr. pf.  humble     NaN  verb      ?
#
#       verb_stem    base_verb  ... left_stem_cand right_stem_cand  \
# 15790         ?  upokarnjati  ...        upokarn      ?karnjati?
# 15791         ?  upokarnjati  ...        upokorn       ?korniti?
#
#       derived_nouns base_noun _prefix    _stem _suffix _is_irregular  \
# 15790                                  upokꜵrn    jati             0
# 15791                                  upokꜵrn     iti             0
#
#        reconstructed aspect
# 15790            NaN    ipf
# 15791            NaN     pf
#
# [2 rows x 21 columns]

# %%
morphemes.query('base_verb.str.contains("dobn?[ia]") and base_verb != "baviti"')
# Out:
#             id          isv addition  partOfSpeech  \
# 9802   34715.0    ozdabjati      NaN    v.tr. ipf.
# 9804   29789.0     ozdobiti      NaN     v.tr. pf.
# 10421  18268.0     podobati      NaN  v.refl. ipf.
# 14211  36557.0    spodobati      NaN   v.refl. pf.
# 15786  19064.0  upodabnjati      NaN  v.refl. ipf.
# 15787  19062.0  upodabnjati      NaN    v.tr. ipf.
# 15788  19068.0   upodobniti      NaN   v.refl. pf.
# 15789  19066.0   upodobniti      NaN     v.tr. pf.
#
#                                     en genesis   pos prefix verb_stem  \
# 9802                   decorate, adorn     NaN  verb      ?         ?
# 9804                   decorate, adorn     NaN  verb      ?         ?
# 10421              please, be liked by     NaN  verb      ?         ?
# 14211              please, be liked by     NaN  verb      ?         ?
# 15786         become similar, blend in     NaN  verb      ?         ?
# 15787  liken, make similar, assimilate     NaN  verb      ?         ?
# 15788         become similar, blend in     NaN  verb      ?         ?
# 15789  liken, make similar, assimilate     NaN  verb      ?         ?
#
#       base_verb  ... left_stem_cand right_stem_cand derived_nouns base_noun  \
# 9802     dobiti  ...          ozdab      ?zdabjati?
# 9804     dobiti  ...          ozdob       ?zdobiti?                  ozdoba
# 10421    dobiti  ...          podob           ?ati?                  podoba
# 14211    dobiti  ...         spodob        podobati
# 15786    dobiti  ...        upodabn       ?abnjati?
# 15787    dobiti  ...        upodabn       ?abnjati?
# 15788    dobiti  ...        upodobn            niti
# 15789    dobiti  ...        upodobn            niti
#
#       _prefix _stem _suffix _is_irregular  reconstructed aspect
# 9802       oz   dab    jati             0            NaN    ipf
# 9804       oz   dob     iti             0            NaN     pf
# 10421      po   dob     ati             0            NaN    ipf
# 14211     spo   dob     ati             0            NaN     pf
# 15786     upo   dab   njati             0            NaN    ipf
# 15787     upo   dab   njati             0            NaN    ipf
# 15788     upo   dob    niti             0            NaN     pf
# 15789     upo   dob    niti             0            NaN     pf
#
# [8 rows x 21 columns]

# %%
g = morphemes.query('base_verb.str.contains("dobn?[ia]") and base_verb != "baviti"')
manual_insert_g(g, 'd[ao]b',  dry_run=0)
set_base_verb(g, 'dobiti')

g = morphemes.query('base_verb == "upokarnjati"')
manual_insert_g(g, 'k[ao]rn',  dry_run=0)
morphemes.loc[g.index, 'base_noun'] = 'pokorny'
set_base_verb(g, 'koriti')


g = morphemes.query('base_verb.str.contains("oprěděliti")')
manual_insert_g(g, 'děl',  dry_run=0)
set_base_verb(g, 'děliti')


g = morphemes.query('isv.str.contains("vplyv")')
manual_insert_g(g, 'vplyv',  dry_run=0)
set_base_verb(g, 'vplyvti')

#g = morphemes.query('isv.str.contains("spravědliv")')
#move_prefix(g, 'u')
#g = morphemes.query('base_verb.str.contains("opravniti")')
#move_prefix(g, 'o')
# Out:
# ozdabjati = oz dab jati
# ozdobiti = oz dob iti
# podobati = po dob ati
# spodobati = spo dob ati
# upodabnjati = upo dab njati
# upodabnjati = upo dab njati
# upodobniti = upo dob niti
# upodobniti = upo dob niti
# ovplyvniti = o vplyv niti
# ovplyvnjati = o vplyv njati
# vplyvati =  vplyv ati
# vplyvti =  vplyv ti

# %%
# last_cons={'c', 'č'},
g = morphemes.query('base_verb.str.contains("možn")')
manual_insert_g(g, 'možn',  dry_run=0)
morphemes.loc[g.index, 'base_noun'] = 'možny'
set_base_verb(g, 'možniti')

g = morphemes.query('base_verb.str.contains("črv")')
manual_insert_g(g, 'črv',  dry_run=0)
set_base_verb(g, 'črveněti')

g = morphemes.query('base_verb.str.contains("ulagoditi")')
move_prefix(g, 'u')


g = morphemes.query('base_verb.str.contains("lučš")')
move_prefix(g, 'u')
morphemes.loc[g.index, 'reconstructed'] = '?lučьjь?'

g = morphemes.query('base_verb.str.contains("menš")')
manual_insert_g(g, 'menš', dry_run=0)
morphemes.loc[g.index, 'reconstructed'] = '?mьňьjь?'
set_base_verb(g, 'menšiti')


g = morphemes.query('base_verb.str.contains("tęg") and not base_verb.str.contains("tęgč")')
set_base_verb(g, 'tęgati')

g = morphemes.query('base_verb.str.contains("tęgč")')
manual_insert_g(g, 'tęgk', last_cons={"č", "k"}, dry_run=0)
morphemes.loc[g.index, 'base_noun'] = 'tęžky'
set_base_verb(g, 'tęgčiti')
# Out:
# umožniti = u možn iti
# umožnjati = u možn jati
# unemožniti = une možn iti
# unemožnjati = une možn jati
# črveněti =  črv eněti
# počrveněti = po črv eněti
# začrveniti = za črv eniti
# začrvenjati = za črv enjati
# smenšati = s menš ati
# smenšiti = s menš iti
# umenšati = u menš ati
# umenšiti = u menš iti
# otęgčati = o tęgk ⒥ati
# otęgčati = o tęgk ⒥ati
# otęgčiti = o tęgk ⒥iti
# otęgčiti = o tęgk ⒥iti
# C:\Users\79165\AppData\Local\Temp\ipykernel_25148\3700476200.py:4: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   morphemes.loc[g.index, '_stem'] = g._stem.str[len(prefix):]

# %%
g = morphemes.query('base_verb.str.contains("osȯvrěmenniti")')
manual_insert_g(g, 'vrěmen', last_cons={"č", "k"}, dry_run=0)
morphemes.loc[g.index, 'base_noun'] = 'vrěmę'
set_base_verb(g, 'osȯvrěmenniti')
# Out:
# osȯvrěmenniti = osȯ vrěmen niti
# osȯvrěmennjati = osȯ vrěmen njati

# %%
morphemes.loc[
    morphemes.query('base_verb.str.contains("orų[ž]")').index,
    'base_verb'
] = 'orųžiti'

# %%
morphemes.query('base_verb.str.contains("menš")')

# %%
g = morphemes.query('base_verb.str.contains("menš")')

g
# Out:
#            id       isv addition partOfSpeech  \
# 13946  2062.0  smenšati      NaN   v.tr. ipf.
# 13948  1297.0  smenšiti      NaN    v.tr. pf.
# 15710  4101.0  umenšati      NaN   v.tr. ipf.
# 15711  4099.0  umenšiti      NaN    v.tr. pf.
#
#                                           en genesis   pos prefix verb_stem  \
# 13946                                 reduce     NaN  verb      ?         ?
# 13948                                 reduce     NaN  verb      ?         ?
# 15710  diminish, reduce, make smaller, abate     NaN  verb      ?         ?
# 15711  diminish, reduce, make smaller, abate     NaN  verb      ?         ?
#
#       base_verb  ... left_stem_cand right_stem_cand derived_nouns base_noun  \
# 13946  smenšati  ...          smenš       ?menšati?
# 13948  smenšati  ...          smenš       ?menšiti?
# 15710  umenšati  ...          umenš       ?menšati?
# 15711  umenšati  ...          umenš       ?menšiti?
#
#       _prefix  _stem _suffix _is_irregular  reconstructed aspect
# 13946          smenš     ati             0            NaN    ipf
# 13948          smenš     iti             0            NaN     pf
# 15710          umenš     ati             0            NaN    ipf
# 15711          umenš     iti             0            NaN     pf
#
# [4 rows x 21 columns]

# %%
g = morphemes.query('base_verb.str.contains("tęgč")')
g
# Out:
#           id       isv addition partOfSpeech              en genesis   pos  \
# 9725  6137.0  otęgčati      NaN   v.tr. ipf.      complicate     NaN  verb
# 9726  6138.0  otęgčati      NaN   v.tr. ipf.  hamper, impede     NaN  verb
# 9727  6140.0  otęgčiti      NaN    v.tr. pf.      complicate     NaN  verb
# 9728  6141.0  otęgčiti      NaN    v.tr. pf.  hamper, impede     NaN  verb
#
#      prefix verb_stem base_verb  ... left_stem_cand right_stem_cand  \
# 9725      ?         ?  otęgčati  ...          otęgč       ?tęgčati?
# 9726      ?         ?  otęgčati  ...          otęgč       ?tęgčati?
# 9727      ?         ?  otęgčati  ...          otęgč       ?tęgčiti?
# 9728      ?         ?  otęgčati  ...          otęgč       ?tęgčiti?
#
#      derived_nouns base_noun _prefix  _stem _suffix _is_irregular  \
# 9725                                  otęgč     ati             0
# 9726                                  otęgč     ati             0
# 9727                                  otęgč     iti             0
# 9728                                  otęgč     iti             0
#
#       reconstructed aspect
# 9725      otęgъčati    ipf
# 9726      otęgъčati    ipf
# 9727      otęgъčiti     pf
# 9728      otęgъčiti     pf
#
# [4 rows x 21 columns]

# %%
g = morphemes.query('base_verb.str.contains("slož")')
manual_insert_g(g, 'slože?n', last_cons={'d', 'đ'}, dry_run=0)
set_base_verb(g, 'složniti')
# Out:
# osloženiti = o složen iti
# osloženjati = o složen jati
# usložniti = u složn iti
# usložnjati = u složn jati

# %%
move_prefix(morphemes.query('base_verb.str.contains("uběd")'), 'u')
move_prefix(morphemes.query('base_verb.str.contains("poběd")'), 'po')
# Out:
# C:\Users\79165\AppData\Local\Temp\ipykernel_25148\3700476200.py:4: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   morphemes.loc[g.index, '_stem'] = g._stem.str[len(prefix):]

# %%
move_prefix(morphemes.query('base_verb.str.contains("ustal")'), 'u')
# Out:
# C:\Users\79165\AppData\Local\Temp\ipykernel_25148\3700476200.py:4: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   morphemes.loc[g.index, '_stem'] = g._stem.str[len(prefix):]

# %%
g = morphemes.query('base_verb.str.contains("věn")')
manual_insert_g(g, 'věnc', last_cons={'c', 'č'}, dry_run=0)
morphemes.loc[g.index, 'base_noun'] = 'věnec'

set_base_verb(g, 'věnčati')
# Out:
# ověnčati = o věnc ⒥ati
# ověnčiti = o věnc ⒥iti

# %%
g = morphemes.query('base_verb.str.contains("rę[dđ][ia]")')
manual_insert_g(g, 'ręd', last_cons={'d', 'đ'}, dry_run=0)
set_base_verb(g, 'ręditi')
# Out:
# oporędčati = opo ręd čati
# oporędčiti = opo ręd čiti
# podręditi = pod ręd iti
# podręđati = pod ręd ⒥ati
# råzporęditi = razpo ręd iti
# råzporęđati = razpo ręd ⒥ati
# uręditi = u ręd iti
# uręđati = u ręd ⒥ati

# %%
g = morphemes.query('base_verb.str.contains("rę[dđ]č")')
# porędȯk
morphemes.loc[g.index, 'base_noun'] = 'porędȯk'
manual_insert_g(g, 'porędk', last_cons={'k', 'č'}, dry_run=0)
set_base_verb(g, 'rędčati')

# %%
g.base_verb.value_counts().index
# Out:
# Index(['podobniti', 'otęgčati', 'uběditi', 'osnovati', 'ovplyvniti',
#        'opravniti', 'ulagoditi', 'unemožniti', 'oporędčati', 'osȯvrěmenniti',
#        'uspravědliviti', 'upokarnjati', 'ustaliti', 'orųdovati', 'ulučšati',
#        'umožniti', 'umenšati', 'oprěděliti', 'ozdobiti', 'usložniti',
#        'osloženiti', 'uręditi', 'ověnčati', 'orųžiti', 'oriti', 'orati', '',
#        'ostriti'],
#       dtype='object')

# %%
#'otęgčati', 'osnovati', 'ustaliti',  'uběditi' 'podobniti', 'upokarnjati',
# 'uspravědliviti'
# 'osȯvrěmenniti'  , 'oporędčati', 'orųdovati', 'unemožniti', 'ulagoditi', 
# 'ovplyvniti', 'opravniti', 'ozdobiti', 'uręditi', 'osloženiti', 'usložniti', 
# 'oprěděliti', 'umenšati', 'umožniti', 'ulučšati', 
for verb in ['orositi', 'osvoboditi', 'udaliti', 'opozdniti', 
       'ozeleniti', 
       'ulěpšati', 'umŕtviti',
       'unarodniti',  'osvěžati', 'oživiti',
       'otrězviti', 'upotrěbiti', 'ulegšati', 
        'upȯlnomoćiti', 'otųpiti',
       'otěniti', 'oznaniti', 'oskvŕniti']:
    g = morphemes.query('base_verb == @verb')
    move_prefix(g, verb[0])
# Out:
# C:\Users\79165\AppData\Local\Temp\ipykernel_25148\3700476200.py:4: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   morphemes.loc[g.index, '_stem'] = g._stem.str[len(prefix):]

# %%
g = morphemes.query('base_verb.str.contains("slab")')
g

manual_insert_g(g, 'slab', last_cons={'š', 'h'}, dry_run=0)
set_base_verb(g, 'slaběti')
# Out:
# oslaběti = o slab ěti
# oslabiti = o slab iti
# oslabiti = o slab iti
# oslabjati = o slab jati
# oslabjati = o slab jati
# slaběti =  slab ěti

# %%
g = morphemes.query('isv.str.contains("smě[hš]") and en.str.contains("(jeer|laugh|smile)")')
g

manual_insert_g(g, 'směh', last_cons={'š', 'h'}, dry_run=0)
set_base_verb(g, 'směhati')
# Out:
# podsměhati = pod směh ati
# podsměhnųti = pod směh nųti
# råzsměšati = raz směh ⒥ati
# råzsměšiti = raz směh ⒥iti
# usměhati = u směh ati
# usměhnųti = u směh nųti
# C:\Users\79165\AppData\Local\Temp\ipykernel_25148\931649352.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   g = morphemes.query('isv.str.contains("smě[hš]") and en.str.contains("(jeer|laugh|smile)")')

# %%
morphemes.loc[g.index, ['reconstructed']] = "?směx?"

# %%
g = morphemes.query('isv.str.contains("[uo]per") and en.str.contains("feather")')
morphemes.loc[g.index, ['derived_nouns', 'base_noun', 'base_verb']] = ['', 'pero', 'pero']
manual_insert_g(g, 'per', last_cons={'z', 'ž'}, dry_run=0)
# Out:
# operiti = o per iti
# operjati = o per jati
# uperiti = u per iti

# %%
g = morphemes.query('base_verb.str.contains("smŕ")')
move_prefix(g, 'u')
# Out:
# C:\Users\79165\AppData\Local\Temp\ipykernel_25148\3700476200.py:4: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   morphemes.loc[g.index, '_stem'] = g._stem.str[len(prefix):]

# %%
g = morphemes.query("base_verb.str.contains('mŕz')")
manual_insert_g(g, 'mŕz', last_cons={'z', 'ž'}, dry_run=0)
# Out:
# omŕziti = o mŕz iti
# omŕžati = o mŕz ⒥ati

# %%
# g = morphemes.query("en.str.contains('coura') and base_verb.str.contains('smě')")
g = morphemes.query(" base_verb.str.contains('směl')")


manual_insert_g(g, 'směl', last_cons={'š', 'h'}, dry_run=0)
set_base_verb(g, 'smělěti')
# Out:
# onesměliti = one směl iti
# onesměljati = one směl jati
# osměliti = o směl iti
# osměliti = o směl iti
# osměljati = o směl jati
# osměljati = o směl jati
# råzsměliti = raz směl iti
# råzsměljati = raz směl jati

# %%
morphemes.query(" base_verb.str.contains('smel')")
# Out:
# Empty DataFrame
# Columns: [id, isv, addition, partOfSpeech, en, genesis, pos, prefix, verb_stem, base_verb, isv_orig, left_stem_cand, right_stem_cand, derived_nouns, base_noun, _prefix, _stem, _suffix, _is_irregular, reconstructed, aspect]
# Index: []
#
# [0 rows x 21 columns]

# %%
g = morphemes.query('isv.str.contains("krųg")')
g
manual_insert_g(g, 'krųgl', dry_run=0)
# Out:
# okrųgliti = o krųgl iti
# okrųgljati = o krųgl jati

# %%
g = morphemes.query('isv.str.contains("t[ě]l")')
g
manual_insert_g(g, 'těles', dry_run=0)
# Out:
# utělesniti = u těles niti
# utělesnjati = u těles njati

# %%
g = morphemes.query('isv.str.contains("tekų")')
g
manual_insert_g(g, 'tekųći', last_cons={'š', 'h'}, dry_run=0)
set_base_verb(g, 'tekti')
# Out:
# utekųćiniti = u tekųći niti
# utekųćinjati = u tekųći njati

# %%
g = morphemes.query('isv.str.contains("umyvati")')
g
manual_insert_g(g, 'my', last_cons={'š', 'h'}, dry_run=0)
set_base_verb(g, 'myti')
# Out:
# umyvati = u my vati

# %%
g = morphemes.query('isv.str.contains("opekati")')
manual_insert_g(g, 'pek', last_cons={'š', 'h'}, dry_run=0)
set_base_verb(g, 'pekti')
# Out:
# opekati = o pek ati

# %%
g = morphemes.query('isv.str.contains("ti[šh]")')
manual_insert_g(g, 'tih', last_cons={'š', 'h'}, dry_run=0)
set_base_verb(g, 'tišati')
# Out:
# otišati = o tih ⒥ati
# otišiti = o tih ⒥iti
# utišati = u tih ⒥ati
# utišiti = u tih ⒥iti

# %%
g = morphemes.query('isv.str.contains("trudn")')
manual_insert_g(g, 'trudn', dry_run=0)
set_base_verb(g, 'trudniti')
# Out:
# otrudniti = o trudn iti
# otrudnjati = o trudn jati
# utrudniti = u trudn iti
# utrudnjati = u trudn jati

# %%
g = morphemes.query('isv.str.contains("tęž.t")')
manual_insert_g(g, 'tęž', dry_run=0)
set_base_verb(g, 'tęžiti')
#g
# Out:
# obtęžati = ob tęž ati
# obtęžiti = ob tęž iti
# utęžati = u tęž ati
# utęžiti = u tęž iti

# %%
# and base_noun == '' and not isv.str.contains(' ')
g = morphemes.query("_prefix == '' and isv.str.contains('^(ob|za|od|do)') ").sort_values(by='base_verb')
g#.sort_values(by='_suffix')
# Out:
# C:\Users\79165\AppData\Local\Temp\ipykernel_25148\3743463430.py:2: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   g = morphemes.query("_prefix == '' and isv.str.contains('^(ob|za|od|do)') ").sort_values(by='base_verb')
#             id            isv addition    partOfSpeech  \
# 17544  31583.0       zavěćati      NaN  v.tr. ipf./pf.
# 2085   35297.0  dokumentovati      NaN  v.tr. ipf./pf.
# 17537  14193.0     zautrakati      NaN    v.intr. ipf.
# 8419   18014.0     obmanyvati      NaN      v.tr. ipf.
# 8418    4216.0     obmanyvati      NaN      v.tr. ipf.
# ...        ...            ...      ...             ...
# 17450  31555.0      zasloniti      NaN       v.tr. pf.
# 17502   1170.0      zatemniti      NaN       v.tr. pf.
# 17503   3090.0     zatemnjati      NaN      v.tr. ipf.
# 17507  33692.0      zatměvati      NaN      v.tr. ipf.
# 17508  31569.0        zatmiti      NaN       v.tr. pf.
#
#                                                     en genesis   pos prefix  \
# 17544                          bequeath, leave by will     NaN  verb      ?
# 2085                                          document       I  verb      ?
# 17537                   eat breakfast, have breakfrast     NaN  verb      ?
# 8419                                              fool     NaN  verb      ?
# 8418             con, cheat, delude, deceive, hoodwink     NaN  verb      ?
# ...                                                ...     ...   ...    ...
# 17450  shelter, cover, shade, shield (from light etc.)     NaN  verb      ?
# 17502                       obscure, darken, make dark     NaN  verb      ?
# 17503                       obscure, darken, make dark     NaN  verb      ?
# 17507                                 eclipse, obscure     NaN  verb      ?
# 17508                                 eclipse, obscure     NaN  verb      ?
#
#       verb_stem  base_verb  ... left_stem_cand right_stem_cand  \
# 17544         ?             ...          zavěć         ?ěćati?
# 2085          ?             ...       dokument   ?kumentovati?
# 17537         ?             ...        zautrak       ?trakati?
# 8419          ?             ...          obman      ?manyvati?
# 8418          ?             ...          obman      ?manyvati?
# ...         ...        ...  ...            ...             ...
# 17450         ?  zasloniti  ...         zaslon        ?loniti?
# 17502         ?  zatemniti  ...         zatemn       ?temniti?
# 17503         ?  zatemniti  ...         zatemn      ?temnjati?
# 17507         ?    zatmiti  ...         zatměv       ?tměvati?
# 17508         ?    zatmiti  ...           zatm         ?tmiti?
#
#         derived_nouns base_noun _prefix     _stem _suffix _is_irregular  \
# 17544                     zavět             zavět    ⒥ati             0
# 2085   |dokumentacija  dokument          dokument   ovati             0
# 17537                  zautraka           zautrak     ati             0
# 8419        |obmannik     obman             obman   yvati             0
# 8418        |obmannik     obman             obman   yvati             0
# ...               ...       ...     ...       ...     ...           ...
# 17450                    zaslon            zaslꜵn     iti             0
# 17502                                      zatemn     iti             0
# 17503                                      zatemn    jati             0
# 17507                                        zatm   ěvati             0
# 17508                                        zatm     iti             0
#
#        reconstructed  aspect
# 17544         ?uměti  ipf/pf
# 2085          ?uměti  ipf/pf
# 17537         ?uměti     ipf
# 8419          ?uměti     ipf
# 8418          ?uměti     ipf
# ...              ...     ...
# 17450            NaN      pf
# 17502            NaN      pf
# 17503            NaN     ipf
# 17507            NaN     ipf
# 17508            NaN      pf
#
# [72 rows x 21 columns]

# %%
g.base_verb.value_counts()
# Out:
#                      9
# oddaliti             4
# obnoviti             4
# zatemniti            2
# zasloniti            2
# zaplěniti            2
# zabezpečati          2
# zabezpamętiti        2
# odščepiti            2
# odčuđati             2
# odsloniti            2
# odročiti             2
# odosobniti           2
# odomašniti           2
# odolěti              2
# odličati             2
# odkųsiti             2
# obmeđati             2
# obobćati             2
# obiděti              2
# obkoliti             2
# oblegčati            2
# oběćati              2
# zatmiti              2
# obognjeodparnjati    2
# obrěmeniti           2
# občiti               2
# observovati          1
# vlěkti               1
# odobriti             1
# doskonaliti          1
# dojiti               1
# dobrěti              1
# byti                 1
# Name: base_verb, dtype: int64

# %%
g.base_verb.value_counts().index
# Out:
# Index(['', 'oddaliti', 'obnoviti', 'zatemniti', 'zasloniti', 'zaplěniti',
#        'zabezpečati', 'zabezpamętiti', 'odščepiti', 'odčuđati', 'odsloniti',
#        'odročiti', 'odosobniti', 'odomašniti', 'odolěti', 'odličati',
#        'odkųsiti', 'obmeđati', 'obobćati', 'obiděti', 'obkoliti', 'oblegčati',
#        'oběćati', 'zatmiti', 'obognjeodparnjati', 'obrěmeniti', 'občiti',
#        'observovati', 'vlěkti', 'odobriti', 'doskonaliti', 'dojiti', 'dobrěti',
#        'byti'],
#       dtype='object')

# %%
'oddaliti', 'obnoviti', 
'zatemniti', 'zasloniti', 'odsloniti', 'zaplěniti',
#'zabezpečati', 
# 'zabezpamętiti',
#'odščepiti', 'odčuđati', 
'odročiti', 
'odosobniti', 
# 'odomašniti', 
'o/dolěti', 
       'odkųsiti', 
    'obmeđati', 
    # 'obobćati',  'obiděti', 
'obkoliti', 
'oblegčati'

# %%
g1 = morphemes.query("isv.str.contains('li[č]') and not isv.str.contains('veli')")
manual_insert_g(g1, 'lik', dry_run=0, last_cons={'k', 'č'})
set_base_verb(g1, 'ličiti')

#
# Out:
# izobličati = izob lik ⒥ati
# izobličiti = izob lik ⒥iti
# odličati = od lik ⒥ati
# odličiti = od lik ⒥iti
# råzličati = raz lik ⒥ati
# råzličati = raz lik ⒥ati
# råzličiti = raz lik ⒥iti

# %%
g1 = morphemes.query("isv.str.contains('zastar') and isv != 'abstrahovati'")
manual_insert_g(g1, 'star', dry_run=0, last_cons={'h', 'š'})
set_base_verb(g1, 'starěti')
# Out:
# zastariti = za star iti
# zastarjati = za star jati

# %%
g1 = morphemes.query("isv.str.contains('stra[hš]') and isv != 'abstrahovati'")
manual_insert_g(g1, 'strah', dry_run=0, last_cons={'h', 'š'})
set_base_verb(g1, 'strašiti')
# Out:
# nastrašiti = na strah ⒥iti
# nastrašiti = na strah ⒥iti
# odstrašati = od strah ⒥ati
# odstrašiti = od strah ⒥iti
# prěstrašiti = prě strah ⒥iti
# strahovati =  strah ovati
# strašiti =  strah ⒥iti
# zastrašati = za strah ⒥ati
# zastrašiti = za strah ⒥iti

# %%
g1 = morphemes.query("isv.str.contains('obr[aå][tć]') or isv.str.contains('vr[aå][tć]')")
manual_insert_g(g1, 'v?r[aå]t', dry_run=0, last_cons={'t', 'ć'})
set_base_verb(g1, 'vråtiti')

g1 = morphemes.query("base_verb.str.contains('†nažiti')")
manual_insert_g(g1, 'nag', dry_run=0, last_cons={'ž', 'g'})
morphemes.loc[g1.index, 'base_noun'] = 'nagy'

g1 = morphemes.query("base_verb.str.contains('hvat')")
manual_insert_g(g1, 'hvat', dry_run=0, last_cons={'t', 'ć'})
set_base_verb(g1, 'hvatati')

g1 = morphemes.query("base_verb.str.contains('bočiti')")
manual_insert_g(g1, 'b[ao]k', dry_run=0, last_cons={'k', 'č'})

g1 = morphemes.query("base_verb.str.contains('doråzuměvati')")
manual_insert_g(g1, 'umě', dry_run=0, last_cons={'t', 'ć'})
set_base_verb(g1, 'uměti')
# Out:
# izvraćati = iz vrat ⒥ati
# izvråtiti = iz vråt iti
# obraćati = ob rat ⒥ati
# obraćati = ob rat ⒥ati
# obraćati = ob rat ⒥ati
# obraćati = ob rat ⒥ati
# obraćati = ob rat ⒥ati
# obraćati = ob rat ⒥ati
# obraćati = ob rat ⒥ati
# obraćati = ob rat ⒥ati
# obraćati = ob rat ⒥ati
# obraćati = ob rat ⒥ati
# obråtiti = ob råt iti
# obråtiti = ob råt iti
# obråtiti = ob råt iti
# obråtiti = ob råt iti
# obråtiti = ob råt iti
# obråtiti = ob råt iti
# obråtiti = ob råt iti
# obråtiti = ob råt iti
# obråtiti = ob råt iti
# obråtiti = ob råt iti
# odvraćati = od vrat ⒥ati
# odvraćati = od vrat ⒥ati
# odvraćati = od vrat ⒥ati
# odvråtiti = od vråt iti
# odvråtiti = od vråt iti
# odvråtiti = od vråt iti
# povraćati = po vrat ⒥ati
# povråtiti = po vråt iti
# povråtiti = po vråt iti
# prěobraćati = prěob rat ⒥ati
# prěobraćati = prěob rat ⒥ati
# prěobråtiti = prěob råt iti
# prěobråtiti = prěob råt iti
# vȯzvraćati = vȯz vrat ⒥ati
# vȯzvråtiti = vȯz vråt iti
# vraćati =  vrat ⒥ati
# vraćati v otčinų =  vrat ⒥ati
# vraćati =  vrat ⒥ati
# vråtiti =  vråt iti
# vråtiti v otčinų =  vråt iti
# vråtiti =  vråt iti
# vråtiti =  vråt iti
# zavraćati = za vrat ⒥ati
# zavråtiti = za vråt iti
# obnažati = ob nag ⒥ati
# obnažati = ob nag ⒥ati
# obnažiti = ob nag ⒥iti
# obnažiti = ob nag ⒥iti
# hvatati =  hvat ati
# nahvatati = na hvat ati
# obhvaćati = ob hvat ⒥ati
# obhvatiti = ob hvat iti
# zahvaćati = za hvat ⒥ati
# zahvatiti = za hvat iti
# odbačati vlěvo = od bak ⒥ati
# odbačati vpravo/vdesno = od bak ⒥ati
# odbočiti vlěvo = od bok ⒥iti
# odbočiti vpravo/vdesno = od bok ⒥iti

# %%
tmp_df = morphemes.query("base_verb.str.contains('hvat')")
tmp_df
# Out:
#             id        isv addition partOfSpeech                  en genesis  \
# 3577    2591.0    hvatati      NaN   v.tr. ipf.  grab, grasp, seize     NaN
# 7171   28002.0  nahvatati      NaN    v.tr. pf.     pick up, snatch     NaN
# 8321   17990.0  obhvaćati      NaN   v.tr. ipf.      embrace, clasp     NaN
# 8322   17992.0  obhvatiti      NaN    v.tr. pf.      embrace, clasp     NaN
# 17178   2292.0  zahvaćati      NaN   v.tr. ipf.             capture     NaN
# 17182    571.0  zahvatiti      NaN    v.tr. pf.             capture     NaN
#
#         pos prefix verb_stem  base_verb  ... left_stem_cand right_stem_cand  \
# 3577   verb      ?         ?    hvatati  ...           hvat         hvatati
# 7171   verb      ?         ?    hvatati  ...         nahvat         hvatati
# 8321   verb      ?         ?  obhvatiti  ...         obhvać       ?hvaćati?
# 8322   verb      ?         ?  obhvatiti  ...         obhvat       ?hvatiti?
# 17178  verb      ?         ?  zahvatiti  ...         zahvać       ?hvaćati?
# 17182  verb      ?         ?  zahvatiti  ...         zahvat       ?hvatiti?
#
#       derived_nouns base_noun _prefix   _stem _suffix _is_irregular  \
# 3577                     hvat            hvat     ati             0
# 7171                              ¬na    hvat     ati             0
# 8321                                   obhvat    ⒥ati             0
# 8322                                   obhvat     iti             0
# 17178                                  zahvat    ⒥ati             0
# 17182                  zahvat          zahvat     iti             0
#
#        reconstructed aspect
# 3577         xvatati    ipf
# 7171    (na)+xvatati     pf
# 8321             NaN    ipf
# 8322             NaN     pf
# 17178            NaN    ipf
# 17182            NaN     pf
#
# [6 rows x 21 columns]

# %%
tmp_df = morphemes.query("isv.str.contains('(čina|čę)ti') and not en.str.contains('rest')")
set_base_verb(
    tmp_df,
    'čęti'
)

for stem_var in ['počin']:
    move_prefix(tmp_df.query('_stem == @stem_var'), stem_var[:2])

morphemes.loc[
    morphemes.query("isv.str.contains('započ')").index,
    ['_prefix', '_stem']
] = ['¬za¬po', 'čin']

morphemes.query("isv.str.contains('(čina|čę)ti') and not en.str.contains('rest')")
# Out:
# C:\Users\79165\AppData\Local\Temp\ipykernel_25148\214419792.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   tmp_df = morphemes.query("isv.str.contains('(čina|čę)ti') and not en.str.contains('rest')")
# C:\Users\79165\AppData\Local\Temp\ipykernel_25148\3700476200.py:4: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   morphemes.loc[g.index, '_stem'] = g._stem.str[len(prefix):]
# C:\Users\79165\AppData\Local\Temp\ipykernel_25148\214419792.py:15: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   morphemes.query("isv.str.contains('(čina|čę)ti') and not en.str.contains('rest')")
#             id         isv   addition  partOfSpeech  \
# 7080    1502.0      načęti    (načne)   v.refl. pf.
# 7081   22780.0      načęti    (načne)     v.tr. pf.
# 7084    5516.0    načinati        NaN  v.refl. ipf.
# 7085   22779.0    načinati        NaN    v.tr. ipf.
# 10306  22788.0   počęti sę    (počne)     v.tr. pf.
# 10307   1078.0      počęti    (počne)     v.tr. pf.
# 10315  10675.0    počinati        NaN  v.refl. ipf.
# 10316   2835.0    počinati        NaN    v.tr. ipf.
# 17107  14040.0      začęti    (začne)     v.tr. pf.
# 17110  14041.0    začinati        NaN    v.tr. ipf.
# 17386  32371.0    započęti  (započne)     v.tr. pf.
# 17387  19401.0  započinati        NaN    v.tr. ipf.
#
#                                                       en genesis   pos prefix  \
# 7080                        begin (intr.), start (intr.)     NaN  verb      ?
# 7081                            begin (tr.), start (tr.)     NaN  verb      ?
# 7084                        begin (intr.), start (intr.)     NaN  verb      ?
# 7085                            begin (tr.), start (tr.)     NaN  verb      ?
# 10306                       begin (intr.), start (intr.)     NaN  verb      ?
# 10307                 begin (tr.), start (tr.), commence     NaN  verb      ?
# 10315                       begin (intr.), start (intr.)     NaN  verb      ?
# 10316                 begin (tr.), start (tr.), commence     NaN  verb      ?
# 17107                   begin (tr.), start (tr.), embark     NaN  verb      ?
# 17110                   begin (tr.), start (tr.), embark     NaN  verb      ?
# 17386  initiate, commence, kick off, originate, start up     NaN  verb      ?
# 17387  initiate, commence, kick off, originate, start up     NaN  verb      ?
#
#       verb_stem base_verb  ... left_stem_cand right_stem_cand derived_nouns  \
# 7080          ?      čęti  ...         načęti          ?čęti?
# 7081          ?      čęti  ...         načęti          ?čęti?
# 7084          ?      čęti  ...          način        ?činati?
# 7085          ?      čęti  ...          način        ?činati?
# 10306         ?      čęti  ...         počęti       ?čęti sę?
# 10307         ?      čęti  ...         počęti          ?čęti?
# 10315         ?      čęti  ...          počin        ?činati?
# 10316         ?      čęti  ...          počin        ?činati?
# 17107         ?      čęti  ...         začęti          ?čęti?
# 17110         ?      čęti  ...          začin        ?činati?
# 17386         ?      čęti  ...       započęti          počęti
# 17387         ?      čęti  ...        započin        počinati
#
#       base_noun _prefix _stem _suffix _is_irregular  reconstructed aspect
# 7080                 na   čin     ⒩ti             0         načęti     pf
# 7081                 na   čin     ⒩ti             0         načęti     pf
# 7084                 na   čin     ati             0       načinati    ipf
# 7085                 na   čin     ati             0       načinati    ipf
# 10306                po   čin     ⒩ti            -1        ?počęti     pf
# 10307                po   čin     ⒩ti            -1         počęti     pf
# 10315     počin      po   čin     ati             0        ?počęti    ipf
# 10316     počin      po   čin     ati             0        ?počęti    ipf
# 17107                za   čin     ⒩ti             0         začęti     pf
# 17110                za   čin     ati             0        ?začęti    ipf
# 17386            ¬za¬po   čin     ⒩ti            -1    (za)+počęti     pf
# 17387            ¬za¬po   čin     ati             0        ?počęti    ipf
#
# [12 rows x 21 columns]

# %%
g.base_verb.value_counts()
# Out:
#                      19
# obraćati             10
# obnoviti              4
# bočiti                4
# oddaliti              4
# †nažiti               4
# odomašniti            2
# obhvatiti             2
# odročiti              2
# odsloniti             2
# odstrašati            2
# odčuđati              2
# odščepiti             2
# zabezpamętiti         2
# zabezpečati           2
# zahvatiti             2
# zaplěniti             2
# zasloniti             2
# zastariti             2
# zastrašati            2
# zatemniti             2
# zatmiti               2
# začinati              2
# odosobniti            2
# odličati              2
# odolěti               2
# obognjeodparnjati     2
# obiděti               2
# obkoliti              2
# oblegčati             2
# obmeđati              2
# obobćati              2
# obrěmeniti            2
# občiti                2
# oběćati               2
# odkųsiti              2
# observovati           1
# odobriti              1
# dojiti                1
# vlěkti                1
# doråzuměvati          1
# dobrěti               1
# byti                  1
# doskonaliti           1
# Name: base_verb, dtype: int64

# %%
g = morphemes.query("_prefix == '' and isv.str.contains('^(u|o)')").sort_values(by='base_verb')
#g = morphemes.query("_prefix == '' and isv.str.contains('^(ob|za|od|do)')").sort_values(by='base_verb')
#g = morphemes.query("_prefix == '' and isv.str.contains('^pod')").sort_values(by='base_verb')


for v1 in g.base_verb.unique():
    v = v1[1:]
    if v == '': continue
    if any(morphemes.isv == v) or any(morphemes.base_verb == v):
        print(v, v1)
        stem_ = None
        for g_cand in [morphemes[morphemes.isv == v], morphemes[morphemes.base_verb == v]]:
            if len(g_cand):
                stem_ = g_cand._stem.unique()
                if len(stem_) == 1:
                    stem = stem_[0]
                print(g_cand.base_verb.unique())
        print(stem)
        if v1 in ['odobriti', 'okupovati', 'osnovati']:
            continue
        g1 = morphemes[morphemes.base_verb == v1]
        LC = None if "slu" not in v1 else {"g", "ž"}
        manual_insert_g(g1, stem, dry_run=0, last_cons=LC)
        set_base_verb(g1, v)
# Out:
# kupovati okupovati
# ['kupiti']
# kupo
# provŕgati oprovŕgati
# ['vŕgati']
# vŕg
# oprovŕgati = opro vŕg ati
# oprovŕgnųti = opro vŕg nųti
# snovati osnovati
# ['']
# sn
# vějati ovějati
# ['vějati']
# ['vějati']
# věj
# ovějati = o věj ati
# ovějivati = o věj ivati
# C:\Users\79165\AppData\Local\Temp\ipykernel_25148\1388065236.py:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   g = morphemes.query("_prefix == '' and isv.str.contains('^(u|o)')").sort_values(by='base_verb')

# %%
manual_insert_g(g.query("isv.str.contains('slu')"), 'slug', dry_run=0, last_cons={"g", "ž"})
# Out:
# zasluživati = za slug ⒥ivati
# zaslužiti = za slug ⒥iti

# %%
g1 = morphemes.query("isv.str.contains('dobr.ti')")
manual_insert_g(g1, 'dobr', dry_run=0, last_cons=None)
set_base_verb(g1, 'dobrěti')
# Out:
# dobrěti =  dobr ěti
# odobriti = o dobr iti

# %%
g.head(44).tail(22)
# Out:
#            id                     isv addition  partOfSpeech  \
# 8707  36711.0  odbačati vpravo/vdesno      NaN  v.intr. ipf.
# 8724  36712.0  odbočiti vpravo/vdesno      NaN   v.intr. pf.
# 9061  36666.0           odsųtstvovati      NaN  v.intr. ipf.
# 2062   1181.0                  dojiti      NaN    v.tr. ipf.
# 2187   7215.0            doråzuměvati      NaN  v.refl. ipf.
# 2207   4208.0             doskonaliti      NaN    v.tr. ipf.
# 2235  21853.0               dostigati      NaN    v.tr. ipf.
# 2236  21855.0               dostigati      NaN    v.tr. ipf.
# 2237  21854.0              dostignųti      NaN     v.tr. pf.
# 2238  21856.0              dostignųti      NaN     v.tr. pf.
# 2203   1059.0               dosęgnųti      NaN     v.tr. pf.
# 2201   1686.0                dosęgati      NaN    v.tr. ipf.
# 8322  17992.0               obhvatiti      NaN     v.tr. pf.
# 8321  17990.0               obhvaćati      NaN    v.tr. ipf.
# 8325  34071.0                 obiđati      NaN    v.tr. ipf.
# 8324  28749.0                 obiděti      NaN     v.tr. pf.
# 8365  19923.0                obkoliti      NaN     v.tr. pf.
# 8364  19922.0               obkaljati      NaN    v.tr. ipf.
# 8387  19929.0               oblegčiti      NaN     v.tr. pf.
# 8385  19926.0               oblegčati      NaN    v.tr. ipf.
# 8426   2801.0                obmeđiti      NaN     v.tr. pf.
# 8423   2977.0                obmeđati      NaN    v.tr. ipf.
#
#                                      en genesis   pos prefix verb_stem  \
# 8707                         turn right     NaN  verb      ?         ?
# 8724                         turn right     NaN  verb      ?         ?
# 9061                 be absent, be away     NaN  verb      ?         ?
# 2062                               milk     NaN  verb      ?         ?
# 2187                        communicate     NaN  verb      ?         ?
# 2207                            perfect     NaN  verb      ?         ?
# 2235                           catch up     NaN  verb      ?         ?
# 2236             reach, achieve, attain     NaN  verb      ?         ?
# 2237                           catch up     NaN  verb      ?         ?
# 2238             reach, achieve, attain     NaN  verb      ?         ?
# 2203             reach, attain, achieve     NaN  verb      ?         ?
# 2201             reach, attain, achieve     NaN  verb      ?         ?
# 8322                     embrace, clasp     NaN  verb      ?         ?
# 8321                     embrace, clasp     NaN  verb      ?         ?
# 8325                     offend, insult     NaN  verb      ?         ?
# 8324                     offend, insult     NaN  verb      ?         ?
# 8365                           surround     NaN  verb      ?         ?
# 8364                           surround     NaN  verb      ?         ?
# 8387  ease, lighten, relieve, alleviate     NaN  verb      ?         ?
# 8385  ease, lighten, relieve, alleviate     NaN  verb      ?         ?
# 8426                            confine     NaN  verb      ?         ?
# 8423                            confine     NaN  verb      ?         ?
#
#          base_verb  ...          left_stem_cand         right_stem_cand  \
# 8707        bočiti  ...  odbačati vpravo/vdesno  ?bačati vpravo/vdesno?
# 8724        bočiti  ...  odbočiti vpravo/vdesno  ?bočiti vpravo/vdesno?
# 9061          byti  ...                odsųtstv             sųtstvovati
# 2062        dojiti  ...                      do                  ?jiti?
# 2187  doråzuměvati  ...               doråzuměv                ?měvati?
# 2207   doskonaliti  ...                doskonal              ?konaliti?
# 2235     dostigati  ...                  dostig                 stigati
# 2236     dostigati  ...                  dostig                 stigati
# 2237     dostigati  ...                  dostig                stignųti
# 2238     dostigati  ...                  dostig                stignųti
# 2203      dosęgati  ...                   dosęg                 sęgnųti
# 2201      dosęgati  ...                   dosęg                  sęgati
# 8322     obhvatiti  ...                  obhvat               ?hvatiti?
# 8321     obhvatiti  ...                  obhvać               ?hvaćati?
# 8325       obiděti  ...                    obiđ                 ?iđati?
# 8324       obiděti  ...                    obid                 ?iděti?
# 8365      obkoliti  ...                   obkol                ?koliti?
# 8364      obkoliti  ...                   obkal               ?kaljati?
# 8387     oblegčati  ...                  oblegč               ?legčiti?
# 8385     oblegčati  ...                  oblegč               ?legčati?
# 8426      obmeđati  ...                   obmeđ                ?međiti?
# 8423      obmeđati  ...                   obmeđ                ?međati?
#
#      derived_nouns base_noun _prefix     _stem _suffix _is_irregular  \
# 8707                                     odbꜵč     ati             0
# 8724                                     odbꜵč     iti             0
# 9061                                                               1
# 2062                                        do    jiti             0
# 2187                                   doråzum   ěvati             0
# 2207  |doskonalosť                    doskonal     iti             0
# 2235                                    dostig     ati             0
# 2236                                    dostig     ati             0
# 2237                                    dostig    nųti             0
# 2238                                    dostig    nųti             0
# 2203                                     dosęg    nųti             0
# 2201                                     dosęg     ati             0
# 8322                                    obhvat     iti             0
# 8321                                    obhvat    ⒥ati             0
# 8325                                      obid    ⒥ati             0
# 8324                   obida              obid     ěti             0
# 8365                                     obkꜵl     iti             0
# 8364                                     obkꜵl    jati             0
# 8387                                    oblegč     iti             0
# 8385                                    oblegč     ati             0
# 8426                                     obmeđ     iti             0
# 8423                                     obmeđ     ati             0
#
#       reconstructed aspect
# 8707            NaN    ipf
# 8724            NaN     pf
# 9061          ?byti    ipf
# 2062         dojiti    ipf
# 2187            NaN    ipf
# 2207            NaN    ipf
# 2235            NaN    ipf
# 2236            NaN    ipf
# 2237            NaN     pf
# 2238            NaN     pf
# 2203            NaN     pf
# 2201            NaN    ipf
# 8322            NaN     pf
# 8321            NaN    ipf
# 8325            NaN    ipf
# 8324            NaN     pf
# 8365            NaN     pf
# 8364            NaN    ipf
# 8387            NaN     pf
# 8385            NaN    ipf
# 8426            NaN     pf
# 8423            NaN    ipf
#
# [22 rows x 21 columns]

# %%
morphemes.loc[2236]
# Out:
# id                                21855.0
# isv                             dostigati
# addition                              NaN
# partOfSpeech                   v.tr. ipf.
# en                 reach, achieve, attain
# genesis                               NaN
# pos                                  verb
# prefix                                  ?
# verb_stem                               ?
# base_verb                         stigati
# isv_orig                        dostigati
# left_stem_cand                     dostig
# right_stem_cand                   stigati
# derived_nouns
# base_noun
# _prefix                                do
# _stem                                stig
# _suffix                               ati
# _is_irregular                           0
# reconstructed                         NaN
# aspect                                ipf
# Name: 2236, dtype: object

# %%
g1
# Out:
# Empty DataFrame
# Columns: [id, isv, addition, partOfSpeech, en, genesis, pos, prefix, verb_stem, base_verb, isv_orig, left_stem_cand, right_stem_cand, derived_nouns, base_noun, _prefix, _stem, _suffix, _is_irregular, reconstructed, aspect]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ## ANOMALY 2: rare verbs

# %%
morphemes.query("_stem.str.len() > 5 and genesis != genesis")
# Out:
#             id             isv addition    partOfSpeech  \
# 712     2880.0      besědovati      NaN    v.intr. ipf.
# 921    24689.0      blaznovati      NaN    v.intr. ipf.
# 1002    4510.0      bogohuliti      NaN    v.intr. ipf.
# 1450    6842.0       čestitati      NaN  v.tr. ipf./pf.
# 2091   19486.0     dȯlgočasiti      NaN    v.refl. ipf.
# ...        ...             ...      ...             ...
# 17673   1892.0  zloupotrěbjati      NaN      v.tr. ipf.
# 17712  22850.0     znamenovati      NaN      v.tr. ipf.
# 17713  22851.0     znamenovati      NaN      v.tr. ipf.
# 17914 -37006.0   råzpečętyvati      NaN      v.tr. ipf.
# 17921 -37004.0    zapečętyvati      NaN       v.tr.ipf.
#
#                                 en genesis   pos prefix   verb_stem  \
# 712                 converse, chat     NaN  verb      ?           ?
# 921             behave like a fool     NaN  verb      ?           ?
# 1002                     blaspheme     NaN  verb      ?           ?
# 1450                  congratulate     NaN  verb      ?           ?
# 2091                      be bored     NaN  verb      ?           ?
# ...                            ...     ...   ...    ...         ...
# 17673                abuse, misuse     NaN  verb      ?           ?
# 17712          mark, put a mark on     NaN  verb      ?           ?
# 17713  signify, mean, be a sign of     NaN  verb      ?           ?
# 17914                       unseal     NaN  verb   råz’  pečętyvati
# 17921                         seal     NaN  verb      ?           ?
#
#            base_verb  ... left_stem_cand right_stem_cand  \
# 712       besědovati  ...          besěd      besědovati
# 921       blaznovati  ...          blazn      blaznovati
# 1002      bogohuliti  ...        bogohul      bogohuliti
# 1450       čestitati  ...         čestit       čestitati
# 2091     dȯlgočasiti  ...       dȯlgočas     dȯlgočasiti
# ...              ...  ...            ...             ...
# 17673  zloupotrěbiti  ...     zloupotrěb  zloupotrěbjati
# 17712    znamenovati  ...         znamen     znamenovati
# 17713    znamenovati  ...         znamen     znamenovati
# 17914       pečętati  ...       råzpečęt    ?pečętyvati?
# 17921       pečętati  ...        zapečęt    ?pečętyvati?
#
#                               derived_nouns base_noun _prefix       _stem  \
# 712                                            besěda              besědo
# 921                                             blazn              blazno
# 1002                                                              bogohul
# 1450                                                               čestit
# 2091   |dȯlgočaśje|dȯlgočasnik|dȯlgočasnica                      dȯlgočas
# ...                                     ...       ...     ...         ...
# 17673                                                          zloupotrěb
# 17712                    |znameńje|znameńje                       znameno
# 17713                    |znameńje|znameńje                       znameno
# 17914                                                    ¬råz      pečęty
# 17921                                                     ¬za      pečęty
#
#       _suffix _is_irregular  reconstructed  aspect
# 712      vati             0     besědovati     ipf
# 921      vati             0            NaN     ipf
# 1002      iti             0            NaN     ipf
# 1450      ati             0            NaN  ipf/pf
# 2091      iti             0            NaN     ipf
# ...       ...           ...            ...     ...
# 17673    jati             0            NaN     ipf
# 17712    vati             0            NaN     ipf
# 17713    vati             0            NaN     ipf
# 17914    vati             0            NaN     ipf
# 17921    vati             0            NaN     ipf
#
# [340 rows x 21 columns]

# %%
vc = morphemes.base_verb.value_counts()

rare_verbs = vc[vc == 1].index

morphemes.query("base_verb in @rare_verbs and genesis != genesis and base_noun == ''")#._prefix.value_counts()
# Out:
#             id          isv     addition  partOfSpeech  \
# 854    34987.0     bičevati          NaN    v.tr. ipf.
# 907    22297.0  blågovolěti  (blågovoli)  v.intr. ipf.
# 922    24690.0     blědněti          NaN  v.intr. ipf.
# 925    24693.0      blejati          NaN  v.intr. ipf.
# 934    24697.0     blěstěti          NaN  v.intr. ipf.
# ...        ...          ...          ...           ...
# 17665  35008.0  zloradovati          NaN  v.refl. ipf.
# 17771   1890.0      zvųčati      (zvųči)  v.intr. ipf.
# 17789   1923.0     žalovati          NaN  v.refl. ipf.
# 17868  31713.0  žmuriti oči          NaN    v.tr. ipf.
# 17905  19473.0       žužati          NaN  v.intr. ipf.
#
#                                            en genesis   pos prefix verb_stem  \
# 854           whip, scourge, flog, flagellate     NaN  verb      ?         ?
# 907           show benevolence, show goodwill     NaN  verb      ?         ?
# 922                                 turn pale     NaN  verb      ?         ?
# 925                                     bleat     NaN  verb      ?         ?
# 934                                     shine     NaN  verb      ?         ?
# ...                                       ...     ...   ...    ...       ...
# 17665                                   gloat     NaN  verb      ?         ?
# 17771                                   sound     NaN  verb      ?         ?
# 17789                                complain     NaN  verb      ?         ?
# 17868  squint, scare off, screw up one’s eyes     NaN  verb      ?         ?
# 17905                                    buzz     NaN  verb      ?         ?
#
#          base_verb  ... left_stem_cand right_stem_cand derived_nouns  \
# 854       bičevati  ...          bičev        bičevati
# 907         volěti  ...       blågovol     blågovolěti
# 922       blědněti  ...          blědn        blědněti
# 925        blejati  ...            ble         blejati
# 934       blěstěti  ...          blěst        blěstěti
# ...            ...  ...            ...             ...           ...
# 17665  zloradovati  ...         zlorad     zloradovati    |zloradosť
# 17771      zvųčati  ...           zvųč         zvųčati      |zvųčnik
# 17789     žalovati  ...            žal        žalovati       |žalosť
# 17868      žmuriti  ...    žmuriti oči   ?žmuriti oči?        žmurky
# 17905       žužati  ...            žuž          žužati
#
#       base_noun _prefix    _stem _suffix _is_irregular  reconstructed aspect
# 854                          bič   evati             0       bičevati    ipf
# 907               blågo      vol     ěti             0            NaN    ipf
# 922                        blědn     ěti             0            NaN    ipf
# 925                          ble    jati             0        blejati    ipf
# 934                        blěst     ěti             0            NaN    ipf
# ...         ...     ...      ...     ...           ...            ...    ...
# 17665                    zlorado    vati             0            NaN    ipf
# 17771                       zvųč     ati             0            NaN    ipf
# 17789                       žalo    vati             0       žalovati    ipf
# 17868                       žmur     iti             0            NaN    ipf
# 17905                        žuž     ati             0         žužati    ipf
#
# [137 rows x 21 columns]

# %%
vc[vc == 2].index
# Out:
# Index(['pracovati', 'męti', 'prěčiti', 'luščiti', 'prědpovědati', 'lupiti',
#        'lokati', 'postigati', 'logovati', 'prěhytriti',
#        ...
#        'hvatati', 'izkusiti', 'iznuriti', 'izpovědati', 'izopačati',
#        'izobličati', 'rydati', 'hudnųti', 'izčrkati', 'hvaliti'],
#       dtype='object', length=409)

# %% [markdown]
# ## ANOMALY 2: rare endings

# %%
vc = morphemes._stem.str[-1].value_counts()

vc[vc < 120]
# Out:
# m    117
# o    117
# h    116
# ž    116
# b    107
# š     99
# i     92
# j     81
# ć     59
# u     45
# a     31
# e     29
# ě     25
# c     17
# å     11
# ŕ      9
# ų      6
# đ      4
# f      3
# Name: _stem, dtype: int64

# %%
vc = morphemes._stem.str[-1].value_counts()
#vc[vc < 120]
#rare_ends = dict(zip(vc[vc < 120].index, vc[vc < 120].values))
rare_ends = vc[vc < 120].index


morphemes[morphemes._stem.str[-1].apply(lambda x: x in rare_ends)]
# Out:
#             id           isv addition    partOfSpeech  \
# 28     19625.0   absorbovati      NaN      v.tr. ipf.
# 29     24056.0  abstrahovati      NaN  v.tr. ipf./pf.
# 363    36413.0    aranževati      NaN  v.tr. ipf./pf.
# 549    24437.0        bajati      NaN    v.intr. ipf.
# 550    34833.0        bajati      NaN    v.intr. ipf.
# ...        ...           ...      ...             ...
# 17846   7191.0          žiti   (žive)    v.intr. ipf.
# 17881  34178.0       žrěbiti      NaN    v.refl. ipf.
# 17894   1490.0     žrtvovati      NaN      v.tr. ipf.
# 17904   2627.0        žuvati   (žuje)    v.intr. ipf.
# 17905  19473.0        žužati      NaN    v.intr. ipf.
#
#                                  en genesis   pos prefix verb_stem  \
# 28                           absorb       I  verb      ?         ?
# 29                         abstract       I  verb      ?         ?
# 363                 arrange (music)       F  verb      ?         ?
# 549    babble, tell fables, narrate     NaN  verb      ?         ?
# 550       practise sorcery, conjure     NaN  verb      ?         ?
# ...                             ...     ...   ...    ...       ...
# 17846                 reside, dwell     NaN  verb      ?         ?
# 17881                          foal     NaN  verb      ?         ?
# 17894                     sacrifice     NaN  verb      ?         ?
# 17904               chew, masticate     NaN  verb      ?         ?
# 17905                          buzz     NaN  verb      ?         ?
#
#           base_verb  ... left_stem_cand right_stem_cand derived_nouns  \
# 28      absorbovati  ...         absorb     absorbovati   |absorbcija
# 29     abstrahovati  ...        abstrah    abstrahovati
# 363      aranževati  ...        aranžev      aranževati
# 549          bajati  ...             ba          bajati
# 550          bajati  ...             ba          bajati
# ...             ...  ...            ...             ...           ...
# 17846          žiti  ...              ž            žiti
# 17881       žrěbiti  ...           žrěb         žrěbiti       |žrěbec
# 17894     žrtvovati  ...           žrtv       žrtvovati
# 17904        žuvati  ...            žuv          žuvati
# 17905        žužati  ...            žuž          žužati
#
#       base_noun _prefix    _stem _suffix _is_irregular  reconstructed  aspect
# 28                        absorb   ovati             0            NaN     ipf
# 29                       abstrah   ovati             0            NaN  ipf/pf
# 363                        aranž   evati             0            NaN  ipf/pf
# 549                          baj     ati             0         bajati     ipf
# 550                          baj     ati             0         bajati     ipf
# ...         ...     ...      ...     ...           ...            ...     ...
# 17846                         ži      ti            -1           žiti     ipf
# 17881                       žrěb     iti             0            NaN     ipf
# 17894     žrtva            žrtvo    vati             0            NaN     ipf
# 17904                         žu    vati             0            NaN     ipf
# 17905                        žuž     ati             0         žužati     ipf
#
# [1084 rows x 21 columns]

# %%
morphemes[morphemes._stem.str[-1].apply(lambda x: x in list('žšćěcåŕųđ'))].base_verb.value_counts()
# Out:
# dŕžati          29
# pušćati         21
# †ložiti         19
# děti            18
# měšati          13
#                 ..
# mrěti            1
# dyšati           1
# dųnųti           1
# distancevati     1
# žužati           1
# Name: base_verb, Length: 83, dtype: int64

# %%
morphemes[morphemes._stem.str[-1].apply(lambda x: x in list('ćåŕųđ'))].base_verb.value_counts()
# Out:
# pušćati         21
# obraćati        12
# vraćati         10
# vŕnųti           9
# klåti            7
# dųti             5
# občiti           5
# strěćati         3
# obråtiti         2
# pråti            2
# odčuđati         2
# obmeđati         2
# obobćati         2
# oběćati          2
# noćevati         2
# upȯlnomoćiti     2
# dųnųti           1
# Name: base_verb, dtype: int64

# %% [markdown]
# ## ANOMALY 3: english doubles

# %%
# g = morphemes.query("base_verb == 'očišćati'")
# manual_insert_g(g, "čist", last_cons={"t", "ć"}, dry_run=0)
# set_base_verb(g, 'čistiti')

# %%
BV = morphemes.query("_prefix == 'p'").base_verb.unique()

EN_BV = morphemes.query("base_verb in @BV").en.unique()


morphemes.query("en in @EN_BV").sort_values(by='en')
# Out:
#             id           isv  addition  partOfSpeech  \
# 8388   22524.0      oblěkati       NaN    v.tr. ipf.
# 8390   22520.0       oblěkti       NaN     v.tr. pf.
# 8768   16840.0         oděti   (oděne)     v.tr. pf.
# 8770   16838.0       oděvati       NaN    v.tr. ipf.
# 8777    5382.0   odgovarjati       NaN    v.tr. ipf.
# 8778   34094.0   odgovarjati       NaN    v.tr. ipf.
# 8780    3242.0    odgovoriti       NaN     v.tr. pf.
# 8781   29087.0    odgovoriti       NaN     v.tr. pf.
# 8816    2225.0     odkladati       NaN    v.tr. ipf.
# 8817    5568.0     odkladati       NaN    v.tr. ipf.
# 8865    2984.0      odložiti       NaN     v.tr. pf.
# 8866    5569.0      odložiti       NaN     v.tr. pf.
# 8949    2189.0    odpovědati       NaN    v.tr. ipf.
# 8951    2972.0    odpověděti  (odpově)     v.tr. pf.
# 9697   32355.0      osvęćati       NaN    v.tr. ipf.
# 9743   34957.0      otręsati       NaN    v.tr. ipf.
# 9744   34958.0       otręsti       NaN     v.tr. pf.
# 10355  18249.0        poděti       NaN   v.refl. pf.
# 10356  18251.0      poděvati       NaN  v.refl. ipf.
# 10362  18254.0  podgovarjati       NaN    v.tr. ipf.
# 10363  18255.0   podgovoriti       NaN     v.tr. pf.
# 10376  32682.0    podkladati       NaN    v.tr. ipf.
# 10393  32683.0     podlagati       NaN    v.tr. ipf.
# 10402  32684.0     podložiti       NaN     v.tr. pf.
# 10962   3070.0     posvęćati       NaN    v.tr. ipf.
# 10968    652.0     posvętiti       NaN     v.tr. pf.
# 11000  34956.0     potręsati       NaN    v.tr. ipf.
# 11470  35288.0      prěoděti       NaN   v.refl. pf.
# 11471  35287.0    prěoděvati       NaN  v.refl. ipf.
#
#                                            en genesis   pos prefix verb_stem  \
# 8388                            clothe, dress     NaN  verb      ?         ?
# 8390                            clothe, dress     NaN  verb      ?         ?
# 8768                            clothe, dress     NaN  verb      ?         ?
# 8770                            clothe, dress     NaN  verb      ?         ?
# 8777                            answer, reply     NaN  verb      ?         ?
# 8778                                 dissuade     NaN  verb      ?         ?
# 8780                            answer, reply     NaN  verb      ?         ?
# 8781                                 dissuade     NaN  verb      ?         ?
# 8816                 suspend, postpone, delay     NaN  verb      ?         ?
# 8817   put away, put off, put aside, put back     NaN  verb      ?         ?
# 8865                 suspend, postpone, delay     NaN  verb      ?         ?
# 8866   put away, put off, put aside, put back     NaN  verb      ?         ?
# 8949                            answer, reply     NaN  verb      ?         ?
# 8951                            answer, reply     NaN  verb      ?         ?
# 9697                     sanctify, consecrate     NaN  verb      ?         ?
# 9743                                shake off     NaN  verb      ?         ?
# 9744                                shake off     NaN  verb      ?         ?
# 10355                    disappear, be hidden     NaN  verb      ?         ?
# 10356                    disappear, be hidden     NaN  verb      ?         ?
# 10362                                  incite     NaN  verb      ?         ?
# 10363                                  incite     NaN  verb      ?         ?
# 10376                               put under     NaN  verb      ?         ?
# 10393                               put under     NaN  verb      ?         ?
# 10402                               put under     NaN  verb      ?         ?
# 10962                        dedicate, devote     NaN  verb      ?         ?
# 10968                        dedicate, devote     NaN  verb      ?         ?
# 11000                        joggle, brandish     NaN  verb      ?         ?
# 11470                dress up, change clothes     NaN  verb      ?         ?
# 11471                dress up, change clothes     NaN  verb      ?         ?
#
#          base_verb       isv_orig left_stem_cand right_stem_cand  \
# 8388        vlěkti       oblěkati          oblěk        ?lěkati?
# 8390        vlěkti        oblěkti        oblěkti         ?lěkti?
# 8768          děti          oděti             od            děti
# 8770       oděvati        oděvati           oděv         ?ěvati?
# 8777   odgovarjati    odgovarjati        odgovar     ?govarjati?
# 8778   odgovarjati    odgovarjati        odgovar     ?govarjati?
# 8780      govoriti     odgovoriti        odgovor        govoriti
# 8781      govoriti     odgovoriti        odgovor        govoriti
# 8816     odkladati      odkladati         odklad       ?kladati?
# 8817     odkladati      odkladati         odklad       ?kladati?
# 8865      odložiti       odložiti          odlož        ?ložiti?
# 8866      odložiti       odložiti          odlož        ?ložiti?
# 8949    odpovědati     odpovědati        odpověd        povědati
# 8951    odpovědati     odpověděti        odpověd          věděti
# 9697      osvęćati       osvęćati          osvęć         ?ęćati?
# 9743      otręsati       otręsati          otręs       ?tręsati?
# 9744        tręsti        otręsti        otręsti          tręsti
# 10355         děti      poděti sę            pod            děti
# 10356      oděvati    poděvati sę          poděv         oděvati
# 10362  odgovarjati   podgovarjati       podgovar     odgovarjati
# 10363     govoriti    podgovoriti       podgovor        govoriti
# 10376    odkladati     podkladati        podklad       odkladati
# 10393      †lagati      podlagati         podlag        ?lagati?
# 10402     odložiti      podložiti         podlož        odložiti
# 10962     osvęćati      posvęćati         posvęć        osvęćati
# 10968      svętiti      posvętiti         posvęt         svętiti
# 11000     otręsati      potręsati         potręs        otręsati
# 11470         děti    prěoděti sę          prěod            děti
# 11471      oděvati  prěoděvati sę        prěoděv         oděvati
#
#       derived_nouns base_noun _prefix    _stem _suffix  _is_irregular
# 8388                               ob      lěk     ati              0
# 8390                               ob      lěk      ti              0
# 8768                                o       dě      ti             -1
# 8770                                        od   ěvati              0
# 8777                                   odgovar    jati              0
# 8778                                   odgovar    jati              0
# 8780                               od    govꜵr     iti              0
# 8781                               od    govꜵr     iti              0
# 8816                                    odklad     ati              0
# 8817                                    odklad     ati              0
# 8865                                     odlož     iti              0
# 8866                                     odlož     iti              0
# 8949    |odpovědnik  !odpověď          odpověd     ati              0
# 8951    |odpovědnik                    odpověd     ěti              0
# 9697                                     osvęć     ati              0
# 9743                                     otręs     ati              0
# 9744                                o     tręs      ti              0
# 10355                              po       dě      ti             -1
# 10356                               p       od   ěvati              0
# 10362                               p  odgovar    jati              0
# 10363                             pod    govꜵr     iti              0
# 10376                               p   odklad     ati              0
# 10393                             pod      lag     ati              0
# 10402     |podložka                 p    odlož     iti              0
# 10962                               p    osvęć     ati              0
# 10968                              po     svęt     iti              0
# 11000                               p    otręs     ati              0
# 11470                            prěo       dě      ti             -1
# 11471                             prě       od   ěvati              0

# %%
CONS = 'hńmzdjčåuđtkbćlsrcťšpŕžfnvg'

# %%
profiles = set()
L = 0

cnt1 = Counter()
for k, g in morphemes.groupby("en"):
    if k[0] != "#" and len(g) > 1 and len(g.base_verb.unique()) > 1:
         
        if "" in g.base_verb.unique():
            cur_profile = tuple(g.isv.unique())
        else:
            cur_profile = tuple(g.base_verb.unique())
        if cur_profile not in profiles:
            profiles.add(cur_profile)
            L += 1
            stem_cons = g._stem.apply(lambda x: ''.join(c for c in x if c in CONS))
            cnt1[(len(cur_profile), len(g._stem.unique()), len(stem_cons.unique()))] += 1
            if len(cur_profile) == 2 and len(g._stem.unique()) == 1:
                print(k, cur_profile)
            if len(cur_profile) == 2 and len(stem_cons.unique()) < 2:
                print("    ", k, cur_profile)
                if len(stem_cons) == 1:
                    pass
                    #print(g.isv.values)
                    #print(g.base_verb.values)


        #if L == 30:
        #    print(k, cur_profile)
# ['jęti' 'imati'] 'pustiti' 'pušćati'
# ['znati' 'poznavati']
# ['byti' 'byvati'] ['baviti' 'dati' 'davati' '†kladati' '†ložiti']
# ['dati' 'davati'] obraćati obråtiti
# ['staviti' 'stavjati'
# posȯvětovati sȯvětovati ['lětati' 'letěti'] ['postaviti' 'staviti']
 # ???  ['vnikati' 'vȯznikati']  ['prikladati' 'priložiti']
    # ['vezti' 'voziti'] ['pokladati' '†lagati' 'položiti']  

L
# Out:
# acquire ('byti', 'byvati')
#      acquire ('byti', 'byvati')
# appear (before a court) ('stati', 'stavati')
#      appear (before a court) ('stati', 'stavati')
#      approve, approbate, sanction ('dobrěti', 'odobriti')
#      arrive (by flying) ('lětati', 'letěti')
# avoid ('běgati', 'běgti')
#      avoid ('běgati', 'běgti')
#      be inclined, be prone to, yield to ('klanjati', 'kloniti')
# become stronger ('krěpěti', 'krěpiti')
#      become stronger ('krěpěti', 'krěpiti')
#      beget, procreate ('raditi', 'roditi')
#      behave like a fool ('blazniti', 'blaznovati')
#      bestow ('dariti', 'darovati')
# blow ('dųnųti', 'dųti')
#      blow ('dųnųti', 'dųti')
#      break ('lamati', 'lomiti')
#      breathe in ('dȯhnųti', 'dyhati')
#      bring away ('vezti', 'voziti')
# chop up ('sěkati', 'sěkti')
#      chop up ('sěkati', 'sěkti')
#      climb ('laziti', 'lězti')
# collapse, fall apart ('valiti', 'råzvaliti')
#      collapse, fall apart ('valiti', 'råzvaliti')
# crawl out ('pȯlzati', 'pȯlzti')
#      crawl out ('pȯlzati', 'pȯlzti')
# crucify ('pęti', 'pinati')
#      crucify ('pęti', 'pinati')
#      disregard, despise, scorn, hold in contempt ('prězirati', 'prězrěti')
#      drive, chase ('gnati', 'goniti')
#      elapse, pass, pass by ('minovati', 'minųti')
# emerge, come to the surface ('plěti', 'plyvti')
#      emerge, come to the surface ('plěti', 'plyvti')
#      examine, consider ('smatrjati', 'smotriti')
#      exploit, take advantage of, utilize ('koristati', 'koristiti')
# grab, grasp, seize ('hvatati', 'shvatiti')
#      grab, grasp, seize ('hvatati', 'shvatiti')
# last, continue, endure, go on ('trajati', 'trvati')
#      last, continue, endure, go on ('trajati', 'trvati')
# lean against ('legati', 'legti')
#      lean against ('legati', 'legti')
#      lean against something, rest on something ('pirati', 'poriti')
# peck, pick, pluck ('kljunųti', 'kljuvati')
#      peck, pick, pluck ('kljunųti', 'kljuvati')
# pick, pluck ('trgati', 'trgnųti')
#      pick, pluck ('trgati', 'trgnųti')
# protrude ('sunųti', 'suvati')
#      protrude ('sunųti', 'suvati')
#      rake ('grabiti', 'grebti')
# see ('uviděti', 'viděti')
#      see ('uviděti', 'viděti')
# sober up ('trězvěti', 'otrězviti')
#      sober up ('trězvěti', 'otrězviti')
# spit ('pljuvati', 'pljunųti')
#      spit ('pljuvati', 'pljunųti')
# spit at ('pljunųti', 'pljuvati')
#      spit at ('pljunųti', 'pljuvati')
#      stone ('kamenovati', 'kameněti')
#      subdue, subjugate ('karati', 'koriti')
# sweeten, add sugar to ('oslåditi', 'slåditi')
#      sweeten, add sugar to ('oslåditi', 'slåditi')
# think, believe, suppose, opine, have an opinion, think likely ('mněti', 'mněvati')
#      think, believe, suppose, opine, have an opinion, think likely ('mněti', 'mněvati')
# throw, toss ('metati', 'metnųti')
#      throw, toss ('metati', 'metnųti')
# vomit ('bljunųti', 'bljuvati')
#      vomit ('bljunųti', 'bljuvati')
#      want ('hotěti', 'htěti')
#      warp ('osnovati', 'snovati')
# 324

# %%
cnt1
# Out:
# Counter({(4, 4, 4): 9,
#          (2, 3, 2): 23,
#          (2, 2, 2): 180,
#          (2, 1, 1): 24,
#          (5, 5, 5): 3,
#          (3, 3, 3): 31,
#          (2, 2, 1): 21,
#          (4, 3, 3): 2,
#          (3, 4, 3): 3,
#          (3, 4, 4): 2,
#          (3, 2, 2): 9,
#          (3, 3, 2): 9,
#          (3, 4, 2): 1,
#          (5, 7, 5): 1,
#          (2, 3, 3): 4,
#          (4, 4, 3): 1,
#          (4, 5, 4): 1})

# %%
morphemes.query("base_verb == 'tkati'")
# Out:
#             id      isv addition partOfSpeech     en genesis   pos prefix  \
# 4309   26247.0  iztkati      NaN    v.tr. pf.  weave     NaN  verb      ?
# 14133  34857.0  sȯtkati      NaN    v.tr. pf.  weave     NaN  verb    sȯ’
# 15231  34856.0    tkati      NaN   v.tr. ipf.  weave     NaN  verb      ?
#
#       verb_stem base_verb  ... left_stem_cand right_stem_cand derived_nouns  \
# 4309          ?     tkati  ...           iztk           tkati
# 14133     tkati     tkati  ...           sȯtk           tkati
# 15231         ?     tkati  ...             tk           tkati
#
#       base_noun _prefix _stem _suffix _is_irregular  reconstructed aspect
# 4309                ¬iz    tk     ati             0    (iz)+tъkati     pf
# 14133               ¬sȯ    tk     ati             0    (sȯ)+tъkati     pf
# 15231                      tk     ati             0         tъkati    ipf
#
# [3 rows x 21 columns]

# %%
len(morphemes.isv.unique()), len(morphemes.base_verb.unique())
# Out:
# (4163, 1308)

# %%
from collections import Counter

Counter(len(p) for p in profiles)
# Out:
# Counter({3: 63, 5: 3, 2: 262, 4: 13, 7: 1})

# %%
morphemes.query("en == 'advise, counsel'")
# Out:
#            id           isv addition partOfSpeech               en genesis  \
# 10905  6019.0  posȯvětovati      NaN    v.tr. pf.  advise, counsel     NaN
# 14143  4475.0    sȯvětovati      NaN   v.tr. ipf.  advise, counsel     NaN
#
#         pos prefix verb_stem   base_verb  ... left_stem_cand right_stem_cand  \
# 10905  verb      ?         ?  sȯvětovati  ...        posȯvět      sȯvětovati
# 14143  verb    sȯ’  větovati              ...          sȯvět       ?ětovati?
#
#       derived_nouns base_noun _prefix  _stem _suffix _is_irregular  \
# 10905          věće            ¬po¬sȯ    vět   ovati             0
# 14143     |sȯvětnik     sȯvět          sȯvět   ovati             0
#
#        reconstructed aspect
# 10905            NaN     pf
# 14143         ?uměti    ipf
#
# [2 rows x 21 columns]

# %%
['jęti' 'imati']

# %%
g
# Out:
#            id        isv addition partOfSpeech   en genesis   pos prefix  \
# 1983  21272.0   dobaviti      NaN    v.tr. pf.  add     NaN  verb      ?
# 1984  21273.0  dobavjati      NaN   v.tr. ipf.  add     NaN  verb      ?
# 2027    311.0     dodati   (doda)    v.tr. pf.  add     NaN  verb      ?
# 2036   1704.0   dodavati      NaN   v.tr. ipf.  add     NaN  verb      ?
# 2068  19676.0  dokladati      NaN   v.tr. ipf.  add     NaN  verb      ?
# 2117  20364.0   doložiti      NaN    v.tr. pf.  add     NaN  verb      ?
#
#      verb_stem base_verb  ... left_stem_cand right_stem_cand derived_nouns  \
# 1983         ?    baviti  ...          dobav          baviti
# 1984         ?    baviti  ...          dobav       ?bavjati?
# 2027         ?      dati  ...            dod            dati
# 2036         ?    davati  ...          dodav          davati
# 2068         ?  †kladati  ...         doklad       ?kladati?
# 2117         ?   †ložiti  ...          dolož        ?ložiti?
#
#      base_noun _prefix _stem _suffix _is_irregular  reconstructed aspect
# 1983               ¬do   bav     iti            -1    (do)+baviti     pf
# 1984               ¬do   bav    jati            -1        ?baviti    ipf
# 2027               ¬do    da      ti             0         dodati     pf
# 2036               ¬do   dav     ati            -1    (do)+davati    ipf
# 2068               ¬do  klad     ati             0   (do)+kladati    ipf
# 2117               ¬do   lož     iti             0    (do)+ložiti     pf
#
# [6 rows x 21 columns]

# %%
'pustiti' 'pušćati'


# g = morphemes.query("base_verb == 'očišćati'")
# manual_insert_g(g, "čist", last_cons={"t", "ć"}, dry_run=0)
# set_base_verb(g, 'čistiti')

# %%
EN_TMP = morphemes.en.value_counts().head(11).index

morphemes.query('en in @EN_TMP').sort_values(by="en")
# Out:
#             id            isv addition  partOfSpeech   en genesis   pos  \
# 1983   21272.0       dobaviti      NaN     v.tr. pf.  add     NaN  verb
# 1984   21273.0      dobavjati      NaN    v.tr. ipf.  add     NaN  verb
# 2027     311.0         dodati   (doda)     v.tr. pf.  add     NaN  verb
# 2036    1704.0       dodavati      NaN    v.tr. ipf.  add     NaN  verb
# 2068   19676.0      dokladati      NaN    v.tr. ipf.  add     NaN  verb
# ...        ...            ...      ...           ...  ...     ...   ...
# 3454   17458.0       hlipnųti      NaN   v.intr. pf.  sob     NaN  verb
# 3453   17457.0        hlipati      NaN  v.intr. ipf.  sob     NaN  verb
# 3110   17418.0  gȯltati sȯlzy      NaN        v.ipf.  sob     NaN  verb
# 13308  18676.0         rydati      NaN  v.intr. ipf.  sob     NaN  verb
# 17441  19407.0       zarydati      NaN   v.intr. pf.  sob     NaN  verb
#
#       prefix verb_stem base_verb  ... left_stem_cand  right_stem_cand  \
# 1983       ?         ?    baviti  ...          dobav           baviti
# 1984       ?         ?    baviti  ...          dobav        ?bavjati?
# 2027       ?         ?      dati  ...            dod             dati
# 2036       ?         ?    davati  ...          dodav           davati
# 2068       ?         ?  †kladati  ...         doklad        ?kladati?
# ...      ...       ...       ...  ...            ...              ...
# 3454       ?         ?   hlipati  ...           hlip         hlipnųti
# 3453       ?         ?   hlipati  ...           hlip          hlipati
# 3110       ?         ?   gȯltati  ...  gȯltati sȯlzy  ?gȯltati sȯlzy?
# 13308      ?         ?    rydati  ...            ryd           rydati
# 17441      ?         ?    rydati  ...          zaryd           rydati
#
#       derived_nouns base_noun _prefix _stem _suffix _is_irregular  \
# 1983                              ¬do   bav     iti            -1
# 1984                              ¬do   bav    jati            -1
# 2027                              ¬do    da      ti             0
# 2036                              ¬do   dav     ati            -1
# 2068                              ¬do  klad     ati             0
# ...             ...       ...     ...   ...     ...           ...
# 3454                                   hlip    nųti             0
# 3453                                   hlip     ati             0
# 3110                                   gȯlt     ati             0
# 13308                                   ryd     ati             0
# 17441                             ¬za   ryd     ati             0
#
#        reconstructed aspect
# 1983     (do)+baviti     pf
# 1984         ?baviti    ipf
# 2027          dodati     pf
# 2036     (do)+davati    ipf
# 2068    (do)+kladati    ipf
# ...              ...    ...
# 3454             NaN     pf
# 3453             NaN    ipf
# 3110             NaN    ipf
# 13308         rydati    ipf
# 17441    (za)+rydati     pf
#
# [79 rows x 21 columns]

# %% [markdown]
# ## ANOMALY 4: empty

# %%
morphemes[morphemes.base_verb == ""]
# Out:
#             id            isv addition      partOfSpeech  \
# 1185   22979.0     bųde/bųdųt      NaN       v.aux. ipf.
# 1710   25144.0     debatovati      NaN      v.intr. ipf.
# 1716   25152.0    debjutovati      NaN  v.intr. ipf./pf.
# 1735   15280.0     defisovati      NaN        v.tr. ipf.
# 2085   35297.0  dokumentovati      NaN    v.tr. ipf./pf.
# ...        ...            ...      ...               ...
# 17164  35915.0  zagospodariti      NaN         v.tr. pf.
# 17231  31509.0      zakliniti      NaN         v.tr. pf.
# 17232  33665.0    zaklinovati      NaN        v.tr. ipf.
# 17537  14193.0     zautrakati      NaN      v.intr. ipf.
# 17544  31583.0       zavěćati      NaN    v.tr. ipf./pf.
#
#                                        en genesis   pos prefix    verb_stem  \
# 1185                        there will be     NaN  verb      ?            ?
# 1710                               debate       I  verb      ’   debatovati
# 1716                     make one’s debut       F  verb      ’  debjutovati
# 1735                            hyphenate       I  verb      ’   defisovati
# 2085                             document       I  verb      ?            ?
# ...                                   ...     ...   ...    ...          ...
# 17164  gain authority over, begin to rule     NaN  verb      ?            ?
# 17231                               wedge     NaN  verb      ?            ?
# 17232                               wedge     NaN  verb      ?            ?
# 17537      eat breakfast, have breakfrast     NaN  verb      ?            ?
# 17544             bequeath, leave by will     NaN  verb      ?            ?
#
#       base_verb  ... left_stem_cand right_stem_cand   derived_nouns base_noun  \
# 1185             ...     bųde/bųdųt    ?bųde/bųdųt?
# 1710             ...          debat      ?batovati?                    debata
# 1716             ...         debjut     ?bjutovati?                    debjut
# 1735             ...          defis      ?fisovati?                     defis
# 2085             ...       dokument   ?kumentovati?  |dokumentacija  dokument
# ...         ...  ...            ...             ...             ...       ...
# 17164            ...     zagospodar   ?gospodariti?                  gospodaŕ
# 17231            ...         zaklin       ?kliniti?                      klin
# 17232            ...         zaklin     ?klinovati?                      klin
# 17537            ...        zautrak       ?trakati?                  zautraka
# 17544            ...          zavěć         ?ěćati?                     zavět
#
#       _prefix     _stem _suffix _is_irregular  reconstructed  aspect
# 1185                                        0         ?uměti     ipf
# 1710              debat   ovati             0         ?uměti     ipf
# 1716             debjut   ovati             0         ?uměti  ipf/pf
# 1735              defis   ovati             0         ?uměti     ipf
# 2085           dokument   ovati             0         ?uměti  ipf/pf
# ...       ...       ...     ...           ...            ...     ...
# 17164     ¬za  gospodar     iti             0         ?uměti      pf
# 17231     ¬za      klin     iti             0         ?uměti      pf
# 17232     ¬za      klin   ovati             0         ?uměti     ipf
# 17537           zautrak     ati             0         ?uměti     ipf
# 17544             zavět    ⒥ati             0         ?uměti  ipf/pf
#
# [105 rows x 21 columns]

# %% [markdown]
# ## ANOMALY 5: pf/ipf counts

# %%
morphemes.partOfSpeech.value_counts()
# Out:
# v.tr. ipf.          1792
# v.tr. pf.           1499
# v.intr. ipf.         574
# v.refl. ipf.         328
# v.intr. pf.          319
# v.refl. pf.          263
# v.tr. ipf./pf.        89
# v.ipf.                56
# v.pf.                 23
# v.intr. ipf./pf.      16
# v.aux. ipf.           12
# v.refl. ipf./pf.       3
# #v.tr. ipf.            3
# #v.intr. ipf.          2
# v.aux. pf.             2
# #v.tr.ipf              1
# #v.intr. pf.           1
# #v.tr. pf.             1
# v.tr.ipf.              1
# Name: partOfSpeech, dtype: int64

# %%
morphemes.query("not isv_orig.str.contains(' sę') and partOfSpeech.str.contains('refl')").isv_orig.unique()
# Out:
# array(['prědstaviti sobě', 'prědstavjati sobě'], dtype=object)

# %%
morphemes['aspect'] = morphemes.partOfSpeech.apply(
    lambda x: (
        "ipf/pf" if "ipf./pf." in x else (
            "ipf" if "ipf" in x else (
                "pf" if "pf" in x else "?"
            )
        )
    )
)

# %%
morphemes['aspect'].value_counts()
# Out:
# ipf       2769
# pf        2108
# ipf/pf     108
# Name: aspect, dtype: int64

# %%
i = 0
for k, g in morphemes.groupby("base_verb"):
    if k == '' or len(g) < 3:
        continue
    for k1, g1 in g.groupby("_prefix"):
        aspects_dict = g1['aspect'].value_counts().to_dict()
        if not (aspects_dict in [{'pf': 1, 'ipf': 1}, {'pf': 1}]):
            if 'pf' not in aspects_dict and k1 == '' and aspects_dict['ipf'] == len(g1.en.unique()):
                continue
            if aspects_dict.get('pf') == aspects_dict.get('ipf') == len(g1.en.str.replace("#", "").unique()):
                continue
            if 'ipf' not in aspects_dict and aspects_dict.get('pf') == len(g1.en.unique()):
                continue
            if 'ipf' not in aspects_dict and aspects_dict.get('pf') == len(g1.partOfSpeech.unique()):
                print("!!!")
                print(aspects_dict)
                print(g1[['isv', 'partOfSpeech', 'en', '_prefix', '_stem',]])
                print("!!!")
                continue
            i += 1
            print(k1)
            print(aspects_dict)
            print(g1[['isv', 'partOfSpeech', 'en', '_prefix', '_stem',]])

    #print(k)
    #print(g['aspect'].value_counts())
    if i == 15: break
# Out:
# ¬de
# {'ipf/pf': 1}
#               isv      partOfSpeech       en _prefix _stem
# 1717  deblokovati  v.intr. ipf./pf.  unblock     ¬de  blok
# ¬za
# {'pf': 2, 'ipf': 1}
#               isv  partOfSpeech                      en _prefix _stem
# 17092    zabolěti   v.intr. pf.      fall ill, get sick     ¬za   bol
# 17093    zabolěti   v.intr. pf.  hurt, ache, be painful     ¬za   bol
# 17096  zabolěvati  v.intr. ipf.      fall ill, get sick     ¬za   bol
# ¬s
# {'ipf': 2}
#            isv  partOfSpeech                                  en _prefix _stem
# 13413  sbirati  v.refl. ipf.                             prepare      ¬s   bir
# 13414  sbirati    v.tr. ipf.  gather, assemble, collect, pick up      ¬s   bir
#
# {'ipf': 2}
#         isv  partOfSpeech     en _prefix _stem
# 1143  briti  v.refl. ipf.  shave            br
# 1144  briti    v.tr. ipf.  shave            br
# !!!
# {'pf': 2}
#          isv partOfSpeech     en _prefix _stem
# 8540  obriti  v.refl. pf.  shave     ¬ob     r
# 8541  obriti    v.tr. pf.  shave     ¬ob     r
# !!!
# ¬o
# {'ipf': 1}
#             isv partOfSpeech                          en _prefix  _stem
# 8559  obryzgati   v.tr. ipf.  splash sb/sth (with water)      ¬o  bryzg
#
# {'ipf': 13}
#                       isv  partOfSpeech  \
# 1246          byti dȯlžen   v.aux. ipf.
# 1248        byti ostråžny        v.ipf.
# 1249         byti podobny        v.ipf.
# 1250      byti prěhlåđeny        v.ipf.
# 1251       byti prinuđeny        v.ipf.
# 1252        byti sȯglåsny        v.ipf.
# 1253                 byti  v.intr. ipf.
# 1254                 byti  v.intr. ipf.
# 4592           jestvovati  v.intr. ipf.
# 9061        odsųtstvovati  v.intr. ipf.
# 11859  prisųtstvovati pri  v.intr. ipf.
# 14700                 sųt   v.aux. ipf.
# 14707         sųtstvovati  v.intr. ipf.
#
#                                                       en _prefix _stem
# 1246   must, have to, ought to, should, be obliged to...            by
# 1248                                 look out, watch out            by
# 1249                                look alike, resemble            by
# 1250                                         have a cold            by
# 1251                               have to, be forced to            by
# 1252                                               agree            by
# 1253                                                  be            by
# 1254                       exist, be there, be available            by
# 4592                                               exist
# 9061                                  be absent, be away
# 11859                              attend, be present at
# 14700                                          there are
# 14707                                              exist
# ¬do
# {'ipf': 3}
#                    isv partOfSpeech                  en _prefix _stem
# 2018  dobyvati ponovno   v.tr. ipf.              regain     ¬do    by
# 2019          dobyvati   v.tr. ipf.         get, obtain     ¬do    by
# 2020          dobyvati   v.tr. ipf.  win, conquer, gain     ¬do    by
# ¬na
# {'ipf': 1}
#            isv partOfSpeech       en _prefix _stem
# 7065  nabyvati   v.tr. ipf.  acquire     ¬na    by
# ¬o
# {'ipf': 1}
#           isv partOfSpeech               en _prefix _stem
# 8659  obyvati   v.tr. ipf.  inhabit, reside      ¬o    by
# ¬od
# {'ipf': 1}
#            isv  partOfSpeech                  en _prefix _stem
# 8729  odbyvati  v.refl. ipf.  happen, take place     ¬od    by
# ¬pri
# {'ipf': 1}
#              isv  partOfSpeech      en _prefix _stem
# 11661  pribyvati  v.intr. ipf.  arrive    ¬pri    by
# ¬prě
# {'ipf': 1}
#              isv  partOfSpeech                                   en _prefix  \
# 11235  prěbyvati  v.intr. ipf.  stay, reside, remain, linger, abide    ¬prě
#
#       _stem
# 11235    by
# ¬za
# {'ipf': 1}
#             isv partOfSpeech      en _prefix _stem
# 17103  zabyvati   v.tr. ipf.  forget     ¬za    by
# ¬do
# {'ipf': 1}
#               isv  partOfSpeech                  en _prefix _stem
# 1985  doběgati do  v.intr. ipf.  reach (by running)     ¬do   běg
# ¬iz
# {'ipf': 3}
#            isv  partOfSpeech            en _prefix _stem
# 3907  izběgati  v.intr. ipf.  escape, flee     ¬iz   běg
# 3908  izběgati  v.intr. ipf.         avoid     ¬iz   běg
# 3909  izběgati  v.intr. ipf.       run out     ¬iz   běg
# ¬od
# {'ipf': 1}
#            isv  partOfSpeech       en _prefix _stem
# 8708  odběgati  v.intr. ipf.  run off     ¬od   běg
# ¬råz
# {'ipf': 2}
#              isv  partOfSpeech                               en _prefix _stem
# 12476  råzběgati  v.refl. ipf.             #start running a lot    ¬råz   běg
# 12477  råzběgati  v.refl. ipf.  run in all directions, disperse    ¬råz   běg
# ¬s
# {'ipf': 1}
#            isv  partOfSpeech                  en _prefix _stem
# 13410  sběgati  v.refl. ipf.  coincide, converge      ¬s   běg
# ¬u
# {'ipf': 1}
#            isv  partOfSpeech        en _prefix _stem
# 15551  uběgati  v.intr. ipf.  run away      ¬u   běg
# blågo
# {'ipf': 1}
#              isv partOfSpeech     en _prefix _stem
# 887  blågodariti   v.tr. ipf.  thank   blågo   dar
# ¬do
# {'ipf': 2}
#            isv partOfSpeech      en _prefix _stem
# 2036  dodavati   v.tr. ipf.     add     ¬do   dav
# 2037  dodavati   v.tr. ipf.  upload     ¬do   dav
# ¬iz
# {'ipf': 4}
#                  isv  partOfSpeech                    en _prefix _stem
# 3964        izdavati  v.refl. ipf.                  seem     ¬iz   dav
# 3965  izdavati zamųž    v.tr. ipf.  marry off (to a man)     ¬iz   dav
# 3966        izdavati    v.tr. ipf.        publish, issue     ¬iz   dav
# 3967        izdavati    v.tr. ipf.              give out     ¬iz   dav
# ¬na
# {'ipf': 1}
#            isv partOfSpeech                    en _prefix _stem
# 7096  nadavati   v.tr. ipf.  bestow, confer, give     ¬na   dav
# ¬od
# {'ipf': 1}
#            isv partOfSpeech         en _prefix _stem
# 8753  oddavati   v.tr. ipf.  give away     ¬od   dav
# ¬po
# {'ipf': 2}
#                            isv partOfSpeech                         en  \
# 10331  podavati parų prikladov       v.ipf.  give a couple of examples
# 10332                 podavati   v.tr. ipf.      give, provide, submit
#
#       _prefix _stem
# 10331     ¬po   dav
# 10332     ¬po   dav
# ¬pod
# {'ipf': 2}
#              isv  partOfSpeech                        en _prefix _stem
# 10345  poddavati  v.refl. ipf.  surrender, yield, submit    ¬pod   dav
# 10346  poddavati    v.tr. ipf.         surrender, submit    ¬pod   dav
# ¬pri
# {'ipf': 1}
#              isv partOfSpeech           en _prefix _stem
# 11671  pridavati   v.tr. ipf.  add, attach    ¬pri   dav
# ¬pro
# {'ipf': 1}
#              isv partOfSpeech    en _prefix _stem
# 11975  prodavati   v.tr. ipf.  sell    ¬pro   dav
# ¬prě
# {'ipf': 3}
#              isv partOfSpeech                          en _prefix _stem
# 11256  prědavati   v.tr. ipf.  hand over, deliver, convey    ¬prě   dav
# 11257  prědavati   v.tr. ipf.                   broadcast    ¬prě   dav
# 11258  prědavati   v.tr. ipf.                      betray    ¬prě   dav
# ¬råz
# {'ipf': 1}
#              isv partOfSpeech                                en _prefix _stem
# 12506  råzdavati   v.tr. ipf.  hand round, give out, distribute    ¬råz   dav
# ¬råz¬pro
# {'ipf': 1}
#                 isv partOfSpeech        en   _prefix _stem
# 12799  råzprodavati   v.tr. ipf.  sell out  ¬råz¬pro   dav
# ¬s
# {'ipf': 1}
#            isv  partOfSpeech    en _prefix _stem
# 13435  sdavati  v.refl. ipf.  seem      ¬s   dav
# ¬u
# {'ipf': 1}
#            isv  partOfSpeech  \
# 15606  udavati  v.refl. ipf.
#
#                                                       en _prefix _stem
# 15606  #succeed, be a success, be successful, turn ou...      ¬u   dav
# ¬vȯz
# {'ipf': 1}
#                   isv partOfSpeech                     en _prefix _stem
# 16679  vȯzdavati česť       v.ipf.  pay honour, pay honor    ¬vȯz   dav
# ¬za
# {'ipf': 1}
#             isv partOfSpeech                                   en _prefix  \
# 17123  zadavati   v.tr. ipf.  inflict, set (task), ask (question)     ¬za
#
#       _stem
# 17123   dav
# ¬u
# {'ipf': 2, 'pf': 1}
#             isv  partOfSpeech                         en _prefix _stem
# 15613   udiviti     v.tr. pf.  surprise, amaze, astonish      ¬u   div
# 15615  udivjati  v.refl. ipf.       wonder, be surprised      ¬u   div
# 15616  udivjati    v.tr. ipf.  surprise, amaze, astonish      ¬u   div
#
# {'ipf': 2, 'pf': 1}
#            isv  partOfSpeech    en _prefix _stem
# 2441   dvigati  v.refl. ipf.  move          dvig
# 2442   dvigati    v.tr. ipf.  move          dvig
# 2443  dvignųti     v.tr. pf.  move          dvig
# ¬po
# {'ipf': 2}
#              isv partOfSpeech      en _prefix _stem
# 10492  podvajati   v.tr. ipf.  double     ¬po  dvaj
# 10503  podvojiti   v.tr. ipf.  double     ¬po   dvo
# ¬na
# {'ipf': 1}
#            isv partOfSpeech       en _prefix _stem
# 7131  nadyhati   v.tr. ipf.  inspire     ¬na   dyh
# ¬od
# {'ipf': 1}
#            isv  partOfSpeech    en _prefix _stem
# 8766  oddyhati  v.intr. ipf.  rest     ¬od   dyh
# ¬s
# {'ipf': 1}
#            isv  partOfSpeech             en _prefix _stem
# 13444  sdyhati  v.intr. ipf.  die (animals)      ¬s   dyh
# ¬v
# {'ipf': 1}
#            isv partOfSpeech          en _prefix _stem
# 16153  vdyhati   v.tr. ipf.  breathe in      ¬v   dyh
# ¬vȯz
# {'ipf': 1}
#              isv  partOfSpeech    en _prefix _stem
# 16698  vȯzdyhati  v.intr. ipf.  sigh    ¬vȯz   dyh
#
# {'ipf': 5}
#                       isv  partOfSpeech          en _prefix _stem
# 1751               dějati  v.refl. ipf.      happen           děj
# 1752               dějati    v.tr. ipf.         act           děj
# 12189        protivdějati  v.intr. ipf.  counteract
# 17046       vzajemodějati  v.intr. ipf.    interact
# 17048  vzajemodějstvovati  v.intr. ipf.    interact
# ¬na
# {'ipf': 1}
#            isv  partOfSpeech    en _prefix _stem
# 7098  nadějati  v.refl. ipf.  hope     ¬na   děj
# ¬pri
# {'ipf': 1}
#                isv  partOfSpeech                          en _prefix _stem
# 11679  pridŕživati  v.refl. ipf.  abide, adhere to, stick to    ¬pri   dŕž
# ¬sȯ
# {'ipf': 2, 'pf': 1}
#               isv partOfSpeech                  en _prefix _stem
# 14062    sȯdŕžati    v.tr. pf.  hold back, inhibit     ¬sȯ   dŕž
# 14063  sȯdŕživati   v.tr. ipf.             contain     ¬sȯ   dŕž
# 14064  sȯdŕživati   v.tr. ipf.  hold back, inhibit     ¬sȯ   dŕž
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[80], line 8
#       6 aspects_dict = g1['aspect'].value_counts().to_dict()
#       7 if not (aspects_dict in [{'pf': 1, 'ipf': 1}, {'pf': 1}]):
# ----> 8     if 'pf' not in aspects_dict and k1 == '' and aspects_dict['ipf'] == len(g1.en.unique()):
#       9         continue
#      10     if aspects_dict.get('pf') == aspects_dict.get('ipf') == len(g1.en.str.replace("#", "").unique()):
#
# KeyError: 'ipf'

# %% [markdown]
# ## ANOMALY 6: rare prefixes

# %%
morphemes.query("isv.str.contains('blågo')").isv.str.partition('blågo')[2].apply(lambda x: x + str(x in morphemes.isv.unique() or x in morphemes.base_verb.unique()))

# %%
morphemes.query("isv.str.contains('blågo')").isv.str.partition('blågo')[2].apply(lambda x: x + str(x in morphemes.isv.unique() or x in morphemes.base_verb.unique()))
# Out:
# 887         daritiTrue
# 899      slavjatiFalse
# 900        slovitiTrue
# 907         volětiTrue
# 912         želatiTrue
# 10292       daritiTrue
# 10293       želatiTrue
# Name: 2, dtype: object

# %%
#morphemes.loc[12828]

# %% [markdown]
# ## stuff

# %%
from isv_nlp_utils import constants
from isv_nlp_utils.slovnik import get_slovnik
# from isv_translate import translate_sentence, postprocess_translation_details, prepare_parsing

from ast import literal_eval
import os
import glob

# %%
from isv_nlp_utils.flavorization.tokenizer import extract_stem_prefix_suffix

slovnik = get_slovnik()
slovnik = slovnik['words']

morph = constants.create_etm_analyzer(r"C:\dev\ISV_data_gathering\\")

isv_dict = morph._units[0][0].dict

# %%
anomalies = []
i = 0

cnt = Counter()
cnt2 = Counter()
mbs = []

for k, g in partial_verb_prefixes.groupby('left_stem_cand'):
    if g.base_verb.apply(len).min() > 0:
        continue
    cnt[len(g.isv.unique())] += 1
    if g.base_verb.apply(len).max() > 0:
        cnt2[len(g.isv.unique())] += 1
        mbs.append((k, g.isv_orig.values, g.base_verb.values))

    if len(k) > 1 and len(g.isv.unique()) == 2:
        i += 1
        aspect_stats = {}
        for aspect in ['ipf.', 'pf.']:
            # print(aspect, len(g[g.partOfSpeech.str.contains(" " + aspect)]))
            aspect_stats[aspect] = list(g[g.partOfSpeech.str.contains("[ .]" + aspect)].isv.values)
        if any(len(x) == 0 for x in aspect_stats.values()):
            anomalies.append((aspect_stats, g.partOfSpeech.values.tolist(), g.en.values.tolist(), g.ru.values.tolist(), g.pl.values.tolist()))
            #print(aspect_stats)
            #print(g.en.values.tolist())
            #print(g.ru.values.tolist())
        else:
            bited, prefices = zip(
                *g.isv.apply(lambda x: bite_all_prefixes_off(x, "")).values.tolist()
            )
            if set(prefices) == {'’'}:
                base_verb = g.loc[g.isv.apply(len).idxmin()].isv
                print(g.isv.values.tolist(), "->", base_verb)
                print(g.en.unique())
                print()
                write_base_verb(g.index, base_verb)
            else:
                stems = g.isv.apply(
                    lambda x: bite_all_prefixes_off(x, "")[0]
                    # lambda x: x[len(bite_all_prefixes_off(x, "").replace('’', '')):]
                )
                for verb_cand in sorted(stems.values, key=len):
                    if morph.word_is_known(verb_cand):
                        if {verb_cand} == {v.normal_form for v in morph.parse(verb_cand)}:
                            base_verb_idx = partial_verb_prefixes.query("isv == @verb_cand").index[0]
                            add_index = g.index.tolist() + [base_verb_idx]
                            print(g.isv.values.tolist(), "+", verb_cand, "->", verb_cand)
                            print(g.en.unique())
                            print(partial_verb_prefixes.loc[base_verb_idx, 'en'])
                            print()
                            write_base_verb(add_index, verb_cand)
                            break
                else:
                    base_verb = g.loc[g.isv.apply(len).idxmin()].isv
                    print(g.isv.values.tolist(), "->", "???", base_verb)
                    write_base_verb(g.index, base_verb)
                
len(anomalies)

# %%
r, p = bite_all_prefixes_off(x, '')
p2 = p.replace('’', "")
print(x, p, r, morph.word_is_known(r), p2)
for len_cand in range(1, len(p2)):
    word_cand = p2[-len_cand:] + r
    print(len_cand, word_cand, morph.word_is_known(word_cand))
    if morph.word_is_known(word_cand):
        n += 1
        print(len_cand, word_cand, morph.word_is_known(word_cand))

# %%
from isv_nlp_utils.slovnik import infer_pos
KNOWN_NOUNS = slovnik[slovnik.partOfSpeech.apply(infer_pos) == 'noun'].isv.unique()

# %%
#partial_verb_prefixes.loc[1875, "base_verb"] = 'infikovati'
morphemes.loc[1875, "base_verb"]
# Out:
# 'dezinfikovati'

# %%
def add_derived_nouns(ending, replacement=''):
    tmp_df = slovnik[slovnik.partOfSpeech.apply(infer_pos) == 'noun'].copy()
    tmp_df['repl'] = tmp_df.isv.str.replace(ending + "$", replacement)
    tmp_df = tmp_df.query(
        "isv not in @BEG and repl in @BEG"
    ).copy()
    for i, row in tmp_df.iterrows():
        repl = row.repl
        matches = partial_verb_prefixes.query("left_stem_cand == @repl")

        partial_verb_prefixes.loc[matches.index, "derived_nouns"] = partial_verb_prefixes.loc[matches.index, "derived_nouns"] + "|" + row.isv

    return tmp_df.isv.values.tolist()

# %%
result = []

result += add_derived_nouns("ťje")
result += add_derived_nouns("je")
result += add_derived_nouns("ńje")
result += add_derived_nouns("ťje")
result += add_derived_nouns("ŕje")


for letter, letter_repl in ['ďd', 'ľl', 'ńn', 'ŕr', 'śs', 'ťt', 'źz']:
    result += add_derived_nouns(letter + "je", letter_repl)
    print(letter, len(result))

result = []
for letter, letter_repl in ['čk', 'šh']:
    result += add_derived_nouns(letter + "je", letter_repl)
    print(letter, len(result))

result += add_derived_nouns('nik')
print(len(result))
result += add_derived_nouns('nica')
print(len(result))

result += add_derived_nouns('ec')
print(len(result))
result += add_derived_nouns('ica')
print(len(result))

result += add_derived_nouns('stvo')
print(len(result))
result += add_derived_nouns('išče')
print(len(result))
result += add_derived_nouns('osť')
print(len(result))
result += add_derived_nouns('ač')
print(len(result))
result += add_derived_nouns('aŕ')
print(len(result))


result

# %% [markdown]
# ## end stuff

# %%
# is_known = partial_verb_prefixes.query("base_verb == '' and not isv.str.contains(' ') and left_stem_cand != isv").left_stem_cand.apply(
# is_known = partial_verb_prefixes.query("not isv.str.contains(' ') and left_stem_cand != isv and (base_verb == '' or base_verb == 'isv')").left_stem_cand.apply(

is_known = partial_verb_prefixes.query("not isv.str.contains(' ') and left_stem_cand != isv and (base_verb == '' or base_verb == isv)").left_stem_cand.apply(
    lambda stem: any(
        (morph.word_is_known(x) and any(v.tag.POS == "NOUN" for v in morph.parse(x)))
        for x in [stem, stem + "a"]
    )
)

tmp = is_known[is_known]

partial_verb_prefixes.loc[tmp.index]

# %%
for i, row in partial_verb_prefixes.loc[tmp.index].iterrows():
    stem = row.left_stem_cand
    base_noun_cands = []
    for x in [stem, stem + "a"]:
        variants = morph.parse(x)
        variants = [v for v in variants if v.tag.POS == "NOUN"]
        variants = [v for v in variants if v.normal_form == v.word and morph.word_is_known(v.normal_form)]
        if variants:
            variants = set([("!" if v.word != x else "") + v.word for v in variants])
            base_noun_cands += list(variants)
    if base_noun_cands:
        print(row.isv, row.base_verb, stem, base_noun_cands)
        partial_verb_prefixes.loc[i, "base_noun"] = "|".join(base_noun_cands)

# %% [markdown]
# ## functions

# %%
def bite_all_prefixes_off(word, verb_nest):

    can_continue = True
    prefixes = []

    while can_continue:
        can_continue = False
        for pref in possible_prefixes:
            if word.startswith(pref):
                # print(pref, word, word[len(pref):])
                new_word = word[len(pref):]
                if new_word.endswith(verb_nest):
                    word = new_word
                    prefixes.append(pref)
                    can_continue = True
                    break
    return word, "’".join(prefixes) + "’"


def bite_all_suffixes_off(word, verb_nest):

    can_continue = True
    suffixes = []

    while can_continue:
        can_continue = False
        for pref in possible_suffixes:
            if word.endswith(pref):
                new_word = word[:-len(pref)]
                if new_word.startswith(verb_nest):
                    word = new_word
                    suffixes.append(pref)
                    can_continue = True
                    break
    return word, "+".join(reversed(suffixes)) + "+"

# %%
BASE = "slěditi"

def check_if_orphan(BASE):

    g = morphemes.query(" base_verb == @BASE")

    base_variants = set((g['_stem'] + g['_suffix']).unique())
    variants = set(base_variants)
    for (src, dst) in [
        ("t" + YI, "ć"), ("sk" + YI, 'šć'), ("st" + YI, 'šć'),
        ("d" + YI, "đ"), ("zd" + YI, "žđ"),
        ("k" + YI, "č"), ("c" + YI, "č"), ("sk" + YI, "šč"),
        ("g" + YI, "ž"), ("z" + YI, "ž"), 
        ("s" + YI, "š"), ("h" + YI, "š"), 
        (AO, "a"), (AO, "o"), (AO, "å"), 
        ("in" + NASAL, "ę"),
        ("tt", "t"),
        ("bv", "v"),
        ("jdti", "idti"), ("jmati", "imati")
        # žđ  "h" + YI ?
    ]:
        variants |= {v.replace(src, dst) for v in base_variants}
    return BASE not in variants

# %%
# morphemes.query(" isv.str.contains('slě')")

# %%
morphemes.query("(_suffix in @sWTF or _suffix == '')  and _is_irregular == 0 and not isv.str.contains('[/,]')")
# Out:
#             id                 isv addition  partOfSpeech  \
# 4336     763.0         izvaljnjati      NaN    v.tr. ipf.
# 4359   22512.0         izvlastniti      NaN     v.tr. pf.
# 4360   22511.0        izvlastnjati      NaN    v.tr. ipf.
# 4377    2956.0          izvoljniti      NaN     v.tr. pf.
# 9102   22538.0         odvlåčivati      NaN    v.tr. ipf.
# 9103   23884.0         odvlåčivati      NaN    v.tr. ipf.
# 10897  17010.0         posluživati     (+5)  v.refl. ipf.
# 11065  22659.0            povŕtati      NaN    v.tr. ipf.
# 11910  23175.0        privlåčivati      NaN    v.tr. ipf.
# 11911  22501.0   privlastniti sobě      NaN     v.tr. pf.
# 11912  22502.0  privlastnjati sobě      NaN    v.tr. ipf.
# 15973  19100.0          uvaljnjati     (+2)  v.refl. ipf.
# 15974  19099.0          uvaljnjati      NaN  v.refl. ipf.
# 15975   3555.0          uvaljnjati      NaN    v.tr. ipf.
# 15976   3562.0          uvaljnjati      NaN    v.tr. ipf.
# 16004  19108.0           uvoljniti     (+2)   v.refl. pf.
# 16005  19107.0           uvoljniti      NaN   v.refl. pf.
# 16006   3558.0           uvoljniti      NaN     v.tr. pf.
# 16007   3560.0           uvoljniti      NaN     v.tr. pf.
# 16511  13681.0           vlastniti      NaN    v.tr. ipf.
#
#                                                       en genesis   pos prefix  \
# 4336   fire (terminate employment), sack, discharge, ...     NaN  verb      ?
# 4359                                         expropriate     NaN  verb      ?
# 4360                                         expropriate     NaN  verb      ?
# 4377   fire (terminate employment), sack, discharge, ...     NaN  verb      ?
# 9102                                           drag away     NaN  verb      ?
# 9103                                            distract     NaN  verb      ?
# 10897                                   use, make use of     NaN  verb      ?
# 11065                                         turn (tr.)     NaN  verb      ?
# 11910                                            attract     NaN  verb      ?
# 11911                              appropriate, arrogate     NaN  verb      ?
# 11912                              appropriate, arrogate     NaN  verb      ?
# 15973                                     rid oneself of     NaN  verb      ?
# 15974                                         break free     NaN  verb      ?
# 15975    discharge, dismiss, fire (terminate employment)     NaN  verb      ?
# 15976                                  release, set free     NaN  verb      ?
# 16004                                     rid oneself of     NaN  verb      ?
# 16005                                         break free     NaN  verb      ?
# 16006    discharge, dismiss, fire (terminate employment)     NaN  verb      ?
# 16007                                  release, set free     NaN  verb      ?
# 16511                                       own, possess     NaN  verb      ?
#
#       verb_stem  base_verb            isv_orig      left_stem_cand  \
# 4336          ?     voliti         izvaljnjati             izvaljn
# 4359          ?  vlastniti         izvlastniti            izvlastn
# 4360          ?  vlastniti        izvlastnjati            izvlastn
# 4377          ?     voliti          izvoljniti             izvoljn
# 9102          ?     vlěkti         odvlåčivati              odvlåč
# 9103          ?     vlěkti         odvlåčivati              odvlåč
# 10897         ?    služiti      posluživati sę              posluž
# 11065         ?     vŕnųti            povŕtati               povŕt
# 11910         ?     vlěkti        privlåčivati             privlåč
# 11911         ?  vlastniti   privlastniti sobě   privlastniti sobě
# 11912         ?  vlastniti  privlastnjati sobě  privlastnjati sobě
# 15973         ?     voliti    uvaljnjati sę od              uvaljn
# 15974         ?     voliti       uvaljnjati sę              uvaljn
# 15975         ?     voliti          uvaljnjati              uvaljn
# 15976         ?     voliti          uvaljnjati              uvaljn
# 16004         ?     voliti     uvoljniti sę od              uvoljn
# 16005         ?     voliti        uvoljniti sę              uvoljn
# 16006         ?     voliti           uvoljniti              uvoljn
# 16007         ?     voliti           uvoljniti              uvoljn
# 16511         ?  vlastniti           vlastniti              vlastn
#
#         right_stem_cand         derived_nouns base_noun _prefix  _stem  \
# 4336         ?aljnjati?                                      iz    vꜵl
# 4359          vlastniti                                      iz  vlast
# 4360        ?lastnjati?                                      iz  vlast
# 4377           ?ljniti?                                      iz    vꜵl
# 9102         ?låčivati?                                     odv    låk
# 9103         ?låčivati?                                     odv    låk
# 10897        ?luživati?                                     pos    lug
# 11065           ?ŕtati?                                     pov      ŕ
# 11910        ?låčivati?                                    priv    låk
# 11911   ?lastniti sobě?                                     pri  vlast
# 11912  ?lastnjati sobě?                                     pri  vlast
# 15973        ?aljnjati?                                       u    vꜵl
# 15974        ?aljnjati?                                       u    vꜵl
# 15975        ?aljnjati?                                       u    vꜵl
# 15976        ?aljnjati?                                       u    vꜵl
# 16004          ?ljniti?                                       u    vꜵl
# 16005          ?ljniti?                                       u    vꜵl
# 16006          ?ljniti?                                       u    vꜵl
# 16007          ?ljniti?                                       u    vꜵl
# 16511        ?lastniti?  |vlastnica|vlastnosť     vlasť          vlast
#
#       _suffix  _is_irregular
# 4336   jnjati              0
# 4359     niti              0
# 4360    njati              0
# 4377    jniti              0
# 9102   ⒥ivati              0
# 9103   ⒥ivati              0
# 10897  ⒥ivati              0
# 11065    tati              0
# 11910  ⒥ivati              0
# 11911    niti              0
# 11912   njati              0
# 15973  jnjati              0
# 15974  jnjati              0
# 15975  jnjati              0
# 15976  jnjati              0
# 16004   jniti              0
# 16005   jniti              0
# 16006   jniti              0
# 16007   jniti              0
# 16511    niti              0

# %%
morphemes.loc[
    morphemes.query("en.str.contains('testif')").index,
    "base_verb"
]

# %%
morphemes[morphemes.isv != morphemes._prefix + morphemes._stem + morphemes._suffix].query(
    "not _stem.str.contains('ꜵ') and not _suffix.str.contains('[⒥⒩]') and not isv.str.contains('[ \/]')"
)
# Out:
#             id                 isv       addition  partOfSpeech  \
# 2179    7211.0           dorastati            NaN  v.intr. ipf.
# 2180   16416.0             doråsti      (doråste)   v.intr. pf.
# 3640    2104.0                idti     (ide; šel)  v.intr. ipf.
# 3685    3325.0               imati            NaN        v.ipf.
# 3686   36890.0               imati            NaN    v.tr. ipf.
# 3687   36928.0               imati            NaN    v.tr. ipf.
# 3688   17485.0               imati            NaN        v.ipf.
# 3690     876.0               imati            NaN        v.ipf.
# 3691   36402.0               imati            NaN        v.ipf.
# 3692   23339.0               imati            NaN  v.intr. ipf.
# 3693   23340.0               imati            NaN  v.intr. ipf.
# 3694    3847.0               imati            NaN        v.ipf.
# 3695     417.0               imati        (imaje)   v.aux. ipf.
# 3696     875.0               imati        (imaje)    v.tr. ipf.
# 4011    5515.0             izimati            NaN    v.tr. ipf.
# 4220    1688.0             izråsti      (izråste)   v.intr. pf.
# 4223    3723.0          izravnjati            NaN  v.refl. ipf.
# 4224   19753.0          izravnjati            NaN    v.tr. ipf.
# 4592   14605.0          jestvovati            NaN  v.intr. ipf.
# 7378   33056.0           narastati            NaN  v.intr. ipf.
# 7379   28139.0             naråsti      (naråste)   v.intr. pf.
# 8273   20918.0              občiti            NaN  v.intr. ipf.
# 8329    3476.0             obimati            NaN    v.tr. ipf.
# 8798   18066.0             odimati            NaN    v.tr. ipf.
# 8799   18067.0             odimati            NaN    v.tr. ipf.
# 8800   33737.0             odimati            NaN    v.tr. ipf.
# 9028   21874.0         odstranjati            NaN    v.tr. ipf.
# 9029   21876.0         odstranjati            NaN    v.tr. ipf.
# 9030   21877.0         odstranjati            NaN    v.tr. ipf.
# 9031   21881.0         odstranjati            NaN    v.tr. ipf.
# 9061   36666.0       odsųtstvovati            NaN  v.intr. ipf.
# 10370   5176.0            podimati            NaN    v.tr. ipf.
# 10816  23903.0             poråsti      (poråste)   v.intr. pf.
# 11492  33068.0          prěrastati            NaN    v.tr. ipf.
# 11493  11338.0            prěråsti     (prěråste)     v.tr. pf.
# 12189   5479.0        protivdějati            NaN  v.intr. ipf.
# 12433   3037.0               råsti        (råste)  v.intr. ipf.
# 12804  33908.0     råzprostranjati            NaN  v.refl. ipf.
# 12805  20117.0     råzprostranjati            NaN    v.tr. ipf.
# 12825  30427.0          råzrastati            NaN  v.refl. ipf.
# 12826  30428.0            råzråsti     (råzråste)   v.refl. pf.
# 12828  18617.0         råzraznjati            NaN    v.tr. ipf.
# 12897  21687.0         råzsvětliti            NaN   v.refl. pf.
# 12898  21519.0        råzsvětljati            NaN  v.refl. ipf.
# 14056  34940.0       sȯčuvstvovati            NaN  v.intr. ipf.
# 14112  21172.0            sȯobčiti            NaN     v.tr. pf.
# 14294  33072.0            srastati            NaN  v.refl. ipf.
# 14295  18730.0              sråsti       (sråste)   v.refl. pf.
# 14700  23008.0                 sųt            NaN   v.aux. ipf.
# 14707  36821.0         sųtstvovati            NaN  v.intr. ipf.
# 16205  31079.0              velěti         (veli)    v.tr. ipf.
# 16528  35545.0             vměsati            NaN     v.tr. pf.
# 16711  23955.0            vȯzimati            NaN    v.tr. ipf.
# 16750  13810.0          vȯzrastati            NaN  v.intr. ipf.
# 16751  16419.0            vȯzråsti     (vȯzråste)   v.intr. pf.
# 17046  13989.0       vzajemodějati  (vzajemoděje)  v.intr. ipf.
# 17048   9090.0  vzajemodějstvovati            NaN  v.intr. ipf.
# 17417  33069.0           zarastati            NaN  v.intr. ipf.
# 17418  14162.0             zaråsti      (zaråste)   v.intr. pf.
# 17464  23842.0          zasramjati            NaN    v.tr. ipf.
#
#                                               en genesis   pos prefix  \
# 2179                    grow up, become an adult     NaN  verb      ?
# 2180                    grow up, become an adult     NaN  verb      ?
# 3640                                          go     NaN  verb      ?
# 3685                                   deal with     NaN  verb      ?
# 3686                          mean, have in mind     NaN  verb      ?
# 3687                          mean, have in mind     NaN  verb      ?
# 3688                                        hope     NaN  verb      ?
# 3690                                    be right     NaN  verb      ?
# 3691                                  make sense     NaN  verb      ?
# 3692                                      matter     NaN  verb      ?
# 3693                                      matter     NaN  verb      ?
# 3694                                      regret     NaN  verb      ?
# 3695                               must, have to     NaN  verb      ?
# 3696                          have, possess, own     NaN  verb      ?
# 4011                                    take out     NaN  verb      ?
# 4220                                        grow     NaN  verb      ?
# 4223                                     line up     NaN  verb      ?
# 4224                                   level out     NaN  verb      ?
# 4592                                       exist     NaN  verb      ?
# 7378                increase, rise, grow, accrue     NaN  verb      ?
# 7379                increase, rise, grow, accrue     NaN  verb      ?
# 8273                                   associate     NaN  verb      ?
# 8329                         embrace, hug, clasp     NaN  verb      ?
# 8798                                   take away     NaN  verb      ?
# 8799                                    amputate     NaN  verb      ?
# 8800                                    subtract     NaN  verb      ?
# 9028                              delete, remove     NaN  verb      ?
# 9029                                     discard     NaN  verb      ?
# 9030                                   eliminate     NaN  verb      ?
# 9031                          discharge, dismiss     NaN  verb      ?
# 9061                          be absent, be away     NaN  verb      ?
# 10370                         take up, undertake     NaN  verb      ?
# 10816                                       grow     NaN  verb      ?
# 11492                                    outgrow     NaN  verb      ?
# 11493                                    outgrow     NaN  verb      ?
# 12189                                 counteract     NaN  verb      ?
# 12433                             grow, increase     NaN  verb      ?
# 12804                             extend, spread     NaN  verb   råz’
# 12805               diffuse, disseminate, spread     NaN  verb   råz’
# 12825               branch out, expand, run wild     NaN  verb   råz’
# 12826               branch out, expand, run wild     NaN  verb   råz’
# 12828                                distinguish     NaN  verb   råz’
# 12897                                #lighten up     NaN  verb   råz’
# 12898                                 lighten up     NaN  verb   råz’
# 14056   sympathize, commiserate, feel compassion     NaN  verb    sȯ’
# 14112                        communicate, report     NaN  verb    sȯ’
# 14294                    grow together, coalesce     NaN  verb      ?
# 14295                    grow together, coalesce     NaN  verb      ?
# 14700                                  there are     NaN  verb      ?
# 14707                                      exist     NaN  verb      ?
# 16205                     order, command, ordain     NaN  verb      ?
# 16528  involve (somebody in a project), mix into     NaN  verb      ?
# 16711                                lift, raise     NaN  verb   vȯz’
# 16750                            become an adult     NaN  verb   vȯz’
# 16751                            become an adult     NaN  verb   vȯz’
# 17046                                   interact     NaN  verb      ?
# 17048                                   interact     NaN  verb      ?
# 17417                                   overgrow     NaN  verb      ?
# 17418                                   overgrow     NaN  verb      ?
# 17464                                  embarrass     NaN  verb      ?
#
#              verb_stem base_verb            isv_orig   left_stem_cand  \
# 2179                 ?     råsti           dorastati           dorast
# 2180                 ?     råsti             doråsti          doråsti
# 3640                 ?      idti                idti             idti
# 3685                 ?     imati        iměti dělo s     iměti dělo s
# 3686                 ?     imati     iměti na myslji  iměti na myslji
# 3687                 ?     imati        iměti na umu     iměti na umu
# 3688                 ?     imati        iměti nadějų     iměti nadějų
# 3690                 ?     imati        iměti pravdų     iměti pravdų
# 3691                 ?     imati         iměti smysl      iměti smysl
# 3692                 ?     imati       iměti važnosť    iměti važnosť
# 3693                 ?     imati      iměti značeńje   iměti značeńje
# 3694                 ?     imati          iměti žalj        iměti žal
# 3695                 ?     imati        iměti, imati        iměti, im
# 3696                 ?     imati        iměti, imati        iměti, im
# 4011                 ?     imati             izimati             izim
# 4220                 ?     råsti             izråsti          izråsti
# 4223                 ?   råvniti       izravnjati sę           izravn
# 4224                 ?   råvniti          izravnjati           izravn
# 4592                 ?      byti          jestvovati            jestv
# 7378                 ?     råsti           narastati           narast
# 7379                 ?     råsti             naråsti          naråsti
# 8273                 ?    občiti              občiti              obč
# 8329                 ?     imati             obimati             obim
# 8798                 ?     imati             odimati             odim
# 8799                 ?     imati             odimati             odim
# 8800                 ?     imati             odimati             odim
# 9028                 ?  stråniti         odstranjati          odstran
# 9029                 ?  stråniti         odstranjati          odstran
# 9030                 ?  stråniti         odstranjati          odstran
# 9031                 ?  stråniti         odstranjati          odstran
# 9061                 ?      byti       odsųtstvovati         odsųtstv
# 10370                ?     imati            podimati            podim
# 10816                ?     råsti             poråsti          poråsti
# 11492                ?     råsti          prěrastati          prěrast
# 11493                ?     råsti            prěråsti         prěråsti
# 12189                ?    dějati        protivdějati         protivdě
# 12433                ?     råsti               råsti            råsti
# 12804  prostranjati sę  stråniti  råzprostranjati sę      råzprostran
# 12805     prostranjati  stråniti     råzprostranjati      råzprostran
# 12825       rastati sę     råsti       råzrastati sę          råzrast
# 12826         råsti sę     råsti         råzråsti sę         råzråsti
# 12828         raznjati      niti         råzraznjati          råzrazn
# 12897      světliti sę   světiti      råzsvětliti sę         råzsvětl
# 12898     světljati sę   světiti     råzsvětljati sę         råzsvětl
# 14056      čuvstvovati    čuvati       sȯčuvstvovati         sȯčuvstv
# 14112           občiti    občiti            sȯobčiti            sȯobč
# 14294                ?     råsti         srastati sę            srast
# 14295                ?     råsti           sråsti sę           sråsti
# 14700                ?      byti                 sųt              sųt
# 14707                ?      byti         sųtstvovati           sųtstv
# 16205                ?    voliti              velěti              vel
# 16528                ?    měšati             vměsati             vměs
# 16711            imati     imati            vȯzimati            vȯzim
# 16750          rastati     råsti          vȯzrastati          vȯzrast
# 16751            råsti     råsti            vȯzråsti         vȯzråsti
# 17046                ?    dějati       vzajemodějati        vzajemodě
# 17048                ?    dějati  vzajemodějstvovati    vzajemodějstv
# 17417                ?     råsti           zarastati           zarast
# 17418                ?     råsti             zaråsti          zaråsti
# 17464                ?   sråmiti          zasramjati           zasram
#
#          right_stem_cand derived_nouns base_noun      _prefix  _stem _suffix  \
# 2179           ?rastati?                                   do   råst     ati
# 2180               råsti                                   do   råst      ti
# 3640                idti                                          jd      ti
# 3685      ?iměti dělo s?                                          jm     ati
# 3686   ?iměti na myslji?                                          jm     ati
# 3687      ?iměti na umu?                                          jm     ati
# 3688      ?iměti nadějų?                                          jm     ati
# 3690      ?iměti pravdų?                                          jm     ati
# 3691       ?iměti smysl?                                          jm     ati
# 3692     ?iměti važnosť?                                          jm     ati
# 3693    ?iměti značeńje?                                          jm     ati
# 3694        ?iměti žalj?                                          jm     ati
# 3695      ?iměti, imati?                                          jm     ati
# 3696      ?iměti, imati?                                          jm     ati
# 4011               imati                                   iz     jm     ati
# 4220               råsti                                   iz   råst      ti
# 4223          ?ravnjati?                                   iz   råvn    jati
# 4224          ?ravnjati?                                   iz   råvn    jati
# 4592          jestvovati
# 7378           ?rastati?                                   na   råst     ati
# 7379               råsti                                   na   råst      ti
# 8273              ?čiti?                                         obć     iti
# 8329               imati                                   ob     jm     ati
# 8798               imati                                   od     jm     ati
# 8799               imati                                   od     jm     ati
# 8800               imati                                   od     jm     ati
# 9028          ?tranjati?                                   od  strån    jati
# 9029          ?tranjati?                                   od  strån    jati
# 9030          ?tranjati?                                   od  strån    jati
# 9031          ?tranjati?                                   od  strån    jati
# 9061         sųtstvovati
# 10370              imati                                  pod     jm     ati
# 10816              råsti                                   po   råst      ti
# 11492          ?rastati?                                  prě   råst     ati
# 11493              råsti                                  prě   råst      ti
# 12189        ?tivdějati?
# 12433              råsti                                        råst      ti
# 12804         ?tranjati?                               råzpro  strån    jati
# 12805         ?tranjati?                               råzpro  strån    jati
# 12825          ?rastati?                                  råz   råst     ati
# 12826              råsti                                  råz   råst      ti
# 12828            ?njati?                          råzråznjati     ni
# 12897           ?ětliti?                                  raz   svět    liti
# 12898          ?ětljati?                                  raz   svět   ljati
# 14056      ?čuvstvovati?
# 14112             občiti                                   sȯ    obć     iti
# 14294          ?rastati?                                    s   råst     ati
# 14295              råsti                                    s   råst      ti
# 14700                ?t?      |sųtstvo
# 14707        ?tstvovati?
# 16205            ?elěti?
# 16528           ?měsati?
# 16711              imati                                  vȯz     jm     ati
# 16750          ?rastati?                                  vȯz   råst     ati
# 16751              råsti                                  vȯz   råst      ti
# 17046       ?jemodějati?
# 17048  ?jemodějstvovati?
# 17417          ?rastati?                                   za   råst     ati
# 17418              råsti                                   za   råst      ti
# 17464          ?ramjati?                                   za   sråm    jati
#
#        _is_irregular
# 2179               0
# 2180               0
# 3640               0
# 3685               0
# 3686               0
# 3687               0
# 3688               0
# 3690               0
# 3691               0
# 3692               0
# 3693               0
# 3694               0
# 3695               0
# 3696               0
# 4011               0
# 4220               0
# 4223               0
# 4224               0
# 4592               1
# 7378               0
# 7379               0
# 8273               0
# 8329               0
# 8798               0
# 8799               0
# 8800               0
# 9028               0
# 9029               0
# 9030               0
# 9031               0
# 9061               1
# 10370              0
# 10816              0
# 11492              0
# 11493              0
# 12189              1
# 12433              0
# 12804              0
# 12805              0
# 12825              0
# 12826              0
# 12828              0
# 12897              0
# 12898              0
# 14056              1
# 14112              0
# 14294              0
# 14295              0
# 14700              1
# 14707              1
# 16205              1
# 16528              1
# 16711              0
# 16750              0
# 16751              0
# 17046              1
# 17048              1
# 17417              0
# 17418              0
# 17464              0

# %%
# !ls -lh | grep wik
# Out:
# -rw-r--r-- 1 79165 197609  230K Mar 26 00:41 data gathering-wiktionary_new.ipynb
# -rw-r--r-- 1 79165 197609  7.9M Nov 11 20:36 isv_wiki.pkl
# -rw-r--r-- 1 79165 197609   33K Nov 11 23:16 isv_wiki_crawling.ipynb
# -rw-r--r-- 1 79165 197609  412K May  6 00:00 morphemes_plus_wiktionary.ipynb
# drwxr-xr-x 1 79165 197609     0 Nov 11 23:16 wiki
# -rw-r--r-- 1 79165 197609  1.5M Nov  8 00:48 wiktionary.json
# -rw-r--r-- 1 79165 197609  342K Nov  8 00:49 wiktionary.zip
# -rw-r--r-- 1 79165 197609   16M Nov 30 04:20 wiktionary_extended.json
# -rw-r--r-- 1 79165 197609  7.5M Mar 25 04:16 wiktionary_extended2.json
# -rw-r--r-- 1 79165 197609   12M Mar 26 00:31 wiktionary_extended_new.json

# %%
from isv_nlp_utils.flavorization.replacer import VOWELS
from isv_nlp_utils.flavorization.parsing import parse_multireplacer_rules
from isv_nlp_utils.flavorization.tokenizer import compute_annotated_tokens, pretty_stringify
from isv_nlp_utils.flavorization.replacer import process_multireplacing, morphological_flavorise
from isv_nlp_utils.flavorization.selector import produce_string, filter_good_spellings, filter_lingua, init_detector, init_hunspell
from isv_nlp_utils.flavorization.tokenizer import tokens_to_exhaustive_string_list

# %%
from razdel import tokenize
from isv_nlp_utils.flavorization.tokenizer import ParseVariant, AnnotatedToken

# %%
rules_struct, declared_constants = parse_multireplacer_rules(
        r"C:\dev\razumlivost\src\flavorizers\slow\protoslavic.ts"
)

def f(word, rules_struct, declared_constants, pos_tag):
    cap = False
    space_after = ""
    
    slovnik_pos = ""
    isv_lemma = None
    variants = [ParseVariant(
                    [word],
                    pos_tag, slovnik_pos, isv_lemma,
                    None, "", 
                    False
                )]

    ann_token = AnnotatedToken(
        variants,
        cap, space_after,
    )
    
    tokens_base = [ann_token]
    # tokens = morphological_flavorise(tokens_base, morph, flavor_rules[LANG])
    tokens = process_multireplacing(tokens_base, rules_struct, declared_constants)
    return tokens

# %%
word = 'bolь'


pretty_stringify(
    f(word, rules_struct, declared_constants, {""})
)
# Out:
# 'bolj'

# %%
all_reconstructions = set()
reconstructed_articles = {}

for k, v in words_data.items():
    if v['Related_Slavic']:
        all_reconstructions |= set([x[1][1:] for x in v['Related_Slavic']])
    all_reconstructions.add(v['*'])
    reconstructed_articles[v['*']] = v

len(all_reconstructions), len(reconstructed_articles)

# %%
pra_verbs = {}
pra_forms = {}

all_reconstructions = set()

for k, v in words_data.items():
    if v['Related_Slavic']:
        all_reconstructions |= set([x[1][1:] for x in v['Related_Slavic']])
    all_reconstructions.add(v['*'])

for word in all_reconstructions:
    if word.endswith('ti') or word.endswith('ťi'):

        evolved = pretty_stringify(
            f(word, rules_struct, declared_constants, {""})
        )
        if "|" in evolved:
            variants = evolved[1:-1].split("|")
            variants = [vr for vr in variants if vr in morphemes.isv.unique()]
            if len(variants) == 1:
                pra_verbs[word] = variants[0]
                pra_forms[variants[0]] = word
            else:
                print(word, evolved, variants)
        else:
            pra_verbs[word] = evolved
            pra_forms[evolved] = word
# Out:
# o(b)klasti [obklasti|oklasti] []
# postiťi [postikti|postigti] []
# pľuti [pljuti|pjuti] []
# -ťi [-gti|-kti] []
# bľukati [bljukati|bjukati] []
# orzkošiti [razkošiti|råzkošiti|rozkošiti] []
# sęťi [sękti|sęgti] []
# orzьniti [roźniti|raźniti|råźniti] []
# orzduxati [rozduhati|razduhati|råzduhati] []
# povelťi [povlěgti|povlěkti] []
# (s)tъrčati [strčati|trčati] []
# orsěsti [råsěsti|rasěsti|rosěsti] []
# orzžaliti [razžaliti|råzžaliti|rozžaliti] []
# pręťi [prękti|pręgti] []
# poteťi [potegti|potekti] []
# ortiti [ratiti|råtiti|rotiti] []
# žegťi [žeggti|žegkti] []
# orsuti [råsuti|rosuti|rasuti] []
# o(b)teťi [otekti|otegti|obtekti|obtegti] []
# skobľati [skobljati|skobjati] []
# dostiťi [dostigti|dostikti] []
# napeťi [napegti|napekti] []
# bel(e)niti [beleniti|blěniti] []
# jьzreťi [izregti|izrekti] []
# sъpeťi [spekti|spegti] []
# ortati [råtati|rotati|ratati] []
# orzuzdati [razuzdati|råzuzdati|rozuzdati] []
# tęťi [tęgti|tękti] []
# orzvětriti [rozvětriti|razvětriti|råzvětriti] []
# stiťi [stikti|stigti] []
# o(b)kladati [okladati|obkladati] []
# otъreťi [otrekti|otregti] []
# verťi [vrěgti|vrěkti] []
# telťi [tlěgti|tlěkti] []
# berťi [brěkti|brěgti] []
# bergťi [brěggti|brěgkti] []
# orzklasti [råzklasti|rozklasti|razklasti] []
# čьpľjěti [čpjjěti|čpljjěti] []
# trijьťi [trijkti|trijgti] []
# d(ъ)vojьťi [dvojkti|dvojgti] []
# pripeťi [pripekti|pripegti] []
# zapeťi [zapegti|zapekti] []
# orbotiti [råbotiti|robotiti|rabotiti] []
# nalęťi [nalęgti|nalękti] []
# nareťi [narekti|naregti] []
# orzpuxati [rozpuhati|råzpuhati|razpuhati] []
# orztelťi [råztlěkti|raztlěkti|raztlěgti|råztlěgti|roztlěkti|roztlěgti] []
# molt(j)ati [mlåtjati|mlåtati] []
# otъtelťi [ottlěgti|ottlěkti] []
# o(b)aditi [obaditi|oaditi] []
# sъvъkupľavati [sȯvkupjavati|sȯvkupljavati] []
# orzstrugati [razstrugati|rozstrugati|råzstrugati] []
# orzgъbnǫti [razgbnųti|rozgbnųti|råzgbnųti] []
# pręgťi [pręggti|pręgkti] []
# skobľiti [skobljiti|skobjiti] []
# orzperti [råzprěti|razprěti|rozprěti] []
# orzpeťi [råzpegti|razpegti|råzpekti|rozpegti|razpekti|rozpekti] []
# pľugaviti [pjugaviti|pljugaviti] []
# zareťi [zarekti|zaregti] []
# orzъręditi [rozręditi|råzręditi|razręditi] []
# mъťi [mgti|mkti] []
# orzvaditi [rozvaditi|razvaditi|råzvaditi] []
# bľumati [bjumati|bljumati] []
# orzstrujiti [råzstrujiti|razstrujiti|rozstrujiti] []
# bľusti [bljusti|bjusti] []
# vergťi [vrěgkti|vrěggti] []
# dъvojьťi [dvojkti|dvojgti] []
# prę(ž)ťi [pręžgti|pręžkti] []
# bagťi [bagkti|baggti] []
# orstiti [rostiti|råstiti|rastiti] []
# orzvějati [rozvějati|råzvějati|razvějati] []
# dъ̏ťi [d̏gti|d̏kti] []
# lękťi [lękkti|lękgti] []
# orbovati [rabovati|robovati|råbovati] []
# nastiťi [nastigti|nastikti] []
# čьrv(j)eniti [čŕvjeniti|čŕveniti] []
# vъreťi [vregti|vrekti] []
# mьrťi [mŕgti|mŕkti] []
# o(b)tekti [otekti|obtekti] []
# natelťi [natlěgti|natlěkti] []
# běgťi [běgkti|běggti] []
# opeťi [opegti|opekti] []
# ureťi [uregti|urekti] []
# slь(p)nǫti [sljpnųti|sljnųti] []
# jьztelťi [iztlěgti|iztlěkti] []
# orzportiti [rozpråtiti|råzpråtiti|razpråtiti] []
# orzxodovati [razhodovati|rozhodovati|råzhodovati] []
# orzxodati [rozhodati|razhodati|råzhodati] []
# orzuditi [razuditi|råzuditi|rozuditi] []
# baťi [bakti|bagti] []
# pristiťi [pristigti|pristikti] []
# (s)mǫditi [mųditi|smųditi] []
# perdъreťi [prědrekti|prědregti] []
# zastiťi [zastikti|zastigti] []
# orzraziti [rozraziti|råzraziti|razraziti] []
# bel(e)novati [blěnovati|belenovati] []
# ortovati [rotovati|råtovati|ratovati] []
# reťi [regti|rekti] []
# pry(g)ti [pryti|prygti] []
# bľuxati [bjuhati|bljuhati] []
# vъz(o)jьti [vȯzjti|vzojti] []
# otъpeťi [otpekti|otpegti] []
# bľьvati [bljvati|bjvati] []
# (u)sętiti [sętiti|usętiti] []
# orzkoxati [rozkohati|razkohati|råzkohati] []
# o(b)sočiti [obsočiti|osočiti] []
# orzbrъkati [rozbrkati|razbrkati|råzbrkati] []
# orzbijati [råzbijati|razbijati|rozbijati] []
# sъbľudati [sbljudati|sbjudati] []
# orběti [råběti|roběti|raběti] []
# orti [råti|rati|roti] []
# perpeťi [prěpegti|prěpekti] []
# o(b)saditi [osaditi|obsaditi] ['osaditi', 'obsaditi']
# pľьvati [pljvati|pjvati] []
# orsedliti [raseliti|roseliti|råseliti] []
# orzbъdriti [råzbdriti|razbdriti|rozbdriti] []
# dъťi [dkti|dgti] []
# vьrťi [vŕgti|vŕkti] []
# dviťi [dvigti|dvikti] []
# bľuti [bljuti|bjuti] []
# o(b)aďati [obađati|oađati] []
# orzpytovati [råzpytovati|rozpytovati|razpytovati] []
# sъlęťi [slęgti|slękti] []
# bľuzgati [bljuzgati|bjuzgati] []
# edьnojьťi [jeďnojgti|jeďnojkti] []
# sъreťi [sregti|srekti] []
# pǫťi [pųgti|pųkti] []
# orzverzti [rozvrězti|råzvrězti|razvrězti] []
# bľuzgnǫti [bljuzgnųti|bjuzgnųti] []
# orzkloniti [råzkloniti|rozkloniti|razkloniti] []
# orzdvignǫti [rozdvignųti|råzdvignųti|razdvignųti] []
# (s)kvьrčěti [kvŕčěti|skvŕčěti] []
# klìťi [klìgti|klìkti] []
# pľugavěti [pjugavěti|pljugavěti] []
# orspariti [rospariti|råspariti|raspariti] []
# otelťi [otlěkti|otlěgti] []
# padъťi [padkti|padgti] []
# je(b)ti [jeti|jebti] []
# čьrv(j)eněti [čŕveněti|čŕvjeněti] []
# nabľudati [nabljudati|nabjudati] []

# %%
len(pra_forms)
# Out:
# 2845

# %%
# pra_verbs

# %%
"" in pra_forms
# Out:
# False

# %%
morphemes['reconstructed'] = ""

# %%
from collections import Counter

cnt = Counter()

unk = []
dfs = []
for nest in morphemes.base_verb.unique():
    g = morphemes.query('base_verb == @nest')
    if nest.strip("†") in pra_forms and nest not in morphemes.isv.unique():
        print("†?", nest, pra_forms[nest.strip("†")])
        morphemes.loc[g.index, 'reconstructed'] = "?" + pra_forms[nest.strip("†")]
        continue

    g2 = g.isv.apply(lambda x: pra_forms.get(x, float("nan")))
    morphemes.loc[g.index, 'reconstructed'] = g2.values
    cnt[len(g2.dropna().unique())] += 1
    if len(g2.dropna().unique()) == 0:
        unk.append(nest)
        continue
    if len(g2.dropna()) != len(g2):
        if len(g2.dropna().unique()) > 1:
            dfs.append(g)
        selected = min(g2.dropna().unique(), key=len)
        g3 = morphemes.loc[g.index].query("isv not in @pra_forms")
        morphemes.loc[g3.index, 'reconstructed'] = "?" + selected


cnt
# Out:
# †? sloviti sloviti
# †? †kladati kladati
# †? †ložiti ložiti
# †? voliti voliti
# †? †gynųti gynǫti
# †? †městiti městiti
# †? mrěti merti
# †? †niknųti niknǫti
# †? obraziti obraziti
# †? †plåšiti polšiti
# †? pęti pęti
# †? poriti poriti
# †? světiti světiti
# †? viniti viniti
# †? †vysiti vysiti
# †? †spěti spěti
# †? †strěti sterti
# †? †trčati tъrčati
# †? †pitati pitati
# Counter({0: 776, 1: 400, 3: 17, 2: 78, 6: 4, 27: 1, 4: 8, 5: 2, 8: 1, 7: 1})

# %%
g
# Out:
#             id     isv addition  partOfSpeech    en genesis   pos prefix  \
# 17905  19473.0  žužati      NaN  v.intr. ipf.  buzz     NaN  verb      ?
#
#       verb_stem base_verb isv_orig left_stem_cand right_stem_cand  \
# 17905         ?    žužati   žužati            žuž          žužati
#
#       derived_nouns base_noun _prefix _stem _suffix  _is_irregular  \
# 17905                                   žuž     ati              0
#
#       reconstructed
# 17905        žužati

# %%
cnt
# Out:
# Counter({0: 779, 1: 401, 3: 17, 2: 78, 6: 4, 27: 1, 4: 8, 5: 2, 8: 1, 7: 1})

# %%
# Out:
# 'None'

# %%
g2
# Out:
# 17905    None
# Name: isv, dtype: object

# %%
t1 = morphemes.dropna(subset=['reconstructed']).query('reconstructed.str.contains("\?")')

t1
# Out:
#             id            isv addition  partOfSpeech  \
# 887     4889.0    blågodariti      NaN    v.tr. ipf.
# 899     5574.0  blågoslavjati      NaN    v.tr. ipf.
# 900     5573.0   blågosloviti      NaN     v.tr. pf.
# 912     6050.0    blågoželati     (+3)  v.intr. ipf.
# 988    36422.0        bodnųti   (bode)   v.refl. pf.
# ...        ...            ...      ...           ...
# 17581  32633.0       zažigati      NaN    v.tr. ipf.
# 17582  32636.0       zažigati      NaN    v.tr. ipf.
# 17583  32638.0       zažigati      NaN    v.tr. ipf.
# 17624  23718.0        zěvnųti      NaN   v.intr. pf.
# 17917 -30731.0         smogti      NaN     v.tr. pf.
#
#                                                 en genesis   pos prefix  \
# 887                                          thank     NaN  verb      ?
# 899                                 bless, beatify     NaN  verb      ?
# 900                                 bless, beatify     NaN  verb      ?
# 912                                   congratulate     NaN  verb      ?
# 988                                     lock horns     NaN  verb      ?
# ...                                            ...     ...   ...    ...
# 17581               ignite, light, kindle, inflame     NaN  verb      ?
# 17582  switch on (the lights), turn on (the light)     NaN  verb      ?
# 17583                                  set fire to     NaN  verb      ?
# 17624                                         yawn     NaN  verb      ?
# 17917         manage to, be able to, cope, make it     NaN  verb      ?
#
#       verb_stem base_verb       isv_orig left_stem_cand right_stem_cand  \
# 887           ?    dariti    blågodariti       blågodar     blågodariti
# 899           ?   sloviti  blågoslavjati      blågoslav   blågoslavjati
# 900           ?   sloviti   blågosloviti        blågosl    blågosloviti
# 912           ?    želati    blågoželati       blågožel     blågoželati
# 988           ?    bodati     bodnųti sę            bod         bodnųti
# ...         ...       ...            ...            ...             ...
# 17581         ?     žegti       zažigati          zažig        ?žigati?
# 17582         ?     žegti       zažigati          zažig        ?žigati?
# 17583         ?     žegti       zažigati          zažig        ?žigati?
# 17624         ?    zěvati        zěvnųti            zěv         zěvnųti
# 17917         ?     mogti         smogti         smogti           mogti
#
#       derived_nouns base_noun _prefix _stem _suffix  _is_irregular  \
# 887                             blågo   dar     iti              0
# 899                             blågo  slav    jati              0
# 900                             blågo  slov     iti              0
# 912                             blågo   žel     ati              0
# 988          |bodec                     bod    nųti              0
# ...             ...       ...     ...   ...     ...            ...
# 17581                              za   žig     ati              0
# 17582                              za   žig     ati              0
# 17583                              za   žig     ati              0
# 17624                                   zěv    nųti             -1
# 17917                               s   mꜵg      ti              0
#
#       reconstructed
# 887         ?dariti
# 899        ?sloviti
# 900        ?sloviti
# 912         ?želati
# 988         ?bodati
# ...             ...
# 17581         ?žeťi
# 17582         ?žeťi
# 17583         ?žeťi
# 17624       ?zěvati
# 17917         ?moťi
#
# [2195 rows x 20 columns]

# %%
morphemes.loc[
    t1[(t1._prefix + t1.reconstructed.str.replace("?", "").apply(pra_verbs.get) == t1.isv)].index,
    "reconstructed"
] = "(" + t1._prefix + ")+" + t1.reconstructed.str.replace("?", "")
# Out:
# C:\Users\79165\AppData\Local\Temp\ipykernel_17612\2634797297.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   ] = "(" + t1._prefix + ")+" + t1.reconstructed.str.replace("?", "")
# C:\Users\79165\AppData\Local\Temp\ipykernel_17612\2634797297.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   t1[(t1._prefix + t1.reconstructed.str.replace("?", "").apply(pra_verbs.get) == t1.isv)].index,
# C:\Users\79165\AppData\Local\Temp\ipykernel_17612\2634797297.py:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   morphemes.loc[

# %%
morphemes.query("reconstructed != reconstructed and genesis != genesis").tail(55)
# Out:
#             id             isv addition  partOfSpeech  \
# 17464  23842.0      zasramjati      NaN    v.tr. ipf.
# 17466   1932.0         zasrati      NaN   v.intr. pf.
# 17468   4112.0       zastariti      NaN   v.intr. pf.
# 17469   4111.0      zastarjati      NaN  v.intr. ipf.
# 17478  21834.0      zastavjati      NaN    v.tr. ipf.
# 17479  21840.0      zastavjati      NaN    v.tr. ipf.
# 17483  19418.0      zastrašati      NaN    v.tr. ipf.
# 17484  19419.0      zastrašiti      NaN     v.tr. pf.
# 17485   3268.0      zastrěliti      NaN     v.tr. pf.
# 17486   5113.0     zastrěljati      NaN    v.tr. ipf.
# 17495  36419.0       zaščićati      NaN    v.tr. ipf.
# 17497  14177.0       zaščititi      NaN     v.tr. pf.
# 17502   1170.0       zatemniti      NaN     v.tr. pf.
# 17503   3090.0      zatemnjati      NaN    v.tr. ipf.
# 17507  33692.0       zatměvati      NaN    v.tr. ipf.
# 17508  31569.0         zatmiti      NaN     v.tr. pf.
# 17531  35005.0      zaustaviti      NaN   v.refl. pf.
# 17532   5656.0      zaustaviti      NaN     v.tr. pf.
# 17533   5655.0     zaustavjati      NaN  v.refl. ipf.
# 17534  35004.0     zaustavjati      NaN    v.tr. ipf.
# 17539  23977.0       zauvažati      NaN    v.tr. ipf.
# 17540  23978.0       zauvažiti      NaN     v.tr. pf.
# 17561  22514.0      zavladnųti      NaN     v.tr. pf.
# 17562  22513.0     zavladyvati      NaN    v.tr. ipf.
# 17564   2355.0      zavojevati      NaN     v.tr. pf.
# 17565   2294.0    zavojevyvati      NaN    v.tr. ipf.
# 17566  19428.0       zavraćati      NaN  v.intr. ipf.
# 17570  19431.0        zavŕšati      NaN    v.tr. ipf.
# 17571  19435.0        zavŕšiti      NaN     v.tr. pf.
# 17577  19439.0     zažartovati      NaN   v.intr. pf.
# 17586  34731.0        zdråvěti      NaN  v.intr. ipf.
# 17594  31602.0           zębti      NaN  v.intr. ipf.
# 17597  31623.0          zějati      NaN  v.intr. ipf.
# 17637  22900.0         zirkati      NaN  v.intr. ipf.
# 17638  22901.0        zirknųti      NaN   v.intr. pf.
# 17642  32974.0         zlåtiti      NaN    v.tr. ipf.
# 17650  36858.0         zlobiti      NaN  v.refl. ipf.
# 17651  34744.0         zlobiti      NaN    v.tr. ipf.
# 17665  35008.0     zloradovati      NaN  v.refl. ipf.
# 17672   1495.0   zloupotrěbiti      NaN     v.tr. pf.
# 17673   1892.0  zloupotrěbjati      NaN    v.tr. ipf.
# 17712  22850.0     znamenovati      NaN    v.tr. ipf.
# 17713  22851.0     znamenovati      NaN    v.tr. ipf.
# 17736   4043.0           zrěti    (zri)  v.intr. ipf.
# 17737  19468.0           zrěti  (zrěje)  v.intr. ipf.
# 17756  34748.0         zvěrěti      NaN  v.intr. ipf.
# 17771   1890.0         zvųčati  (zvųči)  v.intr. ipf.
# 17868  31713.0     žmuriti oči      NaN    v.tr. ipf.
# 17871  34739.0         žȯltěti      NaN  v.intr. ipf.
# 17881  34178.0         žrěbiti      NaN  v.refl. ipf.
# 17894   1490.0       žrtvovati      NaN    v.tr. ipf.
# 17904   2627.0          žuvati   (žuje)  v.intr. ipf.
# 17913 -37005.0     råzpečętati      NaN     v.tr. pf.
# 17914 -37006.0   råzpečętyvati      NaN    v.tr. ipf.
# 17921 -37004.0    zapečętyvati      NaN     v.tr.ipf.
#
#                                            en genesis   pos prefix  \
# 17464                               embarrass     NaN  verb      ?
# 17466                                    shit     NaN  verb      ?
# 17468                                     age     NaN  verb      ?
# 17469                                     age     NaN  verb      ?
# 17478                   block, obstruct, cram     NaN  verb      ?
# 17479                              pawn, hock     NaN  verb      ?
# 17483                              intimidate     NaN  verb      ?
# 17484                              intimidate     NaN  verb      ?
# 17485                             fire, shoot     NaN  verb      ?
# 17486                             fire, shoot     NaN  verb      ?
# 17495                 shield, protect, defend     NaN  verb      ?
# 17497                 shield, protect, defend     NaN  verb      ?
# 17502              obscure, darken, make dark     NaN  verb      ?
# 17503              obscure, darken, make dark     NaN  verb      ?
# 17507                        eclipse, obscure     NaN  verb      ?
# 17508                        eclipse, obscure     NaN  verb      ?
# 17531                             brake, stop     NaN  verb      ?
# 17532             stop, bring to a standstill     NaN  verb      ?
# 17533                             brake, stop     NaN  verb      ?
# 17534             stop, bring to a standstill     NaN  verb      ?
# 17539                                  notice     NaN  verb      ?
# 17540                                  notice     NaN  verb      ?
# 17561               seize, take possession of     NaN  verb      ?
# 17562               seize, take possession of     NaN  verb      ?
# 17564                                 conquer     NaN  verb      ?
# 17565                                 conquer     NaN  verb      ?
# 17566                                 reverse     NaN  verb      ?
# 17570         conclude, end, finish, complete     NaN  verb      ?
# 17571         conclude, end, finish, complete     NaN  verb      ?
# 17577                                    joke     NaN  verb      ?
# 17586    get better, recover (from a disease)     NaN  verb      ?
# 17594            freeze, be very cold, shiver     NaN  verb      ?
# 17597                                    gape     NaN  verb      ?
# 17637                      glance, peep, peek     NaN  verb      ?
# 17638                      glance, peep, peek     NaN  verb      ?
# 17642                                    gild     NaN  verb      ?
# 17650                                be angry     NaN  verb      ?
# 17651                anger, vex, annoy, spite     NaN  verb      ?
# 17665                                   gloat     NaN  verb      ?
# 17672                           abuse, misuse     NaN  verb      ?
# 17673                           abuse, misuse     NaN  verb      ?
# 17712                     mark, put a mark on     NaN  verb      ?
# 17713             signify, mean, be a sign of     NaN  verb      ?
# 17736           see, watch, behold, look (at)     NaN  verb      ?
# 17737                      age, mature, ripen     NaN  verb      ?
# 17756              go wild, become brutalized     NaN  verb      ?
# 17771                                   sound     NaN  verb      ?
# 17868  squint, scare off, screw up one’s eyes     NaN  verb      ?
# 17871                             turn yellow     NaN  verb      ?
# 17881                                    foal     NaN  verb      ?
# 17894                               sacrifice     NaN  verb      ?
# 17904                         chew, masticate     NaN  verb      ?
# 17913                                  unseal     NaN  verb   råz’
# 17914                                  unseal     NaN  verb   råz’
# 17921                                    seal     NaN  verb      ?
#
#         verb_stem      base_verb        isv_orig left_stem_cand  \
# 17464           ?        sråmiti      zasramjati         zasram
# 17466           ?          srati         zasrati           zasr
# 17468           ?      zastariti       zastariti         zastar
# 17469           ?      zastariti      zastarjati         zastar
# 17478           ?       stavjati      zastavjati         zastav
# 17479           ?       stavjati      zastavjati         zastav
# 17483           ?     zastrašati      zastrašati        zastraš
# 17484           ?     zastrašati      zastrašiti        zastraš
# 17485           ?     zastrěliti      zastrěliti        zastrěl
# 17486           ?     zastrěliti     zastrěljati        zastrěl
# 17495           ?        ščititi       zaščićati         zaščić
# 17497           ?        ščititi       zaščititi         zaščit
# 17502           ?      zatemniti       zatemniti         zatemn
# 17503           ?      zatemniti      zatemnjati         zatemn
# 17507           ?        zatmiti       zatměvati         zatměv
# 17508           ?        zatmiti         zatmiti           zatm
# 17531           ?     zaustaviti   zaustaviti sę        zaustav
# 17532           ?     zaustaviti      zaustaviti        zaustav
# 17533           ?     zaustaviti  zaustavjati sę        zaustav
# 17534           ?     zaustaviti     zaustavjati        zaustav
# 17539           ?         važiti       zauvažati         zauvaž
# 17540           ?         važiti       zauvažiti         zauvaž
# 17561           ?        vladati      zavladnųti         zavlad
# 17562           ?        vladati     zavladyvati         zavlad
# 17564           ?     zavojevati      zavojevati        zavojev
# 17565           ?     zavojevati    zavojevyvati        zavojev
# 17566           ?        vraćati       zavraćati         zavrać
# 17570           ?       zavŕšati        zavŕšati          zavŕš
# 17571           ?       zavŕšati        zavŕšiti          zavŕš
# 17577           ?      žartovati     zažartovati         zažart
# 17586           ?       zdråvěti        zdråvěti          zdråv
# 17594           ?          zębti           zębti          zębti
# 17597           ?         zějati          zějati             zě
# 17637           ?        zirkati         zirkati           zirk
# 17638           ?        zirkati        zirknųti           zirk
# 17642           ?        zlåtiti         zlåtiti           zlåt
# 17650           ?        zlobiti      zlobiti sę           zlob
# 17651           ?        zlobiti         zlobiti           zlob
# 17665           ?    zloradovati  zloradovati sę         zlorad
# 17672           ?  zloupotrěbiti   zloupotrěbiti     zloupotrěb
# 17673           ?  zloupotrěbiti  zloupotrěbjati     zloupotrěb
# 17712           ?    znamenovati     znamenovati         znamen
# 17713           ?    znamenovati     znamenovati         znamen
# 17736           ?          zrěti           zrěti             zr
# 17737           ?          zrěti           zrěti             zr
# 17756           ?        zvěrěti         zvěrěti           zvěr
# 17771           ?        zvųčati         zvųčati           zvųč
# 17868           ?        žmuriti     žmuriti oči    žmuriti oči
# 17871           ?        žȯltěti         žȯltěti           žȯlt
# 17881           ?        žrěbiti      žrěbiti sę           žrěb
# 17894           ?      žrtvovati       žrtvovati           žrtv
# 17904           ?         žuvati          žuvati            žuv
# 17913    pečętati       pečętati     råzpečętati       råzpečęt
# 17914  pečętyvati       pečętati   råzpečętyvati       råzpečęt
# 17921           ?       pečętati    zapečętyvati        zapečęt
#
#       right_stem_cand       derived_nouns base_noun _prefix       _stem  \
# 17464       ?ramjati?                                    za        sråm
# 17466           srati                                    za          sr
# 17468        ?tariti?                                            zastar
# 17469       ?tarjati?                                            zastar
# 17478        stavjati                                    za          st
# 17479        stavjati                                    za          st
# 17483       ?trašati?                                           zastraš
# 17484        strašiti                                           zastraš
# 17485        strěliti                                           zastrěl
# 17486       strěljati                                           zastrěl
# 17495       ?ščićati?                                    za        ščit
# 17497         ščititi          |zaščitnik                za        ščit
# 17502       ?temniti?                                            zatemn
# 17503      ?temnjati?                                            zatemn
# 17507       ?tměvati?                                              zatm
# 17508         ?tmiti?                                              zatm
# 17531         staviti                                             zaust
# 17532         staviti                                             zaust
# 17533        stavjati                                             zaust
# 17534        stavjati                                             zaust
# 17539         uvažati                                   zau         vag
# 17540          važiti                                   zau         vag
# 17561       ?ladnųti?                                    za        vlad
# 17562      ?ladyvati?                                    za        vlad
# 17564        vojevati                                           zavojev
# 17565      ?jevyvati?                                           zavojev
# 17566         vraćati                                    za        vrać
# 17570         ?ŕšati?                                             zavŕš
# 17571         ?ŕšiti?                                             zavŕš
# 17577       žartovati                                    za       žarto
# 17586        zdråvěti   |zdråvje|zdråvica                         zdråv
# 17594           zębti                                               zęb
# 17597          zějati             |zěnica                           zěj
# 17637         zirkati                                              zirk
# 17638        zirknųti                                              zirk
# 17642         zlåtiti             |zlåtaŕ                          zlåt
# 17650         zlobiti   |zlobnik|zlobnica     zloba                zlob
# 17651         zlobiti   |zlobnik|zlobnica     zloba                zlob
# 17665     zloradovati          |zloradosť                       zlorado
# 17672   zloupotrěbiti                                        zloupotrěb
# 17673  zloupotrěbjati                                        zloupotrěb
# 17712     znamenovati  |znameńje|znameńje                       znameno
# 17713     znamenovati  |znameńje|znameńje                       znameno
# 17736           zrěti                                                zr
# 17737           zrěti                                                zr
# 17756         zvěrěti                         !zvěŕ                zvěr
# 17771         zvųčati            |zvųčnik                          zvųč
# 17868   ?žmuriti oči?              žmurky                          žmur
# 17871         žȯltěti                                              žȯlt
# 17881         žrěbiti             |žrěbec                          žrěb
# 17894       žrtvovati                         žrtva               žrtvo
# 17904          žuvati                                                žu
# 17913        pečętati                                   råz       pečęt
# 17914    ?pečętyvati?                                   råz      pečęty
# 17921    ?pečętyvati?                                    za      pečęty
#
#       _suffix  _is_irregular reconstructed
# 17464    jati              0           NaN
# 17466     ati              0           NaN
# 17468     iti              0           NaN
# 17469    jati              0           NaN
# 17478  avjati              0           NaN
# 17479  avjati              0           NaN
# 17483     ati              0           NaN
# 17484     iti              0           NaN
# 17485     iti              0           NaN
# 17486    jati              0           NaN
# 17495    ⒥ati              0           NaN
# 17497     iti              0           NaN
# 17502     iti              0           NaN
# 17503    jati              0           NaN
# 17507   ěvati              0           NaN
# 17508     iti              0           NaN
# 17531   aviti              0           NaN
# 17532   aviti              0           NaN
# 17533  avjati              0           NaN
# 17534  avjati              0           NaN
# 17539    ⒥ati              0           NaN
# 17540    ⒥iti              0           NaN
# 17561    nųti              0           NaN
# 17562   yvati              0           NaN
# 17564     ati             -1           NaN
# 17565   yvati             -1           NaN
# 17566     ati              0           NaN
# 17570     ati              0           NaN
# 17571     iti              0           NaN
# 17577    vati              0           NaN
# 17586     ěti              0           NaN
# 17594      ti              0           NaN
# 17597     ati              0           NaN
# 17637     ati              0           NaN
# 17638    nųti              0           NaN
# 17642     iti              0           NaN
# 17650     iti              0           NaN
# 17651     iti              0           NaN
# 17665    vati              0           NaN
# 17672     iti              0           NaN
# 17673    jati              0           NaN
# 17712    vati              0           NaN
# 17713    vati              0           NaN
# 17736     ěti              0           NaN
# 17737     ěti              0           NaN
# 17756     ěti              0           NaN
# 17771     ati              0           NaN
# 17868     iti              0           NaN
# 17871     ěti              0           NaN
# 17881     iti              0           NaN
# 17894    vati              0           NaN
# 17904    vati              0           NaN
# 17913     ati              0           NaN
# 17914    vati              0           NaN
# 17921    vati              0           NaN

# %%
t1[(t1._prefix + t1.reconstructed.str.replace("?", "").apply(pra_verbs.get) != t1.isv)].query('not _suffix.str.contains("nųti")')
# Out:
# C:\Users\79165\AppData\Local\Temp\ipykernel_17612\2727962516.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   t1[(t1._prefix + t1.reconstructed.str.replace("?", "").apply(pra_verbs.get) != t1.isv)].query('not _suffix.str.contains("nųti")')
#             id            isv  addition  partOfSpeech  \
# 1185   22979.0     bųde/bųdųt       NaN   v.aux. ipf.
# 1189   34791.0      buditi sę       NaN    v.tr. ipf.
# 1246   35085.0    byti dȯlžen       NaN   v.aux. ipf.
# 1248   10343.0  byti ostråžny       NaN        v.ipf.
# 1249   17182.0   byti podobny       NaN        v.ipf.
# ...        ...            ...       ...           ...
# 17551  36089.0       zaviděti  (zavidi)  v.intr. ipf.
# 17553  20321.0    zavisěti od  (zavisi)  v.intr. ipf.
# 17581  32633.0       zažigati       NaN    v.tr. ipf.
# 17582  32636.0       zažigati       NaN    v.tr. ipf.
# 17583  32638.0       zažigati       NaN    v.tr. ipf.
#
#                                                       en genesis   pos prefix  \
# 1185                                       there will be     NaN  verb      ?
# 1189                                             wake up     NaN  verb      ?
# 1246   must, have to, ought to, should, be obliged to...     NaN  verb      ?
# 1248                                 look out, watch out     NaN  verb      ?
# 1249                                look alike, resemble     NaN  verb      ?
# ...                                                  ...     ...   ...    ...
# 17551                                               envy     NaN  verb      ?
# 17553                                          depend on     NaN  verb      ?
# 17581                     ignite, light, kindle, inflame     NaN  verb      ?
# 17582        switch on (the lights), turn on (the light)     NaN  verb      ?
# 17583                                        set fire to     NaN  verb      ?
#
#       verb_stem base_verb       isv_orig left_stem_cand  right_stem_cand  \
# 1185          ?               bųde/bųdųt     bųde/bųdųt     ?bųde/bųdųt?
# 1189          ?    buditi      buditi sę            bud      ?buditi sę?
# 1246          ?      byti    byti dȯlžen    byti dȯlžen    ?byti dȯlžen?
# 1248          ?      byti  byti ostråžny  byti ostråžny  ?byti ostråžny?
# 1249          ?      byti   byti podobny   byti podobny   ?byti podobny?
# ...         ...       ...            ...            ...              ...
# 17551         ?    viděti       zaviděti          zavid           viděti
# 17553         ?    visěti    zavisěti od    zavisěti od       ?isěti od?
# 17581         ?     žegti       zažigati          zažig         ?žigati?
# 17582         ?     žegti       zažigati          zažig         ?žigati?
# 17583         ?     žegti       zažigati          zažig         ?žigati?
#
#       derived_nouns base_noun _prefix _stem _suffix  _is_irregular  \
# 1185                                                             0
# 1189         |budka                     bud     iti              0
# 1246                                     by      ti              0
# 1248                                     by      ti              0
# 1249                                     by      ti              0
# ...             ...       ...     ...   ...     ...            ...
# 17551                              za   vid     ěti              0
# 17553                              za   vis     ěti              0
# 17581                              za   žig     ati              0
# 17582                              za   žig     ati              0
# 17583                              za   žig     ati              0
#
#       reconstructed
# 1185         ?uměti
# 1189        ?buditi
# 1246          ?byti
# 1248          ?byti
# 1249          ?byti
# ...             ...
# 17551   ?nenaviděti
# 17553       ?visěti
# 17581         ?žeťi
# 17582         ?žeťi
# 17583         ?žeťi
#
# [973 rows x 20 columns]

# %%
morphemes[morphemes.base_verb == ''].query('isv in @pra_forms')
# Out:
#             id         isv addition      partOfSpeech  \
# 7246    6087.0   nakladati      NaN        v.tr. ipf.
# 7247   28028.0   nakladati      NaN        v.tr. ipf.
# 8290    9775.0     obědati      NaN  v.intr. ipf./pf.
# 8510   22681.0    obråtiti     (+3)       v.refl. pf.
# 8511   22675.0    obråtiti      NaN       v.refl. pf.
# 8512   22677.0    obråtiti      NaN       v.refl. pf.
# 8513   22679.0    obråtiti      NaN       v.refl. pf.
# 8514    3209.0    obråtiti      NaN         v.tr. pf.
# 8515   22666.0    obråtiti      NaN         v.tr. pf.
# 8516   22668.0    obråtiti      NaN         v.tr. pf.
# 8517   22671.0    obråtiti      NaN         v.tr. pf.
# 8518   22673.0    obråtiti      NaN         v.tr. pf.
# 8519   34147.0    obråtiti      NaN         v.tr. pf.
# 9775   29773.0    ovdověti      NaN       v.intr. pf.
# 11405  35802.0  prěkladati      NaN        v.tr. ipf.
# 11734  20079.0  prikladati      NaN        v.tr. ipf.
# 12589  21505.0      raziti      NaN        v.tr. ipf.
# 12613  18607.0  råzkladati      NaN        v.tr. ipf.
# 12614  32691.0  råzkladati      NaN        v.tr. ipf.
# 13330  12075.0      saditi      NaN        v.tr. ipf.
# 13634  21573.0      siliti      NaN      v.refl. ipf.
# 13721   4463.0    skladati     (+2)      v.refl. ipf.
# 13722  20695.0    skladati      NaN      v.refl. ipf.
# 13723   3628.0    skladati      NaN        v.tr. ipf.
# 13769  18821.0     skrběti  (skrbi)      v.intr. ipf.
# 13816  33279.0     slåditi      NaN        v.tr. ipf.
# 14037  34003.0     snovati      NaN        v.tr. ipf.
# 14286  23816.0     sråmiti      NaN        v.tr. ipf.
# 14287  23817.0     sråmiti      NaN        v.tr. ipf.
# 14619   2097.0      sųditi      NaN        v.tr. ipf.
# 14620  22003.0      sųditi      NaN        v.tr. ipf.
# 15720    389.0       uměti      NaN       v.aux. ipf.
# 16087  30996.0     valjati      NaN      v.refl. ipf.
# 16088  22181.0     valjati      NaN        v.tr. ipf.
# 16326  19203.0     větriti      NaN        v.tr. ipf.
# 16367   2185.0      viděti   (vidi)        v.tr. ipf.
# 16463   3954.0    vkladati      NaN        v.tr. ipf.
# 16600   5340.0    vojevati      NaN      v.intr. ipf.
# 16621  23367.0      volěti   (voli)        v.tr. ipf.
# 16645  33169.0     vonjati      NaN      v.intr. ipf.
# 16646  33170.0     vonjati      NaN      v.intr. ipf.
# 16712  36269.0      voziti      NaN      v.refl. ipf.
# 16713    516.0      voziti      NaN        v.tr. ipf.
# 16852  31363.0    vrěščati      NaN      v.intr. ipf.
# 17223    939.0   zakladati      NaN        v.tr. ipf.
# 17224  32698.0   zakladati      NaN        v.tr. ipf.
#
#                                                  en genesis   pos prefix  \
# 7246                                         impose     NaN  verb      ?
# 7247                                        load up     NaN  verb      ?
# 8290                                dine, eat lunch     NaN  verb      ?
# 8510                             address, appeal to     NaN  verb      ?
# 8511                      turn (intr.), turn around     NaN  verb      ?
# 8512                               turn (into sth.)     NaN  verb      ?
# 8513                        convert (to a religion)     NaN  verb      ?
# 8514                                    turn around     NaN  verb      ?
# 8515                          rotate, revolve (tr.)     NaN  verb      ?
# 8516                       convert (sth. into sth.)     NaN  verb      ?
# 8517           direct (attention), turn (attention)     NaN  verb      ?
# 8518                   convert (sbd. to a religion)     NaN  verb      ?
# 8519                                        reverse     NaN  verb      ?
# 9775   be widowed, become a widow, become a widower     NaN  verb      ?
# 11405                                     translate     NaN  verb      ?
# 11734                  attach, append, apply, affix     NaN  verb      ?
# 12589                                   hit, strike     NaN  verb      ?
# 12613                        break apart, decompose     NaN  verb   råz’
# 12614                                       arrange     NaN  verb   råz’
# 13330                                   plant, seat     NaN  verb      ?
# 13634                                   strive, try     NaN  verb      ?
# 13721                                    consist of     NaN  verb      ?
# 13722                 pool money, take a collection     NaN  verb      ?
# 13723                                fold, compound     NaN  verb      ?
# 13769                                        grieve     NaN  verb      ?
# 13816                         sweeten, add sugar to     NaN  verb      ?
# 14037                                          warp     NaN  verb      ?
# 14286          #shame, put to shame, bring shame on     NaN  verb      ?
# 14287                                      disgrace     NaN  verb      ?
# 14619                         judge, try (in court)     NaN  verb      ?
# 14620                        predestine, foreordain     NaN  verb      ?
# 15720                  can, be able to, know how to     NaN  verb      ?
# 16087                 lie about, loll about, wallow     NaN  verb      ?
# 16088                                    felt, roll     NaN  verb      ?
# 16326                                air, ventilate     NaN  verb      ?
# 16367                                           see     NaN  verb      ?
# 16463            contribute, put in, insert, invest     NaN  verb      ?
# 16600                                 fight, combat     NaN  verb      ?
# 16621                           prefer, like better     NaN  verb      ?
# 16645                                         smell     NaN  verb      ?
# 16646                                   stink, reek     NaN  verb      ?
# 16712                           drive (e.g. by car)     NaN  verb      ’
# 16713                 carry (by vehicle), transport     NaN  verb      ’
# 16852                       squeal, screech, squeak     NaN  verb      ?
# 17223                      establish, set up, found     NaN  verb      ?
# 17224                                    pawn, hock     NaN  verb      ?
#
#        verb_stem base_verb        isv_orig left_stem_cand right_stem_cand  \
# 7246           ?                 nakladati         naklad       ?kladati?
# 7247           ?                 nakladati         naklad       ?kladati?
# 8290           ?                   obědati           oběd         ?ědati?
# 8510           ?             obråtiti sę k          obråt        ?råtiti?
# 8511           ?               obråtiti sę          obråt        ?råtiti?
# 8512           ?               obråtiti sę          obråt        ?råtiti?
# 8513           ?               obråtiti sę          obråt        ?råtiti?
# 8514           ?                  obråtiti          obråt        ?råtiti?
# 8515           ?                  obråtiti          obråt        ?råtiti?
# 8516           ?                  obråtiti          obråt        ?råtiti?
# 8517           ?                  obråtiti          obråt        ?råtiti?
# 8518           ?                  obråtiti          obråt        ?råtiti?
# 8519           ?                  obråtiti          obråt        ?råtiti?
# 9775           ?                  ovdověti            ovd           ?ěti?
# 11405          ?                prěkladati        prěklad       ?kladati?
# 11734          ?                prikladati        priklad       ?kladati?
# 12589          ?                    raziti            raz           ?iti?
# 12613    kladati                råzkladati        råzklad       ?kladati?
# 12614    kladati                råzkladati        råzklad       ?kladati?
# 13330          ?                    saditi            sad         ?aditi?
# 13634          ?                 siliti sę            sil         ?iliti?
# 13721          ?            skladati sę iz          sklad       ?kladati?
# 13722          ?               skladati sę          sklad       ?kladati?
# 13723          ?                  skladati          sklad       ?kladati?
# 13769          ?                   skrběti           skrb        ?krběti?
# 13816          ?                   slåditi           slåd        ?låditi?
# 14037          ?                   snovati             sn        ?novati?
# 14286          ?                   sråmiti           sråm        ?råmiti?
# 14287          ?                   sråmiti           sråm        ?råmiti?
# 14619          ?                    sųditi            sųd          ?diti?
# 14620          ?                    sųditi            sųd          ?diti?
# 15720          ?                     uměti             um          ?měti?
# 16087          ?                valjati sę            val        ?aljati?
# 16088          ?                   valjati            val        ?aljati?
# 16326          ?                   větriti           větr        ?ětriti?
# 16367          ?                    viděti            vid         ?iděti?
# 16463          ?                  vkladati          vklad       ?kladati?
# 16600          ?                  vojevati          vojev        ?jevati?
# 16621          ?                    volěti            vol          ?lěti?
# 16645          ?                   vonjati            von         ?njati?
# 16646          ?                   vonjati            von         ?njati?
# 16712  voziti sę                 voziti sę            voz           ?iti?
# 16713     voziti                    voziti            voz           ?iti?
# 16852          ?                  vrěščati          vrěšč       ?rěščati?
# 17223          ?                 zakladati         zaklad       ?kladati?
# 17224          ?                 zakladati         zaklad       ?kladati?
#
#            derived_nouns base_noun _prefix    _stem _suffix  _is_irregular  \
# 7246                        naklad           naklad     ati              0
# 7247                        naklad           naklad     ati              0
# 8290                          oběd             oběd     ati              0
# 8510                         obråt            obråt     iti              0
# 8511                         obråt            obråt     iti              0
# 8512                         obråt            obråt     iti              0
# 8513                         obråt            obråt     iti              0
# 8514                         obråt            obråt     iti              0
# 8515                         obråt            obråt     iti              0
# 8516                         obråt            obråt     iti              0
# 8517                         obråt            obråt     iti              0
# 8518                         obråt            obråt     iti              0
# 8519                         obråt            obråt     iti              0
# 9775                         vdova       o     vdov     ěti              0
# 11405                      prěklad          prěklad     ati              0
# 11734                      priklad          priklad     ati              0
# 12589                          raz              raz     iti              0
# 12613                      råzklad     råz     klad     ati              0
# 12614                      råzklad     råz     klad     ati              0
# 13330                          sad              sad     iti              0
# 13634                         sila              sil     iti              0
# 13721         |skladišče     sklad            sklad     ati              0
# 13722         |skladišče     sklad            sklad     ati              0
# 13723         |skladišče     sklad            sklad     ati              0
# 13769                         skrb             skrb     ěti              0
# 13816  |slådnik|slådnica      slåd             slåd     iti              0
# 14037                           sn               sn   ovati              0
# 14286                         sråm             sråm     iti              0
# 14287                         sråm             sråm     iti              0
# 14619                          sųd              sųd     iti              0
# 14620                          sųd              sųd     iti              0
# 15720             |umnik        um               um     ěti              0
# 16087             |valec  val|vala              val    jati              0
# 16088             |valec  val|vala              val    jati              0
# 16326   |větrnica|větrec      větr             větr     iti              0
# 16367                          vid              vid     ěti              0
# 16463                        vklad            vklad     ati              0
# 16600          |vojevnik     vojna              voj   evati              0
# 16621                          vol              vol     ěti              0
# 16645                         vonj              von    jati              0
# 16646                         vonj              von    jati              0
# 16712                          voz              voz     iti              0
# 16713                          voz              voz     iti              0
# 16852                        vrěsk       v     rěšk    ⒥ati              0
# 17223                       zaklad           zaklad     ati              0
# 17224                       zaklad           zaklad     ati              0
#
#       reconstructed
# 7246      nakladati
# 7247      nakladati
# 8290        obědati
# 8510    ob(v)ortiti
# 8511    ob(v)ortiti
# 8512    ob(v)ortiti
# 8513    ob(v)ortiti
# 8514    ob(v)ortiti
# 8515    ob(v)ortiti
# 8516    ob(v)ortiti
# 8517    ob(v)ortiti
# 8518    ob(v)ortiti
# 8519    ob(v)ortiti
# 9775      ovьdověti
# 11405    perkladati
# 11734    prikladati
# 12589        raziti
# 12613    orzkladati
# 12614    orzkladati
# 13330        saditi
# 13634       sidliti
# 13721     sъkladati
# 13722     sъkladati
# 13723     sъkladati
# 13769      skъrběti
# 13816       solditi
# 14037       snovati
# 14286       sormiti
# 14287       sormiti
# 14619        sǫditi
# 14620        sǫditi
# 15720         uměti
# 16087        vaľati
# 16088        vaľati
# 16326       větriti
# 16367        viděti
# 16463     vъkladati
# 16600      vojevati
# 16621        volěti
# 16645        voňati
# 16646        voňati
# 16712        voziti
# 16713        voziti
# 16852      verščati
# 17223     zakladati
# 17224     zakladati

# %%
morphemes.reconstructed.value_counts()
# Out:
# ?uměti          80
# ?stǫpati        27
# ?voliti         19
# ?obelťi         18
# ?praviti        17
#                 ..
# (od)+aviti       1
# (od)+jьgrati     1
# (od)+xoditi      1
# (od)+gybati      1
# žužati           1
# Name: reconstructed, Length: 1936, dtype: int64

# %%
len(morphemes), len(morphemes.query('reconstructed == reconstructed or genesis == genesis'))
# Out:
# (4985, 3463)

# %%
morphemes.query('(reconstructed != reconstructed) and (genesis != genesis)').head(333).tail(77)
# Out:
#            id         isv addition  partOfSpeech  \
# 5859  20420.0      lęgati      NaN    v.tr. ipf.
# 5894  27115.0      lěniti      NaN  v.refl. ipf.
# 5903  27127.0    lepetati      NaN  v.intr. ipf.
# 5920   2655.0     leskati      NaN  v.intr. ipf.
# 5921   2697.0    lesknųti      NaN   v.intr. pf.
# ...       ...         ...      ...           ...
# 7449  28189.0   naslåditi      NaN   v.refl. pf.
# 7450  28187.0   naslåditi      NaN     v.tr. pf.
# 7451  33275.0   naslađati      NaN  v.refl. ipf.
# 7452  33278.0   naslađati      NaN    v.tr. ipf.
# 7476  33150.0  nastavjati      NaN    v.tr. ipf.
#
#                                   en genesis   pos prefix verb_stem base_verb  \
# 5859                           hatch     NaN  verb      ?         ?    lęgati
# 5894                         be lazy     NaN  verb      ?         ?    lěniti
# 5903                 babble, prattle     NaN  verb      ?         ?  lepetati
# 5920                           shine     NaN  verb      ?         ?   leskati
# 5921                           shine     NaN  verb      ?         ?   leskati
# ...                              ...     ...   ...    ...       ...       ...
# 7449  enjoy, gloat, take pleasure in     NaN  verb      ?         ?   slåditi
# 7450                give pleasure to     NaN  verb      ?         ?   slåditi
# 7451  enjoy, gloat, take pleasure in     NaN  verb      ?         ?   slåditi
# 7452                give pleasure to     NaN  verb      ?         ?   slåditi
# 7476                lengthen, extend     NaN  verb      ?         ?  stavjati
#
#           isv_orig left_stem_cand right_stem_cand derived_nouns base_noun  \
# 5859        lęgati            lęg          lęgati
# 5894     lěniti sę            lěn          lěniti
# 5903      lepetati          lepet        lepetati
# 5920       leskati           lesk         leskati                  !lěska
# 5921      lesknųti           lesk        lesknųti
# ...            ...            ...             ...           ...       ...
# 7449  naslåditi sę         naslåd         slåditi
# 7450     naslåditi         naslåd         slåditi
# 7451  naslađati sę         naslađ        ?lađati?
# 7452     naslađati         naslađ        ?lađati?
# 7476    nastavjati         nastav        stavjati
#
#      _prefix  _stem _suffix  _is_irregular reconstructed
# 5859            lęg     ati              0           NaN
# 5894            lěn     iti              0           NaN
# 5903          lepet     ati              0           NaN
# 5920           lesk     ati              0           NaN
# 5921           lesk    nųti              0           NaN
# ...      ...    ...     ...            ...           ...
# 7449      na   slåd     iti              0           NaN
# 7450      na   slåd     iti              0           NaN
# 7451      na   slåd    ⒥ati              0           NaN
# 7452      na   slåd    ⒥ati              0           NaN
# 7476      na     st  avjati              0           NaN
#
# [77 rows x 20 columns]

# %%
morphemes.query("base_noun in @all_reconstructions")
# Out:
#             id         isv addition  partOfSpeech  \
# 712     2880.0  besědovati      NaN  v.intr. ipf.
# 1292   24918.0      cěniti      NaN    v.tr. ipf.
# 3138     401.0      gorěti   (gori)  v.intr. ipf.
# 3283   17443.0   gromaditi      NaN    v.tr. ipf.
# 3293    2568.0     groziti      NaN  v.intr. ipf.
# 3306    3950.0   grupovati      NaN    v.tr. ipf.
# 4487    1592.0      jedati      NaN  v.intr. ipf.
# 4804    2565.0      karati      NaN    v.tr. ipf.
# 4805   35408.0      karati      NaN    v.tr. ipf.
# 4958   26555.0   klevetati      NaN  v.intr. ipf.
# 5283     834.0      kopati      NaN    v.tr. ipf.
# 5331    8610.0      koriti      NaN    v.tr. ipf.
# 5457   26823.0     krasiti      NaN    v.tr. ipf.
# 5802    4701.0      lapati      NaN    v.tr. ipf.
# 5811     267.0     laskati      NaN    v.tr. ipf.
# 5812   27053.0     laskati      NaN    v.tr. ipf.
# 6208   27355.0     luskati      NaN    v.tr. ipf.
# 6294   17757.0      mamiti      NaN    v.tr. ipf.
# 6488   32926.0     měnjati      NaN  v.refl. ipf.
# 6489   20461.0     měnjati      NaN    v.tr. ipf.
# 6502    1995.0      měriti      NaN    v.tr. ipf.
# 6503   27536.0      měriti      NaN  v.intr. ipf.
# 7582   22551.0   navodniti      NaN     v.tr. pf.
# 7584   22550.0  navodnjati      NaN    v.tr. ipf.
# 8276   23084.0  občudovati      NaN    v.tr. ipf.
# 8324   28749.0     obiděti      NaN     v.tr. pf.
# 8629    4488.0  obvadnjati      NaN    v.tr. ipf.
# 8649    4489.0   obvodniti      NaN     v.tr. pf.
# 9091   10074.0  odvadnjati      NaN    v.tr. ipf.
# 9111   10093.0   odvodniti      NaN     v.tr. pf.
# 9540   29590.0   osamotiti      NaN   v.refl. pf.
# 9541   14812.0   osamotiti      NaN     v.tr. pf.
# 9559   22800.0   osirotiti      NaN     v.tr. pf.
# 9870    2829.0      paliti      NaN    v.tr. ipf.
# 9871   14826.0      paliti      NaN    v.tr. ipf.
# 9938   29859.0      pariti      NaN  v.intr. ipf.
# 10145  34281.0      piliti      NaN    v.tr. ipf.
# 10220   2114.0     platiti      NaN    v.tr. ipf.
# 10286  18232.0    poběditi      NaN   v.intr. pf.
# 11816  35699.0   prisęgati      NaN    v.tr. ipf.
# 12418   1381.0      raniti      NaN    v.tr. ipf.
# 12763  30379.0   råzpěniti      NaN   v.intr. pf.
# 13634  21573.0      siliti      NaN  v.refl. ipf.
# 13670  32542.0    sirotěti      NaN  v.intr. ipf.
# 14113  36052.0     sȯočati      NaN  v.refl. ipf.
# 14114  36053.0     sȯočiti      NaN  v.refl. ipf.
# 14535   1442.0    strěliti      NaN  v.intr. ipf.
# 15338   3276.0     tratiti      NaN    v.tr. ipf.
# 15339  18987.0     tratiti      NaN    v.tr. ipf.
# 15340  34953.0     tratiti      NaN    v.tr. ipf.
# 15782  13312.0     uperiti      NaN     v.tr. pf.
# 15849   4246.0   usilovati      NaN  v.intr. ipf.
# 15971  13422.0   uvadnjati      NaN    v.tr. ipf.
# 16003  13444.0    uvodniti      NaN     v.tr. pf.
# 16173  15128.0      věděti     (vě)    v.tr. ipf.
# 16567   2536.0      voditi      NaN    v.tr. ipf.
# 17827   3399.0      ženiti      NaN  v.refl. ipf.
#
#                                                      en genesis   pos prefix  \
# 712                                      converse, chat     NaN  verb      ?
# 1292                                         appreciate     NaN  verb      ?
# 3138                                   burn, be on fire     NaN  verb      ?
# 3283                                         accumulate     NaN  verb      ?
# 3293                                           threaten     NaN  verb      ?
# 3306                                              group       I  verb      ?
# 4487                                                eat     NaN  verb      ?
# 4804                                             punish     NaN  verb      ?
# 4805                 scold, rebuke, reprimand, reproach     NaN  verb      ?
# 4958                                            slander     NaN  verb      ?
# 5283                                                dig     NaN  verb      ?
# 5331                                    scold, reproach     NaN  verb      ?
# 5457                                           decorate     NaN  verb      ?
# 5802                                                paw     NaN  verb      ?
# 5811                                            flatter     NaN  verb      ?
# 5812                                caress, fondle, pet     NaN  verb      ?
# 6208                                              shell     NaN  verb      ?
# 6294            #cheat, delude, fool, deceive, hoodwink     NaN  verb      ?
# 6488                         alternate, vary, fluctuate     NaN  verb      ?
# 6489                                   change, exchange     NaN  verb      ?
# 6502                                            measure     NaN  verb      ?
# 6503                                                aim     NaN  verb      ?
# 7582                                           irrigate     NaN  verb      ?
# 7584                                           irrigate     NaN  verb      ?
# 8276                                             admire     NaN  verb      ?
# 8324                                     offend, insult     NaN  verb      ?
# 8629                                    irrigate, water     NaN  verb      ?
# 8649                                    irrigate, water     NaN  verb      ?
# 9091                                          dehydrate     NaN  verb      ?
# 9111                                          dehydrate     NaN  verb      ?
# 9540                                    isolate oneself     NaN  verb      ?
# 9541                          isolate, seclude, abandon     NaN  verb      ?
# 9559                                             orphan     NaN  verb      ?
# 9870                                               burn     NaN  verb      ?
# 9871                                              smoke     NaN  verb      ?
# 9938                                              steam     NaN  verb      ?
# 10145                                               saw     NaN  verb      ?
# 10220                                               pay     NaN  verb      ?
# 10286                                  conquer, triumph     NaN  verb      ?
# 11816                                      swear (oath)     NaN  verb      ?
# 12418                               wound, hurt, injure     NaN  verb      ?
# 12763                               foam, froth, lather     NaN  verb   råz’
# 13634                                       strive, try     NaN  verb      ?
# 13670                                       be orphaned     NaN  verb      ?
# 14113                                   face, deal with     NaN  verb      ?
# 14114                                   face, deal with     NaN  verb      ?
# 14535                                       shoot, fire     NaN  verb      ?
# 15338                                     spend, expend     NaN  verb      ?
# 15339                                              lose     NaN  verb      ?
# 15340                                   waste, squander     NaN  verb      ?
# 15782                                           feather     NaN  verb      ?
# 15849         strive, seek, aspire, endeavour, endeavor     NaN  verb      ?
# 15971                                  hydrate, moisten     NaN  verb      ?
# 16003                                  hydrate, moisten     NaN  verb      ?
# 16173                                              know     NaN  verb      ?
# 16567                                              lead     NaN  verb      ?
# 17827  marry (with a woman), get married (with a woman)     NaN  verb      ?
#
#       verb_stem   base_verb                    isv_orig left_stem_cand  \
# 712           ?  besědovati                  besědovati          besěd
# 1292          ?      cěniti                      cěniti            cěn
# 3138          ?      gorěti                      gorěti            gor
# 3283          ?   gromaditi                   gromaditi         gromad
# 3293          ?     groziti                     groziti           groz
# 3306          ?   grupovati                   grupovati           grup
# 4487          ?      jedati                      jedati            jed
# 4804          ?      karati                      karati            kar
# 4805          ?      karati                      karati            kar
# 4958          ?   klevetati                   klevetati         klevet
# 5283          ?      kopati                      kopati            kop
# 5331          ?      koriti                      koriti            kor
# 5457          ?     krasiti                     krasiti           kras
# 5802          ?      lapati                      lapati            lap
# 5811          ?     laskati                     laskati           lask
# 5812          ?     laskati                     laskati           lask
# 6208          ?     luskati                     luskati           lusk
# 6294          ?      mamiti                      mamiti            mam
# 6488          ?     měnjati                  měnjati sę            měn
# 6489          ?     měnjati                     měnjati            měn
# 6502          ?      měriti                      měriti            měr
# 6503          ?      měriti                      měriti            měr
# 7582          ?     vodniti                   navodniti         navodn
# 7584          ?     vodniti                  navodnjati         navodn
# 8276          ?                              občudovati          občud
# 8324          ?     obiděti                     obiděti           obid
# 8629          ?     vodniti                  obvadnjati         obvadn
# 8649          ?     vodniti                   obvodniti         obvodn
# 9091          ?     vodniti                  odvadnjati         odvadn
# 9111          ?     vodniti                   odvodniti         odvodn
# 9540          ?                            osamotiti sę         osamot
# 9541          ?                               osamotiti         osamot
# 9559          ?                               osirotiti         osirot
# 9870          ?      paliti                      paliti            pal
# 9871          ?      paliti                      paliti            pal
# 9938          ?      pariti                      pariti            par
# 10145         ?      piliti                      piliti            pil
# 10220         ?     platiti                     platiti           plat
# 10286         ?    poběditi                    poběditi          poběd
# 11816         ?   prisęgati                   prisęgati         prisęg
# 12418         ?      raniti                      raniti            ran
# 12763    pěniti                               råzpěniti         råzpěn
# 13634         ?                               siliti sę            sil
# 13670         ?    sirotěti                    sirotěti          sirot
# 14113         ?     sȯočiti  sȯočati sę s, sųočati sę s           sȯoč
# 14114         ?     sȯočiti  sȯočiti sę s, sųočiti sę s           sȯoč
# 14535         ?    strěliti                    strěliti          strěl
# 15338         ?     tratiti                     tratiti           trat
# 15339         ?     tratiti                     tratiti           trat
# 15340         ?     tratiti                     tratiti           trat
# 15782         ?                                 uperiti           uper
# 15849         ?                               usilovati           usil
# 15971         ?     vodniti                   uvadnjati          uvadn
# 16003         ?     vodniti                    uvodniti          uvodn
# 16173         ?      věděti                      věděti            věd
# 16567         ?      voditi                      voditi            vod
# 17827         ?      ženiti                   ženiti sę            žen
#
#       right_stem_cand               derived_nouns base_noun _prefix   _stem  \
# 712        besědovati                                besěda          besědo
# 1292           cěniti                                  cěna             cěn
# 3138           gorěti               |gorka|gornik      gora             gꜵr
# 3283        gromaditi                               gromada          gromad
# 3293          groziti                                 groza            grꜵz
# 3306        grupovati                                 grupa           grupo
# 4487           jedati                                  jeda             jed
# 4804           karati                                  kara             kar
# 4805           karati                                  kara             kar
# 4958        klevetati                  |klevetnik   kleveta          klevet
# 5283           kopati               |kopija|kopje      kopa             kop
# 5331           koriti               |korka|korica      kora             kor
# 5457          krasiti                   |krasnica     krasa            kras
# 5802           lapati                      |lapka      lapa             lap
# 5811          laskati                                 laska            lask
# 5812          laskati                                 laska            lask
# 6208          luskati                                 luska            lusk
# 6294           mamiti                                  mama             mam
# 6488          měnjati                                  měna             měn
# 6489          měnjati                                  měna             měn
# 6502           měriti                      |měrka      měra             měr
# 6503           měriti                      |měrka      měra             měr
# 7582            dniti                  |navodnica      voda      na    vꜵdn
# 7584         ?dnjati?                  |navodnica      voda      na    vꜵdn
# 8276       ?čudovati?                                  čudo      ob     čud
# 8324          ?iděti?                                 obida            obid
# 8629        ?adnjati?                                  voda      ob    vꜵdn
# 8649            dniti                                  voda      ob    vꜵdn
# 9091        ?adnjati?                                  voda      od    vꜵdn
# 9111            dniti                                  voda      od    vꜵdn
# 9540        ?amotiti?                                samota       o   samot
# 9541        ?amotiti?                                samota       o   samot
# 9559        ?irotiti?                                sirota       o   sirot
# 9870           paliti                |palka|palec      pala             pal
# 9871           paliti                |palka|palec      pala             pal
# 9938           pariti                                  para             par
# 10145          piliti                                  pila             pil
# 10220         platiti                                 plata            plat
# 10286        ?běditi?                                poběda           poběd
# 11816          sęgati                               prisęga          prisęg
# 12418          raniti                      |ranec      rana             ran
# 12763        ?pěniti?                                  pěna     råz     pěn
# 13634         ?iliti?                                  sila             sil
# 13670       ?irotěti?                  |sirotišče    sirota           sirot
# 14113          ?čati?                                   oko            sȯoč
# 14114          ?čiti?                                   oko            sȯoč
# 14535       ?trěliti?  |strělec|strělec|strělišče    strěla           strěl
# 15338         tratiti                                 trata            trat
# 15339         tratiti                                 trata            trat
# 15340         tratiti                                 trata            trat
# 15782        ?periti?                                  pero       u     per
# 15849       ?ilovati?                     |usiľje      sila       u     sil
# 15971       ?adnjati?                                  voda       u    vꜵdn
# 16003           dniti                                  voda       u    vꜵdn
# 16173         ?ěděti?                                  věda             věd
# 16567          ?diti?              |vodka|vodstvo      voda             vꜵd
# 17827          ženiti                                  žena             žen
#
#       _suffix  _is_irregular reconstructed
# 712      vati              0    besědovati
# 1292      iti              0        cěniti
# 3138      ěti              0        gorěti
# 3283      iti              0           NaN
# 3293      iti              0       groziti
# 3306     vati              0           NaN
# 4487      ati              0           NaN
# 4804      ati              0        karati
# 4805      ati              0        karati
# 4958      ati              0     klevetati
# 5283      ati              0        kopati
# 5331      iti              0        koriti
# 5457      iti              0       krasiti
# 5802      ati              0        olpati
# 5811      ati              0       laskati
# 5812      ati              0       laskati
# 6208      ati              0       luskati
# 6294      iti              0        mamiti
# 6488     jati              0           NaN
# 6489     jati              0           NaN
# 6502      iti              0        měriti
# 6503      iti              0        měriti
# 7582      iti              0           NaN
# 7584     jati              0           NaN
# 8276    ovati              0        ?uměti
# 8324      ěti              0           NaN
# 8629     jati              0           NaN
# 8649      iti              0           NaN
# 9091     jati              0           NaN
# 9111      iti              0           NaN
# 9540      iti              0        ?uměti
# 9541      iti              0        ?uměti
# 9559      iti              0        ?uměti
# 9870      iti              0        paliti
# 9871      iti              0        paliti
# 9938      iti              0        pariti
# 10145     iti              0        piliti
# 10220     iti              0       platiti
# 10286     iti              0      poběditi
# 11816     ati              0           NaN
# 12418     iti              0        raniti
# 12763     iti              0        ?uměti
# 13634     iti              0       sidliti
# 13670     ěti              0           NaN
# 14113     ati              0           NaN
# 14114     iti              0           NaN
# 14535     iti              0      strěliti
# 15338     iti              0       tratiti
# 15339     iti              0       tratiti
# 15340     iti              0       tratiti
# 15782     iti              0        ?uměti
# 15849   ovati              0        ?uměti
# 15971    jati              0           NaN
# 16003     iti              0           NaN
# 16173     ěti             -1        věděti
# 16567     iti              0        voditi
# 17827     iti              0        ženiti

# %%
morphemes.head(1).values
# Out:
# array([[11.0, 'abdikovati', nan, 'v.intr. ipf.', 'abdicate', 'I', 'verb',
#         '?', '?', 'abdikovati', 'abdikovati', 'abdik', 'abdikovati',
#         '|abdikacija', '', '', 'abdiko', 'vati', 0, None]], dtype=object)

# %%
BV = morphemes.query('reconstructed == reconstructed').base_verb.unique()

# %%
len(BV)
# Out:
# 386

# %%
morphemes.query('reconstructed != reconstructed and base_verb in @BV and not isv.str.contains(" ")')
# Out:
#             id          isv  addition      partOfSpeech  \
# 1185   22979.0   bųde/bųdųt       NaN       v.aux. ipf.
# 1710   25144.0   debatovati       NaN      v.intr. ipf.
# 1716   25152.0  debjutovati       NaN  v.intr. ipf./pf.
# 1735   15280.0   defisovati       NaN        v.tr. ipf.
# 1988   25273.0      dobrěti       NaN      v.intr. ipf.
# ...        ...          ...       ...               ...
# 17500  23255.0       zašiti  (zašije)         v.tr. pf.
# 17521   5204.0   zatvarjati       NaN        v.tr. ipf.
# 17524   5205.0    zatvoriti       NaN         v.tr. pf.
# 17537  14193.0   zautrakati       NaN      v.intr. ipf.
# 17544  31583.0     zavěćati       NaN    v.tr. ipf./pf.
#
#                                    en genesis   pos prefix    verb_stem  \
# 1185                    there will be     NaN  verb      ?            ?
# 1710                           debate       I  verb      ’   debatovati
# 1716                 make one’s debut       F  verb      ’  debjutovati
# 1735                        hyphenate       I  verb      ’   defisovati
# 1988                      become good     NaN  verb      ?            ?
# ...                               ...     ...   ...    ...          ...
# 17500                     sew, stitch     NaN  verb      ?            ?
# 17521                     close, shut     NaN  verb      ?            ?
# 17524                     close, shut     NaN  verb      ?            ?
# 17537  eat breakfast, have breakfrast     NaN  verb      ?            ?
# 17544         bequeath, leave by will     NaN  verb      ?            ?
#
#       base_verb     isv_orig left_stem_cand right_stem_cand derived_nouns  \
# 1185              bųde/bųdųt     bųde/bųdųt    ?bųde/bųdųt?
# 1710              debatovati          debat      ?batovati?
# 1716             debjutovati         debjut     ?bjutovati?
# 1735              defisovati          defis      ?fisovati?
# 1988                 dobrěti           dobr         ?brěti?      |dobrosť
# ...         ...          ...            ...             ...           ...
# 17500      šiti       zašiti            zaš            šiti
# 17521   tvoriti   zatvarjati         zatvar      ?tvarjati?
# 17524   tvoriti    zatvoriti         zatvor         tvoriti     |zatvorka
# 17537             zautrakati        zautrak       ?trakati?
# 17544               zavěćati          zavěć         ?ěćati?
#
#       base_noun _prefix    _stem _suffix  _is_irregular reconstructed
# 1185                                                  0           NaN
# 1710     debata            debat   ovati              0           NaN
# 1716     debjut           debjut   ovati              0           NaN
# 1735      defis            defis   ovati              0           NaN
# 1988      dobry             dobr     ěti              0           NaN
# ...         ...     ...      ...     ...            ...           ...
# 17500                za        š     iti             -1           NaN
# 17521                za     tvꜵr    jati              0           NaN
# 17524                za     tvꜵr     iti              0           NaN
# 17537  zautraka          zautrak     ati              0           NaN
# 17544     zavět            zavět    ⒥ati              0           NaN
#
# [293 rows x 20 columns]

# %%
pd.concat(dfs).sort_values(by='base_verb')
# Out:
#             id        isv addition  partOfSpeech                      en  \
# 12589  21505.0     raziti      NaN    v.tr. ipf.             hit, strike
# 13330  12075.0     saditi      NaN    v.tr. ipf.             plant, seat
# 14037  34003.0    snovati      NaN    v.tr. ipf.                    warp
# 14619   2097.0     sųditi      NaN    v.tr. ipf.   judge, try (in court)
# 14620  22003.0     sųditi      NaN    v.tr. ipf.  predestine, foreordain
# ...        ...        ...      ...           ...                     ...
# 14699  18925.0     sušiti      NaN    v.tr. ipf.                     dry
# 17846   7191.0       žiti   (žive)  v.intr. ipf.           reside, dwell
# 17845     28.0       žiti   (žive)  v.intr. ipf.                    live
# 11645  11412.0  prěživati      NaN    v.tr. ipf.            live through
# 11644   4330.0  prěživati      NaN    v.tr. ipf.              experience
#
#       genesis   pos prefix verb_stem base_verb   isv_orig left_stem_cand  \
# 12589     NaN  verb      ?         ?               raziti            raz
# 13330     NaN  verb      ?         ?               saditi            sad
# 14037     NaN  verb      ?         ?              snovati             sn
# 14619     NaN  verb      ?         ?               sųditi            sųd
# 14620     NaN  verb      ?         ?               sųditi            sųd
# ...       ...   ...    ...       ...       ...        ...            ...
# 14699     NaN  verb      ?         ?      šiti     sušiti            suš
# 17846     NaN  verb      ?         ?      žiti       žiti              ž
# 17845     NaN  verb      ?         ?      žiti       žiti              ž
# 11645     NaN  verb      ?         ?      žiti  prěživati           prěž
# 11644     NaN  verb      ?         ?      žiti  prěživati           prěž
#
#       right_stem_cand derived_nouns base_noun _prefix _stem _suffix  \
# 12589           ?iti?                     raz           raz     iti
# 13330         ?aditi?                     sad           sad     iti
# 14037        ?novati?                      sn            sn   ovati
# 14619          ?diti?                     sųd           sųd     iti
# 14620          ?diti?                     sųd           sųd     iti
# ...               ...           ...       ...     ...   ...     ...
# 14699            šiti                                   suh    ⒥iti
# 17846            žiti                                    ži      ti
# 17845            žiti                                    ži      ti
# 11645        ?živati?                             prě    ži    vati
# 11644        ?živati?                             prě    ži    vati
#
#        _is_irregular reconstructed
# 12589              0
# 13330              0
# 14037              0
# 14619              0
# 14620              0
# ...              ...           ...
# 14699              0
# 17846             -1
# 17845             -1
# 11645             -1
# 11644             -1
#
# [86 rows x 20 columns]

# %%
unk
# Out:
# ['abdikovati',
#  'abonovati',
#  'absorbovati',
#  'abstrahovati',
#  'adaptovati',
#  'administrovati',
#  'adoptovati',
#  'adresovati',
#  'agitovati',
#  'agonizovati',
#  'akcentovati',
#  'akceptovati',
#  'aklimatizovati',
#  'akompanovati',
#  'aktivovati',
#  'aktualizovati',
#  'akumulovati',
#  'amnestovati',
#  'amortizovati',
#  'amputovati',
#  'analizovati',
#  'aneksovati',
#  'anulovati',
#  'apelovati',
#  'aplodovati',
#  'aranževati',
#  'areštovati',
#  'argumentovati',
#  'arhivovati',
#  'asimilovati',
#  'atakovati',
#  'avansovati',
#  'avtomatizovati',
#  'avtorizovati',
#  'avtostopovati',
#  'bagatelizovati',
#  'balansovati',
#  'balotovati',
#  'balzamovati',
#  'barikadovati',
#  'barviti',
#  'bazovati',
#  '†pokojiti',
#  'blågodariti',
#  'blågoslavjati',
#  'blågosloviti',
#  'blågovolěti',
#  'blågoželati',
#  'blaznovati',
#  'blědněti',
#  'blěskati',
#  'blěstěti',
#  'bližiti',
#  'bljunųti',
#  'bljuvati',
#  'blokovati',
#  'blųkati',
#  'bogatěti',
#  'bogohuliti',
#  'bojkotovati',
#  'bombardovati',
#  'brahtati',
#  'bratati',
#  'bråzditi',
#  'breknųti',
#  'brenčati',
#  'brenknųti',
#  'budovati',
#  'buntovati',
#  'buriti',
#  'bzděti',
#  'cenzurovati',
#  'citovati',
#  'cmokati',
#  'cvěliti',
#  'cvěsti',
#  'cvětati',
#  'cvětnųti',
#  'cviliti',
#  'cvŕkati',
#  'čaditi',
#  'čestitati',
#  'čestiti',
#  'čisliti',
#  'črněti',
#  'črniti',
#  'črpati',
#  'črstvěti',
#  'črtati',
#  'črveněti',
#  'čtiti',
#  'čučati',
#  'datovati',
#  'daunlodovati',
#  'belěti',
#  'definiovati',
#  'formovati',
#  'generovati',
#  'degradovati',
#  'degustovati',
#  'deklamovati',
#  'dękovati',
#  'demonstrovati',
#  'deportovati',
#  'deprimovati',
#  'stabilizovati',
#  'dezertovati',
#  'dezinfikovati',
#  'diktovati',
#  'diskreditovati',
#  'diskriminovati',
#  'diskutovati',
#  'diskvalifikovati',
#  'distancevati',
#  'dniti',
#  'gorěti',
#  'dȯhnųti',
#  'idti',
#  'jehati',
#  '†kladati',
#  'dokonati',
#  'končati',
#  'dȯlbti',
#  'dȯlgočasiti',
#  '†ložiti',
#  'dȯlžiti',
#  'mněvati',
#  'pȯlniti',
#  'pȯlzti',
#  'pustiti',
#  'pušćati',
#  'doråzuměvati',
#  'rųčiti',
#  'saditi',
#  'dosęgati',
#  'doskonaliti',
#  'stavjati',
#  'dostigati',
#  'tykati',
#  'dovědati',
#  'voziti',
#  'dovŕšati',
#  'zrěti',
#  'dȯžditi',
#  'dražniti',
#  'dreti',
#  'dųbiti',
#  'dubliti',
#  'dųnųti',
#  'durěti',
#  'dvojiti',
#  'dyhtěti',
#  'dymiti',
#  'egzistovati',
#  'ejakulovati',
#  'eksperimentovati',
#  'eksploatovati',
#  'eksplodovati',
#  'eksportovati',
#  'ekstragovati',
#  'eliminovati',
#  'emigrovati',
#  'entuziazmovati',
#  'eskalovati',
#  'eskortovati',
#  'evakuovati',
#  'fabrikovati',
#  'falsifikovati',
#  'farbovati',
#  'filmovati',
#  'filtrovati',
#  'finansovati',
#  'flirtovati',
#  'formalizovati',
#  'formulovati',
#  'fotografovati',
#  'frustrovati',
#  'funkcionovati',
#  'galopovati',
#  'galvanizovati',
#  'garantovati',
#  'garnirovati',
#  'gazovati',
#  'generalizovati',
#  'gestikulovati',
#  'glådovati',
#  'glåsiti',
#  'glåsovati',
#  'globalizovati',
#  'glupěti',
#  'glušiti',
#  'gněvati',
#  'gnězditi',
#  'gniti',
#  'gnojiti',
#  'godovati',
#  'goliti',
#  'gȯltati',
#  'gorčiti',
#  'goŕknųti',
#  'goršiti',
#  'gostiti',
#  'gotoviti',
#  'graničiti',
#  'gravirovati',
#  'grbiti',
#  'grditi',
#  'grebti',
#  'greměti',
#  'grnųti',
#  'grohtati',
#  'gromaditi',
#  'grupovati',
#  'gryzati',
#  'gųstiti',
#  'halucinovati',
#  'harakterizovati',
#  'harmonizovati',
#  'hihotati',
#  'hipnotizovati',
#  'hlåděti',
#  'hlipati',
#  'hmuriti',
#  'homogenizovati',
#  'hrapati',
#  'hrčati',
#  'hromati',
#  'hroměti',
#  'hrupati',
#  'hrustati',
#  'hudnųti',
#  'hvastati',
#  'hvějati',
#  'hvorěti',
#  'hybiti',
#  'idealizovati',
#  'identifikovati',
#  'ignorovati',
#  'ilustrovati',
#  'imigrovati',
#  'imitovati',
#  'implantovati',
#  'imponovati',
#  'importovati',
#  'improvizovati',
#  'informovati',
#  'inicializovati',
#  'inspirovati',
#  'instalovati',
#  'integrovati',
#  'interesovati',
#  'internacionalizovati',
#  'interpretovati',
#  'intrigovati',
#  'investovati',
#  'istnovati',
#  'izčezati',
#  'izčrkati',
#  '†gynųti',
#  'izjasniti',
#  'kalkulovati',
#  'izključati',
#  'kljuvati',
#  'koreniti',
#  'koristati',
#  'koristiti',
#  'kriknųti',
#  'krvaviti',
#  'izkusiti',
#  '†lagati',
#  'měnjati',
#  '†městiti',
#  'mětati',
#  'mrěti',
#  'modelovati',
#  '†niknųti',
#  'niščiti',
#  'iznuriti',
#  'izobličati',
#  'obraziti',
#  'izolovati',
#  'izopačati',
#  '†plåšiti',
#  'pljunųti',
#  'pljuvati',
#  'plyvti',
#  'izpovědati',
#  'izpråzdniti',
#  'pręgti',
#  'izprobovati',
#  'råbotati',
#  'råvniti',
#  'raziti',
#  'rěkti',
#  'rųbati',
#  'sěkati',
#  'izseliti',
#  'sloviti',
#  'izslušati',
#  'smějati',
#  'sȯhnųti',
#  'sȯsati',
#  'izstaviti',
#  'strěliti',
#  'stųpati',
#  'suvati',
#  'školiti',
#  'iztěkati',
#  'treti',
#  'tȯlkti',
#  'izučati',
#  'vajati',
#  'izvěstiti',
#  '†vihnųti',
#  'izviniti',
#  'vlastniti',
#  'vraćati',
#  'značiti',
#  'jalověti',
#  'jasněti',
#  'jedati',
#  'jesti',
#  'jezditi',
#  'kameněti',
#  'kamenovati',
#  'kanalizovati',
#  'kandidovati',
#  'kanonizovati',
#  'kapitulovati',
#  'kaprizovati',
#  'kastrovati',
#  'kategorizovati',
#  'klanjati',
#  'klasifikovati',
#  'klåsiti',
#  'klejiti',
#  'klęknųti',
#  'klěskati',
#  'klevetati',
#  'klicati',
#  'kljunųti',
#  'kljusati',
#  'kodifikovati',
#  'kodovati',
#  'koketovati',
#  'kokodakati',
#  'kolěbati',
#  'kolonizovati',
#  'kolorovati',
#  'kolovati',
#  'kȯlzati',
#  'kombinovati',
#  'komentovati',
#  'kompensovati',
#  'kompjuterizovati',
#  'komplikovati',
#  'komponovati',
#  'komunikovati',
#  'koncentrovati',
#  'konfiskovati',
#  'konkurovati',
#  'konservovati',
#  'konstruovati',
#  'kontrabandovati',
#  'kontrolovati',
#  'kooperovati',
#  'koordinovati',
#  'korigovati',
#  'koronovati',
#  'koštovati',
#  'krěpěti',
#  'kresati',
#  'krestiti',
#  'krijumčariti',
#  'kristalizovati',
#  'kritikovati',
#  'krivditi',
#  'kriviti',
#  'krjakati',
#  'krȯšiti',
#  'kuhati',
#  'kuljgati',
#  'kulminovati',
#  'kustomizovati',
#  'kvakati',
#  'kvalifikovati',
#  'kvasiti',
#  'kvičati',
#  'kvokati',
#  'kymati',
#  'kyvnųti',
#  'lakovati',
#  'lamati',
#  'lapati',
#  'latati',
#  'leděněti',
#  'leděniti',
#  'legalizovati',
#  'lęgati',
#  'lěniti',
#  'lepetati',
#  'leskati',
#  'lětati',
#  'lětovati',
#  'lgati',
#  'liberalizovati',
#  'liceměriti',
#  'likvidovati',
#  'limitovati',
#  'linčevati',
#  'ljuljati',
#  'lobovati',
#  'logovati',
#  'lojiti',
#  'loskotati',
#  'lysěti',
#  'malěti',
#  'maljevati',
#  'maltretovati',
#  'manevrovati',
#  'manipulovati',
#  'marginalizovati',
#  'marširovati',
#  'masakrovati',
#  'masirovati',
#  'maskovati',
#  'mastiti',
#  'masturbovati',
#  'meblovati',
#  'męčkati',
#  'mečtati',
#  'meditovati',
#  'medliti',
#  'mekati',
#  'mękčeti',
#  'mękčiti',
#  'měšati',
#  'metnųti',
#  'mglati',
#  'milovati',
#  'minimalizovati',
#  'mjaukati',
#  'mlåděti',
#  'mljaskati',
#  'množiti',
#  'mobilizovati',
#  'moćněti',
#  'modernizovati',
#  'modifikovati',
#  'modrěti',
#  'modriti',
#  'moknųti',
#  'mokrěti',
#  'mokriti',
#  'molestovati',
#  'montovati',
#  'moralizovati',
#  'morati',
#  'motivovati',
#  'mråziti',
#  'mråzosušati',
#  'mrčati',
#  'mrmjati',
#  'mŕtvěti',
#  'mrznųti',
#  'mučati',
#  'mųdrěti',
#  'mukati',
#  'musěti',
#  'mųtněti',
#  'mųžiti',
#  'myliti',
#  'myškovati',
#  'nacionalizovati',
#  'nagråditi',
#  'naklåti',
#  'legati',
#  'ostriti',
#  'parfumovati',
#  'pęti',
#  'pinati',
#  'pirati',
#  'prųžiti',
#  'rysovati',
#  'scati',
#  'naseliti',
#  'slåditi',
#  'stignųti',
#  'sytiti',
#  'šeptati',
#  'tipkati',
#  'navěditi',
#  'věsiti',
#  'věšati',
#  'naviti',
#  'vlåžiti',
#  'vodniti',
#  'voščiti',
#  'vråžiti',
#  'zdråvěti',
#  'něměti',
#  'viděti',
#  'nevtralizovati',
#  'noćevati',
#  'nominovati',
#  'nrěstiti',
#  'občiti',
#  'obezglåviti',
#  'hråbriti',
#  'obezsiliti',
#  'obhvatiti',
#  'obiděti',
#  'objasniti',
#  'objediniti',
#  'obkoliti',
#  'oblegčati',
#  'obmeđati',
#  'obnoviti',
#  '†nažiti',
#  '†niziti',
#  'obobćati',
#  'obogatiti',
#  'obognjeodparnjati',
#  'obraćati',
#  'radovati',
#  'obrěmeniti',
#  'vŕnųti',
#  'obsęgati',
#  'observovati',
#  'srati',
#  'stanoviti',
#  'světiti',
#  'testovati',
#  'obtęžati',
#  'obučati',
#  'obuzdati',
#  'važiti',
#  'obvěstiti',
#  'viniti',
#  'obviti',
#  'očrkati',
#  'bočiti',
#  'odčajati',
#  'odčuđati',
#  'oddaliti',
#  'odključati',
#  'odkųsiti',
#  'odličati',
#  'odobriti',
#  'odomašniti',
#  'odosobniti',
#  'pečętati',
#  'piliti',
#  'pok⒥iti',
#  'pråšiti',
#  'odročiti',
#  'odsloniti',
#  'stråniti',
#  'odstrašati',
#  'odščepiti',
#  'odšlupati',
#  'odučati',
#  'odvŕgati',
#  'odvykati',
#  'ogråditi',
#  'okrųgliti',
#  'okupovati',
#  'omŕziti',
#  'onesměliti',
#  'pakovati',
#  'operiti',
#  'ploditi',
#  'oporędčati',
#  'opozdniti',
#  'poznavati',
#  'prašćati',
#  'opravdati',
#  'opravniti',
#  'opråzdniti',
#  'oprěděliti',
#  'oprovŕgati',
#  'optimizovati',
#  'publikovati',
#  'pustošiti',
#  'pyliti',
#  'orositi',
#  'orientovati',
#  'orųdovati',
#  'orųžiti',
#  'sědati',
#  'sedlati',
#  'sęsti',
#  'osiliti',
#  'sirotěti',
#  'sivěti',
#  'skubti',
#  'oskvŕniti',
#  'slaběti',
#  'oslabiti',
#  'slěpnųti',
#  'osloženiti',
#  'osměliti',
#  'sněžiti',
#  'osnovati',
#  'osȯvrěmenniti',
#  'sporiti',
#  'sråmiti',
#  'starěti',
#  'sųditi',
#  'svojiti',
#  'svatiti',
#  'svętiti',
#  'osvěžati',
#  'osvoboditi',
#  'šalěti',
#  'ščeniti',
#  'teliti',
#  'otěniti',
#  'otišati',
#  'otraviti',
#  'trězvěti',
#  'otrězviti',
#  'otrudniti',
#  'tųpěti',
#  'otųpiti',
#  'tvŕděti',
#  'ovějati',
#  'ověnčati',
#  'vladati',
#  'ovplyvniti',
#  'ozdobiti',
#  'zębti',
#  'ozeleniti',
#  'zlobiti',
#  'znamenovati',
#  'oznaniti',
#  'zvěrěti',
#  'ženiti',
#  'oživiti',
#  'žȯltěti',
#  'žrěbiti',
#  'paralizovati',
#  'parazitovati',
#  'parkovati',
#  'patronizovati',
#  'pauzovati',
#  'pikirovati',
#  'pirovati',
#  'pišati',
#  'piščeti',
#  'planovati',
#  'pleniti',
#  'pleskati',
#  'pljuskati',
#  'poběditi',
#  'počęti',
#  'podčrkati',
#  'podključati',
#  'podobati',
#  'podręditi',
#  'podslušati',
#  'podsměhati',
#  'podstrěkati',
#  'podvŕgati',
#  'poglųbiti',
#  'pogrųziti',
#  'pohristijaniti',
#  'pohytiti',
#  'pokladati',
#  'pokusiti',
#  'polirati',
#  'položiti',
#  'poplaviti',
#  'probovati',
#  'skųpiti',
#  'slizgnųti',
#  'smotriti',
#  'sȯvětovati',
#  'posrěbriti',
#  'postaviti',
#  'stlati',
#  'postulovati',
#  'posvědčati',
#  'svědčiti',
#  'škoditi',
#  'temněti',
#  'potiti',
#  'trěbovati',
#  'tvŕditi',
#  'poučati',
#  'povědati',
#  'veseliti',
#  'povtoriti',
#  '†vysiti',
#  'zlåtiti',
#  'žrtvovati',
#  'pracovati',
#  'praktikovati',
#  'pråzdnovati',
#  'prědpovědati',
#  'prěduprěditi',
#  'preferovati',
#  'prěhytriti',
#  'prěinačati',
#  'prěključati',
#  'prěnebrěgti',
#  'obråtiti',
#  'programovati',
#  'prěseliti',
#  'prěslušati',
#  'prěstigati',
#  'pretendovati',
#  'prětraviti',
#  'prěuveličati',
#  'prěvariti',
#  'žuvati',
#  'prijateliti',
#  'prilųčati',
#  'primětiti',
#  'prisęgati',
#  'prisjediniti',
#  '†spěti',
#  'prisposobiti',
#  'priučati',
#  'privabiti',
#  'privykati',
#  'prizemjati',
#  'produkovati',
#  'profanovati',
#  'pronikati',
#  'propagovati',
#  'proponovati',
#  'protiviti',
#  'provětriti',
#  'provokovati',
#  'provŕtiti',
#  'provŕgati',
#  'psihovati',
#  'pųkati',
#  'pušiti',
#  'pųtovati',
#  'racionalizovati',
#  'ratifikovati',
#  'råzběsniti',
#  'råzčuliti',
#  'råzgråditi',
#  'råzjariti',
#  'råzjasniti',
#  'råzjediniti',
#  'råzkvartirovati',
#  'råzladiti',
#  'råzličati',
#  'råzlųčati',
#  'niti',
#  'råzorųžati',
#  'råzporęditi',
#  'ruměněti',
#  'smatrjati',
#  'råzsměliti',
#  'råzstrěliti',
#  'råzščepiti',
#  'šifrovati',
#  'širiti',
#  'råzšnurovati',
#  'tȯptati',
#  'råztrěskati',
#  'trojiti',
#  'trųbiti',
#  'råzvaliti',
#  'råzveseliti',
#  'råzviti',
#  'reagovati',
#  'realizovati',
#  'redagovati',
#  'redaktovati',
#  'redukovati',
#  'reformovati',
#  'registrovati',
#  'regulovati',
#  'reklamovati',
#  'rekomendovati',
#  'rekonstruovati',
#  'remontovati',
#  'reorganizovati',
#  'reprezentovati',
#  'reprodukovati',
#  'restavrovati',
#  'revidovati',
#  'revti',
#  'rezervovati',
#  'rezumovati',
#  'rizikovati',
#  'rojiti',
#  'rokirovati',
#  'roptati',
#  'ruinovati',
#  'rųkopleskati',
#  'rųkovati',
#  'rusifikovati',
#  'rymovati',
#  'drěmnųti',
#  'simulovati',
#  'sinhronizovati',
#  'sjediniti',
#  'skenovati',
#  'skråtiti',
#  'skvrčati',
#  'slizgati',
#  'slųčati',
#  'slynųti',
#  'smenšati',
#  'smrkati',
#  'snědati',
#  'sȯočiti',
#  'sȯstaviti',
#  'sȯvŕšati',
#  'sȯzdati',
#  'spekulovati',
#  'spomaliti',
#  'spozdniti',
#  'stačiti',
#  'sterilizovati',
#  '†trčati',
#  'strěćati',
#  'strěsti',
#  'studiovati',
#  'stukati',
#  'sųpostaviti',
#  'surfovati',
#  'sųsrědotočati',
#  'svistati',
#  'svŕgati',
#  'šantažovati',
#  'ščekotati',
#  'ščipati',
#  'ščititi',
#  'šlepati',
#  'šlifovati',
#  'šokovati',
#  'štopati',
#  'šuměti',
#  'tancevati',
#  'tatuovati',
#  'telefonovati',
#  'tlěti',
#  'tonųti',
#  'transkribovati',
#  'transliterovati',
#  'transportovati',
#  'travmatizovati',
#  'trenovati',
#  'trepetati',
#  'trevožiti',
#  'trgnųti',
#  'trgovati',
#  'tvŕdnųti',
#  'uběditi',
#  'udaliti',
#  'ujediniti',
#  'ulagoditi',
#  'ulegšati',
#  'ulěpšati',
#  'ulučšati',
#  'umenšati',
#  'umožniti',
#  'umŕtviti',
#  'unarodniti',
#  'unemožniti',
#  'uneviniti',
#  'podobniti',
#  'upokarnjati',
#  'upȯlnomoćiti',
#  'upotrěbiti',
#  'uręditi',
#  'siliti',
#  'usložniti',
#  'usměhati',
#  'usmŕtiti',
#  'uspravědliviti',
#  'ustaliti',
#  'utekųćiniti',
#  'utělesniti',
#  'utęžati',
#  'utišati',
#  'utočniti',
#  'utrudniti',
#  'uveličati',
#  'uzurpovati',
#  'užasati',
#  'variovati',
#  'včleniti',
#  'ventilovati',
#  'verbovati',
#  'verifikovati',
#  'vibrovati',
#  'vključati',
#  'vkųsiti',
#  'vnikati',
#  'vȯplȯtiti',
#  'vȯzbogatiti',
#  'vȯzkresiti',
#  'vȯznikati',
#  '†pitati',
#  'vȯzveličati',
#  'vȯzvŕšati',
#  'vvŕgati',
#  'zabezpamętiti',
#  'zabezpečati',
#  'začinati',
#  'začrveniti',
#  'zahvatiti',
#  'zaključati',
#  'zamknųti',
#  'zanuriti',
#  'zaplěniti',
#  'projektovati',
#  'zasloniti',
#  'zaslužiti',
#  'zastariti',
#  'zastrašati',
#  'zastrěliti',
#  'zatemniti',
#  'zatmiti',
#  'zaustaviti',
#  'zavojevati',
#  'zavŕšati',
#  'žartovati',
#  'zějati',
#  'zirkati',
#  'zloradovati',
#  'zloupotrěbiti',
#  'zvųčati',
#  'žalovati',
#  'žmuriti',
#  'žužati']

# %%
morphemes.query('not ((isv in @pra_forms) or (base_verb.str.replace("†", "") in @pra_forms))')
# Out:
#             id            isv addition    partOfSpeech                 en  \
# 5         11.0     abdikovati      NaN    v.intr. ipf.           abdicate
# 16      6119.0      abonovati      NaN      v.tr. ipf.  subscribe, engage
# 28     19625.0    absorbovati      NaN      v.tr. ipf.             absorb
# 29     24056.0   abstrahovati      NaN  v.tr. ipf./pf.           abstract
# 43     24070.0     adaptovati      NaN  v.tr. ipf./pf.              adapt
# ...        ...            ...      ...             ...                ...
# 17904   2627.0         žuvati   (žuje)    v.intr. ipf.    chew, masticate
# 17905  19473.0         žužati      NaN    v.intr. ipf.               buzz
# 17913 -37005.0    råzpečętati      NaN       v.tr. pf.             unseal
# 17914 -37006.0  råzpečętyvati      NaN      v.tr. ipf.             unseal
# 17921 -37004.0   zapečętyvati      NaN       v.tr.ipf.               seal
#
#       genesis   pos prefix   verb_stem     base_verb       isv_orig  \
# 5           I  verb      ?           ?    abdikovati     abdikovati
# 16          F  verb      ?           ?     abonovati      abonovati
# 28          I  verb      ?           ?   absorbovati    absorbovati
# 29          I  verb      ?           ?  abstrahovati   abstrahovati
# 43          I  verb      ?           ?    adaptovati     adaptovati
# ...       ...   ...    ...         ...           ...            ...
# 17904     NaN  verb      ?           ?        žuvati         žuvati
# 17905     NaN  verb      ?           ?        žužati         žužati
# 17913     NaN  verb   råz’    pečętati      pečętati    råzpečętati
# 17914     NaN  verb   råz’  pečętyvati      pečętati  råzpečętyvati
# 17921     NaN  verb      ?           ?      pečętati   zapečętyvati
#
#       left_stem_cand right_stem_cand derived_nouns base_noun _prefix  \
# 5              abdik      abdikovati   |abdikacija
# 16              abon       abonovati
# 28            absorb     absorbovati   |absorbcija
# 29           abstrah    abstrahovati
# 43             adapt      adaptovati   |adaptacija
# ...              ...             ...           ...       ...     ...
# 17904            žuv          žuvati
# 17905            žuž          žužati
# 17913       råzpečęt        pečętati                             råz
# 17914       råzpečęt    ?pečętyvati?                             råz
# 17921        zapečęt    ?pečętyvati?                              za
#
#           _stem _suffix  _is_irregular reconstructed
# 5        abdiko    vati              0
# 16        abono    vati              0
# 28      absorbo    vati              0
# 29     abstraho    vati              0
# 43       adapto    vati              0
# ...         ...     ...            ...           ...
# 17904        žu    vati              0
# 17905       žuž     ati              0
# 17913     pečęt     ati              0
# 17914    pečęty    vati              0
# 17921    pečęty    vati              0
#
# [2496 rows x 20 columns]

# %%
morphemes.loc[
    morphemes.query('isv in @VALS').index,
    'reconstructed'
] = morphemes.query('isv in @VALS').isv
# Out:
# C:\Users\79165\AppData\Local\Temp\ipykernel_17612\2085135537.py:1: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   morphemes.loc[

# %%
morphemes
# Out:
#             id            isv addition    partOfSpeech  \
# 5         11.0     abdikovati      NaN    v.intr. ipf.
# 16      6119.0      abonovati      NaN      v.tr. ipf.
# 28     19625.0    absorbovati      NaN      v.tr. ipf.
# 29     24056.0   abstrahovati      NaN  v.tr. ipf./pf.
# 43     24070.0     adaptovati      NaN  v.tr. ipf./pf.
# ...        ...            ...      ...             ...
# 17905  19473.0         žužati      NaN    v.intr. ipf.
# 17913 -37005.0    råzpečętati      NaN       v.tr. pf.
# 17914 -37006.0  råzpečętyvati      NaN      v.tr. ipf.
# 17917 -30731.0         smogti      NaN       v.tr. pf.
# 17921 -37004.0   zapečętyvati      NaN       v.tr.ipf.
#
#                                          en genesis   pos prefix   verb_stem  \
# 5                                  abdicate       I  verb      ?           ?
# 16                        subscribe, engage       F  verb      ?           ?
# 28                                   absorb       I  verb      ?           ?
# 29                                 abstract       I  verb      ?           ?
# 43                                    adapt       I  verb      ?           ?
# ...                                     ...     ...   ...    ...         ...
# 17905                                  buzz     NaN  verb      ?           ?
# 17913                                unseal     NaN  verb   råz’    pečętati
# 17914                                unseal     NaN  verb   råz’  pečętyvati
# 17917  manage to, be able to, cope, make it     NaN  verb      ?           ?
# 17921                                  seal     NaN  verb      ?           ?
#
#           base_verb       isv_orig left_stem_cand right_stem_cand  \
# 5        abdikovati     abdikovati          abdik      abdikovati
# 16        abonovati      abonovati           abon       abonovati
# 28      absorbovati    absorbovati         absorb     absorbovati
# 29     abstrahovati   abstrahovati        abstrah    abstrahovati
# 43       adaptovati     adaptovati          adapt      adaptovati
# ...             ...            ...            ...             ...
# 17905        žužati         žužati            žuž          žužati
# 17913      pečętati    råzpečętati       råzpečęt        pečętati
# 17914      pečętati  råzpečętyvati       råzpečęt    ?pečętyvati?
# 17917         mogti         smogti         smogti           mogti
# 17921      pečętati   zapečętyvati        zapečęt    ?pečętyvati?
#
#       derived_nouns base_noun _prefix     _stem _suffix  _is_irregular  \
# 5       |abdikacija                      abdiko    vati              0
# 16                                        abono    vati              0
# 28      |absorbcija                     absorbo    vati              0
# 29                                     abstraho    vati              0
# 43      |adaptacija                      adapto    vati              0
# ...             ...       ...     ...       ...     ...            ...
# 17905                                       žuž     ati              0
# 17913                             råz     pečęt     ati              0
# 17914                             råz    pečęty    vati              0
# 17917                               s       mꜵg      ti              0
# 17921                              za    pečęty    vati              0
#
#       reconstructed
# 5
# 16
# 28
# 29
# 43
# ...             ...
# 17905
# 17913
# 17914
# 17917
# 17921
#
# [4985 rows x 20 columns]

# %%
prefix_map = {
    "nedoråz": "¬ne¬do¬råz",
    "nezado": "¬ne¬za¬do",
    # "poblågo":
    "prěvȯzȯ": "¬prě¬vȯz¬ȯ" 
}
weird_pref = set()


for p in morphemes._prefix.unique():
    if not p: continue
    if p in prefix_map: continue
    if p in possible_prefixes:
        prefix_map[p] = "¬" + p
    else:
        for length in range(1, len(p)):
            if p[:length] in possible_prefixes and p[length:] in possible_prefixes | {'ȯ', 'z'}:
                prefix_map[p] = "¬" + p[:length] + "¬" + p[length:]
                break
        else:
            print(p)
            weird_pref.add(p)
                
prefix_map
# Out:
# a
# blågo
# mråzo
# poblågo
# protiv
# rųko
# samou
# sebe
# spolu
# {'nedoråz': '¬ne¬do¬råz',
#  'nezado': '¬ne¬za¬do',
#  'prěvȯzȯ': '¬prě¬vȯz¬ȯ',
#  'bez': '¬bez',
#  'de': '¬de',
#  'do': '¬do',
#  'doråz': '¬do¬råz',
#  'doz': '¬do¬z',
#  'iz': '¬iz',
#  'izna': '¬iz¬na',
#  'izne': '¬iz¬ne',
#  'izȯ': '¬iz¬ȯ',
#  'izu': '¬iz¬u',
#  'na': '¬na',
#  'nad': '¬nad',
#  'nadu': '¬nad¬u',
#  'napo': '¬na¬po',
#  'nas': '¬na¬s',
#  'po': '¬po',
#  'sȯ': '¬sȯ',
#  'ne': '¬ne',
#  'nedo': '¬ne¬do',
#  'nena': '¬ne¬na',
#  'o': '¬o',
#  'ob': '¬ob',
#  'obez': '¬obez',
#  'obȯ': '¬ob¬ȯ',
#  'od': '¬od',
#  'odȯ': '¬od¬ȯ',
#  'odpo': '¬od¬po',
#  'odza': '¬od¬za',
#  'opo': '¬o¬po',
#  'os': '¬o¬s',
#  'pod': '¬pod',
#  'podȯ': '¬pod¬ȯ',
#  'podråz': '¬pod¬råz',
#  'poråz': '¬po¬råz',
#  'posȯ': '¬po¬sȯ',
#  'pos': '¬po¬s',
#  'pov': '¬po¬v',
#  'poza': '¬po¬za',
#  'poz': '¬po¬z',
#  'prě': '¬prě',
#  'prěd': '¬prěd',
#  'prědȯ': '¬prěd¬ȯ',
#  'prědpo': '¬prěd¬po',
#  'prědpri': '¬prěd¬pri',
#  'prěds': '¬prěd¬s',
#  'prěna': '¬prě¬na',
#  'prěo': '¬prě¬o',
#  'prěpo': '¬prě¬po',
#  'prěråz': '¬prě¬råz',
#  'prěs': '¬prě¬s',
#  'prěvȯz': '¬prě¬vȯz',
#  'pri': '¬pri',
#  'prina': '¬pri¬na',
#  'pripo': '¬pri¬po',
#  'pro': '¬pro',
#  'proiz': '¬pro¬iz',
#  'prone': '¬pro¬ne',
#  'råz': '¬råz',
#  'råzo': '¬råz¬o',
#  'råzȯ': '¬råz¬ȯ',
#  'råzpo': '¬råz¬po',
#  'råzpro': '¬råz¬pro',
#  'råzråz': '¬råz¬råz',
#  'råzs': '¬råz¬s',
#  's': '¬s',
#  'sde': '¬s¬de',
#  'sna': '¬s¬na',
#  'sne': '¬s¬ne',
#  'spo': '¬s¬po',
#  'sråz': '¬s¬råz',
#  'sų': '¬sų',
#  'sųpro': '¬sų¬pro',
#  'u': '¬u',
#  'us': '¬u¬s',
#  'v': '¬v',
#  'vȯ': '¬vȯ',
#  'vȯz': '¬vȯz',
#  'vȯzȯ': '¬vȯz¬ȯ',
#  'vȯzpo': '¬vȯz¬po',
#  'vy': '¬vy',
#  'vz': '¬v¬z',
#  'za': '¬za',
#  'zado': '¬za¬do',
#  'zane': '¬za¬ne',
#  'zapo': '¬za¬po',
#  'zapro': '¬za¬pro',
#  'zau': '¬za¬u'}

# %%
weird_pref
# Out:
# {'a', 'blågo', 'mråzo', 'poblågo', 'protiv', 'rųko', 'samou', 'sebe', 'spolu'}

# %%
for i, row in morphemes.query("genesis == 'I' and isv.str.startswith('a')").iterrows():
    if row.isv in 'akompanovati anulovati asimilovati'.split(" "):
        morphemes.loc[i, '_prefix'] = 'a'
        morphemes.loc[i, '_stem'] = morphemes.loc[i, '_stem'][1:]
    if row._stem.endswith("o"):
        morphemes.loc[i, '_stem'] = morphemes.loc[i, '_stem'][:-1]
        morphemes.loc[i, '_suffix'] = "o" + morphemes.loc[i, '_suffix']

morphemes.query("genesis == 'I' and isv.str.startswith('a')")
# Out:
#           id             isv addition      partOfSpeech  \
# 5       11.0      abdikovati      NaN      v.intr. ipf.
# 28   19625.0     absorbovati      NaN        v.tr. ipf.
# 29   24056.0    abstrahovati      NaN    v.tr. ipf./pf.
# 43   24070.0      adaptovati      NaN    v.tr. ipf./pf.
# 50   24081.0  administrovati      NaN        v.tr. ipf.
# 54   19628.0      adoptovati      NaN        v.tr. ipf.
# 59    4540.0      adresovati      NaN        v.tr. ipf.
# 92   24114.0       agitovati      NaN      v.intr. ipf.
# 99   24121.0     agonizovati      NaN      v.intr. ipf.
# 120  24148.0     akcentovati      NaN        v.tr. ipf.
# 123    111.0     akceptovati      NaN        v.tr. ipf.
# 130  24156.0  aklimatizovati      NaN      v.intr. ipf.
# 144  24165.0    akompanovati      NaN        v.tr. ipf.
# 163  24190.0      aktivovati      NaN        v.tr. ipf.
# 169  34900.0   aktualizovati      NaN    v.tr. ipf./pf.
# 175  24203.0     akumulovati      NaN        v.tr. ipf.
# 265  24299.0     amnestovati      NaN    v.tr. ipf./pf.
# 272  24307.0    amortizovati      NaN    v.tr. ipf./pf.
# 274  34095.0      amputovati      NaN    v.tr. ipf./pf.
# 285   3969.0     analizovati      NaN        v.tr. ipf.
# 299  36191.0      aneksovati      NaN    v.tr. ipf./pf.
# 338     37.0       anulovati      NaN    v.tr. ipf./pf.
# 346     60.0       apelovati      NaN      v.intr. ipf.
# 369    122.0      areštovati      NaN        v.tr. ipf.
# 375  19640.0   argumentovati      NaN      v.intr. ipf.
# 388  35236.0      arhivovati      NaN    v.tr. ipf./pf.
# 417   6246.0     asimilovati      NaN        v.tr. ipf.
# 430   3970.0       atakovati      NaN        v.tr. ipf.
# 455  24337.0      avansovati      NaN  v.intr. ipf./pf.
# 492  24386.0  avtomatizovati      NaN        v.tr. ipf.
# 508   5033.0    avtorizovati      NaN        v.tr. ipf.
# 515  35869.0   avtostopovati      NaN  v.intr. ipf./pf.
#
#                                      en genesis   pos prefix verb_stem  \
# 5                              abdicate       I  verb      ?         ?
# 28                               absorb       I  verb      ?         ?
# 29                             abstract       I  verb      ?         ?
# 43                                adapt       I  verb      ?         ?
# 50                         administrate       I  verb      ?         ?
# 54                                adopt       I  verb      ?         ?
# 59                              address       I  verb      ?         ?
# 92                              agitate       I  verb      ?         ?
# 99                     agonise, agonize       I  verb      ?         ?
# 120  accentuate, stress (pronunciation)       I  verb      ?         ?
# 123                              accept       I  verb      ?         ?
# 130                         acclimatize       I  verb      ?         ?
# 144                           accompany       I  verb      ?         ?
# 163                            activate       I  verb      ?         ?
# 169                              update       I  verb      ?         ?
# 175                          accumulate       I  verb      ?         ?
# 265                             amnesty       I  verb      ?         ?
# 272                            amortize       I  verb      ?         ?
# 274                            amputate       I  verb      ?         ?
# 285                    analyse, analyze       I  verb      ?         ?
# 299                               annex       I  verb      ?         ?
# 338                     cancel, nullify       I  verb      ?         ?
# 346                              appeal       I  verb      ?         ?
# 369                              arrest       I  verb      ?         ?
# 375                               argue       I  verb      ?         ?
# 388                             archive       I  verb      ?         ?
# 417                          assimilate       I  verb      ?         ?
# 430                              attack       I  verb      ?         ?
# 455                             advance       I  verb      ?         ?
# 492                            automate       I  verb      ?         ?
# 508                authorise, authorize       I  verb      ?         ?
# 515                           hitchhike       I  verb      ?         ?
#
#           base_verb        isv_orig left_stem_cand right_stem_cand  \
# 5        abdikovati      abdikovati          abdik      abdikovati
# 28      absorbovati     absorbovati         absorb     absorbovati
# 29     abstrahovati    abstrahovati        abstrah    abstrahovati
# 43       adaptovati      adaptovati          adapt      adaptovati
# 50   administrovati  administrovati      administr  administrovati
# 54       adoptovati      adoptovati          adopt      adoptovati
# 59       adresovati      adresovati          adres      adresovati
# 92        agitovati       agitovati           agit       agitovati
# 99      agonizovati     agonizovati         agoniz     agonizovati
# 120     akcentovati     akcentovati         akcent     akcentovati
# 123     akceptovati     akceptovati         akcept     akceptovati
# 130  aklimatizovati  aklimatizovati      aklimatiz  aklimatizovati
# 144    akompanovati    akompanovati        akompan    akompanovati
# 163      aktivovati      aktivovati          aktiv      aktivovati
# 169   aktualizovati   aktualizovati       aktualiz   aktualizovati
# 175     akumulovati     akumulovati         akumul     akumulovati
# 265     amnestovati     amnestovati         amnest     amnestovati
# 272    amortizovati    amortizovati        amortiz    amortizovati
# 274      amputovati      amputovati          amput      amputovati
# 285     analizovati     analizovati         analiz     analizovati
# 299      aneksovati      aneksovati          aneks      aneksovati
# 338       anulovati       anulovati           anul       anulovati
# 346       apelovati       apelovati           apel       apelovati
# 369      areštovati      areštovati          arešt      areštovati
# 375   argumentovati   argumentovati       argument   argumentovati
# 388      arhivovati      arhivovati          arhiv      arhivovati
# 417     asimilovati     asimilovati         asimil     asimilovati
# 430       atakovati       atakovati           atak       atakovati
# 455      avansovati      avansovati          avans      avansovati
# 492  avtomatizovati  avtomatizovati      avtomatiz  avtomatizovati
# 508    avtorizovati    avtorizovati        avtoriz    avtorizovati
# 515   avtostopovati   avtostopovati       avtostop   avtostopovati
#
#          derived_nouns     base_noun _prefix      _stem  _suffix  \
# 5          |abdikacija                            abdik    ovati
# 28         |absorbcija                           absorb    ovati
# 29                                              abstrah    ovati
# 43         |adaptacija                            adapt    ovati
# 50     |administracija                        administr    ovati
# 54                                                adopt    ovati
# 59                      adres|adresa              adres    ovati
# 92   |agitacija|agitka                             agit    ovati
# 99                           agonija             agoniz    ovati
# 120                           akcent             akcent    ovati
# 123       |akceptacija                           akcept    ovati
# 130    |aklimatizacija        klimat       a     klimat  izovati
# 144                                        a     kompan    ovati
# 163                                               aktiv    ovati
# 169     |aktualizacija                         aktualiz    ovati
# 175       |akumulacija                           akumul    ovati
# 265         |amnestija                           amnest    ovati
# 272      |amortizacija                          amortiz    ovati
# 274        |amputacija                            amput    ovati
# 285                          analiza             analiz    ovati
# 299          |aneksija                            aneks    ovati
# 338         |anulacija                     a        nul    ovati
# 346         |apelacija                             apel    ovati
# 369                            arešt              arešt    ovati
# 375     |argumentacija      argument           argument    ovati
# 388                            arhiv              arhiv    ovati
# 417       |asimilacija                     a      simil    ovati
# 430                            ataka               atak    ovati
# 455                            avans              avans    ovati
# 492    |avtomatizacija       avtomat          avtomatiz    ovati
# 508      |avtorizacija         avtor            avtoriz    ovati
# 515       |avtostopnik      avtostop           avtostop    ovati
#
#      _is_irregular reconstructed
# 5                0           NaN
# 28               0           NaN
# 29               0           NaN
# 43               0           NaN
# 50               0           NaN
# 54               0           NaN
# 59               0           NaN
# 92               0           NaN
# 99               0           NaN
# 120              0           NaN
# 123              0           NaN
# 130              0           NaN
# 144              0           NaN
# 163              0           NaN
# 169              0           NaN
# 175              0           NaN
# 265              0           NaN
# 272              0           NaN
# 274              0           NaN
# 285              0           NaN
# 299              0           NaN
# 338              0           NaN
# 346              0           NaN
# 369              0           NaN
# 375              0           NaN
# 388              0           NaN
# 417              0           NaN
# 430              0           NaN
# 455              0           NaN
# 492              0           NaN
# 508              0           NaN
# 515              0           NaN

# %%
morphemes.genesis.value_counts()
# Out:
# I    335
# F     11
# D      8
# E      6
# S      2
# M      1
# Name: genesis, dtype: int64

# %%
for i, row in morphemes.query("genesis in ['I', 'F', 'D', 'E', 'S', 'M'] and _stem.str.endswith('o')").iterrows():
    morphemes.loc[i, '_stem'] = morphemes.loc[i, '_stem'][:-1]
    morphemes.loc[i, '_suffix'] = "o" + morphemes.loc[i, '_suffix']

# %%
morphemes.query("genesis in ['I', 'F', 'D', 'E', 'S', 'M'] and _stem.str.endswith('ir')")
# Out:
#             id                isv addition      partOfSpeech  \
# 2916   25578.0        garnirovati      NaN        v.tr. ipf.
# 3229    2668.0        gravirovati      NaN        v.tr. ipf.
# 3790   35896.0        inspirovati      NaN    v.tr. ipf./pf.
# 6333    2869.0        marširovati      NaN      v.intr. ipf.
# 6342   33371.0         masirovati      NaN        v.tr. ipf.
# 10165  10565.0           pirovati      NaN      v.intr. ipf.
# 10657  10857.0           polirati      NaN        v.tr. ipf.
# 12640  36411.0    råzkvartirovati      NaN         v.tr. pf.
# 12641  24162.0  råzkvartirovyvati      NaN        v.tr. ipf.
# 13219  18648.0         rokirovati      NaN  v.intr. ipf./pf.
#
#                      en genesis   pos prefix       verb_stem        base_verb  \
# 2916            garnish       F  verb      ?               ?      garnirovati
# 3229            engrave       I  verb      ?               ?      gravirovati
# 3790            inspire       I  verb      ?               ?      inspirovati
# 6333              march       D  verb      ?               ?      marširovati
# 6342            massage       F  verb      ?               ?       masirovati
# 10165             feast       I  verb      ?               ?         pirovati
# 10657            polish       I  verb      ?               ?         polirati
# 12640  quarter (troops)       I  verb   råz’    kvartirovati  råzkvartirovati
# 12641  quarter (troops)       I  verb   råz’  kvartirovyvati  råzkvartirovati
# 13219    castle (chess)       I  verb      ?               ?       rokirovati
#
#                 isv_orig left_stem_cand   right_stem_cand derived_nouns  \
# 2916         garnirovati         garnir       garnirovati
# 3229         gravirovati         gravir       gravirovati
# 3790         inspirovati         inspir       inspirovati  |inspiracija
# 6333         marširovati         maršir       marširovati
# 6342          masirovati          masir        masirovati
# 10165           pirovati            pir          pirovati
# 10657           polirati          polir          ?lirati?
# 12640    råzkvartirovati     råzkvartir    ?kvartirovati?
# 12641  råzkvartirovyvati     råzkvartir  ?kvartirovyvati?
# 13219         rokirovati          rokir        rokirovati
#
#       base_noun _prefix       _stem  _suffix  _is_irregular reconstructed
# 2916                         garnir    ovati              0           NaN
# 3229                         gravir    ovati              0           NaN
# 3790                         inspir    ovati              0           NaN
# 6333                         maršir    ovati              0           NaN
# 6342                          masir    ovati              0           NaN
# 10165       pir                 pir    ovati              0           NaN
# 10657                         polir      ati              0           NaN
# 12640                    råzkvartir    ovati              0           NaN
# 12641                    råzkvartir  ovyvati              0           NaN
# 13219                         rokir    ovati              0           NaN

# %%
for i, row in morphemes.query("_stem.str.startswith('råz')").iterrows():
    morphemes.loc[i, '_prefix'] = 'råz'
    morphemes.loc[i, '_stem'] = morphemes.loc[i, '_stem'][3:]

# %%
morphemes.loc[13627, ["base_verb", '_prefix', "_stem"]] = ['sikati', '', 'sik']

morphemes.loc[3661, ["reconstructed", '_prefix', "_stem"]] = ['jьkati', '', 'ik']
morphemes.loc[17210, ["reconstructed", '_prefix', "_stem"]] = ['zajьkati', 'za', 'jik']

# %%
morphemes.query("en.str.contains('pee')")
# Out:
#             id            isv    addition  partOfSpeech  \
# 6206   27352.0         lupiti         NaN    v.tr. ipf.
# 6761    1829.0         močiti         NaN  v.refl. ipf.
# 7751   28421.0         něměti         NaN  v.intr. ipf.
# 8280   28724.0       obdirati         NaN    v.tr. ipf.
# 8284   34086.0        obdreti    (obdere)     v.tr. pf.
# 8408   28822.0       oblupiti         NaN     v.tr. pf.
# 9068    4304.0      odšlupati         NaN     v.tr. pf.
# 9069    5552.0    odšlupyvati         NaN    v.tr. ipf.
# 9320   32831.0        oněměti         NaN   v.intr. pf.
# 10181  14838.0         pišati         NaN  v.intr. ipf.
# 10359   5385.0     podględati         NaN  v.intr. ipf.
# 10360   5387.0     podględěti  (podględi)   v.intr. pf.
# 11443   2982.0     prěmȯlviti         NaN   v.intr. pf.
# 11444   2337.0    prěmȯlvjati         NaN  v.intr. ipf.
# 12632  33855.0  råzkrųćati sę         NaN    v.tr. ipf.
# 12634  33852.0  råzkrųtiti sę         NaN     v.tr. pf.
# 13627  12214.0         sikati         NaN  v.intr. ipf.
# 16347  34984.0       vględati         NaN  v.refl. ipf.
# 16348  13607.0       vględěti    (vględi)   v.refl. pf.
# 17637  22900.0        zirkati         NaN  v.intr. ipf.
# 17638  22901.0       zirknųti         NaN   v.intr. pf.
#
#                                                       en genesis   pos prefix  \
# 6206                                                peel     NaN  verb      ?
# 6761                                        urinate, pee     NaN  verb      ?
# 7751   fall silent, become speechless, grow dumb, be ...     NaN  verb      ?
# 8280                                   peel, skin, strip     NaN  verb      ?
# 8284                                   peel, skin, strip     NaN  verb      ?
# 8408                                                peel     NaN  verb      ?
# 9068                                                peel     NaN  verb      ?
# 9069                                                peel     NaN  verb      ?
# 9320   be struck dumb, fall silent, become speechless...     NaN  verb      ?
# 10181                                                pee     NaN  verb      ?
# 10359  peep, watch secretly, spy, glance at, glimpse,...     NaN  verb      ?
# 10360  peep, watch secretly, spy, glance at, glimpse,...     NaN  verb      ?
# 11443                                   deliver a speech     NaN  verb      ?
# 11444                                   deliver a speech     NaN  verb      ?
# 12632                            get going, gather speed     NaN  verb   råz’
# 12634                            get going, gather speed     NaN  verb   råz’
# 13627                                                pee     NaN  verb      ?
# 16347                  peer, gaze, stare, look carefully     NaN  verb      ?
# 16348                  peer, gaze, stare, look carefully     NaN  verb      ?
# 17637                                 glance, peep, peek     NaN  verb      ?
# 17638                                 glance, peep, peek     NaN  verb      ?
#
#         verb_stem  base_verb       isv_orig left_stem_cand right_stem_cand  \
# 6206            ?     lupiti         lupiti            lup          lupiti
# 6761            ?     močiti      močiti sę            moč          močiti
# 7751            ?     něměti         něměti            něm          něměti
# 8280            ?      dreti       obdirati          obdir        ?dirati?
# 8284            ?      dreti        obdreti        obdreti           dreti
# 8408            ?     lupiti       oblupiti          oblup          lupiti
# 9068            ?  odšlupati      odšlupati         odšlup       ?šlupati?
# 9069            ?  odšlupati    odšlupyvati         odšlup     ?šlupyvati?
# 9320            ?     něměti        oněměti           oněm          něměti
# 10181           ?     pišati         pišati            piš          pišati
# 10359           ?    ględěti     podględati        podględ       ?ględati?
# 10360           ?    ględěti     podględěti        podględ         ględěti
# 11443           ?    mȯlviti     prěmȯlviti        prěmȯlv         mȯlviti
# 11444           ?    mȯlviti    prěmȯlvjati        prěmȯlv      ?mȯlvjati?
# 12632  krųćati sę    krųtiti  råzkrųćati sę        råzkrųć    ?krųćati sę?
# 12634  krųtiti sę    krųtiti  råzkrųtiti sę        råzkrųt    ?krųtiti sę?
# 13627           ?      ikati         sikati            sik           ikati
# 16347           ?    ględěti    vględati sę          vględ       ?ględati?
# 16348           ?    ględěti    vględěti sę          vględ         ględěti
# 17637           ?    zirkati        zirkati           zirk         zirkati
# 17638           ?    zirkati       zirknųti           zirk        zirknųti
#
#                      derived_nouns base_noun _prefix _stem _suffix  \
# 6206                                                   lup     iti
# 6761                                moč|!moć           moč     iti
# 7751   |němcija|němka|němec|němosť                     něm     ěti
# 8280                                              ob   dir     ati
# 8284                                              ob   dre      ti
# 8408                                              ob   lup     iti
# 9068                                              od  šlup     ati
# 9069                                              od  šlup   yvati
# 9320                                               o   něm     ěti
# 10181                                                  piš     ati
# 10359                                            pod  ględ     ati
# 10360                                            pod  ględ     ěti
# 11443                                            prě  mȯlv     iti
# 11444                                            prě  mȯlv    jati
# 12632                                            råz  krųt    ⒥ati
# 12634                                            råz  krųt     iti
# 13627                                              s    ik     ati
# 16347                                              v  ględ     ati
# 16348                                              v  ględ     ěti
# 17637                                                 zirk     ati
# 17638                                                 zirk    nųti
#
#        _is_irregular  reconstructed
# 6206               0         lupiti
# 6761               0         močiti
# 7751               0         něměti
# 8280               0            NaN
# 8284               0            NaN
# 8408               0    (ob)+lupiti
# 9068               0            NaN
# 9069               0            NaN
# 9320               0     (o)+něměti
# 10181              0            NaN
# 10359              0       ?ględěti
# 10360              0  (pod)+ględěti
# 11443              0  (prě)+mъlviti
# 11444              0       ?mъlviti
# 12632              1       ?krǫtiti
# 12634              0       ?krǫtiti
# 13627              0         sikati
# 16347              0       ?ględěti
# 16348              0    (v)+ględěti
# 17637              0            NaN
# 17638              0            NaN

# %%
morphemes.query("_prefix in @weird_pref")
# Out:
#             id              isv      addition  partOfSpeech  \
# 130    24156.0   aklimatizovati           NaN  v.intr. ipf.
# 887     4889.0      blågodariti           NaN    v.tr. ipf.
# 899     5574.0    blågoslavjati           NaN    v.tr. ipf.
# 900     5573.0     blågosloviti           NaN     v.tr. pf.
# 907    22297.0      blågovolěti   (blågovoli)  v.intr. ipf.
# 912     6050.0      blågoželati          (+3)  v.intr. ipf.
# 6915   17812.0      mråzosušati           NaN    v.tr. ipf.
# 6918    9263.0      mråzosušiti           NaN     v.tr. pf.
# 7668   20535.0     nedoråzuměti           NaN     v.tr. pf.
# 8064   17948.0    nezadovaljati           NaN    v.tr. ipf.
# 8065   17953.0     nezadovoliti           NaN     v.tr. pf.
# 10292  35143.0    poblågodariti           NaN     v.tr. pf.
# 10293  36892.0    poblågoželati          (+3)   v.intr. pf.
# 11611  18447.0      prěvȯzȯjdti  (prěvȯzȯjde)     v.tr. pf.
# 12200  21484.0     protivrěčiti           NaN  v.intr. ipf.
# 13274  18675.0       rųkovoditi           NaN    v.tr. ipf.
# 13382  15528.0        samoubiti           NaN   v.intr. pf.
# 13453  15530.0      sebesmŕtiti           NaN  v.intr. ipf.
# 14220  18879.0   spolupracovati           NaN  v.intr. ipf.
# 14221  18880.0  spoluråbotyvati           NaN  v.intr. ipf.
# 17210  31503.0         zajikati           NaN  v.refl. ipf.
#
#                                     en genesis   pos prefix verb_stem  \
# 130                        acclimatize       I  verb      ?         ?
# 887                              thank     NaN  verb      ?         ?
# 899                     bless, beatify     NaN  verb      ?         ?
# 900                     bless, beatify     NaN  verb      ?         ?
# 907    show benevolence, show goodwill     NaN  verb      ?         ?
# 912                       congratulate     NaN  verb      ?         ?
# 6915                        freeze-dry     NaN  verb      ?         ?
# 6918                        freeze-dry     NaN  verb      ?         ?
# 7668                     misunderstand     NaN  verb      ?         ?
# 8064             displease, dissatisfy     NaN  verb      ?         ?
# 8065             displease, dissatisfy     NaN  verb      ?         ?
# 10292                            thank     NaN  verb      ?         ?
# 10293                     congratulate     NaN  verb      ?         ?
# 11611                  surpass, exceed     NaN  verb      ?         ?
# 12200         contradict, deny, negate     NaN  verb      ?         ?
# 13274           manage, guide, control     NaN  verb      ?         ?
# 13382                   commit suicide     NaN  verb      ?         ?
# 13453                   commit suicide     NaN  verb      ?         ?
# 14220                    work together     NaN  verb      ?         ?
# 14221                    work together     NaN  verb      ?         ?
# 17210                          stammer     NaN  verb      ?         ?
#
#             base_verb         isv_orig left_stem_cand right_stem_cand  \
# 130    aklimatizovati   aklimatizovati      aklimatiz  aklimatizovati
# 887            dariti      blågodariti       blågodar     blågodariti
# 899           sloviti    blågoslavjati      blågoslav   blågoslavjati
# 900           sloviti     blågosloviti        blågosl    blågosloviti
# 907            volěti      blågovolěti       blågovol     blågovolěti
# 912            želati      blågoželati       blågožel     blågoželati
# 6915      mråzosušati      mråzosušati       mråzosuš     mråzosušati
# 6918      mråzosušati      mråzosušiti       mråzosuš     mråzosušiti
# 7668            uměti     nedoråzuměti      nedoråzum           uměti
# 8064           voliti    nezadovaljati      nezadoval         valjati
# 8065           voliti     nezadovoliti      nezadovol            liti
# 10292          dariti    poblågodariti     poblågodar     blågodariti
# 10293          želati    poblågoželati     poblågožel     blågoželati
# 11611            idti      prěvȯzȯjdti    prěvȯzȯjdti        vȯzȯjdti
# 12200                     protivrěčiti      protivrěč     ?tivrěčiti?
# 13274          voditi       rųkovoditi        rųkovod      rųkovoditi
# 13382            biti        samoubiti         samoub      ?amoubiti?
# 13453                      sebesmŕtiti       sebesmŕt    ?ebesmŕtiti?
# 14220       pracovati   spolupracovati      spoluprac   ?lupracovati?
# 14221        råbotati  spoluråbotyvati     spoluråbot  ?luråbotyvati?
# 17210           ikati      zajikati sę          zajik        ?jikati?
#
#          derived_nouns base_noun  _prefix   _stem  _suffix  _is_irregular  \
# 130    |aklimatizacija    klimat        a  klimat  izovati              0
# 887                                 blågo     dar      iti              0
# 899                                 blågo    slav     jati              0
# 900                                 blågo    slov      iti              0
# 907                                 blågo     vol      ěti              0
# 912                                 blågo     žel      ati              0
# 6915                                mråzo     suh     ⒥ati              0
# 6918                                mråzo     suh     ⒥iti              0
# 7668                              nedoråz      um      ěti              0
# 8064                               nezado     vꜵl     jati              0
# 8065                               nezado     vꜵl      iti              0
# 10292                             poblågo     dar      iti              0
# 10293                             poblågo     žel      ati              0
# 11611                             prěvȯzȯ      jd       ti              0
# 12200                        rěč   protiv     rěč      iti              0
# 13274     |rųkovodstvo               rųko     vꜵd      iti              0
# 13382                               samou      bi       ti              0
# 13453                       smŕt     sebe    smŕt      iti              0
# 14220                               spolu   praco     vati              0
# 14221                               spolu   råbot    yvati             -1
# 17210                                 zaj      ik      ati              0
#
#           reconstructed
# 130                 NaN
# 887      (blågo)+dariti
# 899            ?sloviti
# 900     (blågo)+sloviti
# 907                 NaN
# 912      (blågo)+želati
# 6915                NaN
# 6918                NaN
# 7668          ?orzuměti
# 8064            ?voliti
# 8065    (nezado)+voliti
# 10292  (poblågo)+dariti
# 10293  (poblågo)+želati
# 11611               NaN
# 12200            ?uměti
# 13274     (rųko)+voditi
# 13382      (samou)+biti
# 13453            ?uměti
# 14220               NaN
# 14221         ?orbotati
# 17210           ?sikati

# %%
morphemes._prefix = morphemes._prefix.apply(lambda x: prefix_map.get(x, x))

# %%
morphemes.to_pickle("morphemes_protoslavic.pkl")
morphemes[['id', 'isv_orig', 'addition', 'partOfSpeech', 'en', 'genesis', 
          'isv', 'base_verb', 'derived_nouns', 'base_noun', '_prefix', '_stem',
       '_suffix', 'reconstructed']].to_csv("morphemes_protoslavic.csv")

# %%
print(
    morphemes.query("_prefix.str.contains('¬')")._prefix.value_counts().to_csv(sep="\t")
)
# Out:
# 	_prefix
# ¬råz	349
# ¬iz	261
# ¬od	253
# ¬na	242
# ¬o	242
# ¬za	208
# ¬po	186
# ¬u	174
# ¬ob	152
# ¬s	149
# ¬prě	117
# ¬pri	114
# ¬pro	89
# ¬do	87
# ¬v	65
# ¬pod	52
# ¬vȯz	44
# ¬sȯ	25
# ¬prěd	22
# ¬sų	12
# ¬råz¬pro	9
# ¬obez	7
# ¬vy	7
# ¬s¬po	7
# ¬råz¬s	6
# ¬u¬s	5
# ¬nad	5
# ¬prě¬s	5
# ¬za¬ne	5
# ¬de	4
# ¬prě¬o	4
# ¬pro¬iz	4
# ¬po¬z	4
# ¬po¬v	4
# ¬pri¬po	4
# ¬o¬s	4
# ¬za¬do	4
# ¬ob¬ȯ	4
# ¬iz¬na	4
# ¬vȯ	4
# ¬prěd¬po	3
# ¬na¬s	3
# ¬po¬za	3
# ¬od¬po	3
# ¬ne	3
# ¬vȯz¬po	2
# ¬pro¬ne	2
# ¬s¬na	2
# ¬råz¬o	2
# ¬råz¬råz	2
# ¬råz¬po	2
# ¬sų¬pro	2
# ¬s¬ne	2
# ¬bez	2
# ¬prěd¬pri	2
# ¬za¬u	2
# ¬do¬z	2
# ¬ne¬za¬do	2
# ¬nad¬u	2
# ¬iz¬u	2
# ¬pod¬ȯ	2
# ¬pod¬råz	2
# ¬po¬råz	2
# ¬na¬po	2
# ¬prěd¬s	2
# ¬prě¬na	2
# ¬prě¬po	2
# ¬prě¬råz	2
# ¬do¬råz	1
# ¬ne¬do¬råz	1
# ¬za¬po	1
# ¬v¬z	1
# ¬iz¬ȯ	1
# ¬vȯz¬ȯ	1
# ¬za¬pro	1
# ¬iz¬ne	1
# ¬pri¬na	1
# ¬ne¬do	1
# ¬ne¬na	1
# ¬od¬ȯ	1
# ¬prě¬vȯz¬ȯ	1
# ¬od¬za	1
# ¬o¬po	1
# ¬s¬de	1
# ¬po¬sȯ	1
# ¬po¬s	1
# ¬prěd¬ȯ	1
# ¬råz¬ȯ	1
# ¬prě¬vȯz	1
# ¬s¬råz	1

# %%
morphemes.query("en.str.contains('dis')")
# Out:
#             id             isv        addition      partOfSpeech  \
# 785    19654.0     bezpokojiti             NaN        v.tr. ipf.
# 1875   25241.0   dezinfikovati             NaN    v.tr. ipf./pf.
# 1936   35510.0  diskreditovati             NaN    v.tr. ipf./pf.
# 1939   32603.0  diskriminovati             NaN  v.intr. ipf./pf.
# 1942     301.0     diskutovati             NaN      v.intr. ipf.
# ...        ...             ...             ...               ...
# 16006   3558.0       uvoljniti             NaN         v.tr. pf.
# 17176   5475.0        zahoditi             NaN      v.intr. ipf.
# 17194   5476.0          zajdti  (zajde; zašel)       v.intr. pf.
# 17407  21238.0    zapropastiti             NaN       v.refl. pf.
# 17586  34731.0        zdråvěti             NaN      v.intr. ipf.
#
#                                                     en genesis   pos prefix  \
# 785                    disturb, trouble, upset, bother     NaN  verb      ?
# 1875                                         disinfect       I  verb   dez’
# 1936                                         discredit       I  verb      ?
# 1939                                      discriminate       I  verb      ?
# 1942                                           discuss       I  verb      ?
# ...                                                ...     ...   ...    ...
# 16006  discharge, dismiss, fire (terminate employment)     NaN  verb      ?
# 17176               set (disappear behind the horizon)     NaN  verb      ?
# 17194               set (disappear behind the horizon)     NaN  verb      ?
# 17407                             disappear completely     NaN  verb      ?
# 17586             get better, recover (from a disease)     NaN  verb      ?
#
#         verb_stem       base_verb         isv_orig left_stem_cand  \
# 785             ?       †pokojiti      bezpokojiti        bezpoko
# 1875   infikovati   dezinfikovati    dezinfikovati       dezinfik
# 1936            ?  diskreditovati   diskreditovati      diskredit
# 1939            ?  diskriminovati   diskriminovati      diskrimin
# 1942            ?     diskutovati      diskutovati         diskut
# ...           ...             ...              ...            ...
# 16006           ?          voliti        uvoljniti         uvoljn
# 17176           ?          hoditi         zahoditi          zahod
# 17194           ?            idti           zajdti         zajdti
# 17407           ?           pasti  zapropastiti sę      zapropast
# 17586           ?        zdråvěti         zdråvěti          zdråv
#
#       right_stem_cand      derived_nouns base_noun  _prefix      _stem  \
# 785          ?kojiti?                        pokoj     ¬bez      pokoj
# 1875    ?zinfikovati?                                         dezinfik
# 1936   diskreditovati                                        diskredit
# 1939   diskriminovati    |diskriminacija                     diskrimin
# 1942      diskutovati                                           diskut
# ...               ...                ...       ...      ...        ...
# 16006        ?ljniti?                                    ¬u        vꜵl
# 17176          hoditi                                   ¬za        hꜵd
# 17194          ?jdti?                                   ¬za         jd
# 17407       ?pastiti?                               ¬za¬pro        pas
# 17586        zdråvěti  |zdråvje|zdråvica                         zdråv
#
#       _suffix  _is_irregular reconstructed
# 785       iti              0           NaN
# 1875    ovati              0           NaN
# 1936    ovati              0           NaN
# 1939    ovati              0           NaN
# 1942    ovati              0           NaN
# ...       ...            ...           ...
# 16006   jniti              0       ?voliti
# 17176     iti              0   (za)+xoditi
# 17194      ti              0           NaN
# 17407    titi              0        ?pasti
# 17586     ěti              0           NaN
#
# [190 rows x 20 columns]

# %%
morphemes.query("isv.str.contains('^d[ie][zs]')")
# Out:
#            id               isv addition      partOfSpeech                en  \
# 1826  35733.0   destabilizovati      NaN    v.tr. ipf./pf.       destabilize
# 1873  25239.0       dezertovati      NaN  v.intr. ipf./pf.            desert
# 1875  25241.0     dezinfikovati      NaN    v.tr. ipf./pf.         disinfect
# 1936  35510.0    diskreditovati      NaN    v.tr. ipf./pf.         discredit
# 1939  32603.0    diskriminovati      NaN  v.intr. ipf./pf.      discriminate
# 1942    301.0       diskutovati      NaN      v.intr. ipf.           discuss
# 1944  35295.0  diskvalifikovati      NaN    v.tr. ipf./pf.        disqualify
# 1946  35944.0      distancevati      NaN  v.refl. ipf./pf.  distance oneself
#
#      genesis   pos prefix      verb_stem         base_verb          isv_orig  \
# 1826       I  verb    de’  stabilizovati     stabilizovati   destabilizovati
# 1873       I  verb      ’    dezertovati       dezertovati       dezertovati
# 1875       I  verb   dez’     infikovati     dezinfikovati     dezinfikovati
# 1936       I  verb      ?              ?    diskreditovati    diskreditovati
# 1939       I  verb      ?              ?    diskriminovati    diskriminovati
# 1942       I  verb      ?              ?       diskutovati       diskutovati
# 1944       I  verb      ?              ?  diskvalifikovati  diskvalifikovati
# 1946       I  verb      ?              ?      distancevati   distancevati sę
#
#      left_stem_cand   right_stem_cand      derived_nouns base_noun _prefix  \
# 1826     destabiliz     stabilizovati   |destabilizacija               ¬de
# 1873         dezert       ?zertovati?
# 1875       dezinfik     ?zinfikovati?
# 1936      diskredit    diskreditovati
# 1939      diskrimin    diskriminovati    |diskriminacija
# 1942         diskut       diskutovati
# 1944    diskvalifik  diskvalifikovati  |diskvalifikacija
# 1946      distancev      distancevati
#
#             _stem _suffix  _is_irregular reconstructed
# 1826     stabiliz   ovati              0           NaN
# 1873       dezert   ovati              0           NaN
# 1875     dezinfik   ovati              0           NaN
# 1936    diskredit   ovati              0           NaN
# 1939    diskrimin   ovati              0           NaN
# 1942       diskut   ovati              0           NaN
# 1944  diskvalifik   ovati              0           NaN
# 1946      distanc   evati              0           NaN

# %%
morphemes.query("base_verb.str.contains('dti')")
# Out:
#             id           isv                addition  partOfSpeech  \
# 2057    5345.0        dojdti          (dojde; došel)   v.intr. pf.
# 3638   13823.0    idti vprěd             #(ide; šel)        v.ipf.
# 3639   15654.0     idti vzad             #(ide; šel)        v.ipf.
# 3640    2104.0          idti              (ide; šel)  v.intr. ipf.
# 4124   36803.0      iznajdti               (iznajde)     v.tr. pf.
# 4148    5354.0       izȯjdti         (izȯjde; izšel)   v.intr. pf.
# 7187     781.0        najdti          (najde; našel)     v.tr. pf.
# 8469   18025.0       obȯjdti         (obȯjde; obšel)   v.refl. pf.
# 8470   18023.0       obȯjdti         (obȯjde; obšel)   v.refl. pf.
# 8471    5370.0       obȯjdti         (obȯjde; obšel)     v.tr. pf.
# 8793   15415.0     odidti od          (odide; odšel)     v.tr. pf.
# 8892     181.0       odȯjdti         (odȯjde; odšel)   v.intr. pf.
# 10426  34766.0  podȯjdti (k)  (podȯjde; podšėl) (+3)   v.intr. pf.
# 10427  36534.0      podȯjdti       (podȯjde; podšėl)   v.intr. pf.
# 10580   4027.0        pojdti          (pojde; pošel)   v.intr. pf.
# 11300   1578.0     prědȯjdti     (prědȯjde; prědšel)     v.tr. pf.
# 11400   1711.0       prějdti        (prějde; prěšel)   v.intr. pf.
# 11611  18447.0   prěvȯzȯjdti            (prěvȯzȯjde)     v.tr. pf.
# 11711   1151.0       prijdti        (prijde; prišel)   v.intr. pf.
# 12047   5481.0       projdti        (projde; prošel)     v.tr. pf.
# 12743  35645.0      råzȯjdti       (råzȯjde; råzšėl)   v.refl. pf.
# 14079   5446.0        sȯjdti         #(sȯjde; sȯšel)   v.refl. pf.
# 14080   5434.0        sȯjdti          (sȯjde; sȯšel)   v.intr. pf.
# 15648   5483.0         ujdti            (ujde; ušel)   v.intr. pf.
# 16592   3108.0        vȯjdti           (vȯjde; všel)   v.intr. pf.
# 16739   5463.0      vȯzȯjdti       (vȯzȯjde; vȯzšel)   v.intr. pf.
# 17008  16541.0        vyjdti          (vyjde; vyšel)   v.intr. pf.
# 17194   5476.0        zajdti          (zajde; zašel)   v.intr. pf.
#
#                                          en genesis   pos prefix verb_stem  \
# 2057                                 arrive     NaN  verb      ?         ?
# 3638                                advance     NaN  verb      ?         ?
# 3639                                back up     NaN  verb      ?         ?
# 3640                                     go     NaN  verb      ?         ?
# 4124          invent (create something new)     NaN  verb      ?         ?
# 4148                     exit, go out, quit     NaN  verb      ?         ?
# 7187                                   find     NaN  verb      ?         ?
# 8469                             do without     NaN  verb      ?         ?
# 8470           manage, make do with, get by     NaN  verb      ?         ?
# 8471                  go around, circumvent     NaN  verb      ?         ?
# 8793                                abandon     NaN  verb      ?         ?
# 8892   go away, walk away, leave, backtrack     NaN  verb      ?         ?
# 10426                              approach     NaN  verb      ?         ?
# 10427     suit, be suitable, befit, go with     NaN  verb      ?         ?
# 10580                                    go     NaN  verb      ?         ?
# 11300                               precede     NaN  verb      ?         ?
# 11400      transcend, cross over, pass over     NaN  verb      ?         ?
# 11611                       surpass, exceed     NaN  verb      ?         ?
# 11711                                  come     NaN  verb      ?         ?
# 12047                            go through     NaN  verb      ?         ?
# 12743     go apart, part, disperse, diverge     NaN  verb   råz’  ȯjdti sę
# 14079        come together, meet up, gather     NaN  verb    sȯ’   jdti sę
# 14080           descend, come down, go down     NaN  verb    sȯ’      jdti
# 15648                               go away     NaN  verb      ?         ?
# 16592                                 enter     NaN  verb    vȯ’      jdti
# 16739                             go uphill     NaN  verb   vȯz’     ȯjdti
# 17008                            exit, quit     NaN  verb    vy’      jdti
# 17194    set (disappear behind the horizon)     NaN  verb      ?         ?
#
#       base_verb        isv_orig left_stem_cand right_stem_cand derived_nouns  \
# 2057       idti          dojdti         dojdti          ?jdti?
# 3638       idti      idti vprěd     idti vprěd    ?idti vprěd?
# 3639       idti       idti vzad      idti vzad     ?idti vzad?
# 3640       idti            idti           idti            idti
# 4124       idti        iznajdti       iznajdti          najdti
# 4148       idti         izȯjdti        izȯjdti         ?ȯjdti?
# 7187       idti          najdti         najdti           ?dti?
# 8469       idti  obȯjdti sę bez        obȯjdti         ?ȯjdti?
# 8470       idti      obȯjdti sę        obȯjdti         ?ȯjdti?
# 8471       idti         obȯjdti        obȯjdti         ?ȯjdti?
# 8793       idti       odidti od      odidti od       ?idti od?
# 8892       idti         odȯjdti        odȯjdti         ?ȯjdti?
# 10426      idti    podȯjdti (k)   podȯjdti (k)     ?ȯjdti (k)?
# 10427      idti        podȯjdti       podȯjdti         odȯjdti
# 10580      idti          pojdti         pojdti          ?jdti?
# 11300      idti       prědȯjdti      prědȯjdti         ?ȯjdti?
# 11400      idti         prějdti        prějdti          ?jdti?
# 11611      idti     prěvȯzȯjdti    prěvȯzȯjdti        vȯzȯjdti
# 11711      idti         prijdti        prijdti          ?jdti?
# 12047      idti         projdti        projdti          ?jdti?
# 12743      idti     råzȯjdti sę       råzȯjdti         ?ȯjdti?
# 14079      idti       sȯjdti sę         sȯjdti          ?jdti?
# 14080      idti          sȯjdti         sȯjdti          ?jdti?
# 15648      idti           ujdti          ujdti          ?jdti?
# 16592      idti          vȯjdti         vȯjdti          ?jdti?
# 16739      idti        vȯzȯjdti       vȯzȯjdti         ?ȯjdti?
# 17008      idti          vyjdti         vyjdti          ?jdti?
# 17194      idti          zajdti         zajdti          ?jdti?
#
#       base_noun     _prefix _stem _suffix  _is_irregular reconstructed
# 2057                    ¬do    jd      ti              0           NaN
# 3638                           jd      ti              0           NaN
# 3639                           jd      ti              0           NaN
# 3640                           jd      ti              0           NaN
# 4124                 ¬iz¬na    jd      ti              0           NaN
# 4148                  ¬iz¬ȯ    jd      ti              0           NaN
# 7187                    ¬na    jd      ti              0           NaN
# 8469                  ¬ob¬ȯ    jd      ti              0           NaN
# 8470                  ¬ob¬ȯ    jd      ti              0           NaN
# 8471                  ¬ob¬ȯ    jd      ti              0           NaN
# 8793                    ¬od    jd      ti              0           NaN
# 8892                  ¬od¬ȯ    jd      ti              0           NaN
# 10426                ¬pod¬ȯ    jd      ti              0           NaN
# 10427                ¬pod¬ȯ    jd      ti              0           NaN
# 10580                   ¬po    jd      ti              0           NaN
# 11300               ¬prěd¬ȯ    jd      ti              0           NaN
# 11400                  ¬prě    jd      ti              0           NaN
# 11611            ¬prě¬vȯz¬ȯ    jd      ti              0           NaN
# 11711                  ¬pri    jd      ti              0           NaN
# 12047                  ¬pro    jd      ti              0           NaN
# 12743                ¬råz¬ȯ    jd      ti              0           NaN
# 14079                   ¬sȯ    jd      ti              0           NaN
# 14080                   ¬sȯ    jd      ti              0           NaN
# 15648                    ¬u    jd      ti              0           NaN
# 16592                   ¬vȯ    jd      ti              0           NaN
# 16739                ¬vȯz¬ȯ    jd      ti              0           NaN
# 17008                   ¬vy    jd      ti              0           NaN
# 17194                   ¬za    jd      ti              0           NaN

# %%
morphemes.query("isv.str.contains('odryvati')")
# Out:
#            id       isv addition partOfSpeech         en genesis   pos prefix  \
# 9006  29227.0  odryvati      NaN   v.tr. ipf.     dig up     NaN  verb      ?
# 9007  34361.0  odryvati      NaN   v.tr. ipf.  tear away     NaN  verb      ?
#
#      verb_stem base_verb  isv_orig left_stem_cand right_stem_cand  \
# 9006         ?      ryti  odryvati            odr        ?ryvati?
# 9007         ?     rvati  odryvati            odr        ?ryvati?
#
#      derived_nouns base_noun _prefix _stem _suffix  _is_irregular  \
# 9006                             ¬od    ry    vati              0
# 9007                             ¬od   ryv     ati              0
#
#      reconstructed
# 9006         ?ryti
# 9007       ?rъvati

# %%
morphemes.query("en.str.contains('separate')")
# Out:
#             id         isv addition partOfSpeech  \
# 1781    1754.0      děliti      NaN   v.tr. ipf.
# 8756    2951.0    odděliti      NaN    v.tr. pf.
# 8757    3016.0   odděljati      NaN   v.tr. ipf.
# 12508    595.0   råzděliti      NaN    v.tr. pf.
# 12509   2249.0  råzděljati      NaN   v.tr. ipf.
# 12676  20108.0   råzlųčati      NaN   v.tr. ipf.
# 12678  20109.0   råzlųčiti      NaN    v.tr. pf.
#
#                                   en genesis   pos prefix verb_stem  \
# 1781   share, divide, part, separate     NaN  verb      ?         ?
# 8756                        separate     NaN  verb      ?         ?
# 8757                        separate     NaN  verb      ?         ?
# 12508        separate, sever, divide     NaN  verb   råz’    děliti
# 12509        separate, sever, divide     NaN  verb   råz’   děljati
# 12676                       separate     NaN  verb   råz’    lųčati
# 12678                       separate     NaN  verb   råz’    lųčiti
#
#        base_verb    isv_orig left_stem_cand right_stem_cand derived_nouns  \
# 1781      děliti      děliti            děl          děliti
# 8756      děliti    odděliti          odděl          děliti
# 8757      děliti   odděljati          odděl       ?děljati?
# 12508     děliti   råzděliti         råzděl          děliti
# 12509     děliti  råzděljati         råzděl       ?děljati?
# 12676  råzlųčati   råzlųčati         råzlųč        ?lųčati?    |råzlųčnik
# 12678  råzlųčati   råzlųčiti         råzlųč        ?lųčiti?    |råzlųčnik
#
#       base_noun _prefix _stem _suffix  _is_irregular reconstructed
# 1781        děl           děl     iti              0        děliti
# 8756                ¬od   děl     iti              0   (od)+děliti
# 8757                ¬od   děl    jati              0       ?děliti
# 12508              ¬råz   děl     iti              0  (råz)+děliti
# 12509              ¬råz   děl    jati              0       ?děliti
# 12676              ¬råz   lųč     ati              0           NaN
# 12678              ¬råz   lųč     iti              0           NaN

# %%
morphemes.query("_prefix == '' and prefix != '?'")
# Out:
#             id            isv addition      partOfSpeech  \
# 1710   25144.0     debatovati      NaN      v.intr. ipf.
# 1711   25146.0       debelěti      NaN      v.intr. ipf.
# 1716   25152.0    debjutovati      NaN  v.intr. ipf./pf.
# 1729    4956.0    definiovati      NaN        v.tr. ipf.
# 1735   15280.0     defisovati      NaN        v.tr. ipf.
# 1742   25172.0    degradovati      NaN    v.tr. ipf./pf.
# 1744   25175.0    degustovati      NaN    v.tr. ipf./pf.
# 1757   35941.0    deklamovati      NaN    v.tr. ipf./pf.
# 1795    6266.0  demonstrovati      NaN        v.tr. ipf.
# 1806     398.0    deportovati      NaN    v.tr. ipf./pf.
# 1810   36182.0    deprimovati      NaN    v.tr. ipf./pf.
# 1873   25239.0    dezertovati      NaN  v.intr. ipf./pf.
# 1875   25241.0  dezinfikovati      NaN    v.tr. ipf./pf.
# 8298     773.0    obezglåviti      NaN         v.tr. pf.
# 8299    1587.0   obezglåvjati      NaN        v.tr. ipf.
# 8303    5374.0     obezsiliti      NaN         v.tr. pf.
# 8304    5373.0    obezsiljati      NaN        v.tr. ipf.
# 10122  32905.0          phati      NaN        v.tr. ipf.
# 14056  34940.0  sȯčuvstvovati      NaN      v.intr. ipf.
# 14076  34119.0        sȯhnųti      NaN      v.intr. ipf.
# 14077  34121.0        sȯhnųti      NaN      v.intr. ipf.
# 14092  33026.0         soliti      NaN        v.tr. ipf.
# 14107  30748.0      sondovati      NaN    v.tr. ipf./pf.
# 14118  34894.0      sortovati      NaN    v.tr. ipf./pf.
# 14119   4150.0         sȯsati      NaN        v.tr. ipf.
# 14125   4202.0      sȯstaviti      NaN         v.tr. pf.
# 14126   4201.0     sȯstavjati      NaN        v.tr. ipf.
# 14143   4475.0     sȯvětovati      NaN        v.tr. ipf.
# 14156  22569.0       sȯvŕšati      NaN        v.tr. ipf.
# 14157  36808.0       sȯvŕšati      NaN      v.intr. ipf.
# 14161  22571.0       sȯvŕšiti      NaN         v.tr. pf.
# 14162  36809.0       sȯvŕšiti      NaN       v.intr. pf.
# 14164  22744.0        sȯzdati      NaN         v.tr. pf.
# 14165  22743.0      sȯzdavati      NaN        v.tr. ipf.
# 16627  31309.0       vȯlgnųti      NaN      v.intr. ipf.
# 16653  36187.0      vȯplȯćati      NaN        v.tr. ipf.
# 16654  36188.0      vȯplȯtiti      NaN         v.tr. pf.
# 16665  20278.0    vȯzbogaćati      NaN        v.tr. ipf.
# 16666  20279.0    vȯzbogatiti      NaN         v.tr. pf.
# 16712  36269.0         voziti      NaN      v.refl. ipf.
# 16713    516.0         voziti      NaN        v.tr. ipf.
# 16723  32439.0     vȯzkresiti      NaN         v.tr. pf.
# 16725  32438.0     vȯzkrešati      NaN        v.tr. ipf.
# 16732  15156.0      vȯznikati      NaN      v.intr. ipf.
# 16733  20801.0      vȯznikati      NaN      v.intr. ipf.
# 16735  20803.0     vȯzniknųti      NaN       v.intr. pf.
# 16736  20804.0     vȯzniknųti      NaN       v.intr. pf.
# 16743  19149.0      vȯzpitati      NaN         v.tr. pf.
# 16772  22294.0    vȯzveličati      NaN         v.tr. pf.
# 16773  22293.0  vȯzveličivati      NaN        v.tr. ipf.
# 16781  13400.0      vȯzvŕšati      NaN        v.tr. ipf.
# 16783  13402.0      vȯzvŕšiti      NaN         v.tr. pf.
# 17010  36406.0         vykati      NaN        v.tr. ipf.
# 17034  31446.0           vyti      NaN      v.intr. ipf.
#
#                                                       en genesis   pos prefix  \
# 1710                                              debate       I  verb      ’
# 1711                                            grow fat     NaN  verb      ’
# 1716                                    make one’s debut       F  verb      ’
# 1729                                              define       I  verb      ’
# 1735                                           hyphenate       I  verb      ’
# 1742                                     degrade, demote       I  verb      ’
# 1744                                               taste       I  verb      ’
# 1757                                     declaim, recite       I  verb      ’
# 1795                                         demonstrate       I  verb      ’
# 1806                                              deport       I  verb    de’
# 1810                                             depress       I  verb      ’
# 1873                                              desert       I  verb      ’
# 1875                                           disinfect       I  verb   dez’
# 8298                                          decapitate     NaN  verb  obez’
# 8299                                          decapitate     NaN  verb  obez’
# 8303                                          disempower     NaN  verb  obez’
# 8304                                          disempower     NaN  verb  obez’
# 10122                                        push, shove     NaN  verb      ’
# 14056           sympathize, commiserate, feel compassion     NaN  verb    sȯ’
# 14076                    dry (intr.), become dry, wither     NaN  verb    sȯ’
# 14077                                          pine away     NaN  verb    sȯ’
# 14092                                               salt     NaN  verb      ’
# 14107                                              probe       I  verb      ’
# 14118                                               sort       I  verb      ’
# 14119                                               suck     NaN  verb    sȯ’
# 14125  put together, assemble, compile, arrange, make...     NaN  verb    sȯ’
# 14126  put together, assemble, compile, arrange, make...     NaN  verb    sȯ’
# 14143                                    advise, counsel     NaN  verb    sȯ’
# 14156                               accomplish, complete     NaN  verb    sȯ’
# 14157                              come (have an orgasm)     NaN  verb    sȯ’
# 14161                               accomplish, complete     NaN  verb    sȯ’
# 14162                              come (have an orgasm)     NaN  verb    sȯ’
# 14164                                             create     NaN  verb    sȯ’
# 14165                                             create     NaN  verb    sȯ’
# 16627                                get humid, get damp     NaN  verb      ’
# 16653                                  incarnate, embody     NaN  verb    vȯ’
# 16654                                  incarnate, embody     NaN  verb    vȯ’
# 16665                                             enrich     NaN  verb   vȯz’
# 16666                                             enrich     NaN  verb   vȯz’
# 16712                                drive (e.g. by car)     NaN  verb      ’
# 16713                      carry (by vehicle), transport     NaN  verb      ’
# 16723                     resurrect, raise from the dead     NaN  verb   vȯz’
# 16725                     resurrect, raise from the dead     NaN  verb   vȯz’
# 16732                                          originate     NaN  verb   vȯz’
# 16733                                      arise, emerge     NaN  verb   vȯz’
# 16735                                              arise     NaN  verb   vȯz’
# 16736                                             emerge     NaN  verb   vȯz’
# 16743                     bring up, nurture, raise, rear     NaN  verb   vȯz’
# 16772                                     extol, glorify     NaN  verb   vȯz’
# 16773                                     extol, glorify     NaN  verb   vȯz’
# 16781                                            perfect     NaN  verb   vȯz’
# 16783                                            perfect     NaN  verb   vȯz’
# 17010                             you, address with «vy»     NaN  verb      ’
# 17034                                         howl, wail     NaN  verb      ’
#
#            verb_stem      base_verb       isv_orig left_stem_cand  \
# 1710      debatovati                    debatovati          debat
# 1711        debelěti         belěti       debelěti          debel
# 1716     debjutovati                   debjutovati         debjut
# 1729     definiovati    definiovati    definiovati         defini
# 1735      defisovati                    defisovati          defis
# 1742     degradovati    degradovati    degradovati         degrad
# 1744     degustovati    degustovati    degustovati         degust
# 1757     deklamovati    deklamovati    deklamovati         deklam
# 1795   demonstrovati  demonstrovati  demonstrovati       demonstr
# 1806       portovati    deportovati    deportovati         deport
# 1810     deprimovati    deprimovati    deprimovati         deprim
# 1873     dezertovati    dezertovati    dezertovati         dezert
# 1875      infikovati  dezinfikovati  dezinfikovati       dezinfik
# 8298         glåviti    obezglåviti    obezglåviti       obezglåv
# 8299        glåvjati    obezglåviti   obezglåvjati       obezglåv
# 8303          siliti     obezsiliti     obezsiliti        obezsil
# 8304         siljati     obezsiliti    obezsiljati        obezsil
# 10122   phati/pihati          phati          phati             ph
# 14056    čuvstvovati         čuvati  sȯčuvstvovati       sȯčuvstv
# 14076          hnųti        sȯhnųti        sȯhnųti            sȯh
# 14077          hnųti        sȯhnųti        sȯhnųti            sȯh
# 14092         soliti         soliti         soliti            sol
# 14107      sondovati                     sondovati           sond
# 14118      sortovati                     sortovati           sort
# 14119           sati         sȯsati         sȯsati            sȯs
# 14125        staviti      sȯstaviti      sȯstaviti         sȯstav
# 14126       stavjati      sȯstaviti     sȯstavjati         sȯstav
# 14143       větovati                    sȯvětovati          sȯvět
# 14156         vŕšati       sȯvŕšati       sȯvŕšati          sȯvŕš
# 14157         vŕšati       sȯvŕšati       sȯvŕšati          sȯvŕš
# 14161         vŕšiti       sȯvŕšati       sȯvŕšiti          sȯvŕš
# 14162         vŕšiti       sȯvŕšati       sȯvŕšiti          sȯvŕš
# 14164          zdati        sȯzdati        sȯzdati           sȯzd
# 14165        zdavati        sȯzdati      sȯzdavati         sȯzdav
# 16627       vȯlgnųti       vȯlgnųti       vȯlgnųti           vȯlg
# 16653        plȯćati      vȯplȯtiti      vȯplȯćati         vȯplȯć
# 16654        plȯtiti      vȯplȯtiti      vȯplȯtiti         vȯplȯt
# 16665       bogaćati    vȯzbogatiti    vȯzbogaćati       vȯzbogać
# 16666       bogatiti    vȯzbogatiti    vȯzbogatiti       vȯzbogat
# 16712      voziti sę                     voziti sę            voz
# 16713         voziti                        voziti            voz
# 16723        kresiti     vȯzkresiti     vȯzkresiti        vȯzkres
# 16725        krešati     vȯzkresiti     vȯzkrešati        vȯzkreš
# 16732         nikati      vȯznikati      vȯznikati         vȯznik
# 16733         nikati      vȯznikati      vȯznikati         vȯznik
# 16735        niknųti      vȯznikati     vȯzniknųti         vȯznik
# 16736        niknųti      vȯznikati     vȯzniknųti         vȯznik
# 16743         pitati        †pitati      vȯzpitati         vȯzpit
# 16772       veličati    vȯzveličati    vȯzveličati       vȯzvelič
# 16773     veličivati    vȯzveličati  vȯzveličivati       vȯzvelič
# 16781         vŕšati      vȯzvŕšati      vȯzvŕšati         vȯzvŕš
# 16783         vŕšiti      vȯzvŕšati      vȯzvŕšiti         vȯzvŕš
# 17010         vykati           kati         vykati            vyk
# 17034           vyti           vyti           vyti           vyti
#
#       right_stem_cand   derived_nouns base_noun _prefix     _stem _suffix  \
# 1710       ?batovati?                    debata             debat   ovati
# 1711           belěti                                       debel     ěti
# 1716      ?bjutovati?                    debjut            debjut   ovati
# 1729      ?finiovati?     |definicija                      defini   ovati
# 1735       ?fisovati?                     defis             defis   ovati
# 1742      ?gradovati?    |degradacija                      degrad   ovati
# 1744      ?gustovati?    |degustacija                      degust   ovati
# 1757      ?klamovati?                                      deklam   ovati
# 1795    ?monstrovati?  |demonstracija                    demonstr   ovati
# 1806        ?rtovati?    |deportacija                      deport   ovati
# 1810         ?movati?                                      deprim   ovati
# 1873      ?zertovati?                                      dezert   ovati
# 1875    ?zinfikovati?                                    dezinfik   ovati
# 8298        ?glåviti?                                    obezglåv     iti
# 8299       ?glåvjati?                                    obezglåv    jati
# 8303           siliti                                     obezsil     iti
# 8304         ?iljati?                                     obezsil    jati
# 10122           phati                                          ph     ati
# 14056   ?čuvstvovati?
# 14076         ?hnųti?                                         sȯh    nųti
# 14077         ?hnųti?                                         sȯh    nųti
# 14092            liti                                         sol     iti
# 14107       ?ndovati?                     sonda              sond   ovati
# 14118       ?rtovati?                      sort              sort   ovati
# 14119           ?ati?          |sȯska                         sȯs     ati
# 14125         staviti                    sȯstav              sȯst   aviti
# 14126        stavjati                                        sȯst  avjati
# 14143       ?ětovati?       |sȯvětnik     sȯvět             sȯvět   ovati
# 14156         ?ŕšati?                                       sȯvŕš     ati
# 14157         ?ŕšati?                                       sȯvŕš     ati
# 14161         ?ŕšiti?                                       sȯvŕš     iti
# 14162         ?ŕšiti?                                       sȯvŕš     iti
# 14164         ?zdati?                                        sȯzd     ati
# 14165       ?zdavati?                                        sȯzd   avati
# 16627        ?lgnųti?                     vȯlga              vȯlg    nųti
# 16653       ?plȯćati?                                      vȯplȯt    ⒥ati
# 16654       ?plȯtiti?                                      vȯplȯt     iti
# 16665      ?bogaćati?                                    vȯzbogat    ⒥ati
# 16666      ?bogatiti?                                    vȯzbogat     iti
# 16712           ?iti?                       voz               voz     iti
# 16713           ?iti?                       voz               voz     iti
# 16723       ?kresiti?                                     vȯzkres     iti
# 16725       ?krešati?                                     vȯzkres    ⒥ati
# 16732        ?nikati?                                      vȯznik     ati
# 16733        ?nikati?                                      vȯznik     ati
# 16735       ?niknųti?                                      vȯznik    nųti
# 16736       ?niknųti?                                      vȯznik    nųti
# 16743        ?pitati?                                      vȯzpit     ati
# 16772       ?eličati?                                    vȯzvelič     ati
# 16773     ?eličivati?                                    vȯzvelič   ivati
# 16781         ?ŕšati?                                      vȯzvŕš     ati
# 16783         ?ŕšiti?                                      vȯzvŕš     iti
# 17010            kati                                         vyk     ati
# 17034              ti                                          vy      ti
#
#        _is_irregular reconstructed
# 1710               0        ?uměti
# 1711               0           NaN
# 1716               0        ?uměti
# 1729               0           NaN
# 1735               0        ?uměti
# 1742               0           NaN
# 1744               0           NaN
# 1757               0           NaN
# 1795               0           NaN
# 1806               0           NaN
# 1810               0           NaN
# 1873               0           NaN
# 1875               0           NaN
# 8298               0           NaN
# 8299               0           NaN
# 8303               0           NaN
# 8304               0           NaN
# 10122              0        pьxati
# 14056              1         ?čuti
# 14076              0           NaN
# 14077              0           NaN
# 14092              0        soliti
# 14107              0        ?uměti
# 14118              0        ?uměti
# 14119              0           NaN
# 14125              0           NaN
# 14126              0           NaN
# 14143              0        ?uměti
# 14156              0           NaN
# 14157              0           NaN
# 14161              0           NaN
# 14162              0           NaN
# 14164              0           NaN
# 14165              0           NaN
# 16627              0      vьlgnǫti
# 16653              0           NaN
# 16654              0           NaN
# 16665              0           NaN
# 16666              0           NaN
# 16712              0        voziti
# 16713              0        voziti
# 16723              0           NaN
# 16725              0           NaN
# 16732              0           NaN
# 16733              0           NaN
# 16735              0           NaN
# 16736              0           NaN
# 16743              0       ?pitati
# 16772              0           NaN
# 16773              0           NaN
# 16781              0           NaN
# 16783              0           NaN
# 17010              0        vykati
# 17034              0          vyti

# %%
morphemes.query("_prefix == '' and prefix not in ['’', '?']")
# Out:
#             id            isv addition    partOfSpeech  \
# 1806     398.0    deportovati      NaN  v.tr. ipf./pf.
# 1875   25241.0  dezinfikovati      NaN  v.tr. ipf./pf.
# 8298     773.0    obezglåviti      NaN       v.tr. pf.
# 8299    1587.0   obezglåvjati      NaN      v.tr. ipf.
# 8303    5374.0     obezsiliti      NaN       v.tr. pf.
# 8304    5373.0    obezsiljati      NaN      v.tr. ipf.
# 14056  34940.0  sȯčuvstvovati      NaN    v.intr. ipf.
# 14076  34119.0        sȯhnųti      NaN    v.intr. ipf.
# 14077  34121.0        sȯhnųti      NaN    v.intr. ipf.
# 14119   4150.0         sȯsati      NaN      v.tr. ipf.
# 14125   4202.0      sȯstaviti      NaN       v.tr. pf.
# 14126   4201.0     sȯstavjati      NaN      v.tr. ipf.
# 14143   4475.0     sȯvětovati      NaN      v.tr. ipf.
# 14156  22569.0       sȯvŕšati      NaN      v.tr. ipf.
# 14157  36808.0       sȯvŕšati      NaN    v.intr. ipf.
# 14161  22571.0       sȯvŕšiti      NaN       v.tr. pf.
# 14162  36809.0       sȯvŕšiti      NaN     v.intr. pf.
# 14164  22744.0        sȯzdati      NaN       v.tr. pf.
# 14165  22743.0      sȯzdavati      NaN      v.tr. ipf.
# 16653  36187.0      vȯplȯćati      NaN      v.tr. ipf.
# 16654  36188.0      vȯplȯtiti      NaN       v.tr. pf.
# 16665  20278.0    vȯzbogaćati      NaN      v.tr. ipf.
# 16666  20279.0    vȯzbogatiti      NaN       v.tr. pf.
# 16723  32439.0     vȯzkresiti      NaN       v.tr. pf.
# 16725  32438.0     vȯzkrešati      NaN      v.tr. ipf.
# 16732  15156.0      vȯznikati      NaN    v.intr. ipf.
# 16733  20801.0      vȯznikati      NaN    v.intr. ipf.
# 16735  20803.0     vȯzniknųti      NaN     v.intr. pf.
# 16736  20804.0     vȯzniknųti      NaN     v.intr. pf.
# 16743  19149.0      vȯzpitati      NaN       v.tr. pf.
# 16772  22294.0    vȯzveličati      NaN       v.tr. pf.
# 16773  22293.0  vȯzveličivati      NaN      v.tr. ipf.
# 16781  13400.0      vȯzvŕšati      NaN      v.tr. ipf.
# 16783  13402.0      vȯzvŕšiti      NaN       v.tr. pf.
#
#                                                       en genesis   pos prefix  \
# 1806                                              deport       I  verb    de’
# 1875                                           disinfect       I  verb   dez’
# 8298                                          decapitate     NaN  verb  obez’
# 8299                                          decapitate     NaN  verb  obez’
# 8303                                          disempower     NaN  verb  obez’
# 8304                                          disempower     NaN  verb  obez’
# 14056           sympathize, commiserate, feel compassion     NaN  verb    sȯ’
# 14076                    dry (intr.), become dry, wither     NaN  verb    sȯ’
# 14077                                          pine away     NaN  verb    sȯ’
# 14119                                               suck     NaN  verb    sȯ’
# 14125  put together, assemble, compile, arrange, make...     NaN  verb    sȯ’
# 14126  put together, assemble, compile, arrange, make...     NaN  verb    sȯ’
# 14143                                    advise, counsel     NaN  verb    sȯ’
# 14156                               accomplish, complete     NaN  verb    sȯ’
# 14157                              come (have an orgasm)     NaN  verb    sȯ’
# 14161                               accomplish, complete     NaN  verb    sȯ’
# 14162                              come (have an orgasm)     NaN  verb    sȯ’
# 14164                                             create     NaN  verb    sȯ’
# 14165                                             create     NaN  verb    sȯ’
# 16653                                  incarnate, embody     NaN  verb    vȯ’
# 16654                                  incarnate, embody     NaN  verb    vȯ’
# 16665                                             enrich     NaN  verb   vȯz’
# 16666                                             enrich     NaN  verb   vȯz’
# 16723                     resurrect, raise from the dead     NaN  verb   vȯz’
# 16725                     resurrect, raise from the dead     NaN  verb   vȯz’
# 16732                                          originate     NaN  verb   vȯz’
# 16733                                      arise, emerge     NaN  verb   vȯz’
# 16735                                              arise     NaN  verb   vȯz’
# 16736                                             emerge     NaN  verb   vȯz’
# 16743                     bring up, nurture, raise, rear     NaN  verb   vȯz’
# 16772                                     extol, glorify     NaN  verb   vȯz’
# 16773                                     extol, glorify     NaN  verb   vȯz’
# 16781                                            perfect     NaN  verb   vȯz’
# 16783                                            perfect     NaN  verb   vȯz’
#
#          verb_stem      base_verb       isv_orig left_stem_cand  \
# 1806     portovati    deportovati    deportovati         deport
# 1875    infikovati  dezinfikovati  dezinfikovati       dezinfik
# 8298       glåviti    obezglåviti    obezglåviti       obezglåv
# 8299      glåvjati    obezglåviti   obezglåvjati       obezglåv
# 8303        siliti     obezsiliti     obezsiliti        obezsil
# 8304       siljati     obezsiliti    obezsiljati        obezsil
# 14056  čuvstvovati         čuvati  sȯčuvstvovati       sȯčuvstv
# 14076        hnųti        sȯhnųti        sȯhnųti            sȯh
# 14077        hnųti        sȯhnųti        sȯhnųti            sȯh
# 14119         sati         sȯsati         sȯsati            sȯs
# 14125      staviti      sȯstaviti      sȯstaviti         sȯstav
# 14126     stavjati      sȯstaviti     sȯstavjati         sȯstav
# 14143     větovati                    sȯvětovati          sȯvět
# 14156       vŕšati       sȯvŕšati       sȯvŕšati          sȯvŕš
# 14157       vŕšati       sȯvŕšati       sȯvŕšati          sȯvŕš
# 14161       vŕšiti       sȯvŕšati       sȯvŕšiti          sȯvŕš
# 14162       vŕšiti       sȯvŕšati       sȯvŕšiti          sȯvŕš
# 14164        zdati        sȯzdati        sȯzdati           sȯzd
# 14165      zdavati        sȯzdati      sȯzdavati         sȯzdav
# 16653      plȯćati      vȯplȯtiti      vȯplȯćati         vȯplȯć
# 16654      plȯtiti      vȯplȯtiti      vȯplȯtiti         vȯplȯt
# 16665     bogaćati    vȯzbogatiti    vȯzbogaćati       vȯzbogać
# 16666     bogatiti    vȯzbogatiti    vȯzbogatiti       vȯzbogat
# 16723      kresiti     vȯzkresiti     vȯzkresiti        vȯzkres
# 16725      krešati     vȯzkresiti     vȯzkrešati        vȯzkreš
# 16732       nikati      vȯznikati      vȯznikati         vȯznik
# 16733       nikati      vȯznikati      vȯznikati         vȯznik
# 16735      niknųti      vȯznikati     vȯzniknųti         vȯznik
# 16736      niknųti      vȯznikati     vȯzniknųti         vȯznik
# 16743       pitati        †pitati      vȯzpitati         vȯzpit
# 16772     veličati    vȯzveličati    vȯzveličati       vȯzvelič
# 16773   veličivati    vȯzveličati  vȯzveličivati       vȯzvelič
# 16781       vŕšati      vȯzvŕšati      vȯzvŕšati         vȯzvŕš
# 16783       vŕšiti      vȯzvŕšati      vȯzvŕšiti         vȯzvŕš
#
#       right_stem_cand derived_nouns base_noun _prefix     _stem _suffix  \
# 1806        ?rtovati?  |deportacija                      deport   ovati
# 1875    ?zinfikovati?                                  dezinfik   ovati
# 8298        ?glåviti?                                  obezglåv     iti
# 8299       ?glåvjati?                                  obezglåv    jati
# 8303           siliti                                   obezsil     iti
# 8304         ?iljati?                                   obezsil    jati
# 14056   ?čuvstvovati?
# 14076         ?hnųti?                                       sȯh    nųti
# 14077         ?hnųti?                                       sȯh    nųti
# 14119           ?ati?        |sȯska                         sȯs     ati
# 14125         staviti                  sȯstav              sȯst   aviti
# 14126        stavjati                                      sȯst  avjati
# 14143       ?ětovati?     |sȯvětnik     sȯvět             sȯvět   ovati
# 14156         ?ŕšati?                                     sȯvŕš     ati
# 14157         ?ŕšati?                                     sȯvŕš     ati
# 14161         ?ŕšiti?                                     sȯvŕš     iti
# 14162         ?ŕšiti?                                     sȯvŕš     iti
# 14164         ?zdati?                                      sȯzd     ati
# 14165       ?zdavati?                                      sȯzd   avati
# 16653       ?plȯćati?                                    vȯplȯt    ⒥ati
# 16654       ?plȯtiti?                                    vȯplȯt     iti
# 16665      ?bogaćati?                                  vȯzbogat    ⒥ati
# 16666      ?bogatiti?                                  vȯzbogat     iti
# 16723       ?kresiti?                                   vȯzkres     iti
# 16725       ?krešati?                                   vȯzkres    ⒥ati
# 16732        ?nikati?                                    vȯznik     ati
# 16733        ?nikati?                                    vȯznik     ati
# 16735       ?niknųti?                                    vȯznik    nųti
# 16736       ?niknųti?                                    vȯznik    nųti
# 16743        ?pitati?                                    vȯzpit     ati
# 16772       ?eličati?                                  vȯzvelič     ati
# 16773     ?eličivati?                                  vȯzvelič   ivati
# 16781         ?ŕšati?                                    vȯzvŕš     ati
# 16783         ?ŕšiti?                                    vȯzvŕš     iti
#
#        _is_irregular reconstructed
# 1806               0           NaN
# 1875               0           NaN
# 8298               0           NaN
# 8299               0           NaN
# 8303               0           NaN
# 8304               0           NaN
# 14056              1         ?čuti
# 14076              0           NaN
# 14077              0           NaN
# 14119              0           NaN
# 14125              0           NaN
# 14126              0           NaN
# 14143              0        ?uměti
# 14156              0           NaN
# 14157              0           NaN
# 14161              0           NaN
# 14162              0           NaN
# 14164              0           NaN
# 14165              0           NaN
# 16653              0           NaN
# 16654              0           NaN
# 16665              0           NaN
# 16666              0           NaN
# 16723              0           NaN
# 16725              0           NaN
# 16732              0           NaN
# 16733              0           NaN
# 16735              0           NaN
# 16736              0           NaN
# 16743              0       ?pitati
# 16772              0           NaN
# 16773              0           NaN
# 16781              0           NaN
# 16783              0           NaN

# %%
morphemes.query("_prefix != '' and reconstructed == reconstructed")
# Out:
#             id            isv addition  partOfSpeech  \
# 887     4889.0    blågodariti      NaN    v.tr. ipf.
# 899     5574.0  blågoslavjati      NaN    v.tr. ipf.
# 900     5573.0   blågosloviti      NaN     v.tr. pf.
# 912     6050.0    blågoželati     (+3)  v.intr. ipf.
# 1983   21272.0       dobaviti      NaN     v.tr. pf.
# ...        ...            ...      ...           ...
# 17580  32644.0        zažegti  (zažže)     v.tr. pf.
# 17581  32633.0       zažigati      NaN    v.tr. ipf.
# 17582  32636.0       zažigati      NaN    v.tr. ipf.
# 17583  32638.0       zažigati      NaN    v.tr. ipf.
# 17917 -30731.0         smogti      NaN     v.tr. pf.
#
#                                                 en genesis   pos prefix  \
# 887                                          thank     NaN  verb      ?
# 899                                 bless, beatify     NaN  verb      ?
# 900                                 bless, beatify     NaN  verb      ?
# 912                                   congratulate     NaN  verb      ?
# 1983                                           add     NaN  verb      ?
# ...                                            ...     ...   ...    ...
# 17580                                  set fire to     NaN  verb      ?
# 17581               ignite, light, kindle, inflame     NaN  verb      ?
# 17582  switch on (the lights), turn on (the light)     NaN  verb      ?
# 17583                                  set fire to     NaN  verb      ?
# 17917         manage to, be able to, cope, make it     NaN  verb      ?
#
#       verb_stem base_verb       isv_orig left_stem_cand right_stem_cand  \
# 887           ?    dariti    blågodariti       blågodar     blågodariti
# 899           ?   sloviti  blågoslavjati      blågoslav   blågoslavjati
# 900           ?   sloviti   blågosloviti        blågosl    blågosloviti
# 912           ?    želati    blågoželati       blågožel     blågoželati
# 1983          ?    baviti       dobaviti          dobav          baviti
# ...         ...       ...            ...            ...             ...
# 17580         ?     žegti        zažegti        zažegti           žegti
# 17581         ?     žegti       zažigati          zažig        ?žigati?
# 17582         ?     žegti       zažigati          zažig        ?žigati?
# 17583         ?     žegti       zažigati          zažig        ?žigati?
# 17917         ?     mogti         smogti         smogti           mogti
#
#       derived_nouns base_noun _prefix _stem _suffix  _is_irregular  \
# 887                             blågo   dar     iti              0
# 899                             blågo  slav    jati              0
# 900                             blågo  slov     iti              0
# 912                             blågo   žel     ati              0
# 1983                              ¬do   bav     iti             -1
# ...             ...       ...     ...   ...     ...            ...
# 17580                             ¬za   žeg      ti              0
# 17581                             ¬za   žig     ati              0
# 17582                             ¬za   žig     ati              0
# 17583                             ¬za   žig     ati              0
# 17917                              ¬s   mꜵg      ti              0
#
#          reconstructed
# 887     (blågo)+dariti
# 899           ?sloviti
# 900    (blågo)+sloviti
# 912     (blågo)+želati
# 1983       (do)+baviti
# ...                ...
# 17580        (za)+žeťi
# 17581            ?žeťi
# 17582            ?žeťi
# 17583            ?žeťi
# 17917         (s)+moťi
#
# [2241 rows x 20 columns]

# %%
def bite_all_prefixes_off(word, verb_nest):

    can_continue = True
    prefixes = []

    while can_continue:
        can_continue = False
        for pref in possible_prefixes:
            if word.startswith(pref):
                # print(pref, word, word[len(pref):])
                new_word = word[len(pref):]
                if new_word.endswith(verb_nest):
                    word = new_word
                    prefixes.append(pref)
                    can_continue = True
                    break
    return ("¬" if prefixes else "") + "¬".join(prefixes)

# %%
morphemes.query("_prefix == ''").isv.apply(lambda x: bite_all_prefixes_off(x, "")).value_counts().head(33)
# Out:
#           1054
# ¬s         137
# ¬v          99
# ¬o          58
# ¬ob         55
# ¬po         48
# ¬u          45
# ¬za         22
# ¬od         22
# ¬iz         20
# ¬o¬s        18
# ¬pro        14
# ¬pri        12
# ¬po¬s       12
# ¬s¬v        11
# ¬de         11
# ¬prě        11
# ¬za¬s       10
# ¬u¬s        10
# ¬prě¬s       8
# ¬iz¬s        8
# ¬do¬s        7
# ¬na          7
# ¬v¬o         7
# ¬iz¬v        7
# ¬pri¬s       6
# ¬pro¬v       6
# ¬o¬v         6
# ¬o¬po        6
# ¬u¬po        6
# ¬sȯ¬v        5
# ¬sȯ          5
# ¬s¬po        5
# Name: isv, dtype: int64

# %%
morphemes[morphemes._stem.str.len() > 5]
# Out:
#             id             isv addition    partOfSpeech  \
# 28     19625.0     absorbovati      NaN      v.tr. ipf.
# 29     24056.0    abstrahovati      NaN  v.tr. ipf./pf.
# 50     24081.0  administrovati      NaN      v.tr. ipf.
# 99     24121.0     agonizovati      NaN    v.intr. ipf.
# 120    24148.0     akcentovati      NaN      v.tr. ipf.
# ...        ...             ...      ...             ...
# 17673   1892.0  zloupotrěbjati      NaN      v.tr. ipf.
# 17712  22850.0     znamenovati      NaN      v.tr. ipf.
# 17713  22851.0     znamenovati      NaN      v.tr. ipf.
# 17914 -37006.0   råzpečętyvati      NaN      v.tr. ipf.
# 17921 -37004.0    zapečętyvati      NaN       v.tr.ipf.
#
#                                        en genesis   pos prefix   verb_stem  \
# 28                                 absorb       I  verb      ?           ?
# 29                               abstract       I  verb      ?           ?
# 50                           administrate       I  verb      ?           ?
# 99                       agonise, agonize       I  verb      ?           ?
# 120    accentuate, stress (pronunciation)       I  verb      ?           ?
# ...                                   ...     ...   ...    ...         ...
# 17673                       abuse, misuse     NaN  verb      ?           ?
# 17712                 mark, put a mark on     NaN  verb      ?           ?
# 17713         signify, mean, be a sign of     NaN  verb      ?           ?
# 17914                              unseal     NaN  verb   råz’  pečętyvati
# 17921                                seal     NaN  verb      ?           ?
#
#             base_verb        isv_orig left_stem_cand right_stem_cand  \
# 28        absorbovati     absorbovati         absorb     absorbovati
# 29       abstrahovati    abstrahovati        abstrah    abstrahovati
# 50     administrovati  administrovati      administr  administrovati
# 99        agonizovati     agonizovati         agoniz     agonizovati
# 120       akcentovati     akcentovati         akcent     akcentovati
# ...               ...             ...            ...             ...
# 17673   zloupotrěbiti  zloupotrěbjati     zloupotrěb  zloupotrěbjati
# 17712     znamenovati     znamenovati         znamen     znamenovati
# 17713     znamenovati     znamenovati         znamen     znamenovati
# 17914        pečętati   råzpečętyvati       råzpečęt    ?pečętyvati?
# 17921        pečętati    zapečętyvati        zapečęt    ?pečętyvati?
#
#             derived_nouns base_noun _prefix       _stem _suffix  \
# 28            |absorbcija                        absorb   ovati
# 29                                              abstrah   ovati
# 50        |administracija                     administr   ovati
# 99                          agonija              agoniz   ovati
# 120                          akcent              akcent   ovati
# ...                   ...       ...     ...         ...     ...
# 17673                                        zloupotrěb    jati
# 17712  |znameńje|znameńje                       znameno    vati
# 17713  |znameńje|znameńje                       znameno    vati
# 17914                                  ¬råz      pečęty    vati
# 17921                                   ¬za      pečęty    vati
#
#        _is_irregular reconstructed
# 28                 0           NaN
# 29                 0           NaN
# 50                 0           NaN
# 99                 0           NaN
# 120                0           NaN
# ...              ...           ...
# 17673              0           NaN
# 17712              0           NaN
# 17713              0           NaN
# 17914              0           NaN
# 17921              0           NaN
#
# [580 rows x 20 columns]

# %%
morphemes.query("_prefix == ''").isv.str[:3].value_counts()
# Out:
# prě    33
# pri    29
# pro    25
# obr    22
# str    18
#        ..
# let     1
# lep     1
# lěn     1
# lat     1
# žuž     1
# Name: isv, Length: 869, dtype: int64

# %%
morphemes.query("_prefix == '' and right_stem_cand != isv and not isv.str.contains(' ') and not right_stem_cand.str.startswith('?')").base_verb.value_counts()
# Out:
# vvŕgati        4
# dostigati      4
# zaustaviti     4
# postaviti      4
# podključati    4
#               ..
# podslušati     1
# poučati        1
# povědati       1
# prěslušati     1
# zavojevati     1
# Name: base_verb, Length: 77, dtype: int64
